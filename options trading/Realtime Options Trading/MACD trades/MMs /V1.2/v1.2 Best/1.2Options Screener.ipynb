# %% [markdown]
# Do a random forest return predictor for long time equity screens, maybe including rates/ sectors / commodities / geoploitic indicators.
# Find the % of regimes in the last 30 days that have a higher volatility than the current IV
# Add trend in shannon entropy or/and regime percentages to evaluate recessions / hostile environments beginning. could also look at earnings timestamps affecting options prices

# %% [markdown]
# Want to find stocks with a low hv/iv high regime % in highest stdev state, and high # of days with stdev above avg iv on options

# %%
import yfinance as yf 
from yfinance import EquityQuery
import numpy as np
import pandas as pd
import time

# %%
from yfinance import EquityQuery, screen
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time

# --- Helper Functions ---

def find_closest_value(data_list, target_value):
    if len(data_list) == 0:
        return None
    return min(data_list, key=lambda x: abs(x - target_value))

def filter_special_expiry(expiry_list):
    """Return the two soonest (earliest) expiry dates from the list."""
    sorted_expiries = sorted(expiry_list)
    return sorted_expiries[:2]

def get_prev_day_price_volume(symbol):
    """Fetch the most recent full day's close price and volume for the symbol."""
    try:
        data = yf.Ticker(symbol).history(period="5d")
        if data.shape[0] < 2:
            return None, None
        prev_day = data.iloc[-2]
        price = float(prev_day['Close'])
        volume = int(prev_day['Volume'])
        return price, volume
    except Exception as e:
        print(f"Error fetching previous day price/volume for {symbol}: {e}")
        return None, None

def get_historical_volatility(symbol, window=20):
    try:
        data = yf.Ticker(symbol).history(period=f"{window*2}d")
        if data.shape[0] < window + 1:
            return None
        data = data['Close'].dropna()
        log_returns = np.log(data / data.shift(1)).dropna()
        vol = log_returns[-window:].std() * np.sqrt(252)
        return vol
    except Exception as e:
        print(f"Error calculating historical volatility for {symbol}: {e}")
        return None

def get_options(symbol, max_retries=3, retry_delay=60):
    for attempt in range(max_retries):
        try:
            stock = yf.Ticker(symbol)
            options_chain = stock.options
            if not options_chain:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            filtered_expiries = filter_special_expiry(options_chain)
            options_data = []
            current_price, _ = get_prev_day_price_volume(symbol)
            if current_price is None:
                continue
            for expiry in filtered_expiries:
                chain = stock.option_chain(expiry)
                for opt_type, df in [('call', chain.calls), ('put', chain.puts)]:
                    if not df.empty:
                        closest_strike = find_closest_value(df['strike'], current_price)
                        filtered = df[df['strike'] == closest_strike].copy()
                        filtered['type'] = opt_type
                        filtered['expiry'] = expiry
                        filtered['symbol'] = symbol
                        options_data.append(filtered)
            if options_data:
                result = pd.concat(options_data, ignore_index=True)
                result = result[result['openInterest'] > 1000]
                return result[['strike', 'impliedVolatility', 'openInterest', 'symbol']]
            else:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
        except Exception as e:
            print(f"Error fetching options for {symbol}: {e}")
            if attempt < max_retries - 1:
                time.sleep(retry_delay)
                continue
            else:
                print(f"Max retries reached for {symbol}.")
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
    return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])

# --- Screen Query ---
screen_query = EquityQuery("and", [
    EquityQuery("is-in", ["region", "us"]),
    EquityQuery("is-in", ["sector",
        "Technology",
        "Financial Services",
        "Consumer Cyclical",
        "Communication Services",
        "Basic Materials",
        "Industrials"
    ]),
    EquityQuery("GTE", ["eodprice", 0.50]),
    EquityQuery("GTE", ["avgdailyvol3m", 100000]),
    EquityQuery("LTE", ["short_percentage_of_float.value", 100])
])

# --- Batch Processing Function ---
def process_batch(offset, filterdf, options):
    batch_size = 250
    screener = screen(
        screen_query,
        sortField="avgdailyvol3m",
        sortAsc=False,
        size=batch_size,
        offset=offset
    )
    stocks = screener.get('quotes', [])
    if not stocks:
        print("No more stocks to load.")
        return filterdf, options, offset

    current_filterdf = pd.DataFrame(stocks)

    # --- Add price*volume filter for most recent full day ---
    current_filterdf['prev_day_price'] = None
    current_filterdf['prev_day_volume'] = None
    current_filterdf['price_volume'] = None

    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        price, volume = get_prev_day_price_volume(symbol)
        current_filterdf.at[idx, 'prev_day_price'] = price
        current_filterdf.at[idx, 'prev_day_volume'] = volume
        if price is not None and volume is not None:
            current_filterdf.at[idx, 'price_volume'] = price * volume

    current_filterdf = current_filterdf[current_filterdf['price_volume'] > 400_000_000]

    if current_filterdf.empty:
        print("No stocks passed the price*volume filter in this batch.")
        offset += batch_size
        return filterdf, options, offset

    current_filterdf['historical_volatility'] = None
    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        hv = get_historical_volatility(symbol, window=20)
        current_filterdf.at[idx, 'historical_volatility'] = hv

    filterstocks = current_filterdf['symbol'].tolist()
    options_list = []
    for symbol in filterstocks:
        options_data = get_options(symbol)
        options_list.append(options_data)

    if options_list:
        current_options = pd.concat(options_list, ignore_index=True)
        options = pd.concat([options, current_options], ignore_index=True)
    else:
        current_options = pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])

    if not current_options.empty:
        qualifying_symbols = set(current_options['symbol'].str.upper().unique())
        current_filterdf = current_filterdf[current_filterdf['symbol'].str.upper().isin(qualifying_symbols)]
    else:
        current_filterdf = current_filterdf.iloc[0:0]

    if current_filterdf.empty:
        print("No stocks passed the open interest filter in this batch.")
        offset += batch_size
        return filterdf, options, offset

    if not options.empty and 'symbol' in options.columns and 'impliedVolatility' in options.columns:
        avg_iv = options.groupby('symbol')['impliedVolatility'].mean().reset_index()
        avg_iv.columns = ['symbol', 'avg_iv']
    else:
        avg_iv = pd.DataFrame(columns=['symbol', 'avg_iv'])

    current_filterdf['symbol'] = current_filterdf['symbol'].astype(str).str.upper()
    avg_iv['symbol'] = avg_iv['symbol'].astype(str).str.upper()
    current_filterdf = current_filterdf.merge(avg_iv, on='symbol', how='left')

    if 'avg_iv' in current_filterdf.columns and 'historical_volatility' in current_filterdf.columns:
        current_filterdf["iv/hv_ratio"] = current_filterdf["avg_iv"] / current_filterdf["historical_volatility"]
    else:
        current_filterdf["iv/hv_ratio"] = None

    filterdf = pd.concat([filterdf, current_filterdf], ignore_index=True)

    offset += batch_size
    return filterdf, options, offset

# --- Main loop ---
offset = 0
filterdf = pd.DataFrame()
options = pd.DataFrame()

filterdf, options, offset = process_batch(offset, filterdf, options)
print("Initial batch:")
print(filterdf)

while True:
    user_input = input("Process next 100 stocks? (y/n): ")
    if user_input.lower() != 'y':
        break
    filterdf, options, offset = process_batch(offset, filterdf, options)
    print("Updated results:")
    print(filterdf)
# Out:
# Initial batch:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 5     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 14    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 16    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 17    en-US     US    EQUITY   Equity           Delayed Quote        False
# 18    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 21    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 22    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 23    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 24    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 25    en-US     US    EQUITY   Equity           Delayed Quote        False
# 26    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 28    en-US     US    EQUITY   Equity           Delayed Quote        False
# 29    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 30    en-US     US    EQUITY   Equity           Delayed Quote        False
# 31    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33    en-US     US    EQUITY   Equity           Delayed Quote        False
# 34    en-US     US    EQUITY   Equity           Delayed Quote        False
# 35    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 36    en-US     US    EQUITY   Equity           Delayed Quote        False
# 37    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38    en-US     US    EQUITY   Equity           Delayed Quote        False
# 39    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 40    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 41    en-US     US    EQUITY   Equity           Delayed Quote        False
# 42    en-US     US    EQUITY   Equity           Delayed Quote        False
# 43    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 44    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 45    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 47    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 48    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 49    en-US     US    EQUITY   Equity           Delayed Quote        False
# 50    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 53    en-US     US    EQUITY   Equity           Delayed Quote        False
# 54    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55    en-US     US    EQUITY   Equity           Delayed Quote        False
# 56    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57    en-US     US    EQUITY   Equity           Delayed Quote        False
# 58    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 59    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
#
#    customPriceAlertConfidence currency  regularMarketChangePercent  \
# 0                        HIGH      USD                    1.329090
# 1                        HIGH      USD                   -0.095038
# 2                        HIGH      USD                    1.695430
# 3                        HIGH      USD                    2.787940
# 4                        HIGH      USD                    2.483440
# 5                        HIGH      USD                    0.522501
# 6                        HIGH      USD                    0.515903
# 7                        HIGH      USD                   -1.041670
# 8                        HIGH      USD                    1.586940
# 9                        HIGH      USD                   -0.369307
# 10                       HIGH      USD                   -0.440370
# 11                        LOW      USD                    0.451655
# 12                       HIGH      USD                   -3.653810
# 13                        LOW      USD                   -0.786513
# 14                       HIGH      USD                    0.498208
# 15                        LOW      USD                   -1.172700
# 16                        LOW      USD                   -0.583652
# 17                        LOW      USD                    0.176620
# 18                        LOW      USD                    0.684925
# 19                        LOW      USD                    1.045530
# 20                       HIGH      USD                    1.956280
# 21                       HIGH      USD                    0.804605
# 22                       HIGH      USD                    0.451785
# 23                       HIGH      USD                    0.446553
# 24                       HIGH      USD                    1.578120
# 25                        LOW      USD                    1.716450
# 26                        LOW      USD                    0.000000
# 27                        LOW      USD                   -0.091766
# 28                        LOW      USD                    1.505580
# 29                        LOW      USD                   -1.815560
# 30                        LOW      USD                    2.259100
# 31                        LOW      USD                    0.513697
# 32                       HIGH      USD                    0.425075
# 33                        LOW      USD                   -0.266400
# 34                        LOW      USD                    0.528447
# 35                       HIGH      USD                    0.380865
# 36                        LOW      USD                    3.191590
# 37                       HIGH      USD                    1.524790
# 38                        LOW      USD                    1.456210
# 39                        LOW      USD                    0.829400
# 40                        LOW      USD                    0.398632
# 41                        LOW      USD                   -0.939786
# 42                        LOW      USD                    1.374470
# 43                        LOW      USD                    0.926508
# 44                       HIGH      USD                    0.366923
# 45                        LOW      USD                    1.858220
# 46                       HIGH      USD                   -0.067768
# 47                        LOW      USD                    0.153281
# 48                       HIGH      USD                    0.547344
# 49                        LOW      USD                    1.092090
# 50                        LOW      USD                  -14.396900
# 51                        LOW      USD                    1.309920
# 52                       HIGH      USD                   -0.412232
# 53                        LOW      USD                    0.851090
# 54                        LOW      USD                    0.438914
# 55                        LOW      USD                    0.584488
# 56                       HIGH      USD                   14.917400
# 57                        LOW      USD                    0.940724
# 58                       HIGH      USD                    8.509260
# 59                        LOW      USD                    0.959740
#
#     hasPrePostMarketData  ...                                 displayName  \
# 0                   True  ...                                      NVIDIA
# 1                   True  ...                                       Tesla
# 2                   True  ...                                    Palantir
# 3                   True  ...                                       Intel
# 4                   True  ...                                        SoFi
# 5                   True  ...                                       Apple
# 6                   True  ...                           American Airlines
# 7                   True  ...                             Applied Digital
# 8                   True  ...                                  Amazon.com
# 9                   True  ...                        Super Micro Computer
# 10                  True  ...                      Advanced Micro Devices
# 11                  True  ...                             Bank of America
# 12                  True  ...                           Robinhood Markets
# 13                  True  ...                                        MARA
# 14                  True  ...                                         NaN
# 15                  True  ...                                        Snap
# 16                  True  ...                                        Vale
# 17                  True  ...                                        AT&T
# 18                  True  ...                            Cleveland-Cliffs
# 19                  True  ...                      Carnival Corporation &
# 20                  True  ...                                    Broadcom
# 21                  True  ...                                         NaN
# 22                  True  ...                           Micron Technology
# 23                  True  ...                                         NaN
# 24                  True  ...                                   Microsoft
# 25                  True  ...                                        Uber
# 26                  True  ...                                        NIKE
# 27                  True  ...                      Verizon Communications
# 28                  True  ...                                         NaN
# 29                  True  ...                       Alibaba Group Holding
# 30                  True  ...                                   Citigroup
# 31                  True  ...  Taiwan Semiconductor Manufacturing Company
# 32                  True  ...                                         NaN
# 33                  True  ...                                     Newmont
# 34                  True  ...                      Chipotle Mexican Grill
# 35                  True  ...                             Coinbase Global
# 36                  True  ...                                      Oracle
# 37                  True  ...                                     Shopify
# 38                  True  ...                             Delta Air Lines
# 39                  True  ...                                         NaN
# 40                  True  ...                                         NaN
# 41                  True  ...                                         Dow
# 42                  True  ...                             Arista Networks
# 43                  True  ...                                         NaN
# 44                  True  ...                                      PayPal
# 45                  True  ...                            JPMorgan Chase &
# 46                  True  ...                                         NaN
# 47                  True  ...                          The Charles Schwab
# 48                  True  ...                           Applied Materials
# 49                  True  ...                                  Salesforce
# 50                  True  ...                                        Mogo
# 51                  True  ...                                        Visa
# 52                  True  ...                         Interactive Brokers
# 53                  True  ...                                         RTX
# 54                  True  ...                           The TJX Companies
# 55                  True  ...                                     Wayfair
# 56                  True  ...                                     Datadog
# 57                  True  ...                                         NaN
# 58                  True  ...                                 First Solar
# 59                  True  ...                       Capital One Financial
#
#     symbol  ipoExpectedDate  newListingDate  prev_day_price  prev_day_volume  \
# 0     NVDA              NaN             NaN          157.25        171224100
# 1     TSLA              NaN             NaN      315.649994        119191500
# 2     PLTR       2024-11-26             NaN      132.119995         59523500
# 3     INTC              NaN             NaN       21.879999        138245300
# 4     SOFI       2021-06-01             NaN       18.120001         66916300
# 5     AAPL              NaN             NaN      212.440002         67941800
# 6      AAL              NaN             NaN           11.63         41658400
# 7     APLD       2022-04-13             NaN           10.56         45648300
# 8     AMZN              NaN             NaN      219.919998         30894200
# 9     SMCI              NaN             NaN       48.740002         27631900
# 10     AMD              NaN             NaN      138.520004         39228000
# 11     BAC              NaN             NaN       48.709999         48003600
# 12    HOOD       2021-07-29             NaN       97.980003        112489000
# 13    MARA              NaN             NaN       17.799999         81907800
# 14   GOOGL              NaN             NaN      178.639999         29100000
# 15    SNAP              NaN             NaN            9.38         47994100
# 16    VALE              NaN             NaN           10.28        109623200
# 17       T              NaN             NaN       28.309999         47012300
# 18     CLF              NaN             NaN            8.76         47923800
# 19     CCL              NaN             NaN           29.65         33758000
# 20    AVGO              NaN             NaN      269.899994         17566100
# 21    HBAN              NaN             NaN            17.4         31339900
# 22      MU              NaN             NaN      121.739998         29303800
# 23   CMCSA              NaN             NaN       35.830002         24144800
# 24    MSFT              NaN             NaN      491.089996         16319600
# 25    UBER              NaN             NaN       92.050003         13599900
# 26     NKE              NaN             NaN       76.389999         36882300
# 27      VZ              NaN             NaN           43.59         18313900
# 28     WFC              NaN             NaN       82.360001         15195100
# 29    BABA              NaN             NaN      110.709999         13800800
# 30       C              NaN             NaN       86.760002         13420200
# 31     TSM              NaN             NaN      233.600006         12012500
# 32    MSTR              NaN             NaN      402.279999         17454400
# 33     NEM              NaN             NaN       60.060001          9316500
# 34     CMG              NaN             NaN           56.77         14396600
# 35    COIN       2021-04-14             NaN      354.450012         12441300
# 36    ORCL              NaN             NaN      229.979996         22326900
# 37    SHOP       2025-03-31             NaN      114.769997          6724300
# 38     DAL              NaN             NaN       50.130001          9828600
# 39     DIS              NaN             NaN      122.980003          7317100
# 40      GM              NaN             NaN           52.68          9459100
# 41     DOW              NaN             NaN           28.73         14109800
# 42    ANET              NaN             NaN      101.129997          8323100
# 43     USB              NaN             NaN       47.490002         15421800
# 44    PYPL              NaN             NaN       76.309998          9357800
# 45     JPM              NaN             NaN      290.600006          8158700
# 46    QCOM              NaN             NaN      162.320007          8916400
# 47    SCHW              NaN             NaN       91.339996          6121700
# 48    AMAT              NaN             NaN      190.009995          8800600
# 49     CRM              NaN             NaN      269.209991          6113300
# 50    MOGO              NaN             NaN            2.57        265729800
# 51       V              NaN             NaN      354.220001          5130900
# 52    IBKR              NaN             NaN       58.220001          6902500
# 53     RTX              NaN             NaN      144.520004          3253300
# 54     TJX              NaN             NaN      125.309998          4790200
# 55       W              NaN             NaN       56.459999          8272200
# 56    DDOG              NaN             NaN      135.009995          4511500
# 57   BRK-B              NaN             NaN      480.480011          6707200
# 58    FSLR              NaN             NaN      170.520004          6327800
# 59     COF              NaN             NaN      218.809998          3573100
#
#           price_volume  historical_volatility    avg_iv  iv/hv_ratio
# 0        26924989725.0               0.273381  0.342292     1.252069
# 1   37622796247.512817               0.788471  0.495824     0.628843
# 2     7864244529.35791               0.621793  0.482671     0.776257
# 3    3024807047.979927               0.526153  0.440435     0.837086
# 4    1212523412.158394               0.516192  0.523442     1.014045
# 5   14433556157.873535               0.199263  0.241910     1.214027
# 6     484487196.767426               0.478833  0.559086     1.167602
# 7     482046067.154789               0.830653  0.938803     1.130198
# 8     6794252407.43103               0.237427  0.274849     1.157612
# 9    1346778852.379227               0.736804  0.644535     0.874771
# 10   5433862727.600098               0.491873  0.382819     0.778288
# 11   2338255312.051392               0.147878  0.273933     1.852425
# 12  11021672597.618103               0.645766  0.731448     1.132683
# 13   1457958777.509308               0.666074  0.684573     1.027774
# 14    5198423982.23877               0.271609  0.263964     0.971855
# 15    450184663.492489               0.532014  0.504888     0.949012
# 16   1126926466.727448               0.366905  0.330085     0.899647
# 17   1330918187.892723               0.189472  0.182625     0.963864
# 18    419812498.968887               0.720103  0.657230     0.912689
# 19   1000924687.122345               0.452088  0.371100     0.820857
# 20   4741090282.785034                0.36746  0.362230     0.985765
# 21    545314248.044777               0.216378  0.393561     1.818855
# 22    3567444549.40033               0.287873  0.387213     1.345082
# 23    865108228.210449               0.185314  0.236336     1.275327
# 24    8014392304.23584               0.124587  0.185586     1.489606
# 25   1251870836.503601               0.333231  0.337002     1.011317
# 26   2817438874.488831               0.592114  0.313972     0.530255
# 27    798302903.794479                0.16225  0.122079     0.752414
# 28   1251468445.274353                0.21825  0.310717     1.423672
# 29    1527886555.36499               0.282093  0.363043     1.286965
# 30    1164336580.66864               0.194252  0.298591     1.537135
# 31   2806120073.318481               0.270156  0.440924     1.632106
# 32   7021556010.693359               0.518833  0.485194     0.935164
# 33    559549002.794266               0.365641  0.311530     0.852012
# 34     817294988.59024               0.324237  0.310310     0.957046
# 35   4409818936.871338               0.867563  0.588139     0.677921
# 36   5134740366.609192               0.573931  0.343634     0.598739
# 37    771747888.426971               0.434768  0.444097     1.021457
# 38    492707728.498077               0.421378  0.684085     1.623449
# 39    899856982.563019               0.161224  0.197762     1.226628
# 40    498305390.886688               0.275764  0.334317     1.212327
# 41    405374547.541046               0.421957  0.463873     1.099335
# 42    841715080.139923               0.522328  0.428961     0.821248
# 43    732381307.884979               0.226255  0.299079     1.321869
# 44    714093695.153809               0.312426  0.273689     0.876011
# 45   2370918269.796753               0.146362  0.201302     1.375371
# 46   1447310113.305664               0.238333  0.287849      1.20776
# 47    559156055.581665               0.126153  0.180672     1.432167
# 48    1672201957.65686               0.291596  0.353278     1.211531
# 49   1645761440.762329               0.244223  0.283943     1.162639
# 50    682925568.260622               2.808818  2.171877     0.773235
# 51   1817467404.263306               0.310477  0.198555     0.639518
# 52    401863558.425903                0.30227  0.408697     1.352092
# 53    470166929.899597               0.230284  0.216316     0.939346
# 54    600259950.305176               0.137609  0.178231     1.295194
# 55    467048404.426575               0.395889  0.538091     1.359194
# 56     609097590.21759               0.542161  0.570317     1.051933
# 57     3222675529.6875               0.134162  0.154183      1.14923
# 58   1079016483.035278               0.907891  0.590092     0.649959
# 59    781830002.276611               0.227113  0.263069     1.158318
#
# [60 rows x 94 columns]

# %%
import yfinance as yf
import numpy as np
from hmmlearn.hmm import GaussianHMM
from tqdm import tqdm

def get_last_120_returns(symbol):
    """Get last 120 days of daily log returns for a symbol."""
    try:
        data = yf.Ticker(symbol).history(period="130d")
        closes = data['Close'].dropna()
        if len(closes) < 121:
            return None
        returns = np.log(closes / closes.shift(1)).dropna()
        return returns[-120:]
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

def fit_hmm_and_stats(returns, n_states=3):
    """Fit HMM to returns, return means, stds, and state sequence."""
    model = GaussianHMM(
        n_components=n_states,
        covariance_type="diag",
        n_iter=500,
        tol=1e-2,
        random_state=42,
        verbose=False
    )
    X = returns.values.reshape(-1, 1)
    model.fit(X)
    hidden_states = model.predict(X)
    means = model.means_.flatten()
    stds = np.sqrt(np.array([np.diag(cov)[0] for cov in model.covars_]))
    return hidden_states, means, stds

def hmm_analysis(symbol):
    returns = get_last_120_returns(symbol)
    if returns is None:
        return {
            "hmm_mean_0": None,
            "hmm_std_0": None,
            "hmm_mean_1": None,
            "hmm_std_1": None,
            "hmm_mean_2": None,
            "hmm_std_2": None,
            "pct_last30_in_highest_stdev_state": None,
            "highest_stdev_state": None
        }
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    # Identify the state with the highest stdev
    high_stdev_state = int(np.argmax(stds))
    last30 = hidden_states[-30:]
    pct_high = np.mean(last30 == high_stdev_state) * 100
    return {
        "hmm_mean_0": means[0],
        "hmm_std_0": stds[0],
        "hmm_mean_1": means[1],
        "hmm_std_1": stds[1],
        "hmm_mean_2": means[2],
        "hmm_std_2": stds[2],
        "pct_last30_in_highest_stdev_state": pct_high,
        "highest_stdev_state": high_stdev_state
    }

# --- Apply to filterdf ---

filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()

for col in [
    'hmm_mean_0','hmm_std_0',
    'hmm_mean_1','hmm_std_1',
    'hmm_mean_2','hmm_std_2',
    'pct_last30_in_highest_stdev_state',
    'highest_stdev_state'
]:
    filterdf[col] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    hmm_stats = hmm_analysis(symbol)
    for col in hmm_stats:
        filterdf.at[idx, col] = hmm_stats[col]

# filterdf now has the HMM columns for states 0, 1, 2, and the % of last 30 closes in the highest stdev state.
# Out:
#  28%|██▊       | 17/60 [00:03<00:10,  4.15it/s]Model is not converging.  Current: 320.7209037539965 is not greater than 320.7403861480697. Delta is -0.019482394073236264
#  32%|███▏      | 19/60 [00:04<00:09,  4.49it/s]Model is not converging.  Current: 244.04643532109827 is not greater than 244.05839444648248. Delta is -0.011959125384208846
#  33%|███▎      | 20/60 [00:04<00:08,  4.57it/s]Model is not converging.  Current: 243.38405483218392 is not greater than 243.3896602709769. Delta is -0.005605438792969153
#  35%|███▌      | 21/60 [00:04<00:08,  4.54it/s]Model is not converging.  Current: 308.82831018770867 is not greater than 308.8857099270271. Delta is -0.057399739318441334
#  37%|███▋      | 22/60 [00:04<00:08,  4.47it/s]Model is not converging.  Current: 227.68607968071038 is not greater than 227.68618330324807. Delta is -0.00010362253769358176
#  38%|███▊      | 23/60 [00:05<00:08,  4.35it/s]Model is not converging.  Current: 327.41504471810003 is not greater than 327.41705427108207. Delta is -0.002009552982030982
#  45%|████▌     | 27/60 [00:06<00:07,  4.25it/s]Model is not converging.  Current: 340.0583871312435 is not greater than 340.16798679864075. Delta is -0.10959966739727633
#  47%|████▋     | 28/60 [00:06<00:07,  4.11it/s]Model is not converging.  Current: 309.40539227724076 is not greater than 309.8199493240637. Delta is -0.41455704682294936
#  52%|█████▏    | 31/60 [00:07<00:07,  3.92it/s]Model is not converging.  Current: 262.08352177562705 is not greater than 262.0927461001974. Delta is -0.00922432457036848
#  53%|█████▎    | 32/60 [00:07<00:06,  4.24it/s]Model is not converging.  Current: 203.05670232626974 is not greater than 203.08689646935926. Delta is -0.030194143089516956
#  75%|███████▌  | 45/60 [00:10<00:03,  4.48it/s]Model is not converging.  Current: 319.6470454925969 is not greater than 319.6481014723354. Delta is -0.0010559797385099046
#  85%|████████▌ | 51/60 [00:11<00:02,  3.75it/s]Model is not converging.  Current: 322.3048622774952 is not greater than 322.3681755961549. Delta is -0.06331331865970924
#  98%|█████████▊| 59/60 [00:13<00:00,  4.15it/s]Model is not converging.  Current: 276.0706673178507 is not greater than 276.0748141492251. Delta is -0.004146831374441717
# 100%|██████████| 60/60 [00:13<00:00,  4.33it/s]

# %%
N = 252  # Or use 261, depending on your convention

def pct_regimes_higher_than_iv(hidden_states, stds, avg_iv):
    """% of regimes in last 30 days with annualized stdev higher than avg_iv."""
    last30 = hidden_states[-30:]
    # Annualize regime stdevs
    stds_annualized = stds * np.sqrt(N)
    last30_vols_annualized = stds_annualized[last30]
    pct_higher = np.mean(last30_vols_annualized > avg_iv) * 100
    return pct_higher

filterdf['pct_regimes_last30_higher_than_avg_iv'] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    avg_iv = row['avg_iv']
    returns = get_last_120_returns(symbol)
    if returns is None or avg_iv is None:
        filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = None
        continue
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    pct_higher = pct_regimes_higher_than_iv(hidden_states, stds, avg_iv)
    filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = pct_higher
# Out:
#  28%|██▊       | 17/60 [00:04<00:08,  5.10it/s]Model is not converging.  Current: 320.7209037539965 is not greater than 320.7403861480697. Delta is -0.019482394073236264
#  32%|███▏      | 19/60 [00:04<00:11,  3.54it/s]Model is not converging.  Current: 244.04643532109827 is not greater than 244.05839444648248. Delta is -0.011959125384208846
#  33%|███▎      | 20/60 [00:05<00:10,  3.83it/s]Model is not converging.  Current: 243.3840401344055 is not greater than 243.389644127086. Delta is -0.005603992680505598
#  35%|███▌      | 21/60 [00:05<00:09,  4.15it/s]Model is not converging.  Current: 308.82831018770867 is not greater than 308.8857099270271. Delta is -0.057399739318441334
#  37%|███▋      | 22/60 [00:05<00:09,  4.16it/s]Model is not converging.  Current: 227.68607968071038 is not greater than 227.68618330324807. Delta is -0.00010362253769358176
#  38%|███▊      | 23/60 [00:05<00:08,  4.27it/s]Model is not converging.  Current: 327.41504471810003 is not greater than 327.41705427108207. Delta is -0.002009552982030982
#  45%|████▌     | 27/60 [00:06<00:06,  4.78it/s]Model is not converging.  Current: 340.0583871312435 is not greater than 340.16798679864075. Delta is -0.10959966739727633
#  47%|████▋     | 28/60 [00:06<00:06,  4.79it/s]Model is not converging.  Current: 309.40539227724076 is not greater than 309.8199493240637. Delta is -0.41455704682294936
#  52%|█████▏    | 31/60 [00:07<00:06,  4.59it/s]Model is not converging.  Current: 262.08352177562705 is not greater than 262.0927461001974. Delta is -0.00922432457036848
#  53%|█████▎    | 32/60 [00:07<00:05,  4.75it/s]Model is not converging.  Current: 203.05670232626974 is not greater than 203.08689646935926. Delta is -0.030194143089516956
#  75%|███████▌  | 45/60 [00:10<00:04,  3.75it/s]Model is not converging.  Current: 319.6470454925969 is not greater than 319.6481014723354. Delta is -0.0010559797385099046
#  85%|████████▌ | 51/60 [00:12<00:02,  4.38it/s]Model is not converging.  Current: 322.30484885314763 is not greater than 322.36816223028626. Delta is -0.06331337713862695
#  98%|█████████▊| 59/60 [00:14<00:00,  4.06it/s]Model is not converging.  Current: 276.0706673178507 is not greater than 276.0748141492251. Delta is -0.004146831374441717
# 100%|██████████| 60/60 [00:14<00:00,  4.13it/s]

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import entropy
from hmmlearn.hmm import GaussianHMM

def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]
    return entropy(hist, base=2)

def hmm_regime_switch_prob_and_count(returns, n_states=2):
    returns = returns.values.reshape(-1, 1)
    model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=100)
    model.fit(returns)
    hidden_states = model.predict(returns)
    # Probability of regime switch tomorrow
    last_state = hidden_states[-1]
    transmat = model.transmat_
    switch_prob = 1 - transmat[last_state, last_state]
    # Count regime switches in last 30 days
    regime_switch_count = np.sum(hidden_states[1:] != hidden_states[:-1])
    return switch_prob, regime_switch_count

entropy_list = []
regimeswitchprob_list = []
regimeswitchcount_list = []

for ticker in filterdf['symbol']:
    try:
        df = yf.download(ticker, period="90d", interval="1d", progress=False)
        closes = df['Close'].dropna()
        if len(closes) < 31:
            entropy_list.append(np.nan)
            regimeswitchprob_list.append(np.nan)
            regimeswitchcount_list.append(np.nan)
            continue
        returns = np.log(closes).diff().dropna()[-30:]
        # Shannon entropy
        ent = shannon_entropy(returns)
        entropy_list.append(ent)
        # HMM regime switch probability and count
        switch_prob, switch_count = hmm_regime_switch_prob_and_count(returns)
        regimeswitchprob_list.append(round(switch_prob * 100, 2))  # as percentage
        regimeswitchcount_list.append(int(switch_count))
    except Exception as e:
        entropy_list.append(np.nan)
        regimeswitchprob_list.append(np.nan)
        regimeswitchcount_list.append(np.nan)

filterdf['ShannonEntropy'] = entropy_list
filterdf['Regimeswitchprob'] = regimeswitchprob_list
filterdf['Regimeswitchcount'] = regimeswitchcount_list
# Out:
# YF.download() has changed argument auto_adjust default to True
# Model is not converging.  Current: 57.478812274044095 is not greater than 57.49332653987788. Delta is -0.014514265833781792
# Model is not converging.  Current: 63.76627481686214 is not greater than 63.8353808019857. Delta is -0.06910598512355648
# Model is not converging.  Current: 84.1100387763145 is not greater than 84.1229528229154. Delta is -0.012914046600897677
# Model is not converging.  Current: 62.43770816734808 is not greater than 62.56169587891942. Delta is -0.12398771157134547
# Model is not converging.  Current: 69.15328894278267 is not greater than 69.20968656540614. Delta is -0.05639762262347858
# Model is not converging.  Current: 71.4864193925033 is not greater than 71.53482655771977. Delta is -0.04840716521647437
# Model is not converging.  Current: 67.08596831878633 is not greater than 67.18617209849934. Delta is -0.10020377971301286
# Model is not converging.  Current: 70.45229383283139 is not greater than 70.5067861488892. Delta is -0.0544923160578179
# Model is not converging.  Current: 59.59424447502596 is not greater than 59.708804716345945. Delta is -0.11456024131998532
# Model is not converging.  Current: 71.82946666224592 is not greater than 71.86517993294639. Delta is -0.03571327070046948
# Model is not converging.  Current: 75.65849310352607 is not greater than 75.66572119234876. Delta is -0.007228088822685663
# Model is not converging.  Current: 62.013005308212485 is not greater than 62.02936818368882. Delta is -0.016362875476332306
# Model is not converging.  Current: 54.386168848596654 is not greater than 54.43850904314877. Delta is -0.052340194552115804

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
filterdf["Shannon/IV"] = filterdf["ShannonEntropy"] / filterdf["avg_iv"]
display(filterdf)
# Out:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 5     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 14    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 16    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 17    en-US     US    EQUITY   Equity           Delayed Quote        False
# 18    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 21    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 22    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 23    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 24    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 25    en-US     US    EQUITY   Equity           Delayed Quote        False
# 26    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 28    en-US     US    EQUITY   Equity           Delayed Quote        False
# 29    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 30    en-US     US    EQUITY   Equity           Delayed Quote        False
# 31    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33    en-US     US    EQUITY   Equity           Delayed Quote        False
# 34    en-US     US    EQUITY   Equity           Delayed Quote        False
# 35    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 36    en-US     US    EQUITY   Equity           Delayed Quote        False
# 37    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38    en-US     US    EQUITY   Equity           Delayed Quote        False
# 39    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 40    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 41    en-US     US    EQUITY   Equity           Delayed Quote        False
# 42    en-US     US    EQUITY   Equity           Delayed Quote        False
# 43    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 44    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 45    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 47    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 48    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 49    en-US     US    EQUITY   Equity           Delayed Quote        False
# 50    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 53    en-US     US    EQUITY   Equity           Delayed Quote        False
# 54    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55    en-US     US    EQUITY   Equity           Delayed Quote        False
# 56    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57    en-US     US    EQUITY   Equity           Delayed Quote        False
# 58    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 59    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
#
#    customPriceAlertConfidence currency  regularMarketChangePercent  \
# 0                        HIGH      USD                    1.329090
# 1                        HIGH      USD                   -0.095038
# 2                        HIGH      USD                    1.695430
# 3                        HIGH      USD                    2.787940
# 4                        HIGH      USD                    2.483440
# 5                        HIGH      USD                    0.522501
# 6                        HIGH      USD                    0.515903
# 7                        HIGH      USD                   -1.041670
# 8                        HIGH      USD                    1.586940
# 9                        HIGH      USD                   -0.369307
# 10                       HIGH      USD                   -0.440370
# 11                        LOW      USD                    0.451655
# 12                       HIGH      USD                   -3.653810
# 13                        LOW      USD                   -0.786513
# 14                       HIGH      USD                    0.498208
# 15                        LOW      USD                   -1.172700
# 16                        LOW      USD                   -0.583652
# 17                        LOW      USD                    0.176620
# 18                        LOW      USD                    0.684925
# 19                        LOW      USD                    1.045530
# 20                       HIGH      USD                    1.956280
# 21                       HIGH      USD                    0.804605
# 22                       HIGH      USD                    0.451785
# 23                       HIGH      USD                    0.446553
# 24                       HIGH      USD                    1.578120
# 25                        LOW      USD                    1.716450
# 26                        LOW      USD                    0.000000
# 27                        LOW      USD                   -0.091766
# 28                        LOW      USD                    1.505580
# 29                        LOW      USD                   -1.815560
# 30                        LOW      USD                    2.259100
# 31                        LOW      USD                    0.513697
# 32                       HIGH      USD                    0.425075
# 33                        LOW      USD                   -0.266400
# 34                        LOW      USD                    0.528447
# 35                       HIGH      USD                    0.380865
# 36                        LOW      USD                    3.191590
# 37                       HIGH      USD                    1.524790
# 38                        LOW      USD                    1.456210
# 39                        LOW      USD                    0.829400
# 40                        LOW      USD                    0.398632
# 41                        LOW      USD                   -0.939786
# 42                        LOW      USD                    1.374470
# 43                        LOW      USD                    0.926508
# 44                       HIGH      USD                    0.366923
# 45                        LOW      USD                    1.858220
# 46                       HIGH      USD                   -0.067768
# 47                        LOW      USD                    0.153281
# 48                       HIGH      USD                    0.547344
# 49                        LOW      USD                    1.092090
# 50                        LOW      USD                  -14.396900
# 51                        LOW      USD                    1.309920
# 52                       HIGH      USD                   -0.412232
# 53                        LOW      USD                    0.851090
# 54                        LOW      USD                    0.438914
# 55                        LOW      USD                    0.584488
# 56                       HIGH      USD                   14.917400
# 57                        LOW      USD                    0.940724
# 58                       HIGH      USD                    8.509260
# 59                        LOW      USD                    0.959740
#
#     hasPrePostMarketData  firstTradeDateMilliseconds  priceHint  \
# 0                   True                917015400000          2
# 1                   True               1277818200000          2
# 2                   True               1601472600000          2
# 3                   True                322151400000          2
# 4                   True               1609770600000          2
# 5                   True                345479400000          2
# 6                   True               1127827800000          2
# 7                   True               1649856600000          2
# 8                   True                863703000000          2
# 9                   True               1175175000000          2
# 10                  True                322151400000          2
# 11                  True                 99153000000          2
# 12                  True               1627565400000          2
# 13                  True               1336138200000          2
# 14                  True               1092922200000          2
# 15                  True               1488465000000          2
# 16                  True               1016721000000          2
# 17                  True                438273000000          2
# 18                  True                 99153000000          2
# 19                  True                554131800000          2
# 20                  True               1249565400000          2
# 21                  True                322151400000          2
# 22                  True                454944600000          2
# 23                  True                322151400000          2
# 24                  True                511108200000          2
# 25                  True               1557495000000          2
# 26                  True                344615400000          2
# 27                  True                438273000000          2
# 28                  True                 76253400000          2
# 29                  True               1411133400000          2
# 30                  True                221149800000          2
# 31                  True                876403800000          2
# 32                  True                897571800000          2
# 33                  True                322151400000          2
# 34                  True               1138285800000          2
# 35                  True               1618407000000          2
# 36                  True                511021800000          2
# 37                  True               1432128600000          2
# 38                  True               1178199000000          2
# 39                  True               -252322200000          2
# 40                  True               1290090600000          2
# 41                  True               1553088600000          2
# 42                  True               1402061400000          2
# 43                  True                105283800000          2
# 44                  True               1436189400000          2
# 45                  True                322151400000          2
# 46                  True                692634600000          2
# 47                  True                559315800000          2
# 48                  True                322151400000          2
# 49                  True               1087997400000          2
# 50                  True               1494941400000          4
# 51                  True               1205933400000          2
# 52                  True               1178285400000          2
# 53                  True               -244546200000          2
# 54                  True                551712600000          2
# 55                  True               1412256600000          2
# 56                  True               1568899800000          2
# 57                  True                831648600000          2
# 58                  True               1163773800000          2
# 59                  True                784996200000          2
#
#     postMarketChangePercent  postMarketTime  postMarketPrice  \
# 0                 -0.056481      1751576398       159.250000
# 1                 -0.849847      1751576398       312.670000
# 2                  0.007439      1751576391       134.370000
# 3                 -0.266783      1751576399        22.430000
# 4                 -0.215396      1751576394        18.530000
# 5                  0.000000      1751576398       213.550000
# 6                  0.000000      1751576290        11.690000
# 7                 -0.669854      1751576301        10.380000
# 8                 -0.161139      1751576398       223.050000
# 9                  0.061777      1751576399        48.590000
# 10                 0.014494      1751576398       137.930000
# 11                 0.051097      1751576384        48.955000
# 12                -0.391952      1751576387        94.030000
# 13                 0.283121      1751576354        17.710000
# 14                -0.027852      1751576391       179.480000
# 15                -0.106797      1751576364         9.260100
# 16                 0.440314      1751576389        10.265000
# 17                -0.105785      1751576341        28.330000
# 18                -0.453514      1751575964         8.780000
# 19                 0.000000      1751576385        29.960000
# 20                 0.170798      1751576398       275.650000
# 21                 0.000000      1751574911        17.540000
# 22                -0.367981      1751576304       121.840000
# 23                 0.000000      1751575214        35.990000
# 24                -0.264615      1751576398       497.520000
# 25                -0.128159      1751576389        93.510000
# 26                -0.222540      1751576386        76.220000
# 27                 0.195176      1751576397        43.635000
# 28                -0.119615      1751576375        83.500000
# 29                -0.064488      1751576399       108.630000
# 30                 0.090173      1751576389        88.800000
# 31                 0.315158      1751576386       235.540000
# 32                 0.435657      1751576377       405.750000
# 33                -0.041968      1751576321        59.874863
# 34                 0.175221      1751576377        57.170000
# 35                 0.098372      1751576375       356.150000
# 36                 0.033704      1751576399       237.400000
# 37                 0.506354      1751576364       117.110000
# 38                 0.078649      1751576372        50.900000
# 39                -0.193547      1751576334       123.760000
# 40                 0.113446      1751576140        52.950000
# 41                -0.210820      1751576199        28.400000
# 42                -0.097540      1751576388       102.420000
# 43                 0.000000      1751576313        47.930000
# 44                 0.091405      1751576127        76.660000
# 45                 0.016929      1751576348       296.050000
# 46                -0.184947      1751576370       161.910000
# 47                 0.207690      1751576059        91.670000
# 48                -0.099452      1751576361       190.860000
# 49                 0.000000      1751576390       272.150000
# 50                -0.909090      1751576391         2.180000
# 51                -0.058516      1751576358       358.650000
# 52                -0.017244      1751576116        57.970000
# 53                 0.157802      1751576346       145.980000
# 54                 0.223105      1751575761       126.141000
# 55                -0.211310      1751576341        56.670000
# 56                 1.005490      1751576386       156.710000
# 57                -0.041240      1751576315       484.800000
# 58                -0.016213      1751576382       185.000000
# 59                 0.013580      1751576260       220.940000
#
#     postMarketChange  regularMarketChange  regularMarketTime  \
# 0          -0.089996             2.090000         1751562000
# 1          -2.679990            -0.299988         1751562000
# 2           0.009995             2.240010         1751562000
# 3          -0.059999             0.610001         1751562001
# 4          -0.039999             0.449999         1751562000
# 5           0.000000             1.110000         1751562001
# 6           0.000000             0.059999         1751562001
# 7          -0.070000            -0.110001         1751562001
# 8          -0.360001             3.490010         1751562000
# 9           0.029999            -0.180000         1751562000
# 10          0.019989            -0.610001         1751562001
# 11          0.025001             0.220001         1751562002
# 12         -0.370003            -3.580000         1751562001
# 13          0.049999            -0.139999         1751562000
# 14         -0.050003             0.889999         1751562000
# 15         -0.009900            -0.110000         1751562002
# 16          0.045000            -0.059999         1751562001
# 17         -0.030001             0.050001         1751562021
# 18         -0.040000             0.059999         1751562002
# 19          0.000000             0.309999         1751562002
# 20          0.470001             5.280000         1751562001
# 21          0.000000             0.140001         1751562001
# 22         -0.450005             0.550003         1751562001
# 23          0.000000             0.160000         1751562001
# 24         -1.320010             7.750000         1751562001
# 25         -0.119995             1.579990         1751562002
# 26         -0.169998             0.000000         1751562002
# 27          0.084999            -0.040001         1751562002
# 28         -0.099998             1.240000         1751562002
# 29         -0.070099            -2.010000         1751562002
# 30          0.080002             1.960000         1751562002
# 31          0.739990             1.200000         1751562002
# 32          1.760010             1.709990         1751562001
# 33         -0.025139            -0.160000         1751562002
# 34          0.099998             0.299999         1751562002
# 35          0.350006             1.349980         1751562001
# 36          0.079987             7.340010         1751562002
# 37          0.590004             1.750000         1751562000
# 38          0.040001             0.730000         1751562002
# 39         -0.239998             1.020000         1751562002
# 40          0.060001             0.209999         1751562002
# 41         -0.059999            -0.270000         1751562002
# 42         -0.099998             1.390000         1751562002
# 43          0.000000             0.439999         1751562002
# 44          0.070007             0.279999         1751562000
# 45          0.050110             5.399990         1751562002
# 46         -0.300003            -0.110001         1751562000
# 47          0.189995             0.140007         1751562002
# 48         -0.190002             1.040010         1751562000
# 49          0.000000             2.940000         1751562002
# 50         -0.020000            -0.370000         1751562000
# 51         -0.209991             4.639980         1751562002
# 52         -0.009998            -0.240002         1751562001
# 53          0.229996             1.230000         1751562001
# 54          0.280800             0.550003         1751562002
# 55         -0.120003             0.330002         1751562002
# 56          1.560010            20.140000         1751562001
# 57         -0.200012             4.519990         1751562002
# 58         -0.029999            14.510000         1751562001
# 59          0.029999             2.100010         1751562002
#
#     regularMarketPrice  regularMarketDayHigh regularMarketDayRange  \
# 0               159.34              160.9800       157.77 - 160.98
# 1               315.35              318.4500       312.76 - 318.45
# 2               134.36              135.6200       132.51 - 135.62
# 3                22.49               22.6300         21.99 - 22.63
# 4                18.57               18.6399       18.08 - 18.6399
# 5               213.55              214.6500     211.8101 - 214.65
# 6                11.69               11.9300        11.665 - 11.93
# 7                10.45               10.6698       10.26 - 10.6698
# 8               223.41              224.0100       221.36 - 224.01
# 9                48.56               49.6300         48.42 - 49.63
# 10              137.91              139.5000        137.32 - 139.5
# 11               48.93               49.3050        48.81 - 49.305
# 12               94.40               95.6100         92.11 - 95.61
# 13               17.66               18.2177       17.38 - 18.2177
# 14              179.53              179.6700       177.06 - 179.67
# 15                9.27                9.4600           9.19 - 9.46
# 16               10.22               10.3700         10.17 - 10.37
# 17               28.36               28.4100         28.13 - 28.41
# 18                8.82                8.9000            8.61 - 8.9
# 19               29.96               30.2381       29.66 - 30.2381
# 20              275.18              275.8000        270.12 - 275.8
# 21               17.54               17.7450      17.5107 - 17.745
# 22              122.29              123.6300       121.83 - 123.63
# 23               35.99               36.3950        35.78 - 36.395
# 24              498.84              500.1200       493.44 - 500.12
# 25               93.63               94.1100         92.61 - 94.11
# 26               76.39               77.0300         75.58 - 77.03
# 27               43.55               43.7700        43.415 - 43.77
# 28               83.60               83.9450        82.51 - 83.945
# 29              108.70              109.0800       107.95 - 109.08
# 30               88.72               88.7950        86.85 - 88.795
# 31              234.80              237.5700       233.27 - 237.57
# 32              403.99              414.6000         400.4 - 414.6
# 33               59.90               60.1836       59.06 - 60.1836
# 34               57.07               57.2500         56.72 - 57.25
# 35              355.80              357.8699      348.5 - 357.8699
# 36              237.32              237.9899      231.2 - 237.9899
# 37              116.52              117.4600       114.97 - 117.46
# 38               50.86               51.3898       50.35 - 51.3898
# 39              124.00              124.2400        122.9 - 124.24
# 40               52.89               53.9601      52.745 - 53.9601
# 41               28.46               28.7800         28.37 - 28.78
# 42              102.52              103.4900        101.3 - 103.49
# 43               47.93               48.0550        47.52 - 48.055
# 44               76.59               77.3600         76.48 - 77.36
# 45              296.00              296.3800       291.21 - 296.38
# 46              162.21              163.9573     162.09 - 163.9573
# 47               91.48               92.1500        91.095 - 92.15
# 48              191.05              192.0400       189.27 - 192.04
# 49              272.15              274.7300      269.315 - 274.73
# 50                2.20                2.6700           2.04 - 2.67
# 51              358.86              359.0000        353.61 - 359.0
# 52               57.98               58.4799       57.29 - 58.4799
# 53              145.75              146.3900       144.37 - 146.39
# 54              125.86              126.1100       124.77 - 126.11
# 55               56.79               57.6300         56.13 - 57.63
# 56              155.15              156.5300       146.91 - 156.53
# 57              485.00              486.4900        480.4 - 486.49
# 58              185.03              188.5000        177.85 - 188.5
# 59              220.91              221.9200        218.9 - 221.92
#
#     regularMarketDayLow  regularMarketVolume  regularMarketPreviousClose  \
# 0              157.7700            142313659                      157.25
# 1              312.7600             58042302                      315.65
# 2              132.5100             41812483                      132.12
# 3               21.9900             60704082                       21.88
# 4               18.0800             44097903                       18.12
# 5              211.8101             34697317                      212.44
# 6               11.6650             30237867                       11.63
# 7               10.2600             17883734                       10.56
# 8              221.3600             29295154                      219.92
# 9               48.4200             18283790                       48.74
# 10             137.3200             28331975                      138.52
# 11              48.8100             21577976                       48.71
# 12              92.1100             56373803                       97.98
# 13              17.3800             32142502                       17.80
# 14             177.0600             21563145                      178.64
# 15               9.1900             21666576                        9.38
# 16              10.1700             23585163                       10.28
# 17              28.1300             21085177                       28.31
# 18               8.6100             24914896                        8.76
# 19              29.6600             19978354                       29.65
# 20             270.1200             10507344                      269.90
# 21              17.5107             21787294                       17.40
# 22             121.8300             13247931                      121.74
# 23              35.7800             10160934                       35.83
# 24             493.4400             13917734                      491.09
# 25              92.6100              8112562                       92.05
# 26              75.5800             11545304                       76.39
# 27              43.4150             10063458                       43.59
# 28              82.5100             11237287                       82.36
# 29             107.9500             11733528                      110.71
# 30              86.8500             13229886                       86.76
# 31             233.2700              7710776                      233.60
# 32             400.4000              9886038                      402.28
# 33              59.0600              5369766                       60.06
# 34              56.7200             10384051                       56.77
# 35             348.5000              6704285                      354.45
# 36             231.2000             18441376                      229.98
# 37             114.9700              3734741                      114.77
# 38              50.3500              6123398                       50.13
# 39             122.9000              4191063                      122.98
# 40              52.7450              6599331                       52.68
# 41              28.3700              5949954                       28.73
# 42             101.3000              5296699                      101.13
# 43              47.5200              7031644                       47.49
# 44              76.4800              5263390                       76.31
# 45             291.2100              6480148                      290.60
# 46             162.0900              4267702                      162.32
# 47              91.0950              5765549                       91.34
# 48             189.2700              3565632                      190.01
# 49             269.3150              5031804                      269.21
# 50               2.0400             13049659                        2.57
# 51             353.6100              3702810                      354.22
# 52              57.2900              4499824                       58.22
# 53             144.3700              1888713                      144.52
# 54             124.7700              2986646                      125.31
# 55              56.1300              3314876                       56.46
# 56             146.9100             29996674                      135.01
# 57             480.4000              3443318                      480.48
# 58             177.8500              6399688                      170.52
# 59             218.9000              1853959                      218.81
#
#     bidSize  askSize     market   messageBoardId fullExchangeName  \
# 0         0        0  us_market      finmb_32307         NasdaqGS
# 1         1        1  us_market   finmb_27444752         NasdaqGS
# 2        11        8  us_market   finmb_43580005         NasdaqGS
# 3         0        0  us_market      finmb_21127         NasdaqGS
# 4         0        0  us_market  finmb_141582707         NasdaqGS
# 5         1        1  us_market      finmb_24937         NasdaqGS
# 6         0        0  us_market     finmb_168569         NasdaqGS
# 7         0        0  us_market    finmb_3563673         NasdaqGS
# 8         0        0  us_market      finmb_18749         NasdaqGS
# 9         0        0  us_market    finmb_6479558         NasdaqGS
# 10        0        0  us_market     finmb_168864         NasdaqGS
# 11       68       37  us_market      finmb_19049             NYSE
# 12        0        0  us_market  finmb_276763615         NasdaqGS
# 13        0        0  us_market  finmb_158387416         NasdaqCM
# 14        0        0  us_market      finmb_29096         NasdaqGS
# 15      798      152  us_market  finmb_224055283             NYSE
# 16      434      319  us_market     finmb_874225             NYSE
# 17      192      104  us_market     finmb_100231             NYSE
# 18      115      119  us_market     finmb_261738             NYSE
# 19       80       26  us_market     finmb_258823             NYSE
# 20        0        0  us_market   finmb_25016048         NasdaqGS
# 21        0        0  us_market     finmb_278614         NasdaqGS
# 22        0        0  us_market     finmb_289030         NasdaqGS
# 23        0        0  us_market     finmb_173341         NasdaqGS
# 24        0        0  us_market      finmb_21835         NasdaqGS
# 25        7        2  us_market  finmb_144524848             NYSE
# 26        3        4  us_market     finmb_291981             NYSE
# 27       15       38  us_market     finmb_415798             NYSE
# 28        5        6  us_market     finmb_292891             NYSE
# 29        4        4  us_market   finmb_42083601             NYSE
# 30        9        3  us_market     finmb_391687             NYSE
# 31        4        1  us_market     finmb_380075             NYSE
# 32        0        0  us_market     finmb_384976         NasdaqGS
# 33        5        9  us_market     finmb_291795             NYSE
# 34       12        8  us_market      finmb_26446             NYSE
# 35        0        0  us_market  finmb_377154867         NasdaqGS
# 36        3        1  us_market      finmb_22247             NYSE
# 37        8        8  us_market   finmb_84159238         NasdaqGS
# 38        7        7  us_market     finmb_266311             NYSE
# 39        5        1  us_market     finmb_191564             NYSE
# 40        4        5  us_market   finmb_61206100             NYSE
# 41       12       12  us_market    finmb_9830660             NYSE
# 42        4        5  us_market   finmb_33348547             NYSE
# 43       18       37  us_market     finmb_305304             NYSE
# 44        0        0  us_market     finmb_112732         NasdaqGS
# 45        8        3  us_market     finmb_658776             NYSE
# 46        0        0  us_market      finmb_33493         NasdaqGS
# 47        4        4  us_market      finmb_34093             NYSE
# 48        0        0  us_market     finmb_251230         NasdaqGS
# 49        1        3  us_market     finmb_122917             NYSE
# 50        0        0  us_market  finmb_224013466         NasdaqCM
# 51        6        2  us_market   finmb_38043467             NYSE
# 52        0        0  us_market    finmb_4185357         NasdaqGS
# 53        1        1  us_market     finmb_159230             NYSE
# 54        3        1  us_market     finmb_306688             NYSE
# 55       10        3  us_market   finmb_30663855             NYSE
# 56        0        0  us_market  finmb_134521275         NasdaqGS
# 57        1        1  us_market     finmb_255251             NYSE
# 58        0        0  us_market    finmb_4593731         NasdaqGS
# 59        2        1  us_market     finmb_336241             NYSE
#
#                                              longName financialCurrency  \
# 0                                  NVIDIA Corporation               USD
# 1                                         Tesla, Inc.               USD
# 2                          Palantir Technologies Inc.               USD
# 3                                   Intel Corporation               USD
# 4                             SoFi Technologies, Inc.               USD
# 5                                          Apple Inc.               USD
# 6                        American Airlines Group Inc.               USD
# 7                         Applied Digital Corporation               USD
# 8                                    Amazon.com, Inc.               USD
# 9                          Super Micro Computer, Inc.               USD
# 10                       Advanced Micro Devices, Inc.               USD
# 11                        Bank of America Corporation               USD
# 12                            Robinhood Markets, Inc.               USD
# 13                                MARA Holdings, Inc.               USD
# 14                                      Alphabet Inc.               USD
# 15                                          Snap Inc.               USD
# 16                                          Vale S.A.               BRL
# 17                                          AT&T Inc.               USD
# 18                              Cleveland-Cliffs Inc.               USD
# 19                         Carnival Corporation & plc               USD
# 20                                      Broadcom Inc.               USD
# 21                 Huntington Bancshares Incorporated               USD
# 22                            Micron Technology, Inc.               USD
# 23                                Comcast Corporation               USD
# 24                              Microsoft Corporation               USD
# 25                            Uber Technologies, Inc.               USD
# 26                                         NIKE, Inc.               USD
# 27                        Verizon Communications Inc.               USD
# 28                              Wells Fargo & Company               USD
# 29                      Alibaba Group Holding Limited               CNY
# 30                                     Citigroup Inc.               USD
# 31  Taiwan Semiconductor Manufacturing Company Lim...               TWD
# 32                              Strategy Incorporated               USD
# 33                                Newmont Corporation               USD
# 34                       Chipotle Mexican Grill, Inc.               USD
# 35                              Coinbase Global, Inc.               USD
# 36                                 Oracle Corporation               USD
# 37                                       Shopify Inc.               USD
# 38                              Delta Air Lines, Inc.               USD
# 39                            The Walt Disney Company               USD
# 40                             General Motors Company               USD
# 41                                           Dow Inc.               USD
# 42                                Arista Networks Inc               USD
# 43                                       U.S. Bancorp               USD
# 44                              PayPal Holdings, Inc.               USD
# 45                               JPMorgan Chase & Co.               USD
# 46                              QUALCOMM Incorporated               USD
# 47                     The Charles Schwab Corporation               USD
# 48                            Applied Materials, Inc.               USD
# 49                                   Salesforce, Inc.               USD
# 50                                          Mogo Inc.               CAD
# 51                                          Visa Inc.               USD
# 52                    Interactive Brokers Group, Inc.               USD
# 53                                    RTX Corporation               USD
# 54                            The TJX Companies, Inc.               USD
# 55                                       Wayfair Inc.               USD
# 56                                      Datadog, Inc.               USD
# 57                            Berkshire Hathaway Inc.               USD
# 58                                  First Solar, Inc.               USD
# 59                  Capital One Financial Corporation               USD
#
#     regularMarketOpen  averageDailyVolume3Month  averageDailyVolume10Day  \
# 0             158.350                 239364726                203802200
# 1             317.950                 118500386                110280080
# 2             134.360                  97534968                 83994650
# 3              22.145                  88713055                 92466790
# 4              18.312                  66622131                 80178880
# 5             212.145                  62010880                 64380450
# 6              11.725                  60366554                 48406960
# 7              10.600                  52750834                 36940840
# 8             221.705                  47654257                 51116600
# 9              49.230                  47620863                 52937190
# 10            139.110                  47289767                 58448480
# 11             48.945                  45885314                 44916320
# 12             95.490                  44957673                 60870010
# 13             17.560                  44767745                 46186790
# 14            178.695                  41874408                 49937310
# 15              9.410                  39023265                 42274000
# 16             10.230                  36650122                 56059890
# 17             28.290                  34715200                 33576920
# 18              8.750                  31219486                 33286610
# 19             29.790                  26166054                 36282140
# 20            270.710                  25480457                 24631900
# 21             17.630                  24399298                 29951660
# 22            122.325                  23658283                 30826110
# 23             35.800                  22832863                 23682960
# 24            493.495                  22561063                 23697780
# 25             92.630                  22178672                 20559040
# 26             76.265                  19945736                 32445380
# 27             43.740                  19115837                 19335250
# 28             82.640                  18463185                 18397430
# 29            108.335                  17473304                 12136940
# 30             87.130                  14922311                 16320570
# 31            233.870                  14533704                 10868790
# 32            400.585                  14152967                 13162550
# 33             59.295                  13619385                 12123530
# 34             56.970                  13557547                 14445670
# 35            350.221                  13080200                 20877660
# 36            233.220                  12519932                 17936600
# 37            115.055                  12204401                  7812230
# 38             50.500                  11223527                 10399490
# 39            123.065                  11126467                  9957140
# 40             52.790                  11085272                 11287210
# 41             28.670                  10887496                 16042060
# 42            101.330                  10710019                 11443660
# 43             47.680                  10424591                 13611930
# 44             76.710                  10169377                  9898040
# 45            292.150                   9683996                 10169760
# 46            163.045                   9149449                  9384160
# 47             91.500                   9015236                  9010440
# 48            189.350                   7907409                  8033630
# 49            269.700                   7693036                  9232630
# 50              2.440                   7025383                 28122360
# 51            354.590                   6634570                  8189280
# 52             58.405                   6568454                  6359830
# 53            144.490                   5887834                  6488860
# 54            125.350                   5785721                  5735070
# 55             56.250                   5649962                  4388160
# 56            147.560                   5301072                  6771530
# 57            480.890                   5294001                  5278670
# 58            177.850                   5220118                  5306380
# 59            219.400                   5011737                  4024180
#
#    corporateActions  fiftyTwoWeekLowChange  fiftyTwoWeekLowChangePercent  \
# 0                []              72.719990                      0.839529
# 1                []             133.350000                      0.732692
# 2                []             113.130005                      5.328780
# 3                []               4.820000                      0.272779
# 4                []              12.559999                      2.089850
# 5                []              44.339996                      0.262041
# 6                []               3.190000                      0.375294
# 7                []               7.440000                      2.471761
# 8                []              71.800000                      0.473584
# 9                []              31.310001                      1.815073
# 10               []              61.430000                      0.803216
# 11               []              15.860001                      0.479589
# 12               []              80.420000                      5.752504
# 13               []               7.849999                      0.800204
# 14               []              39.000000                      0.277521
# 15               []               2.190001                      0.309322
# 16               []               2.160000                      0.267990
# 17               []              10.220001                      0.563396
# 18               []               3.190000                      0.566607
# 19               []              16.180000                      1.174165
# 20               []             146.680000                      1.141479
# 21               []               5.620001                      0.471477
# 22               []              60.750000                      0.987163
# 23               []               4.550001                      0.144720
# 24               []             154.049990                      0.446794
# 25               []              38.789997                      0.707330
# 26               []              24.110000                      0.461171
# 27               []               5.959999                      0.158553
# 28               []              33.449997                      0.666999
# 29               []              35.750000                      0.490062
# 30               []              35.210003                      0.658008
# 31               []             101.229996                      0.757880
# 32               []             301.587980                      2.945137
# 33               []              23.040000                      0.625068
# 34               []              12.610001                      0.283626
# 35               []             213.219990                      1.495441
# 36               []             118.460010                      0.996635
# 37               []              67.959990                      1.399506
# 38               []              16.119999                      0.464018
# 39               []              43.900000                      0.548065
# 40               []              13.930000                      0.357546
# 41               []               3.400000                      0.135674
# 42               []              43.089996                      0.725055
# 43               []              12.750000                      0.362422
# 44               []              20.739998                      0.371352
# 45               []             105.100006                      0.550550
# 46               []              41.410004                      0.342798
# 47               []              30.470005                      0.499426
# 48               []              67.310005                      0.543963
# 49               []              42.149994                      0.183261
# 50               []               1.460000                      1.972973
# 51               []             106.159990                      0.420103
# 52               []              32.057500                      1.236667
# 53               []              46.330000                      0.466003
# 54               []              18.150002                      0.168508
# 55               []              36.380000                      1.782460
# 56               []              73.520000                      0.900649
# 57               []              78.890015                      0.194258
# 58               []              68.470000                      0.587423
# 59               []              92.680010                      0.722764
#
#     fiftyTwoWeekRange  fiftyTwoWeekHighChange  fiftyTwoWeekHighChangePercent  \
# ...
# 27               0.16225  0.122079    0.752414  -0.007238  0.075914
# 28               0.21825  0.310717    1.423672  -0.004397  0.067827
# 29              0.282093  0.363043    1.286965   0.013307  0.029841
# 30              0.194252  0.298591    1.537135   0.006522  0.026503
# 31              0.270156  0.440924    1.632106   0.007539  0.026267
# 32              0.518833  0.485194    0.935164   0.003566  0.029873
# 33              0.365641  0.311530    0.852012   0.003986  0.022057
# 34              0.324237  0.310310    0.957046  -0.004364  0.024201
# 35              0.867563  0.588139    0.677921  -0.012917  0.037543
# 36              0.573931  0.343634    0.598739     0.0061  0.033334
# 37              0.434768  0.444097    1.021457   0.006656  0.038627
# 38              0.421378  0.684085    1.623449   0.005662  0.034698
# 39              0.161224  0.197762    1.226628  -0.001729   0.01901
# 40              0.275764  0.334317    1.212327  -0.000593  0.025059
# 41              0.421957  0.463873    1.099335   0.003593  0.026337
# 42              0.522328  0.428961    0.821248   0.007974  0.036287
# 43              0.226255  0.299079    1.321869   0.004558   0.02165
# 44              0.312426  0.273689    0.876011   0.002223  0.104343
# 45              0.146362  0.201302    1.375371   0.004518  0.021585
# 46              0.238333  0.287849     1.20776   0.014835  0.106965
# 47              0.126153  0.180672    1.432167   0.001349  0.017084
# 48              0.291596  0.353278    1.211531   0.006085   0.02536
# 49              0.244223  0.283943    1.162639  -0.005694   0.02361
# 50              2.808818  2.171877    0.773235  -0.109044  0.053841
# 51              0.310477  0.198555    0.639518   0.003369  0.018946
# 52               0.30227  0.408697    1.352092   0.010708  0.027842
# 53              0.230284  0.216316    0.939346   0.005743  0.021633
# 54              0.137609  0.178231    1.295194   0.002188   0.01794
# 55              0.395889  0.538091    1.359194    0.00874  0.047922
# 56              0.542161  0.570317    1.051933   0.003719  0.026897
# 57              0.134162  0.154183     1.14923   0.003356  0.018901
# 58              0.907891  0.590092    0.649959  -0.014704  0.034977
# 59              0.227113  0.263069    1.158318   0.016058  0.108849
#
#    hmm_mean_1 hmm_std_1 hmm_mean_2  hmm_std_2  \
# 0    0.011938  0.039754  -0.113334   0.098977
# 1    -0.00021  0.038285  -0.012638   0.119405
# 2    0.011185  0.059616  -0.027296   0.078263
# 3   -0.011021  0.031924   0.029704   0.086389
# 4   -0.000397  0.040588  -0.023745   0.094597
# 5   -0.004762  0.024717   0.017527   0.111919
# 6    0.194315  0.106166  -0.001101   0.028502
# 7   -0.014205   0.05076  -0.379186    0.09931
# 8   -0.003182  0.022766   0.018112   0.090669
# 9   -0.008096  0.061293   0.060534   0.077799
# 10  -0.005927  0.034537   0.156504   0.127782
# 11   0.006267  0.019711  -0.085201   0.071292
# 12  -0.001442  0.043004   0.000322   0.152844
# 13   0.010491  0.061553  -0.086662   0.081374
# 14    0.00334  0.028483  -0.047184  31.622784
# 15  -0.007303  0.030597   0.017408   0.153791
# 16   0.005925  0.019433  -0.021952   0.065126
# 17   0.002059  0.020387  -0.042355   0.086984
# 18  -0.017403  0.054386   0.000107   0.038318
# 19   -0.04112  0.067741   0.003844      0.028
# 20  -0.042326  0.062355   0.004771   0.025772
# 21  -0.045347  0.059831   0.002305   0.018344
# 22  -0.000079  0.033476  -0.038625   0.116767
# 23  -0.059397  0.064531   0.001418   0.015771
# 24  -0.000658  0.017743   0.075914   0.075147
# 25   0.005994  0.025986   0.011282   0.068124
# 26   -0.00401  0.026591   0.026228   0.112681
# 27   -0.02349  0.069602   0.002014   0.015242
# 28  -0.029598  0.049305   0.003776   0.017332
# 29  -0.002388  0.031371  -0.087216   0.055815
# 30   0.000542  0.020569  -0.098797   0.077739
# 31  -0.000928  0.025989  -0.026501   0.078226
# 32   0.002394  0.038731  -0.001149   0.083256
# 33   0.000293  0.029628   0.060458   0.062811
# 34   0.002346  0.022847   0.098535   0.100228
# 35    0.01304  0.043233   0.048688   0.144883
# 36  -0.000299   0.02751   0.010522   0.114657
# 37  -0.002427  0.031146  -0.024117   0.115608
# 38  -0.007813   0.02704   -0.01048   0.115947
# 39   0.004371  0.019461  -0.004299   0.082482
# 40   0.002775  0.027087  -0.042534    0.09011
# 41  -0.004246  0.023785  -0.036816   0.094379
# 42  -0.002125  0.035708  -0.148582   0.095027
# 43  -0.001893  0.020212  -0.021866   0.067077
# 44  -0.059662  0.061257   0.001456   0.020386
# 45   0.000504  0.017105   -0.01427   0.068921
# 46  -0.060518  0.057325    0.00232   0.019971
# 47   0.003941  0.024369  -0.066038   0.096032
# 48  -0.003809  0.029397  -0.006595   0.088117
# 49   0.002691  0.026012  -0.013333  31.622777
# 50   0.256034  0.228416  -0.005001   0.037891
# 51  -0.000043  0.018877  -0.011202   0.071353
# 52  -0.006048  0.031249  -0.004615   0.110969
# 53   0.001828  0.018433  -0.098503    0.07217
# 54  -0.001517  0.018327   0.014651  31.622777
# 55  -0.003561  0.038905  -0.005654   0.147722
# 56   -0.00402  0.025572   0.017925   0.086631
# 57  -0.002176  0.019681  -0.042559  31.622777
# 58   0.011283  0.037097   0.016342   0.137089
# 59  -0.054484   0.06347   0.003059   0.023219
#
#    pct_last30_in_highest_stdev_state highest_stdev_state  \
# 0                                0.0                   2
# 1                           3.333333                   2
# 2                                0.0                   2
# 3                                0.0                   2
# 4                                0.0                   2
# 5                                0.0                   2
# 6                                0.0                   1
# 7                                0.0                   2
# 8                                0.0                   2
# 9                                0.0                   2
# 10                               0.0                   2
# 11                               0.0                   2
# 12                               0.0                   2
# 13                          3.333333                   2
# 14                               0.0                   2
# 15                               0.0                   2
# 16                               0.0                   2
# 17                               0.0                   2
# 18                          3.333333                   0
# 19                               0.0                   0
# 20                               0.0                   0
# 21                               0.0                   0
# 22                               0.0                   2
# 23                               0.0                   0
# 24                               0.0                   2
# 25                          3.333333                   2
# 26                          3.333333                   2
# 27                               0.0                   0
# 28                               0.0                   0
# 29                               0.0                   2
# 30                               0.0                   2
# 31                               0.0                   2
# 32                               0.0                   2
# 33                               0.0                   2
# 34                               0.0                   2
# 35                          3.333333                   2
# 36                          3.333333                   2
# 37                               0.0                   2
# 38                               0.0                   2
# 39                               0.0                   2
# 40                               0.0                   2
# 41                               0.0                   2
# 42                               0.0                   2
# 43                               0.0                   2
# 44                               0.0                   0
# 45                               0.0                   2
# 46                               0.0                   0
# 47                               0.0                   2
# 48                               0.0                   2
# 49                               0.0                   2
# 50                          3.333333                   1
# 51                               0.0                   2
# 52                               0.0                   2
# 53                               0.0                   2
# 54                               0.0                   2
# 55                               0.0                   2
# 56                          3.333333                   2
# 57                               0.0                   2
# 58                          3.333333                   2
# 59                               0.0                   0
#
#    pct_regimes_last30_higher_than_avg_iv  ShannonEntropy  Regimeswitchprob  \
# 0                                  100.0        3.181076              0.00
# 1                                  100.0        2.542367              5.57
# 2                                  100.0        2.724092              4.97
# 3                                  100.0        2.730125              0.00
# 4                                  100.0        3.143762             33.76
# 5                                  100.0        2.971629              0.00
# 6                                    0.0        2.851841             42.28
# 7                              46.666667        2.103119              7.95
# 8                                  100.0        3.164735              0.00
# 9                                  100.0        2.884523             14.73
# 10                                 100.0        2.824210              6.13
# 11                                 100.0        2.739572              0.00
# 12                             46.666667        2.755913             22.26
# 13                                  50.0        2.881194             18.14
# 14                                 100.0        2.757544              0.00
# 15                                  50.0        3.057426             76.77
# 16                                  50.0        2.755913             75.67
# 17                                 100.0        2.989898              0.00
# 18                              6.666667        2.598278              5.90
# 19                                 100.0        2.851933             99.59
# 20                                 100.0        2.853236              0.00
# 21                                   0.0        2.909686              0.00
# 22                                 100.0        3.244414              0.00
# 23                                 100.0        3.012593              0.00
# 24                                 100.0        2.721440             99.62
# 25                                 100.0        2.305587              1.13
# 26                                 100.0        2.321928              4.63
# 27                                 100.0        3.098930             99.22
# 28                                   0.0        2.994088              0.00
# 29                                 100.0        2.949255              0.00
# 30                                 100.0        2.802376              0.00
# 31                                   0.0        3.072906              0.00
# 32                                  50.0        2.851307              0.00
# 33                                 100.0        2.986569              0.00
# 34                                 100.0        2.973024              0.00
# 35                                 100.0        2.869577             17.84
# 36                                 100.0        2.469043              4.76
# 37                                 100.0        3.202910              0.00
# 38                                   0.0        3.013132             47.52
# 39                                 100.0        3.044414              0.00
# 40                                 100.0        2.796792             70.25
# 41                                   0.0        3.028934              0.00
# 42                                 100.0        2.909686             20.65
# 43                                 100.0        3.019251              0.00
# 44                                 100.0        2.747861             42.62
# 45                                 100.0        3.165596              0.00
# 46                                 100.0        2.947861              0.00
# 47                                 100.0        2.981076              0.00
# 48                                 100.0        3.152584              0.00
# 49                                 100.0        2.879799              0.00
# 50                              3.333333        1.248609              3.57
# 51                                 100.0        2.562944              0.00
# 52                                 100.0        3.190759             76.09
# 53                                 100.0        2.831402             89.68
# 54                                 100.0        2.951189              0.00
# 55                                 100.0        2.562944              8.54
# 56                              3.333333        2.046439             99.89
# 57                                 100.0        3.177747              0.00
# 58                              3.333333        2.197417              5.15
# 59                                 100.0        2.841085              0.00
#
#     Regimeswitchcount  Shannon/IV
# 0                   0    9.293464
# 1                   2    5.127559
# 2                   0    5.643785
# 3                   0    6.198697
# 4                   1    6.005939
# 5                   0   12.284013
# 6                  16    5.100895
# 7                   4    2.240215
# 8                   0   11.514469
# 9                   2    4.475356
# 10                  0    7.377410
# 11                  1   10.000883
# 12                  4    3.767750
# 13                  1    4.208743
# 14                  0   10.446663
# 15                 29    6.055654
# 16                 29    8.349106
# 17                  0   16.371757
# 18                  2    3.953377
# 19                 29    7.685078
# 20                  0    7.876869
# 21                  0    7.393231
# 22                  0    8.378883
# 23                  0   12.747090
# 24                 29   14.664073
# 25                  0    6.841463
# 26                  2    7.395342
# 27                 29   25.384605
# 28                  1    9.636076
# 29                  0    8.123697
# 30                  0    9.385334
# 31                  0    6.969248
# 32                  0    5.876634
# 33                  0    9.586769
# 34                  0    9.580829
# 35                  4    4.879080
# 36                  2    7.185085
# 37                  0    7.212180
# 38                 27    4.404616
# 39                  0   15.394337
# 40                 29    8.365699
# 41                  0    6.529669
# 42                  3    6.783104
# 43                  0   10.095153
# 44                  3   10.040088
# 45                  0   15.725613
# 46                  0   10.240999
# 47                  0   16.499910
# 48                  0    8.923807
# 49                  0   10.142184
# 50                  2    0.574899
# 51                  0   12.907954
# 52                 29    7.807145
# 53                 29   13.089167
# 54                  0   16.558239
# 55                  2    4.763034
# 56                  1    3.588250
# 57                  0   20.610195
# 58                  2    3.723855
# 59                  1   10.799775

# %%
import datetime

today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-07-04.csv
