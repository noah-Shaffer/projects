# %% [markdown]
# Do a random forest return predictor for long time equity screens, maybe including rates/ sectors / commodities / geoploitic indicators.
# Find the % of regimes in the last 30 days that have a higher volatility than the current IV
# Add trend in shannon entropy or/and regime percentages to evaluate recessions / hostile environments beginning. could also look at earnings timestamps affecting options prices

# %% [markdown]
# Want to find stocks with a low hv/iv high regime % in highest stdev state, and high # of days with stdev above avg iv on options

# %%
import yfinance as yf 
from yfinance import EquityQuery
import numpy as np
import pandas as pd
import time

# %%
from yfinance import EquityQuery, screen
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time

# --- Helper Functions ---

def find_closest_value(data_list, target_value):
    if len(data_list) == 0:
        return None
    return min(data_list, key=lambda x: abs(x - target_value))

def filter_special_expiry(expiry_list):
    """Return the two soonest (earliest) expiry dates from the list."""
    sorted_expiries = sorted(expiry_list)
    return sorted_expiries[:2]

def get_prev_day_price_volume(symbol):
    """Fetch the most recent full day's close price and volume for the symbol."""
    try:
        data = yf.Ticker(symbol).history(period="5d")
        if data.shape[0] < 2:
            return None, None
        prev_day = data.iloc[-2]
        price = float(prev_day['Close'])
        volume = int(prev_day['Volume'])
        return price, volume
    except Exception as e:
        print(f"Error fetching previous day price/volume for {symbol}: {e}")
        return None, None

def get_historical_volatility(symbol, window=20):
    try:
        data = yf.Ticker(symbol).history(period=f"{window*2}d")
        if data.shape[0] < window + 1:
            return None
        data = data['Close'].dropna()
        log_returns = np.log(data / data.shift(1)).dropna()
        vol = log_returns[-window:].std() * np.sqrt(252)
        return vol
    except Exception as e:
        print(f"Error calculating historical volatility for {symbol}: {e}")
        return None

def get_options(symbol, max_retries=3, retry_delay=60):
    for attempt in range(max_retries):
        try:
            stock = yf.Ticker(symbol)
            options_chain = stock.options
            if not options_chain:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            filtered_expiries = filter_special_expiry(options_chain)
            options_data = []
            current_price, _ = get_prev_day_price_volume(symbol)
            if current_price is None:
                continue
            for expiry in filtered_expiries:
                chain = stock.option_chain(expiry)
                for opt_type, df in [('call', chain.calls), ('put', chain.puts)]:
                    if not df.empty:
                        closest_strike = find_closest_value(df['strike'], current_price)
                        filtered = df[df['strike'] == closest_strike].copy()
                        filtered['type'] = opt_type
                        filtered['expiry'] = expiry
                        filtered['symbol'] = symbol
                        options_data.append(filtered)
            if options_data:
                result = pd.concat(options_data, ignore_index=True)
                result = result[result['openInterest'] > 500]
                return result[['strike', 'impliedVolatility', 'openInterest', 'symbol']]
            else:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
        except Exception as e:
            print(f"Error fetching options for {symbol}: {e}")
            if attempt < max_retries - 1:
                time.sleep(retry_delay)
                continue
            else:
                print(f"Max retries reached for {symbol}.")
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
    return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])

# --- Screen Query ---
screen_query = EquityQuery("and", [
    EquityQuery("is-in", ["region", "us"]),
    EquityQuery("is-in", ["sector",
        "Technology",
        "Financial Services",
        "Consumer Cyclical",
        "Communication Services",
        "Basic Materials",
        "Industrials"
    ]),
    EquityQuery("GTE", ["eodprice", 0.50]),
    EquityQuery("GTE", ["avgdailyvol3m", 100000]),
    EquityQuery("LTE", ["short_percentage_of_float.value", 100])
])

# --- Batch Processing Function ---
def process_batch(offset, filterdf, options):
    batch_size = 100
    screener = screen(
        screen_query,
        sortField="avgdailyvol3m",
        sortAsc=False,
        size=batch_size,
        offset=offset
    )
    stocks = screener.get('quotes', [])
    if not stocks:
        print("No more stocks to load.")
        return filterdf, options, offset

    current_filterdf = pd.DataFrame(stocks)

    # --- Add price*volume filter for most recent full day ---
    current_filterdf['prev_day_price'] = None
    current_filterdf['prev_day_volume'] = None
    current_filterdf['price_volume'] = None

    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        price, volume = get_prev_day_price_volume(symbol)
        current_filterdf.at[idx, 'prev_day_price'] = price
        current_filterdf.at[idx, 'prev_day_volume'] = volume
        if price is not None and volume is not None:
            current_filterdf.at[idx, 'price_volume'] = price * volume

    current_filterdf = current_filterdf[current_filterdf['price_volume'] > 100_000_000]

    if current_filterdf.empty:
        print("No stocks passed the price*volume filter in this batch.")
        offset += batch_size
        return filterdf, options, offset

    current_filterdf['historical_volatility'] = None
    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        hv = get_historical_volatility(symbol, window=20)
        current_filterdf.at[idx, 'historical_volatility'] = hv

    filterstocks = current_filterdf['symbol'].tolist()
    options_list = []
    for symbol in filterstocks:
        options_data = get_options(symbol)
        options_list.append(options_data)

    if options_list:
        current_options = pd.concat(options_list, ignore_index=True)
        options = pd.concat([options, current_options], ignore_index=True)
    else:
        current_options = pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])

    if not current_options.empty:
        qualifying_symbols = set(current_options['symbol'].str.upper().unique())
        current_filterdf = current_filterdf[current_filterdf['symbol'].str.upper().isin(qualifying_symbols)]
    else:
        current_filterdf = current_filterdf.iloc[0:0]

    if current_filterdf.empty:
        print("No stocks passed the open interest filter in this batch.")
        offset += batch_size
        return filterdf, options, offset

    if not options.empty and 'symbol' in options.columns and 'impliedVolatility' in options.columns:
        avg_iv = options.groupby('symbol')['impliedVolatility'].mean().reset_index()
        avg_iv.columns = ['symbol', 'avg_iv']
    else:
        avg_iv = pd.DataFrame(columns=['symbol', 'avg_iv'])

    current_filterdf['symbol'] = current_filterdf['symbol'].astype(str).str.upper()
    avg_iv['symbol'] = avg_iv['symbol'].astype(str).str.upper()
    current_filterdf = current_filterdf.merge(avg_iv, on='symbol', how='left')

    if 'avg_iv' in current_filterdf.columns and 'historical_volatility' in current_filterdf.columns:
        current_filterdf["iv/hv_ratio"] = current_filterdf["avg_iv"] / current_filterdf["historical_volatility"]
    else:
        current_filterdf["iv/hv_ratio"] = None

    filterdf = pd.concat([filterdf, current_filterdf], ignore_index=True)

    offset += batch_size
    return filterdf, options, offset

# --- Main loop ---
offset = 0
filterdf = pd.DataFrame()
options = pd.DataFrame()

filterdf, options, offset = process_batch(offset, filterdf, options)
print("Initial batch:")
print(filterdf)

while True:
    user_input = input("Process next 100 stocks? (y/n): ")
    if user_input.lower() != 'y':
        break
    filterdf, options, offset = process_batch(offset, filterdf, options)
    print("Updated results:")
    print(filterdf)
# Out:
# Initial batch:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 5     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15    en-US     US    EQUITY   Equity           Delayed Quote        False
# 16    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 17    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 18    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 21    en-US     US    EQUITY   Equity           Delayed Quote        False
# 22    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 24    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 25    en-US     US    EQUITY   Equity           Delayed Quote        False
# 26    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27    en-US     US    EQUITY   Equity           Delayed Quote        False
# 28    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 29    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 30    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33    en-US     US    EQUITY   Equity           Delayed Quote        False
# 34    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 35    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 36    en-US     US    EQUITY   Equity           Delayed Quote        False
# 37    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 40    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 41    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 42    en-US     US    EQUITY   Equity           Delayed Quote        False
# 43    en-US     US    EQUITY   Equity           Delayed Quote        False
# 44    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 45    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46    en-US     US    EQUITY   Equity           Delayed Quote        False
# 47    en-US     US    EQUITY   Equity           Delayed Quote        False
# 48    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 49    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 50    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52    en-US     US    EQUITY   Equity           Delayed Quote         True
# 53    en-US     US    EQUITY   Equity           Delayed Quote        False
# 54    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55    en-US     US    EQUITY   Equity           Delayed Quote        False
# 56    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 58    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 59    en-US     US    EQUITY   Equity           Delayed Quote        False
# 60    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 62    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 63    en-US     US    EQUITY   Equity           Delayed Quote        False
# 64    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 65    en-US     US    EQUITY   Equity           Delayed Quote        False
# 66    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 67    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 68    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 69    en-US     US    EQUITY   Equity           Delayed Quote        False
# 70    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 71    en-US     US    EQUITY   Equity           Delayed Quote        False
# 72    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 73    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 74    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 75    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 76    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 77    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 78    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#    customPriceAlertConfidence currency     bid     ask  \
# 0                        HIGH      USD  172.00  175.00
# 1                        HIGH      USD    2.95    2.99
# 2                         LOW      USD    1.74    1.90
# 3                        HIGH      USD  305.15  310.00
# 4                         LOW      USD   11.27   11.28
# 5                        HIGH      USD  154.68  155.13
# 6                        HIGH      USD   22.52   23.17
# 7                        HIGH      USD   21.00   21.52
# 8                        HIGH      USD   11.44   11.95
# 9                        HIGH      USD  203.20  224.70
# 10                       HIGH      USD   11.17   11.22
# 11                        LOW      USD   17.22   17.31
# 12                       HIGH      USD  159.00  164.00
# 13                       HIGH      USD   52.43   52.60
# 14                       HIGH      USD  100.50  108.70
# 15                        LOW      USD    4.83    4.84
# 16                       HIGH      USD  232.07  232.36
# 17                       HIGH      USD  191.00  195.00
# 18                        LOW      USD   48.47   48.47
# 19                        LOW      USD   14.63   14.73
# 20                        LOW      USD    9.75    9.72
# 21                        LOW      USD   10.22   10.26
# 22                        LOW      USD   12.50   12.70
# 23                        LOW      USD   10.93   11.03
# 24                        LOW      USD    3.22    9.00
# 25                        LOW      USD    9.75    9.77
# 26                        LOW      USD   27.88   27.83
# 27                        LOW      USD    6.34    6.37
# 28                        LOW      USD   12.42   17.86
# 29                       HIGH      USD   16.59   16.68
# 30                        LOW      USD   12.30   12.39
# 31                        LOW      USD   29.78   29.81
# 32                       HIGH      USD    9.11   12.04
# 33                        LOW      USD    6.19    6.21
# 34                       HIGH      USD  111.66  111.85
# 35                        LOW      USD   20.21   25.43
# 36                        LOW      USD   90.85   91.13
# 37                       HIGH      USD  288.45  289.05
# 38                       HIGH      USD   69.74   77.68
# 39                       HIGH      USD  483.11  534.45
# 40                       HIGH      USD   68.24   68.35
# 41                       HIGH      USD   35.35   35.43
# 42                        LOW      USD    9.61    9.68
# 43                        LOW      USD    4.36    4.36
# 44                        LOW      USD   20.51   20.60
# 45                        LOW      USD   83.82   84.01
# 46                        LOW      USD   43.11   43.14
# 47                        LOW      USD    8.34    8.36
# 48                        LOW      USD   75.53   75.59
# 49                       HIGH      USD   14.33   15.21
# 50                        LOW      USD   18.51   18.52
# 51                        LOW      USD   14.86   14.95
# 52                       HIGH      USD   33.82   36.79
# 53                        LOW      USD   23.49   23.60
# 54                        LOW      USD   23.53   23.55
# 55                        LOW      USD    9.43    9.43
# 56                       HIGH      USD  396.10  427.14
# 57                        LOW      USD   61.51   61.56
# 58                        LOW      USD  121.25  121.31
# 59                        LOW      USD   33.34   33.72
# 60                        LOW      USD   95.42   95.59
# 61                       HIGH      USD   59.47   63.61
# 62                        LOW      USD   45.83   45.84
# 63                        LOW      USD   44.51   44.80
# 64                        LOW      USD   13.60   13.66
# 65                        LOW      USD  242.46  242.96
# 66                       HIGH      USD  414.30  415.73
# 67                        LOW      USD   63.95   64.11
# 68                        LOW      USD   33.28   33.37
# 69                        LOW      USD  241.02  243.68
# 70                        LOW      USD   25.16   25.14
# 71                        LOW      USD   17.68   17.74
# 72                        LOW      USD   84.80   85.13
# 73                        LOW      USD   12.32   12.34
# 74                        LOW      USD   37.66   37.67
# 75                        LOW      USD   54.72   54.96
# 76                        LOW      USD   30.10   30.30
# 77                       HIGH      USD   29.11   38.02
# 78                        LOW      USD   52.38   52.34
#
#     regularMarketChangePercent exchange  fiftyTwoWeekHigh  fiftyTwoWeekLow  \
# 0                     1.733230      NMS           174.250        86.620000
# 1                    -2.922080      NMS             4.430         1.930000
# 2                    -2.209940      NCM             3.320         0.690000
# 3                    -8.197020      NMS           488.540       182.000000
# 4                    -1.054480      NYQ            11.970         8.440000
# 5                     0.155865      NMS           155.680        21.230000
# 6                    -3.661140      NMS            31.560        17.670000
# 7                    -0.231907      NMS            22.740         6.010000
# 8                    -9.621450      NMS            19.100         8.500000
# 9                    -0.182115      NMS           260.100       169.210000
# 10                    2.470260      NMS            15.420         3.010000
# 11                   -1.764370      NCM            30.280         9.810000
# 12                    2.187210      NMS           174.050        76.480000
# 13                    1.586070      NMS            73.001        17.250000
# 14                   -0.146945      NMS           113.439        13.980000
# 15                   -1.829270      NYQ             7.710         3.020000
# 16                    1.725880      NMS           242.520       151.610000
# 17                    1.019820      NMS           207.050       140.530000
# 18                    0.519319      NYQ            49.310        33.070000
# 19                    2.440720      NCM            15.870         6.190000
# 20                   -3.277060      NYQ            13.950         7.080000
# 21                   -1.634620      NYQ            12.050         8.060000
# 22                   -1.558840      NYQ            15.030         3.400000
# 23                   -3.194330      NYQ            15.710         5.630000
# 24                   -3.869040      NCM             5.740         1.690000
# 25                   -0.509686      NYQ            11.480         8.370000
# 26                    0.612613      NYQ            29.190        18.640000
# 27                   -1.550390      NYQ             6.950         4.418182
# 28                   -2.976520      NCM            27.150         0.530000
# 29                   -1.070160      NMS            18.450        11.920000
# 30                   -0.883531      NCM            18.050         6.452000
# 31                   -3.122960      NYQ            31.010        13.780000
# 32                   -0.479726      NMS            22.260         5.380000
# 33                   -1.592360      NYQ             7.680         4.410000
# 34                    1.729950      NMS           129.850        61.540000
# 35                   -9.647420      NCM           124.120         2.280000
# 36                    1.034020      NYQ            97.715        54.840000
# 37                    1.769530      NMS           291.200       128.500000
# 38                    1.050910      NMS           127.480        47.090000
# 39                    0.990375      NMS           514.640       344.790000
# 40                   -0.480912      NMS            69.780        44.500000
# 41                   -1.173520      NMS            45.310        31.440000
# 42                   -7.350100      NYQ            17.740         8.390000
# 43                   -3.982300      NYQ             5.480         3.700000
# 44                   -1.204240      NYQ            24.660        11.965000
# 45                    0.203113      NYQ            84.830        50.150000
# 46                    0.560228      NYQ            47.360        37.590000
# 47                    2.846970      NYQ             8.800         6.530000
# 48                   -1.732900      NYQ            90.620        52.280000
# 49                   -2.376100      NMS            19.065         8.925000
# 50                   -1.595740      NYQ            20.040        12.730000
# 51                   -8.328190      NYQ            21.380        10.060000
# 52                    0.085784      NMS            37.100        26.220000
# 53                   -3.371710      NYQ            29.290        14.210000
# 54                   -1.794650      NYQ            35.810        18.730000
# 55                   -1.156680      NYQ             9.970         4.570000
# 56                   -0.279024      NMS           444.650       142.580000
# 57                    0.686951      NYQ            65.050        10.020000
# 58                   -1.166590      NYQ           148.430        73.870000
# 59                   -0.209517      NYQ            38.960        13.895000
# 60                   -0.625064      NYQ            96.910        53.510000
# 61                    1.934830      NMS            60.950        16.890000
# 62                  -13.338400      NYQ            66.740        44.460000
# 63                   -0.579836      NYQ            52.610        27.660000
# 64                   10.813000      NYQ            22.530         6.040000
# 65                    0.384460      NYQ           251.600       118.860000
# 66                    0.545230      NMS           543.000       102.402000
# 67                    0.146532      NYQ            62.560        36.860000
# 68                  -11.164500      NYQ            37.960        23.580000
# 69                    0.528442      NYQ           248.280       133.570000
# 70                  -17.451400      NYQ            55.670        24.370000
# 71                   -4.173440      NYQ            23.630        15.820000
# 72                    0.437200      NGM           141.530        42.960000
# 73                   -2.377180      NYQ            15.930         9.380000
# 74                   -0.317552      NYQ            40.900        23.680000
# 75                   -2.268670      NYQ            69.980        34.740000
# 76                   -1.309760      NYQ            31.645        18.160000
# 77                   -1.355730      NMS            47.820        24.130000
# 78                   -1.486920      NYQ            61.240        38.960000
#
#    averageAnalystRating  dividendYield                        shortName  \
# 0      1.4 - Strong Buy           0.02               NVIDIA Corporation
# 1            3.1 - Hold            NaN                Lucid Group, Inc.
# 2            2.9 - Hold            NaN                 Plug Power, Inc.
# 3            2.6 - Hold            NaN                      Tesla, Inc.
# 4            3.0 - Hold           6.59               Ford Motor Company
# 5            3.0 - Hold            NaN       Palantir Technologies Inc.
# 6            3.0 - Hold            NaN                Intel Corporation
# 7            2.8 - Hold            NaN          SoFi Technologies, Inc.
# 8             2.1 - Buy            NaN    American Airlines Group, Inc.
# 9             2.0 - Buy           0.49                       Apple Inc.
# 10            1.6 - Buy            NaN      Applied Digital Corporation
# 11            2.4 - Buy            NaN              MARA Holdings, Inc.
# 12            1.7 - Buy            NaN     Advanced Micro Devices, Inc.
# 13           2.8 - Hold            NaN       Super Micro Computer, Inc.
# 14            2.0 - Buy            NaN          Robinhood Markets, Inc.
# 15            2.3 - Buy            NaN                         NIO Inc.
# 16     1.4 - Strong Buy            NaN                 Amazon.com, Inc.
# 17            1.5 - Buy           0.44                    Alphabet Inc.
# 18            1.6 - Buy           2.16      Bank of America Corporation
# 19     1.4 - Strong Buy            NaN             Riot Platforms, Inc.
# 20           2.8 - Hold            NaN                        Snap Inc.
# 21            2.0 - Buy          13.25                        VALE S.A.
# 22           3.4 - Hold            NaN         QuantumScape Corporation
# 23            2.4 - Buy            NaN            Cleveland-Cliffs Inc.
# 24     1.2 - Strong Buy            NaN                Bit Digital, Inc.
# 25            1.9 - Buy           5.20                        Amcor plc
# 26            2.0 - Buy           4.05                        AT&T Inc.
# 27            1.7 - Buy           0.58   Itau Unibanco Banco Holding SA
# 28                  NaN            NaN           Quantum Computing Inc.
# 29            1.7 - Buy           3.69  Huntington Bancshares Incorpora
# 30            1.5 - Buy            NaN                 CleanSpark, Inc.
# 31            1.6 - Buy            NaN             Carnival Corporation
# 32            2.3 - Buy            NaN                      Sunrun Inc.
# 33            2.2 - Buy           0.24             Hecla Mining Company
# 34            1.5 - Buy           0.42          Micron Technology, Inc.
# 35                  NaN            NaN           SharpLink Gaming, Inc.
# 36            1.6 - Buy            NaN          Uber Technologies, Inc.
# 37     1.4 - Strong Buy           0.83                    Broadcom Inc.
# 38            1.5 - Buy           0.33         Marvell Technology, Inc.
# 39     1.4 - Strong Buy           0.66            Microsoft Corporation
# 40            1.9 - Buy           2.39              Cisco Systems, Inc.
# 41            2.3 - Buy           3.69              Comcast Corporation
# 42           2.6 - Hold           7.45                  Stellantis N.V.
# 43            2.4 - Buy           3.14      Nokia Corporation Sponsored
# 44            2.1 - Buy           2.50  Hewlett Packard Enterprise Comp
# 45            2.0 - Buy           1.91            Wells Fargo & Company
# 46            2.3 - Buy           6.33      Verizon Communications Inc.
# 47            2.4 - Buy           2.61                         ADT Inc.
# 48            2.2 - Buy           2.08                       Nike, Inc.
# 49           2.6 - Hold            NaN                       Lyft, Inc.
# 50            2.2 - Buy           4.36                          KeyCorp
# 51           2.8 - Hold            NaN           Rocket Companies, Inc.
# 52            1.8 - Buy           1.49                  CSX Corporation
# 53            1.8 - Buy            NaN  Norwegian Cruise Line Holdings
# 54                  NaN            NaN             GameStop Corporation
# 55     1.4 - Strong Buy            NaN               Coeur Mining, Inc.
# 56            2.2 - Buy            NaN            Coinbase Global, Inc.
# 57            1.8 - Buy            NaN               MP Materials Corp.
# 58     1.3 - Strong Buy           0.86    Alibaba Group Holding Limited
# 59            2.2 - Buy            NaN              Unity Software Inc.
# 60            1.8 - Buy           2.50                  Citigroup, Inc.
# 61            1.7 - Buy            NaN            AST SpaceMobile, Inc.
# 62            1.7 - Buy            NaN     Chipotle Mexican Grill, Inc.
# 63            2.3 - Buy           1.31           Freeport-McMoRan, Inc.
# 64   3.6 - Underperform           4.07               Kohl's Corporation
# 65            1.8 - Buy           0.83               Oracle Corporation
# 66            1.6 - Buy            NaN       MicroStrategy Incorporated
# 67            1.9 - Buy           1.63              Newmont Corporation
# 68           3.0 - Hold           1.92       Southwest Airlines Company
# 69     1.4 - Strong Buy           1.37  Taiwan Semiconductor Manufactur
# 70           2.8 - Hold           9.22                         Dow Inc.
# 71            2.3 - Buy           2.81                  Infosys Limited
# 72            1.9 - Buy            NaN             The Trade Desk, Inc.
# 73           2.7 - Hold            NaN                     UiPath, Inc.
# 74            1.6 - Buy            NaN                  Pinterest, Inc.
# 75     1.5 - Strong Buy           1.34            Delta Air Lines, Inc.
# 76            1.8 - Buy            NaN                    Coupang, Inc.
# 77     1.4 - Strong Buy           2.95                     JD.com, Inc.
# 78            2.3 - Buy           1.23           General Motors Company
#
#    corporateActions  fiftyTwoWeekLowChange  fiftyTwoWeekLowChangePercent  \
# 0                []              87.120000                      1.005772
# 1                []               1.060000                      0.549223
# 2                []               1.080000                      1.565217
# 3                []             123.299990                      0.677473
# 4                []               2.820001                      0.334123
# 5                []             133.630000                      6.294395
# 6                []               4.959999                      0.280702
# 7                []              15.500000                      2.579035
# 8                []               2.960000                      0.348235
# 9                []              44.549988                      0.263282
# 10               []               8.190000                      2.720930
# 11               []               7.450000                      0.759429
# 12               []              85.639990                      1.119770
# 13               []              35.270000                      2.044638
# 14               []              87.950000                      6.291130
# 15               []               1.810000                      0.599338
# 16               []              80.619995                      0.531759
# 17               []              51.640000                      0.367466
# 18               []              15.320000                      0.463260
# 19               []               8.500000                      1.373182
# 20               []               2.660000                      0.375706
# 21               []               2.169999                      0.269231
# 22               []               9.230000                      2.714706
# 23               []               5.280000                      0.937833
# 24               []               1.540000                      0.911243
# 25               []               1.390000                      0.166069
# 26               []               9.280001                      0.497854
# 27               []               1.931818                      0.437243
# 28               []              16.420000                     30.981134
# 29               []               4.719999                      0.395973
# 30               []               5.888000                      0.912585
# 31               []              16.000000                      1.161103
# 32               []               5.200000                      0.966543
# 33               []               1.770000                      0.401361
# 34               []              50.190002                      0.815567
# 35               []              21.039999                      9.228070
# 36               []              36.030003                      0.657002
# 37               []             160.209990                      1.246770
# 38               []              26.950000                      0.572308
# 39               []             166.090000                      0.481713
# 40               []              23.790000                      0.534607
# 41               []               3.929998                      0.125000
# 42               []               1.190000                      0.141835
# 43               []               0.640000                      0.172973
# 44               []               8.545000                      0.714166
# 45               []              33.720000                      0.672383
# 46               []               5.490002                      0.146050
# 47               []               2.140000                      0.327718
# 48               []              23.140000                      0.442617
# 49               []               5.455000                      0.611204
# 50               []               5.770001                      0.453260
# 51               []               4.799999                      0.477137
# 52               []               8.780001                      0.334859
# 53               []               9.290000                      0.653765
# 54               []               4.800001                      0.256273
# 55               []               4.829999                      1.056893
# 56               []             254.120010                      1.782298
# 57               []              51.540000                      5.143713
# 58               []              47.280000                      0.640043
# 59               []              19.445000                      1.399424
# 60               []              41.880000                      0.782658
# 61               []              43.170002                      2.555950
# 62               []               1.280003                      0.028790
# 63               []              16.920002                      0.611714
# 64               []               7.590000                      1.256623
# 65               []             123.970000                      1.042992
# 66               []             312.518000                      3.051874
# 67               []              24.649998                      0.668747
# 68               []               9.679998                      0.410517
# 69               []             108.030000                      0.808789
# 70               []               0.699999                      0.028724
# 71               []               1.860001                      0.117573
# 72               []              42.040000                      0.978585
# 73               []               2.940000                      0.313433
# 74               []              13.989998                      0.590794
# 75               []              19.969997                      0.574842
# 76               []              11.980000                      0.659692
# 77               []               9.340002                      0.387070
# 78               []              13.380001                      0.343429
#
#    fiftyTwoWeekRange  fiftyTwoWeekHighChange  fiftyTwoWeekHighChangePercent  \
# 0     86.62 - 174.25               -0.509995                      -0.002927
# 1        1.93 - 4.43               -1.440000                      -0.325056
# 2        0.69 - 3.32               -1.550000                      -0.466867
# 3     182.0 - 488.54             -183.240020                      -0.375077
# 4       8.44 - 11.97               -0.710000                      -0.059315
# 5     21.23 - 155.68               -0.819992                      -0.005267
# 6      17.67 - 31.56               -8.930000                      -0.282953
# 7       6.01 - 22.74               -1.229999                      -0.054090
# 8         8.5 - 19.1               -7.640000                      -0.400000
# 9     169.21 - 260.1              -46.340010                      -0.178162
# 10      3.01 - 15.42               -4.220000                      -0.273671
# 11      9.81 - 30.28              -13.020000                      -0.429987
# 12    76.48 - 174.05              -11.930008                      -0.068544
# 13    17.25 - 73.001              -20.480999                      -0.280558
# 14   13.98 - 113.439              -11.509003                      -0.101455
# 15       3.02 - 7.71               -2.880000                      -0.373541
# 16   151.61 - 242.52              -10.290009                      -0.042430
# 17   140.53 - 207.05              -14.880005                      -0.071867
# 18     33.07 - 49.31               -0.920002                      -0.018658
# 19      6.19 - 15.87               -1.180000                      -0.074354
# 20      7.08 - 13.95               -4.210000                      -0.301792
# 21      8.06 - 12.05               -1.820001                      -0.151037
# 22       3.4 - 15.03               -2.400000                      -0.159681
# 23      5.63 - 15.71               -4.800000                      -0.305538
# 24       1.69 - 5.74               -2.510000                      -0.437282
# 25      8.37 - 11.48               -1.719999                      -0.149826
# 26     18.64 - 29.19               -1.270001                      -0.043508
# 27   4.418182 - 6.95               -0.600000                      -0.086331
# 28      0.53 - 27.15              -10.199999                      -0.375691
# 29     11.92 - 18.45               -1.810001                      -0.098103
# 30     6.452 - 18.05               -5.709999                      -0.316343
# 31     13.78 - 31.01               -1.229999                      -0.039665
# 32      5.38 - 22.26              -11.680000                      -0.524708
# 33       4.41 - 7.68               -1.500000                      -0.195312
# 34    61.54 - 129.85              -18.120003                      -0.139546
# 35     2.28 - 124.12             -100.800000                      -0.812117
# 36    54.84 - 97.715               -6.844994                      -0.070051
# 37     128.5 - 291.2               -2.490021                      -0.008551
# 38    47.09 - 127.48              -53.440002                      -0.419203
# 39   344.79 - 514.64               -3.760010                      -0.007306
# 40      44.5 - 69.78               -1.489998                      -0.021353
# 41     31.44 - 45.31               -9.940002                      -0.219378
# 42      8.39 - 17.74               -8.160000                      -0.459977
# 43        3.7 - 5.48               -1.140000                      -0.208029
# 44    11.965 - 24.66               -4.150000                      -0.168289
# 45     50.15 - 84.83               -0.959999                      -0.011317
# 46     37.59 - 47.36               -4.279999                      -0.090372
# 47        6.53 - 8.8               -0.130000                      -0.014773
# 48     52.28 - 90.62              -15.200005                      -0.167733
# 49    8.925 - 19.065               -4.685000                      -0.245738
# 50     12.73 - 20.04               -1.540001                      -0.076846
# 51     10.06 - 21.38               -6.519999                      -0.304958
# 52      26.22 - 37.1               -2.099998                      -0.056604
# 53     14.21 - 29.29               -5.790001                      -0.197678
# 54     18.73 - 35.81              -12.280001                      -0.342921
# 55       4.57 - 9.97               -0.570001                      -0.057172
# 56   142.58 - 444.65              -47.949980                      -0.107838
# 57     10.02 - 65.05               -3.490002                      -0.053651
# 58    73.87 - 148.43              -27.279991                      -0.183790
# 59    13.895 - 38.96               -5.619999                      -0.144250
# 60     53.51 - 96.91               -1.520004                      -0.015685
# 61     16.89 - 60.95               -0.889999                      -0.014602
# 62     44.46 - 66.74              -20.999996                      -0.314654
# 63     27.66 - 52.61               -8.029999                      -0.152633
# 64      6.04 - 22.53               -8.900001                      -0.395029
# 65    118.86 - 251.6               -8.770004                      -0.034857
# 66   102.402 - 543.0             -128.079990                      -0.235875
# 67     36.86 - 62.56               -1.050003                      -0.016784
# 68     23.58 - 37.96               -4.700001                      -0.123815
# 69   133.57 - 248.28               -6.679993                      -0.026905
# 70     24.37 - 55.67              -30.599998                      -0.549668
# 71     15.82 - 23.63               -5.949999                      -0.251798
# 72    42.96 - 141.53              -56.530000                      -0.399421
# 73      9.38 - 15.93               -3.610001                      -0.226616
# 74      23.68 - 40.9               -3.230003                      -0.078973
# 75     34.74 - 69.98              -15.270004                      -0.218205
# 76    18.16 - 31.645               -1.505001                      -0.047559
# 77     24.13 - 47.82              -14.349998                      -0.300084
# 78     38.96 - 61.24               -8.900002                      -0.145330
#
#     fiftyTwoWeekChangePercent  dividendDate  earningsTimestamp  \
# 0                   53.670620  1.751501e+09       1.756325e+09
# 1                  -11.538464           NaN       1.754424e+09
# 2                  -28.915660           NaN       1.745843e+09
# 3                   38.899006           NaN       1.753301e+09
# 4                    0.625563  1.748822e+09       1.753906e+09
# 5                  469.757170           NaN       1.754338e+09
# 6                  -27.814991  1.725149e+09       1.753387e+09
# 7                  190.283390           NaN       1.753792e+09
# 8                    7.909608  1.582070e+09       1.753360e+09
# 9                   -1.926959  1.747267e+09       1.753992e+09
# 10                 152.252240           NaN       1.753906e+09
# 11                 -19.981457  1.554682e+09       1.753819e+09
# 12                  15.808272           NaN       1.754424e+09
# 13                 -26.255630           NaN       1.754424e+09
# 14                 380.801880           NaN       1.753906e+09
# 15                   9.029341  1.462147e+09       1.748950e+09
# 16                  27.249313           NaN       1.753992e+09
# 17                  15.071857  1.750032e+09       1.753301e+09
# 18                  16.126705  1.750982e+09       1.760531e+09
# 19                  31.160713  1.508285e+09       1.753992e+09
# 20                 -26.931732           NaN       1.754424e+09
# 21                  -5.801106  1.742515e+09                NaN
# 22                  79.403410           NaN       1.753301e+09
# 23                 -29.476404  1.586909e+09       1.753101e+09
# 24                 -11.263734           NaN       1.747339e+09
# 25                  -5.973023  1.749514e+09       1.746043e+09
# 26                  46.870064  1.754006e+09       1.753274e+09
# 27                  15.264023  1.767917e+09       1.754424e+09
# 28                2202.989300  1.530576e+09       1.747340e+09
# 29                   9.980166  1.751328e+09       1.752842e+09
# 30                 -27.920563  1.576022e+09       1.746735e+09
# 31                  72.437750  1.584058e+09       1.750768e+09
# 32                 -40.761480           NaN       1.754510e+09
# 33                   9.380531  1.749514e+09       1.754510e+09
# 34                   2.120459  1.753142e+09       1.750889e+09
# 35                 235.057480  1.504656e+09       1.747339e+09
# 36                  41.102480           NaN       1.754483e+09
# 37                  90.404274  1.751242e+09       1.749154e+09
# 38                  12.659764  1.753920e+09       1.748549e+09
# 39                  20.130741  1.757549e+09       1.753906e+09
# 40                  42.627407  1.753229e+09       1.747253e+09
# 41                 -10.884357  1.753229e+09       1.753965e+09
# 42                 -45.753117  1.746403e+09       1.753792e+09
# 43                  13.020838  1.747267e+09       1.753360e+09
# 44                   3.795552  1.752710e+09       1.748981e+09
# 45                  38.880610  1.748736e+09       1.760445e+09
# 46                   7.458222  1.754006e+09       1.761050e+09
# 47                  12.160408  1.751933e+09       1.753360e+09
# 48                   3.941560  1.751328e+09       1.750968e+09
# 49                  17.579723           NaN       1.754510e+09
# 50                  12.393677  1.757894e+09       1.760618e+09
# 51                  -6.599623  1.743638e+09       1.753992e+09
# 52                   1.981354  1.757894e+09       1.753301e+09
# 53                  27.233350           NaN       1.753965e+09
# 54                  -2.486533  1.529971e+09       1.749586e+09
# 55                  49.920260           NaN       1.754510e+09
# 56                  63.298070           NaN       1.753992e+09
# 57                 342.877700           NaN       1.754597e+09
# 58                  58.303930  1.752106e+09       1.747302e+09
# 59                 100.722460           NaN       1.754483e+09
# 60                  46.348570  1.755821e+09       1.760445e+09
# 61                 218.789810           NaN       1.747082e+09
# 62                  -8.207905           NaN       1.753301e+09
# 63                  -0.933331  1.754006e+09       1.753274e+09
# 64                 -33.544613  1.750810e+09       1.748516e+09
# 65                  74.685270  1.753315e+09       1.749676e+09
# 66                 136.730550  1.747872e+09       1.753992e+09
# 67                  31.628502  1.750378e+09       1.753387e+09
# 68                  22.144700  1.752019e+09       1.753360e+09
# 69                  49.191060  1.759968e+09       1.752755e+09
# 70                 -52.572834  1.749773e+09       1.753360e+09
# 71                 -22.422117  1.751414e+09       1.760618e+09
# 72                  -8.038515           NaN       1.754597e+09
# 73                  -0.323623           NaN       1.748549e+09
# 74                   0.319576           NaN       1.754597e+09
# 75                  23.974620  1.755734e+09       1.752151e+09
# 76                  49.355793           NaN       1.754424e+09
# 77                  26.016570  1.745885e+09       1.747127e+09
# 78                  18.631004  1.750291e+09       1.761050e+09
#
#     earningsTimestampStart  earningsTimestampEnd  earningsCallTimestampStart  \
# 0               1756324800            1756324800                1.748466e+09
# 1               1754424000            1754424000                1.754429e+09
# 2               1754483400            1754915400                1.741095e+09
# 3               1761163200            1761163200                1.753306e+09
# 4               1753905600            1753905600                1.753909e+09
# 5               1754337600            1754337600                1.754341e+09
# 6               1753387200            1753387200                1.753391e+09
# 7               1753792200            1753792200                1.753790e+09
# 8               1753360200            1753360200                1.753360e+09
# 9               1753992000            1753992000                1.753996e+09
# 10              1753905600            1753905600                1.753909e+09
# 11              1753819200            1753819200                1.753823e+09
# 12              1754424000            1754424000                1.754428e+09
# 13              1754424000            1754424000                1.754428e+09
# 14              1753905600            1753905600                1.753909e+09
# 15              1756902600            1757334600                1.748952e+09
# 16              1753992000            1753992000                1.753996e+09
# 17              1753300800            1753300800                1.753303e+09
# 18              1760531400            1760531400                1.760531e+09
# 19              1753992000            1753992000                1.753994e+09
# 20              1754424000            1754424000                1.754428e+09
# 21              1753297200            1753729200                1.745590e+09
# 22              1761163200            1761163200                1.753304e+09
# 23              1753101000            1753101000                1.746707e+09
# 24              1755547200            1755547200                1.747404e+09
# 25              1755201600            1755201600                1.746049e+09
# 26              1761136200            1761136200                1.753274e+09
# 27              1754424000            1754424000                1.754478e+09
# 28              1755201600            1755201600                1.747341e+09
# 29              1760704200            1760704200                1.760706e+09
# 30              1754564340            1754913600                1.746736e+09
# 31              1750768200            1750768200                1.750774e+09
# 32              1754510400            1754510400                1.754512e+09
# 33              1754510400            1754510400                1.746194e+09
# 34              1758744000            1758744000                1.750883e+09
# 35              1755201600            1755201600                         NaN
# 36              1754483400            1754483400                1.754482e+09
# 37              1756897140            1757332800                1.756327e+09
# 38              1756411200            1756411200                1.748552e+09
# 39              1753905600            1753905600                1.753911e+09
# 40              1754996340            1755518400                1.755117e+09
# 41              1753101000            1753446600                1.753965e+09
# 42              1753792200            1753792200                1.753819e+09
# 43              1753360200            1753360200                1.753346e+09
# 44              1756929600            1756929600                1.748984e+09
# 45              1760445000            1760445000                1.760450e+09
# 46              1761049800            1761049800                1.761050e+09
# 47              1753360200            1753360200                1.753366e+09
# 48              1759262400            1759262400                1.750972e+09
# 49              1754510400            1754510400                1.754514e+09
# 50              1760617800            1760617800                1.760623e+09
# 51              1753992000            1753992000                1.753994e+09
# 52              1760558400            1760558400                1.753303e+09
# 53              1753965000            1753965000                1.753963e+09
# 54              1757329140            1757678400                         NaN
# 55              1754510400            1754510400                1.746716e+09
# 56              1753992000            1753992000                1.753997e+09
# 57              1754596800            1754596800                1.754600e+09
# 58              1755088200            1755520200                1.747309e+09
# 59              1754483400            1754483400                1.754483e+09
# 60              1760445000            1760445000                1.760454e+09
# 61              1754996340            1755518400                1.741126e+09
# 62              1753300800            1753300800                1.753303e+09
# 63              1761049800            1761049800                1.753279e+09
# 64              1756297800            1756297800                1.748524e+09
# 65              1757361600            1757361600                1.749676e+09
# 66              1753992000            1753992000                1.746133e+09
# 67              1753387200            1753387200                1.753393e+09
# 68              1761163200            1761163200                1.761237e+09
# 69              1760617800            1760617800                1.752732e+09
# 70              1753360200            1753360200                1.761221e+09
# 71              1760617800            1760617800                1.753272e+09
# 72              1754596800            1754596800                1.754600e+09
# 73              1756897140            1757332800                1.748552e+09
# 74              1754596800            1754596800                1.754599e+09
# 75              1760013000            1760013000                1.752156e+09
# 76              1754424000            1754424000                1.754429e+09
# 77              1755088200            1755520200                1.747138e+09
# 78              1761049800            1761049800                1.746103e+09
#
#     earningsCallTimestampEnd  isEarningsDateEstimate  \
# 0               1.748466e+09                   False
# 1               1.754429e+09                   False
# 2               1.741095e+09                    True
# 3               1.753306e+09                    True
# 4               1.753909e+09                   False
# 5               1.754341e+09                   False
# 6               1.753391e+09                   False
# 7               1.753790e+09                   False
# 8               1.753360e+09                   False
# 9               1.753996e+09                   False
# 10              1.753909e+09                   False
# 11              1.753823e+09                   False
# ...
# 57             60.870                  13912778                 30396620
# 58            121.850                  13858354                 16830780
# 59             33.500                  13766959                 17515970
# 60             96.290                  13624959                 19200860
# 61             58.920                  13523555                 11863440
# 62             46.200                  13459981                 19061160
# 63             44.955                  13127244                 14780340
# 64             12.335                  13020501                 32847170
# 65            242.410                  12751883                 10640030
# 66            414.370                  12545431                 13018860
# 67             60.680                  12271229                 13830390
# 68             36.095                  12207637                 13972470
# 69            240.205                  12111137                 13532260
# 70             27.190                  11646422                 16339760
# 71             17.880                  11380014                 15367530
# 72             84.770                  11105131                 23558870
# 73             12.600                  11032945                 14686310
# 74             37.910                  10919718                  8512870
# 75             55.450                  10867609                 10756120
# 76             30.610                  10709401                  8953490
# 77             33.930                  10665006                 11345400
# 78             52.970                  10592637                 12662470
#
#                                    displayName symbol ipoExpectedDate  \
# 0                                       NVIDIA   NVDA             NaN
# 1                                        Lucid   LCID      2021-07-26
# 2                                   Plug Power   PLUG             NaN
# 3                                        Tesla   TSLA             NaN
# 4                                          NaN      F             NaN
# 5                                     Palantir   PLTR      2024-11-26
# 6                                        Intel   INTC             NaN
# 7                                         SoFi   SOFI      2021-06-01
# 8                            American Airlines    AAL             NaN
# 9                                        Apple   AAPL             NaN
# 10                             Applied Digital   APLD      2022-04-13
# 11                                        MARA   MARA             NaN
# 12                      Advanced Micro Devices    AMD             NaN
# 13                        Super Micro Computer   SMCI             NaN
# 14                           Robinhood Markets   HOOD      2021-07-29
# 15                                         NIO    NIO             NaN
# 16                                  Amazon.com   AMZN             NaN
# 17                                         NaN  GOOGL             NaN
# 18                             Bank of America    BAC             NaN
# 19                              Riot Platforms   RIOT             NaN
# 20                                        Snap   SNAP             NaN
# 21                                        Vale   VALE             NaN
# 22                                QuantumScape     QS             NaN
# 23                            Cleveland-Cliffs    CLF             NaN
# 24                                 Bit Digital   BTBT             NaN
# 25                                       Amcor   AMCR             NaN
# 26                                        AT&T      T             NaN
# 27                       Itaú Unibanco Holding   ITUB             NaN
# 28                           Quantum Computing   QUBT      2021-07-15
# 29                                         NaN   HBAN             NaN
# 30                                  CleanSpark   CLSK             NaN
# 31                      Carnival Corporation &    CCL             NaN
# 32                                      Sunrun    RUN             NaN
# 33                                         NaN     HL             NaN
# 34                           Micron Technology     MU             NaN
# 35                            SharpLink Gaming   SBET             NaN
# 36                                        Uber   UBER             NaN
# 37                                    Broadcom   AVGO             NaN
# 38                          Marvell Technology   MRVL             NaN
# 39                                   Microsoft   MSFT             NaN
# 40                               Cisco Systems   CSCO             NaN
# 41                                         NaN  CMCSA             NaN
# 42                                  Stellantis   STLA             NaN
# 43                                       Nokia    NOK             NaN
# 44                                         NaN    HPE             NaN
# 45                                         NaN    WFC             NaN
# 46                      Verizon Communications     VZ             NaN
# 47                                         ADT    ADT             NaN
# 48                                        NIKE    NKE             NaN
# 49                                        Lyft   LYFT             NaN
# 50                                         NaN    KEY             NaN
# 51                            Rocket Companies    RKT      2020-08-06
# 52                                         CSX    CSX             NaN
# 53                       Norwegian Cruise Line   NCLH             NaN
# 54                                    GameStop    GME             NaN
# 55                                Coeur Mining    CDE             NaN
# 56                             Coinbase Global   COIN      2021-04-14
# 57                                MP Materials     MP             NaN
# 58                       Alibaba Group Holding   BABA             NaN
# 59                              Unity Software      U      2020-09-18
# 60                                   Citigroup      C             NaN
# 61                             AST SpaceMobile   ASTS             NaN
# 62                      Chipotle Mexican Grill    CMG             NaN
# 63                            Freeport-McMoRan    FCX             NaN
# 64                                      Kohl's    KSS             NaN
# 65                                      Oracle   ORCL             NaN
# 66                                         NaN   MSTR             NaN
# 67                                     Newmont    NEM             NaN
# 68                          Southwest Airlines    LUV             NaN
# 69  Taiwan Semiconductor Manufacturing Company    TSM             NaN
# 70                                         Dow    DOW             NaN
# 71                                     Infosys   INFY             NaN
# 72                              The Trade Desk    TTD             NaN
# 73                                      UiPath   PATH      2021-04-21
# 74                                   Pinterest   PINS             NaN
# 75                             Delta Air Lines    DAL             NaN
# 76                                     Coupang   CPNG      2021-03-11
# 77                                      JD.com     JD             NaN
# 78                                         NaN     GM             NaN
#
#    prev_day_price prev_day_volume        price_volume historical_volatility  \
# 0      170.779999       154082200  26314157927.911377              0.260627
# 1            3.08       181511400    559055098.151779              1.286375
# 2            1.81        68101300    123263349.103212              1.409719
# 3      332.559998        92553800  30779691502.038574              0.553936
# 4           11.38        76163200    866737224.716187              0.297705
# 5      154.630005        48062000   7431827294.677734              0.515426
# 6           23.49        68711700    1614037817.27314              0.390701
# 7       21.559999        49653700   1070533745.482063              0.394418
# 8           12.68        75685400    959690895.097351              0.635021
# 9      214.149994        46989300  10062758308.200073              0.147295
# 10          10.93        17567100    192008408.361053              0.790015
# 11          17.57       138542800   2434196953.720093              0.802481
# 12     158.649994        41510900   6585704031.637573              0.379563
# 13      51.700001        25249600   1305404339.263916              0.489941
# 14     102.080002        33805200    3450834877.89917              0.616974
# 15           4.92       108246500    532572788.258553              0.591832
# 16     228.289993        28294900   6459442531.031799              0.203662
# 17     190.229996        58681900  11163057586.283875              0.190084
# 18      48.139999        31380100   1510637994.847107              0.193392
# 19          14.34        65549400    939978406.002045              0.535574
# 20          10.07        28357200    285556995.346069              0.488327
# 21           10.4        62197000    646848776.273727               0.34457
# 22          12.83        78357300   1005324153.021812              1.675343
# 23          11.27        33990200    383069569.559479              0.734384
# 24           3.36        30684100     103098572.78111              1.447675
# 25           9.81        18275700    179284624.668789              0.221107
# 26          27.75        65616300        1820852325.0              0.183771
# 27           6.45        33797400    217993223.553658              0.272738
# 28      17.469999        15793900     275919422.15519              0.961079
# 29          16.82        38911700    654494782.125092               0.22599
# 30          12.45        20137100    250706891.159153              0.681567
# 31          30.74        22087400    678966670.944595              0.317087
# 32          10.64        14608600    155435509.015465              1.047343
# 33           6.28        17962000    112801363.768578               0.55897
# 34     109.830002        17810000   1956072332.611084              0.330582
# 35      25.809999        36592300    944447243.457603              2.138447
# 36      89.940002        18617900   1674493971.453857              0.242409
# 37     283.690002        20556200   5831588428.186035              0.296536
# 38      73.269997        11239000    823481492.271423              0.381381
# 39     505.869995        16396600   8294547961.938477                0.1167
# 40      68.620003        13042300    894962661.821747              0.135062
# 41      35.790001        16430400     588044031.04248              0.203795
# 42          10.34        56235300    581473010.580826              0.592521
# 43           4.52        41256000    186477119.213104              0.286502
# 44          20.76        16135000    334962603.693008              0.457758
# 45      83.699997        19379200   1622038980.859375              0.272241
# 46          42.84        23357200   1000622451.564026              0.197746
# 47           8.43        12848300     108311172.92099              0.204575
# 48          76.75        16428100        1260856675.0              0.577287
# 49          14.73        12189000    179543964.420319              0.316474
# 50      18.799999        44310800    833043006.193542              0.225185
# 51      16.209999        64280900   1041993330.149078              0.577592
# 52      34.970001        32168300   1124925490.267944              0.217748
# 53          24.32        14824500    360531835.475922              0.379803
# 54      23.959999         8305100    198990188.396454              0.329221
# 55           9.51        11714500    111404897.681236              0.454201
# 56     397.809998        12433200   4946051261.645508              0.501875
# 57      61.139999        12451400    761278588.400269              1.685336
# 58     122.580002        12874200   1578119459.573364              0.393395
# 59          33.41        14145500    472601152.841568              0.701427
# 60      95.989998        22339800   2144397354.277039              0.244097
# 61      58.919998         9828300    579083418.003845               0.60745
# 62      52.779999        20980500   1107350764.389038               0.56818
# 63          44.84        23135900   1037413759.530258              0.379837
# 64           12.3        44989000    553364708.580971              1.375103
# 65     241.899994         7255800   1755177975.714111              0.333209
# 66     412.670013        12990000    5360583474.42627              0.589297
# 67      61.419998        13305100    817199217.637634              0.391293
# 68      37.439999        12692500    475207182.569504              0.557245
# 69     240.330002         9885400   2375758200.100708              0.297597
# 70      30.370001        20963300    636655438.593102              0.823971
# 71      18.450001        24739700    456447483.874893               0.24662
# 72      84.629997         8909600    754019423.529053              0.334225
# 73          12.62        14496800    182949614.340973               0.29555
# 74      37.790001         6083200    229884133.569336              0.186217
# 75          55.98         6782300    379673150.895309              0.473063
# 76      30.540001        14876000    454313053.619385              0.248838
# 77          33.93         8726200    296079968.663025              0.307696
# 78      53.130001        25657000   1363156437.404633              0.498854
#
#       avg_iv iv/hv_ratio
# 0   0.357428    1.371416
# 1   1.029299    0.800155
# 2   1.871097    1.327284
# 3   0.757633    1.367727
# 4   0.484380    1.627045
# 5   0.424261    0.823128
# 6   1.384767    3.544311
# 7   0.705081     1.78765
# 8   0.738285    1.162615
# 9   0.311286    2.113346
# 10  1.107424    1.401777
# 11  0.807131    1.005795
# 12  0.465398    1.226144
# 13  0.608891    1.242784
# 14  0.707950    1.147455
# 15  0.880861    1.488362
# 16  0.423224    2.078072
# 17  0.370795    1.950688
# 18  0.231575    1.197438
# 19  0.869630    1.623735
# 20  0.622074    1.273888
# 21  0.421881    1.224369
# 22  1.312503    0.783424
# 23  0.715823    0.974726
# 24  1.355472     0.93631
# 25  0.316413    1.431042
# 26  0.285652    1.554389
# 27  0.357428     1.31052
# 28  0.917483    0.954638
# 29  0.277351    1.227273
# 30  0.914066    1.341124
# 31  0.439459    1.385926
# 32  1.013024    0.967233
# 33  0.589848    1.055241
# 34  0.441717    1.336181
# 35  3.896487    1.822111
# 36  0.345282    1.424377
# 37  0.430914    1.453157
# 38  0.515996    1.352967
# 39  0.290565     2.48985
# 40  0.178475    1.321434
# 41  0.518560    2.544516
# 42  1.265629    2.136007
# 43  0.710940    2.481446
# 44  0.543950    1.188292
# 45  0.223478    0.820883
# 46  0.184456    0.932793
# 47  0.472662    2.310461
# 48  0.356452    0.617461
# 49  0.441412    1.394783
# 50  0.381842    1.695681
# 51  0.950197      1.6451
# 52  0.415696    1.909067
# 53  0.585942    1.542753
# 54  0.529790    1.609222
# 55  0.569991    1.254933
# 56  0.630497    1.256284
# 57  0.766278    0.454674
# 58  0.439296    1.116679
# 59  0.769534    1.097097
# 60  0.243904     0.99921
# 61  0.853517    1.405082
# 62  0.902348    1.588138
# 63  0.372077    0.979569
# 64  1.489260    1.083017
# 65  0.355475    1.066824
# 66  0.498072    0.845198
# 67  1.029138    2.630094
# 68  1.179689    2.117002
# 69  0.329078    1.105783
# 70  3.191409    3.873205
# 71  0.258634    1.048714
# 72  0.438970    1.313397
# 73  0.534510    1.808524
# 74  0.376471    2.021683
# 75  0.396246    0.837618
# 76  0.470708    1.891628
# 77  0.445074    1.446473
# 78  0.325934    0.653367

# %%
import yfinance as yf
import numpy as np
from hmmlearn.hmm import GaussianHMM
from tqdm import tqdm

def get_last_120_returns(symbol):
    """Get last 120 days of daily log returns for a symbol."""
    try:
        data = yf.Ticker(symbol).history(period="130d")
        closes = data['Close'].dropna()
        if len(closes) < 121:
            return None
        returns = np.log(closes / closes.shift(1)).dropna()
        return returns[-120:]
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

def fit_hmm_and_stats(returns, n_states=3):
    """Fit HMM to returns, return means, stds, and state sequence."""
    model = GaussianHMM(
        n_components=n_states,
        covariance_type="diag",
        n_iter=500,
        tol=1e-2,
        random_state=42,
        verbose=False
    )
    X = returns.values.reshape(-1, 1)
    model.fit(X)
    hidden_states = model.predict(X)
    means = model.means_.flatten()
    stds = np.sqrt(np.array([np.diag(cov)[0] for cov in model.covars_]))
    return hidden_states, means, stds

def hmm_analysis(symbol):
    returns = get_last_120_returns(symbol)
    if returns is None:
        return {
            "hmm_mean_0": None,
            "hmm_std_0": None,
            "hmm_mean_1": None,
            "hmm_std_1": None,
            "hmm_mean_2": None,
            "hmm_std_2": None,
            "pct_last30_in_highest_stdev_state": None,
            "highest_stdev_state": None
        }
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    # Identify the state with the highest stdev
    high_stdev_state = int(np.argmax(stds))
    last30 = hidden_states[-30:]
    pct_high = np.mean(last30 == high_stdev_state) * 100
    return {
        "hmm_mean_0": means[0],
        "hmm_std_0": stds[0],
        "hmm_mean_1": means[1],
        "hmm_std_1": stds[1],
        "hmm_mean_2": means[2],
        "hmm_std_2": stds[2],
        "pct_last30_in_highest_stdev_state": pct_high,
        "highest_stdev_state": high_stdev_state
    }

# --- Apply to filterdf ---

filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()

for col in [
    'hmm_mean_0','hmm_std_0',
    'hmm_mean_1','hmm_std_1',
    'hmm_mean_2','hmm_std_2',
    'pct_last30_in_highest_stdev_state',
    'highest_stdev_state'
]:
    filterdf[col] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    hmm_stats = hmm_analysis(symbol)
    for col in hmm_stats:
        filterdf.at[idx, col] = hmm_stats[col]

# filterdf now has the HMM columns for states 0, 1, 2, and the % of last 30 closes in the highest stdev state.
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Model is not converging.  Current: 250.28804324156005 is not greater than 250.29019346407003. Delta is -0.0021502225099823136
#   6%|▋         | 5/79 [00:01<00:19,  3.72it/s]Model is not converging.  Current: 198.38908695714406 is not greater than 198.4211117851402. Delta is -0.03202482799613904
#   9%|▉         | 7/79 [00:01<00:17,  4.22it/s]Model is not converging.  Current: 221.22709121808649 is not greater than 221.24990603266616. Delta is -0.022814814579675158
#  16%|█▋        | 13/79 [00:03<00:15,  4.29it/s]Model is not converging.  Current: 168.49629344990134 is not greater than 168.49702392631966. Delta is -0.0007304764183118095
#  22%|██▏       | 17/79 [00:03<00:13,  4.67it/s]Model is not converging.  Current: 287.050518141094 is not greater than 287.059963634226. Delta is -0.0094454931319774
#  34%|███▍      | 27/79 [00:06<00:13,  3.87it/s]Model is not converging.  Current: 310.32710329862493 is not greater than 310.6392610106887. Delta is -0.3121577120637653
#  38%|███▊      | 30/79 [00:07<00:13,  3.63it/s]Model is not converging.  Current: 181.07943395791276 is not greater than 181.0869929050101. Delta is -0.007558947097351165
#  51%|█████     | 40/79 [00:09<00:09,  4.04it/s]Model is not converging.  Current: 343.4561635222556 is not greater than 343.47957090942197. Delta is -0.02340738716634405
#  54%|█████▍    | 43/79 [00:10<00:09,  3.90it/s]Model is not converging.  Current: 301.5520438802553 is not greater than 301.7362838227309. Delta is -0.1842399424755854
#  58%|█████▊    | 46/79 [00:11<00:09,  3.63it/s]Model is not converging.  Current: 337.8191901876249 is not greater than 337.957368949087. Delta is -0.13817876146214303
#  80%|███████▉  | 63/79 [00:15<00:03,  4.18it/s]Model is not converging.  Current: 258.9526917009864 is not greater than 259.03425961035333. Delta is -0.0815679093669246
#  85%|████████▍ | 67/79 [00:16<00:02,  4.45it/s]Model is not converging.  Current: 271.83889270439255 is not greater than 271.85334118177514. Delta is -0.014448477382586589
#  87%|████████▋ | 69/79 [00:16<00:02,  4.30it/s]Model is not converging.  Current: 270.5454708098928 is not greater than 270.56801512409487. Delta is -0.022544314202093574
#  90%|████████▉ | 71/79 [00:17<00:01,  4.51it/s]Model is not converging.  Current: 313.15658123538935 is not greater than 313.3775412739705. Delta is -0.2209600385811541
# 100%|██████████| 79/79 [00:18<00:00,  4.18it/s]

# %%
N = 252  # Or use 261, depending on your convention

def pct_regimes_higher_than_iv(hidden_states, stds, avg_iv):
    """% of regimes in last 30 days with annualized stdev higher than avg_iv."""
    last30 = hidden_states[-30:]
    # Annualize regime stdevs
    stds_annualized = stds * np.sqrt(N)
    last30_vols_annualized = stds_annualized[last30]
    pct_higher = np.mean(last30_vols_annualized > avg_iv) * 100
    return pct_higher

filterdf['pct_regimes_last30_higher_than_avg_iv'] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    avg_iv = row['avg_iv']
    returns = get_last_120_returns(symbol)
    if returns is None or avg_iv is None:
        filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = None
        continue
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    pct_higher = pct_regimes_higher_than_iv(hidden_states, stds, avg_iv)
    filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = pct_higher
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Model is not converging.  Current: 250.28804324156005 is not greater than 250.29019346407003. Delta is -0.0021502225099823136
#   6%|▋         | 5/79 [00:01<00:21,  3.48it/s]Model is not converging.  Current: 198.38908695714406 is not greater than 198.4211117851402. Delta is -0.03202482799613904
#   9%|▉         | 7/79 [00:01<00:18,  3.98it/s]Model is not converging.  Current: 221.22709121808649 is not greater than 221.24990603266616. Delta is -0.022814814579675158
#  16%|█▋        | 13/79 [00:03<00:16,  4.12it/s]Model is not converging.  Current: 168.49629344990134 is not greater than 168.49702392631966. Delta is -0.0007304764183118095
#  22%|██▏       | 17/79 [00:04<00:13,  4.43it/s]Model is not converging.  Current: 287.050518141094 is not greater than 287.059963634226. Delta is -0.0094454931319774
#  34%|███▍      | 27/79 [00:06<00:12,  4.10it/s]Model is not converging.  Current: 310.3271048241259 is not greater than 310.63926280601294. Delta is -0.3121579818870259
#  38%|███▊      | 30/79 [00:07<00:12,  4.05it/s]Model is not converging.  Current: 181.07943395791276 is not greater than 181.0869929050101. Delta is -0.007558947097351165
#  51%|█████     | 40/79 [00:09<00:09,  4.32it/s]Model is not converging.  Current: 343.4561635222556 is not greater than 343.47957090942197. Delta is -0.02340738716634405
#  54%|█████▍    | 43/79 [00:10<00:07,  4.73it/s]Model is not converging.  Current: 301.5520438802553 is not greater than 301.7362838227309. Delta is -0.1842399424755854
#  58%|█████▊    | 46/79 [00:11<00:07,  4.21it/s]Model is not converging.  Current: 337.8191901876249 is not greater than 337.957368949087. Delta is -0.13817876146214303
#  80%|███████▉  | 63/79 [00:15<00:03,  4.73it/s]Model is not converging.  Current: 258.9526848415027 is not greater than 259.034253311938. Delta is -0.08156847043534299
#  85%|████████▍ | 67/79 [00:16<00:03,  3.63it/s]Model is not converging.  Current: 271.8388914588745 is not greater than 271.85334034929946. Delta is -0.014448890424944238
#  87%|████████▋ | 69/79 [00:17<00:02,  3.67it/s]Model is not converging.  Current: 270.5454708098928 is not greater than 270.56801512409487. Delta is -0.022544314202093574
#  90%|████████▉ | 71/79 [00:17<00:02,  3.89it/s]Model is not converging.  Current: 313.15658123538935 is not greater than 313.3775412739705. Delta is -0.2209600385811541
# 100%|██████████| 79/79 [00:19<00:00,  4.04it/s]

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import entropy
from hmmlearn.hmm import GaussianHMM
from statsmodels.tsa.stattools import adfuller

def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]
    return entropy(hist, base=2)

def hmm_regime_switch_prob_and_count(returns, n_states=2):
    returns = returns.values.reshape(-1, 1)
    model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=100)
    model.fit(returns)
    hidden_states = model.predict(returns)
    last_state = hidden_states[-1]
    transmat = model.transmat_
    switch_prob = 1 - transmat[last_state, last_state]
    regime_switch_count = np.sum(hidden_states[1:] != hidden_states[:-1])
    return switch_prob, regime_switch_count

entropy_list = []
regimeswitchprob_list = []
regimeswitchcount_list = []
adf_pvalue_list = []
avg_return_list = []

for ticker in filterdf['symbol']:
    try:
        # Download last 7 days of 1-minute data
        df = yf.download(ticker, period="7d", interval="1m", progress=False)
        closes = df['Close'].dropna()
        # Make sure you have enough data (e.g., at least 1000 minutes)
        if len(closes) < 1000:
            entropy_list.append(np.nan)
            regimeswitchprob_list.append(np.nan)
            regimeswitchcount_list.append(np.nan)
            adf_pvalue_list.append(np.nan)
            avg_return_list.append(np.nan)
            continue
        log_returns = np.log(closes).diff().dropna()         # For entropy, HMM, etc.
        simple_returns = closes.pct_change().dropna()        # For avg return only

        # Shannon entropy (log returns)
        ent = shannon_entropy(log_returns)
        entropy_list.append(ent)
        # HMM regime switch probability and count (log returns)
        switch_prob, switch_count = hmm_regime_switch_prob_and_count(log_returns)
        regimeswitchprob_list.append(round(switch_prob * 100, 2))  # as percentage
        regimeswitchcount_list.append(int(switch_count))
        # ADF test p-value on last 7 days of prices (not returns)
        adf_pvalue = adfuller(closes)[1]
        adf_pvalue_list.append(adf_pvalue)
        # Average return over last 7 days (mean of simple returns)
        avg_return = simple_returns.mean()
        avg_return_list.append(avg_return)
    except Exception as e:
        entropy_list.append(np.nan)
        regimeswitchprob_list.append(np.nan)
        regimeswitchcount_list.append(np.nan)
        adf_pvalue_list.append(np.nan)
        avg_return_list.append(np.nan)


filterdf['ShannonEntropy'] = entropy_list
filterdf['Regimeswitchprob'] = regimeswitchprob_list
filterdf['Regimeswitchcount'] = regimeswitchcount_list
filterdf['ADF_Pvalue'] = adf_pvalue_list
filterdf['AvgReturn_7d'] = avg_return_list
# Out:
# Model is not converging.  Current: 11317.616355197464 is not greater than 11318.87451379854. Delta is -1.2581586010765022
# Model is not converging.  Current: 13773.933746580622 is not greater than 13775.376309052843. Delta is -1.442562472220743
# Model is not converging.  Current: 14028.75770316379 is not greater than 14030.157983025352. Delta is -1.4002798615620122
# Model is not converging.  Current: 13951.307513971167 is not greater than 13951.322339935436. Delta is -0.014825964268311509
# Model is not converging.  Current: 13914.709259650219 is not greater than 13916.595369124567. Delta is -1.8861094743479043
# Model is not converging.  Current: 13523.684640400046 is not greater than 13526.443661365221. Delta is -2.7590209651752957
# Model is not converging.  Current: 13564.66683990842 is not greater than 13568.522645832987. Delta is -3.8558059245679033
# Model is not converging.  Current: 13862.650379939389 is not greater than 13867.532912505118. Delta is -4.8825325657289795
# Model is not converging.  Current: 13512.956847996827 is not greater than 13518.860193063801. Delta is -5.903345066973998
# Model is not converging.  Current: 13364.783469160218 is not greater than 13365.438435382834. Delta is -0.6549662226152577
# Model is not converging.  Current: 12871.112549622503 is not greater than 12884.878350635066. Delta is -13.765801012563315
# Model is not converging.  Current: 14237.428912768877 is not greater than 14240.058598859529. Delta is -2.6296860906513757
# Model is not converging.  Current: 13608.679361936229 is not greater than 13609.47805887531. Delta is -0.7986969390804006
# Model is not converging.  Current: 14088.6057540523 is not greater than 14090.828677385913. Delta is -2.2229233336129255
# Model is not converging.  Current: 12945.016757517116 is not greater than 12946.28478808439. Delta is -1.2680305672729446
# Model is not converging.  Current: 11678.026737026867 is not greater than 11682.26658425541. Delta is -4.239847228544022
# Model is not converging.  Current: 14243.460209504934 is not greater than 14243.598022457898. Delta is -0.13781295296394092
# Model is not converging.  Current: 14133.928490284483 is not greater than 14136.101078185595. Delta is -2.1725879011119105
# Model is not converging.  Current: 14057.232667892444 is not greater than 14058.051986555558. Delta is -0.8193186631142453
# Model is not converging.  Current: 12459.058553513134 is not greater than 12463.907763359091. Delta is -4.849209845957375
# Model is not converging.  Current: 14034.988972422214 is not greater than 14038.12125606749. Delta is -3.1322836452764022
# Model is not converging.  Current: 12819.969378734726 is not greater than 12820.500090883043. Delta is -0.5307121483165247
# Model is not converging.  Current: 12559.667551292187 is not greater than 12559.668763771639. Delta is -0.0012124794520786963
# Model is not converging.  Current: 13493.409356178317 is not greater than 13497.421057999753. Delta is -4.011701821435054
# Model is not converging.  Current: 13933.891802427184 is not greater than 13934.207120058798. Delta is -0.31531763161365234
# Model is not converging.  Current: 14064.054858048386 is not greater than 14066.144660071024. Delta is -2.089802022637741
# Model is not converging.  Current: 13808.835549064012 is not greater than 13811.614900059845. Delta is -2.779350995833738
# Model is not converging.  Current: 13725.474789529002 is not greater than 13725.605233997478. Delta is -0.1304444684756163
# Model is not converging.  Current: 14217.131144594709 is not greater than 14218.771350826415. Delta is -1.640206231706543
# Model is not converging.  Current: 14271.288283804191 is not greater than 14271.47753492131. Delta is -0.1892511171190563
# Model is not converging.  Current: 13979.8867085186 is not greater than 13982.477786719282. Delta is -2.591078200683114
# Model is not converging.  Current: 14164.750421955012 is not greater than 14165.62809712739. Delta is -0.8776751723780762
# Model is not converging.  Current: 13883.810621094866 is not greater than 13884.382219643874. Delta is -0.571598549007831
# Model is not converging.  Current: 14071.372961732115 is not greater than 14076.00150534039. Delta is -4.628543608274413
# Model is not converging.  Current: 14085.938127192361 is not greater than 14088.705001618198. Delta is -2.766874425837159
# Model is not converging.  Current: 13738.260877034641 is not greater than 13745.649405536198. Delta is -7.388528501556721
# Model is not converging.  Current: 13541.51958448258 is not greater than 13544.716147704212. Delta is -3.1965632216324593
# Model is not converging.  Current: 13127.279662785219 is not greater than 13129.17332209703. Delta is -1.893659311812371
# Model is not converging.  Current: 12452.387648409725 is not greater than 12453.43503713188. Delta is -1.04738872215421
# Model is not converging.  Current: 14127.914815802054 is not greater than 14128.030722358259. Delta is -0.11590655620420875
# Model is not converging.  Current: 12863.820846484386 is not greater than 12866.909436756374. Delta is -3.088590271987414
# Model is not converging.  Current: 14209.110592607862 is not greater than 14216.448277850908. Delta is -7.337685243046508
# Model is not converging.  Current: 14022.04105849928 is not greater than 14027.3556445655. Delta is -5.314586066218908
# Model is not converging.  Current: 13555.418254814356 is not greater than 13556.022883034315. Delta is -0.604628219958613
# Model is not converging.  Current: 14043.852537464 is not greater than 14045.140986721957. Delta is -1.2884492579578364
# Model is not converging.  Current: 13777.281994468582 is not greater than 13782.378372031908. Delta is -5.096377563326314
# Model is not converging.  Current: 14150.403805787106 is not greater than 14150.48200425195. Delta is -0.07819846484380832
# Model is not converging.  Current: 13683.455116286745 is not greater than 13683.985205021525. Delta is -0.5300887347802927
# Model is not converging.  Current: 14239.391370167532 is not greater than 14241.0172124861. Delta is -1.625842318568175
# Model is not converging.  Current: 13731.680775021958 is not greater than 13735.381663749393. Delta is -3.7008887274350855
# Model is not converging.  Current: 13883.146146954161 is not greater than 13884.978557370165. Delta is -1.8324104160037678
# Model is not converging.  Current: 14008.21959471523 is not greater than 14012.616676271624. Delta is -4.397081556393459
# Model is not converging.  Current: 13859.20794314116 is not greater than 13863.573667189752. Delta is -4.365724048591801
# Model is not converging.  Current: 14153.952400340713 is not greater than 14154.64180172734. Delta is -0.6894013866276509
# Model is not converging.  Current: 14151.762769325012 is not greater than 14152.981893436585. Delta is -1.2191241115724551
# Model is not converging.  Current: 13923.200608843003 is not greater than 13924.43111472046. Delta is -1.2305058774581994

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
filterdf["Shannon/IV"] = filterdf["ShannonEntropy"] / filterdf["avg_iv"]
display(filterdf)
# Out:
#    language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 5     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15    en-US     US    EQUITY   Equity           Delayed Quote        False
# 16    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 17    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 18    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 21    en-US     US    EQUITY   Equity           Delayed Quote        False
# 22    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 24    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 25    en-US     US    EQUITY   Equity           Delayed Quote        False
# 26    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27    en-US     US    EQUITY   Equity           Delayed Quote        False
# 28    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 29    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 30    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33    en-US     US    EQUITY   Equity           Delayed Quote        False
# 34    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 35    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 36    en-US     US    EQUITY   Equity           Delayed Quote        False
# 37    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 40    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 41    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 42    en-US     US    EQUITY   Equity           Delayed Quote        False
# 43    en-US     US    EQUITY   Equity           Delayed Quote        False
# 44    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 45    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46    en-US     US    EQUITY   Equity           Delayed Quote        False
# 47    en-US     US    EQUITY   Equity           Delayed Quote        False
# 48    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 49    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 50    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52    en-US     US    EQUITY   Equity           Delayed Quote         True
# 53    en-US     US    EQUITY   Equity           Delayed Quote        False
# 54    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55    en-US     US    EQUITY   Equity           Delayed Quote        False
# 56    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 58    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 59    en-US     US    EQUITY   Equity           Delayed Quote        False
# 60    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 62    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 63    en-US     US    EQUITY   Equity           Delayed Quote        False
# 64    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 65    en-US     US    EQUITY   Equity           Delayed Quote        False
# 66    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 67    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 68    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 69    en-US     US    EQUITY   Equity           Delayed Quote        False
# 70    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 71    en-US     US    EQUITY   Equity           Delayed Quote        False
# 72    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 73    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 74    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 75    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 76    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 77    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 78    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#    customPriceAlertConfidence currency     bid     ask  \
# 0                        HIGH      USD  172.00  175.00
# 1                        HIGH      USD    2.95    2.99
# 2                         LOW      USD    1.74    1.90
# 3                        HIGH      USD  305.15  310.00
# 4                         LOW      USD   11.27   11.28
# 5                        HIGH      USD  154.68  155.13
# 6                        HIGH      USD   22.52   23.17
# 7                        HIGH      USD   21.00   21.52
# 8                        HIGH      USD   11.44   11.95
# 9                        HIGH      USD  203.20  224.70
# 10                       HIGH      USD   11.17   11.22
# 11                        LOW      USD   17.22   17.31
# 12                       HIGH      USD  159.00  164.00
# 13                       HIGH      USD   52.43   52.60
# 14                       HIGH      USD  100.50  108.70
# 15                        LOW      USD    4.83    4.84
# 16                       HIGH      USD  232.07  232.36
# 17                       HIGH      USD  191.00  195.00
# 18                        LOW      USD   48.47   48.47
# 19                        LOW      USD   14.63   14.73
# 20                        LOW      USD    9.75    9.72
# 21                        LOW      USD   10.22   10.26
# 22                        LOW      USD   12.50   12.70
# 23                        LOW      USD   10.93   11.03
# 24                        LOW      USD    3.22    9.00
# 25                        LOW      USD    9.75    9.77
# 26                        LOW      USD   27.88   27.83
# 27                        LOW      USD    6.34    6.37
# 28                        LOW      USD   12.42   17.86
# 29                       HIGH      USD   16.59   16.68
# 30                        LOW      USD   12.30   12.39
# 31                        LOW      USD   29.78   29.81
# 32                       HIGH      USD    9.11   12.04
# 33                        LOW      USD    6.19    6.21
# 34                       HIGH      USD  111.66  111.85
# 35                        LOW      USD   20.21   25.43
# 36                        LOW      USD   90.85   91.13
# 37                       HIGH      USD  288.45  289.05
# 38                       HIGH      USD   69.74   77.68
# 39                       HIGH      USD  483.11  534.45
# 40                       HIGH      USD   68.24   68.35
# 41                       HIGH      USD   35.35   35.43
# 42                        LOW      USD    9.61    9.68
# 43                        LOW      USD    4.36    4.36
# 44                        LOW      USD   20.51   20.60
# 45                        LOW      USD   83.82   84.01
# 46                        LOW      USD   43.11   43.14
# 47                        LOW      USD    8.34    8.36
# 48                        LOW      USD   75.53   75.59
# 49                       HIGH      USD   14.33   15.21
# 50                        LOW      USD   18.51   18.52
# 51                        LOW      USD   14.86   14.95
# 52                       HIGH      USD   33.82   36.79
# 53                        LOW      USD   23.49   23.60
# 54                        LOW      USD   23.53   23.55
# 55                        LOW      USD    9.43    9.43
# 56                       HIGH      USD  396.10  427.14
# 57                        LOW      USD   61.51   61.56
# 58                        LOW      USD  121.25  121.31
# 59                        LOW      USD   33.34   33.72
# 60                        LOW      USD   95.42   95.59
# 61                       HIGH      USD   59.47   63.61
# 62                        LOW      USD   45.83   45.84
# 63                        LOW      USD   44.51   44.80
# 64                        LOW      USD   13.60   13.66
# 65                        LOW      USD  242.46  242.96
# 66                       HIGH      USD  414.30  415.73
# 67                        LOW      USD   63.95   64.11
# 68                        LOW      USD   33.28   33.37
# 69                        LOW      USD  241.02  243.68
# 70                        LOW      USD   25.16   25.14
# 71                        LOW      USD   17.68   17.74
# 72                        LOW      USD   84.80   85.13
# 73                        LOW      USD   12.32   12.34
# 74                        LOW      USD   37.66   37.67
# 75                        LOW      USD   54.72   54.96
# 76                        LOW      USD   30.10   30.30
# 77                       HIGH      USD   29.11   38.02
# 78                        LOW      USD   52.38   52.34
#
#     regularMarketChangePercent exchange  fiftyTwoWeekHigh  fiftyTwoWeekLow  \
# 0                     1.733230      NMS           174.250        86.620000
# 1                    -2.922080      NMS             4.430         1.930000
# 2                    -2.209940      NCM             3.320         0.690000
# 3                    -8.197020      NMS           488.540       182.000000
# 4                    -1.054480      NYQ            11.970         8.440000
# 5                     0.155865      NMS           155.680        21.230000
# 6                    -3.661140      NMS            31.560        17.670000
# 7                    -0.231907      NMS            22.740         6.010000
# 8                    -9.621450      NMS            19.100         8.500000
# 9                    -0.182115      NMS           260.100       169.210000
# 10                    2.470260      NMS            15.420         3.010000
# 11                   -1.764370      NCM            30.280         9.810000
# 12                    2.187210      NMS           174.050        76.480000
# 13                    1.586070      NMS            73.001        17.250000
# 14                   -0.146945      NMS           113.439        13.980000
# 15                   -1.829270      NYQ             7.710         3.020000
# 16                    1.725880      NMS           242.520       151.610000
# 17                    1.019820      NMS           207.050       140.530000
# 18                    0.519319      NYQ            49.310        33.070000
# 19                    2.440720      NCM            15.870         6.190000
# 20                   -3.277060      NYQ            13.950         7.080000
# 21                   -1.634620      NYQ            12.050         8.060000
# 22                   -1.558840      NYQ            15.030         3.400000
# 23                   -3.194330      NYQ            15.710         5.630000
# 24                   -3.869040      NCM             5.740         1.690000
# 25                   -0.509686      NYQ            11.480         8.370000
# 26                    0.612613      NYQ            29.190        18.640000
# 27                   -1.550390      NYQ             6.950         4.418182
# 28                   -2.976520      NCM            27.150         0.530000
# 29                   -1.070160      NMS            18.450        11.920000
# 30                   -0.883531      NCM            18.050         6.452000
# 31                   -3.122960      NYQ            31.010        13.780000
# 32                   -0.479726      NMS            22.260         5.380000
# 33                   -1.592360      NYQ             7.680         4.410000
# 34                    1.729950      NMS           129.850        61.540000
# 35                   -9.647420      NCM           124.120         2.280000
# 36                    1.034020      NYQ            97.715        54.840000
# 37                    1.769530      NMS           291.200       128.500000
# 38                    1.050910      NMS           127.480        47.090000
# 39                    0.990375      NMS           514.640       344.790000
# 40                   -0.480912      NMS            69.780        44.500000
# 41                   -1.173520      NMS            45.310        31.440000
# 42                   -7.350100      NYQ            17.740         8.390000
# 43                   -3.982300      NYQ             5.480         3.700000
# 44                   -1.204240      NYQ            24.660        11.965000
# 45                    0.203113      NYQ            84.830        50.150000
# 46                    0.560228      NYQ            47.360        37.590000
# 47                    2.846970      NYQ             8.800         6.530000
# 48                   -1.732900      NYQ            90.620        52.280000
# 49                   -2.376100      NMS            19.065         8.925000
# 50                   -1.595740      NYQ            20.040        12.730000
# 51                   -8.328190      NYQ            21.380        10.060000
# 52                    0.085784      NMS            37.100        26.220000
# 53                   -3.371710      NYQ            29.290        14.210000
# 54                   -1.794650      NYQ            35.810        18.730000
# 55                   -1.156680      NYQ             9.970         4.570000
# 56                   -0.279024      NMS           444.650       142.580000
# 57                    0.686951      NYQ            65.050        10.020000
# 58                   -1.166590      NYQ           148.430        73.870000
# 59                   -0.209517      NYQ            38.960        13.895000
# 60                   -0.625064      NYQ            96.910        53.510000
# 61                    1.934830      NMS            60.950        16.890000
# 62                  -13.338400      NYQ            66.740        44.460000
# 63                   -0.579836      NYQ            52.610        27.660000
# 64                   10.813000      NYQ            22.530         6.040000
# 65                    0.384460      NYQ           251.600       118.860000
# 66                    0.545230      NMS           543.000       102.402000
# 67                    0.146532      NYQ            62.560        36.860000
# 68                  -11.164500      NYQ            37.960        23.580000
# 69                    0.528442      NYQ           248.280       133.570000
# 70                  -17.451400      NYQ            55.670        24.370000
# 71                   -4.173440      NYQ            23.630        15.820000
# 72                    0.437200      NGM           141.530        42.960000
# 73                   -2.377180      NYQ            15.930         9.380000
# 74                   -0.317552      NYQ            40.900        23.680000
# 75                   -2.268670      NYQ            69.980        34.740000
# 76                   -1.309760      NYQ            31.645        18.160000
# 77                   -1.355730      NMS            47.820        24.130000
# 78                   -1.486920      NYQ            61.240        38.960000
#
#    averageAnalystRating  dividendYield                        shortName  \
# 0      1.4 - Strong Buy           0.02               NVIDIA Corporation
# 1            3.1 - Hold            NaN                Lucid Group, Inc.
# 2            2.9 - Hold            NaN                 Plug Power, Inc.
# 3            2.6 - Hold            NaN                      Tesla, Inc.
# 4            3.0 - Hold           6.59               Ford Motor Company
# 5            3.0 - Hold            NaN       Palantir Technologies Inc.
# 6            3.0 - Hold            NaN                Intel Corporation
# 7            2.8 - Hold            NaN          SoFi Technologies, Inc.
# 8             2.1 - Buy            NaN    American Airlines Group, Inc.
# 9             2.0 - Buy           0.49                       Apple Inc.
# 10            1.6 - Buy            NaN      Applied Digital Corporation
# 11            2.4 - Buy            NaN              MARA Holdings, Inc.
# 12            1.7 - Buy            NaN     Advanced Micro Devices, Inc.
# 13           2.8 - Hold            NaN       Super Micro Computer, Inc.
# 14            2.0 - Buy            NaN          Robinhood Markets, Inc.
# 15            2.3 - Buy            NaN                         NIO Inc.
# 16     1.4 - Strong Buy            NaN                 Amazon.com, Inc.
# 17            1.5 - Buy           0.44                    Alphabet Inc.
# 18            1.6 - Buy           2.16      Bank of America Corporation
# 19     1.4 - Strong Buy            NaN             Riot Platforms, Inc.
# 20           2.8 - Hold            NaN                        Snap Inc.
# 21            2.0 - Buy          13.25                        VALE S.A.
# 22           3.4 - Hold            NaN         QuantumScape Corporation
# 23            2.4 - Buy            NaN            Cleveland-Cliffs Inc.
# 24     1.2 - Strong Buy            NaN                Bit Digital, Inc.
# 25            1.9 - Buy           5.20                        Amcor plc
# 26            2.0 - Buy           4.05                        AT&T Inc.
# 27            1.7 - Buy           0.58   Itau Unibanco Banco Holding SA
# 28                  NaN            NaN           Quantum Computing Inc.
# 29            1.7 - Buy           3.69  Huntington Bancshares Incorpora
# 30            1.5 - Buy            NaN                 CleanSpark, Inc.
# 31            1.6 - Buy            NaN             Carnival Corporation
# 32            2.3 - Buy            NaN                      Sunrun Inc.
# 33            2.2 - Buy           0.24             Hecla Mining Company
# 34            1.5 - Buy           0.42          Micron Technology, Inc.
# 35                  NaN            NaN           SharpLink Gaming, Inc.
# 36            1.6 - Buy            NaN          Uber Technologies, Inc.
# 37     1.4 - Strong Buy           0.83                    Broadcom Inc.
# 38            1.5 - Buy           0.33         Marvell Technology, Inc.
# 39     1.4 - Strong Buy           0.66            Microsoft Corporation
# 40            1.9 - Buy           2.39              Cisco Systems, Inc.
# 41            2.3 - Buy           3.69              Comcast Corporation
# 42           2.6 - Hold           7.45                  Stellantis N.V.
# 43            2.4 - Buy           3.14      Nokia Corporation Sponsored
# 44            2.1 - Buy           2.50  Hewlett Packard Enterprise Comp
# 45            2.0 - Buy           1.91            Wells Fargo & Company
# 46            2.3 - Buy           6.33      Verizon Communications Inc.
# 47            2.4 - Buy           2.61                         ADT Inc.
# 48            2.2 - Buy           2.08                       Nike, Inc.
# 49           2.6 - Hold            NaN                       Lyft, Inc.
# 50            2.2 - Buy           4.36                          KeyCorp
# 51           2.8 - Hold            NaN           Rocket Companies, Inc.
# 52            1.8 - Buy           1.49                  CSX Corporation
# 53            1.8 - Buy            NaN  Norwegian Cruise Line Holdings
# 54                  NaN            NaN             GameStop Corporation
# 55     1.4 - Strong Buy            NaN               Coeur Mining, Inc.
# 56            2.2 - Buy            NaN            Coinbase Global, Inc.
# 57            1.8 - Buy            NaN               MP Materials Corp.
# 58     1.3 - Strong Buy           0.86    Alibaba Group Holding Limited
# 59            2.2 - Buy            NaN              Unity Software Inc.
# 60            1.8 - Buy           2.50                  Citigroup, Inc.
# 61            1.7 - Buy            NaN            AST SpaceMobile, Inc.
# 62            1.7 - Buy            NaN     Chipotle Mexican Grill, Inc.
# 63            2.3 - Buy           1.31           Freeport-McMoRan, Inc.
# 64   3.6 - Underperform           4.07               Kohl's Corporation
# 65            1.8 - Buy           0.83               Oracle Corporation
# 66            1.6 - Buy            NaN       MicroStrategy Incorporated
# 67            1.9 - Buy           1.63              Newmont Corporation
# 68           3.0 - Hold           1.92       Southwest Airlines Company
# 69     1.4 - Strong Buy           1.37  Taiwan Semiconductor Manufactur
# 70           2.8 - Hold           9.22                         Dow Inc.
# 71            2.3 - Buy           2.81                  Infosys Limited
# 72            1.9 - Buy            NaN             The Trade Desk, Inc.
# 73           2.7 - Hold            NaN                     UiPath, Inc.
# 74            1.6 - Buy            NaN                  Pinterest, Inc.
# 75     1.5 - Strong Buy           1.34            Delta Air Lines, Inc.
# 76            1.8 - Buy            NaN                    Coupang, Inc.
# 77     1.4 - Strong Buy           2.95                     JD.com, Inc.
# 78            2.3 - Buy           1.23           General Motors Company
#
#    corporateActions  fiftyTwoWeekLowChange  fiftyTwoWeekLowChangePercent  \
# 0                []              87.120000                      1.005772
# 1                []               1.060000                      0.549223
# 2                []               1.080000                      1.565217
# 3                []             123.299990                      0.677473
# 4                []               2.820001                      0.334123
# 5                []             133.630000                      6.294395
# 6                []               4.959999                      0.280702
# 7                []              15.500000                      2.579035
# 8                []               2.960000                      0.348235
# 9                []              44.549988                      0.263282
# 10               []               8.190000                      2.720930
# 11               []               7.450000                      0.759429
# 12               []              85.639990                      1.119770
# 13               []              35.270000                      2.044638
# 14               []              87.950000                      6.291130
# 15               []               1.810000                      0.599338
# 16               []              80.619995                      0.531759
# 17               []              51.640000                      0.367466
# 18               []              15.320000                      0.463260
# 19               []               8.500000                      1.373182
# 20               []               2.660000                      0.375706
# 21               []               2.169999                      0.269231
# 22               []               9.230000                      2.714706
# 23               []               5.280000                      0.937833
# 24               []               1.540000                      0.911243
# 25               []               1.390000                      0.166069
# 26               []               9.280001                      0.497854
# 27               []               1.931818                      0.437243
# 28               []              16.420000                     30.981134
# 29               []               4.719999                      0.395973
# 30               []               5.888000                      0.912585
# 31               []              16.000000                      1.161103
# 32               []               5.200000                      0.966543
# 33               []               1.770000                      0.401361
# 34               []              50.190002                      0.815567
# 35               []              21.039999                      9.228070
# 36               []              36.030003                      0.657002
# 37               []             160.209990                      1.246770
# 38               []              26.950000                      0.572308
# 39               []             166.090000                      0.481713
# 40               []              23.790000                      0.534607
# 41               []               3.929998                      0.125000
# 42               []               1.190000                      0.141835
# 43               []               0.640000                      0.172973
# 44               []               8.545000                      0.714166
# 45               []              33.720000                      0.672383
# 46               []               5.490002                      0.146050
# 47               []               2.140000                      0.327718
# 48               []              23.140000                      0.442617
# 49               []               5.455000                      0.611204
# 50               []               5.770001                      0.453260
# 51               []               4.799999                      0.477137
# 52               []               8.780001                      0.334859
# 53               []               9.290000                      0.653765
# 54               []               4.800001                      0.256273
# 55               []               4.829999                      1.056893
# 56               []             254.120010                      1.782298
# 57               []              51.540000                      5.143713
# 58               []              47.280000                      0.640043
# 59               []              19.445000                      1.399424
# 60               []              41.880000                      0.782658
# 61               []              43.170002                      2.555950
# 62               []               1.280003                      0.028790
# 63               []              16.920002                      0.611714
# 64               []               7.590000                      1.256623
# 65               []             123.970000                      1.042992
# 66               []             312.518000                      3.051874
# 67               []              24.649998                      0.668747
# 68               []               9.679998                      0.410517
# 69               []             108.030000                      0.808789
# 70               []               0.699999                      0.028724
# 71               []               1.860001                      0.117573
# 72               []              42.040000                      0.978585
# 73               []               2.940000                      0.313433
# 74               []              13.989998                      0.590794
# 75               []              19.969997                      0.574842
# 76               []              11.980000                      0.659692
# 77               []               9.340002                      0.387070
# 78               []              13.380001                      0.343429
#
#    fiftyTwoWeekRange  fiftyTwoWeekHighChange  fiftyTwoWeekHighChangePercent  \
# 0     86.62 - 174.25               -0.509995                      -0.002927
# 1        1.93 - 4.43               -1.440000                      -0.325056
# 2        0.69 - 3.32               -1.550000                      -0.466867
# 3     182.0 - 488.54             -183.240020                      -0.375077
# 4       8.44 - 11.97               -0.710000                      -0.059315
# 5     21.23 - 155.68               -0.819992                      -0.005267
# 6      17.67 - 31.56               -8.930000                      -0.282953
# 7       6.01 - 22.74               -1.229999                      -0.054090
# 8         8.5 - 19.1               -7.640000                      -0.400000
# 9     169.21 - 260.1              -46.340010                      -0.178162
# 10      3.01 - 15.42               -4.220000                      -0.273671
# 11      9.81 - 30.28              -13.020000                      -0.429987
# 12    76.48 - 174.05              -11.930008                      -0.068544
# 13    17.25 - 73.001              -20.480999                      -0.280558
# 14   13.98 - 113.439              -11.509003                      -0.101455
# 15       3.02 - 7.71               -2.880000                      -0.373541
# 16   151.61 - 242.52              -10.290009                      -0.042430
# 17   140.53 - 207.05              -14.880005                      -0.071867
# 18     33.07 - 49.31               -0.920002                      -0.018658
# 19      6.19 - 15.87               -1.180000                      -0.074354
# 20      7.08 - 13.95               -4.210000                      -0.301792
# 21      8.06 - 12.05               -1.820001                      -0.151037
# 22       3.4 - 15.03               -2.400000                      -0.159681
# 23      5.63 - 15.71               -4.800000                      -0.305538
# 24       1.69 - 5.74               -2.510000                      -0.437282
# 25      8.37 - 11.48               -1.719999                      -0.149826
# 26     18.64 - 29.19               -1.270001                      -0.043508
# 27   4.418182 - 6.95               -0.600000                      -0.086331
# 28      0.53 - 27.15              -10.199999                      -0.375691
# 29     11.92 - 18.45               -1.810001                      -0.098103
# 30     6.452 - 18.05               -5.709999                      -0.316343
# 31     13.78 - 31.01               -1.229999                      -0.039665
# 32      5.38 - 22.26              -11.680000                      -0.524708
# 33       4.41 - 7.68               -1.500000                      -0.195312
# 34    61.54 - 129.85              -18.120003                      -0.139546
# 35     2.28 - 124.12             -100.800000                      -0.812117
# 36    54.84 - 97.715               -6.844994                      -0.070051
# 37     128.5 - 291.2               -2.490021                      -0.008551
# 38    47.09 - 127.48              -53.440002                      -0.419203
# 39   344.79 - 514.64               -3.760010                      -0.007306
# 40      44.5 - 69.78               -1.489998                      -0.021353
# 41     31.44 - 45.31               -9.940002                      -0.219378
# 42      8.39 - 17.74               -8.160000                      -0.459977
# 43        3.7 - 5.48               -1.140000                      -0.208029
# 44    11.965 - 24.66               -4.150000                      -0.168289
# 45     50.15 - 84.83               -0.959999                      -0.011317
# 46     37.59 - 47.36               -4.279999                      -0.090372
# 47        6.53 - 8.8               -0.130000                      -0.014773
# 48     52.28 - 90.62              -15.200005                      -0.167733
# 49    8.925 - 19.065               -4.685000                      -0.245738
# 50     12.73 - 20.04               -1.540001                      -0.076846
# 51     10.06 - 21.38               -6.519999                      -0.304958
# 52      26.22 - 37.1               -2.099998                      -0.056604
# 53     14.21 - 29.29               -5.790001                      -0.197678
# 54     18.73 - 35.81              -12.280001                      -0.342921
# 55       4.57 - 9.97               -0.570001                      -0.057172
# 56   142.58 - 444.65              -47.949980                      -0.107838
# 57     10.02 - 65.05               -3.490002                      -0.053651
# 58    73.87 - 148.43              -27.279991                      -0.183790
# 59    13.895 - 38.96               -5.619999                      -0.144250
# 60     53.51 - 96.91               -1.520004                      -0.015685
# 61     16.89 - 60.95               -0.889999                      -0.014602
# 62     44.46 - 66.74              -20.999996                      -0.314654
# 63     27.66 - 52.61               -8.029999                      -0.152633
# 64      6.04 - 22.53               -8.900001                      -0.395029
# 65    118.86 - 251.6               -8.770004                      -0.034857
# 66   102.402 - 543.0             -128.079990                      -0.235875
# 67     36.86 - 62.56               -1.050003                      -0.016784
# 68     23.58 - 37.96               -4.700001                      -0.123815
# 69   133.57 - 248.28               -6.679993                      -0.026905
# 70     24.37 - 55.67              -30.599998                      -0.549668
# 71     15.82 - 23.63               -5.949999                      -0.251798
# 72    42.96 - 141.53              -56.530000                      -0.399421
# 73      9.38 - 15.93               -3.610001                      -0.226616
# 74      23.68 - 40.9               -3.230003                      -0.078973
# 75     34.74 - 69.98              -15.270004                      -0.218205
# 76    18.16 - 31.645               -1.505001                      -0.047559
# 77     24.13 - 47.82              -14.349998                      -0.300084
# 78     38.96 - 61.24               -8.900002                      -0.145330
#
#     fiftyTwoWeekChangePercent  dividendDate  earningsTimestamp  \
# 0                   53.670620  1.751501e+09       1.756325e+09
# 1                  -11.538464           NaN       1.754424e+09
# 2                  -28.915660           NaN       1.745843e+09
# 3                   38.899006           NaN       1.753301e+09
# 4                    0.625563  1.748822e+09       1.753906e+09
# 5                  469.757170           NaN       1.754338e+09
# 6                  -27.814991  1.725149e+09       1.753387e+09
# 7                  190.283390           NaN       1.753792e+09
# 8                    7.909608  1.582070e+09       1.753360e+09
# 9                   -1.926959  1.747267e+09       1.753992e+09
# 10                 152.252240           NaN       1.753906e+09
# 11                 -19.981457  1.554682e+09       1.753819e+09
# 12                  15.808272           NaN       1.754424e+09
# 13                 -26.255630           NaN       1.754424e+09
# 14                 380.801880           NaN       1.753906e+09
# 15                   9.029341  1.462147e+09       1.748950e+09
# 16                  27.249313           NaN       1.753992e+09
# 17                  15.071857  1.750032e+09       1.753301e+09
# 18                  16.126705  1.750982e+09       1.760531e+09
# 19                  31.160713  1.508285e+09       1.753992e+09
# 20                 -26.931732           NaN       1.754424e+09
# 21                  -5.801106  1.742515e+09                NaN
# 22                  79.403410           NaN       1.753301e+09
# 23                 -29.476404  1.586909e+09       1.753101e+09
# 24                 -11.263734           NaN       1.747339e+09
# 25                  -5.973023  1.749514e+09       1.746043e+09
# 26                  46.870064  1.754006e+09       1.753274e+09
# 27                  15.264023  1.767917e+09       1.754424e+09
# 28                2202.989300  1.530576e+09       1.747340e+09
# 29                   9.980166  1.751328e+09       1.752842e+09
# 30                 -27.920563  1.576022e+09       1.746735e+09
# 31                  72.437750  1.584058e+09       1.750768e+09
# 32                 -40.761480           NaN       1.754510e+09
# 33                   9.380531  1.749514e+09       1.754510e+09
# 34                   2.120459  1.753142e+09       1.750889e+09
# 35                 235.057480  1.504656e+09       1.747339e+09
# 36                  41.102480           NaN       1.754483e+09
# 37                  90.404274  1.751242e+09       1.749154e+09
# 38                  12.659764  1.753920e+09       1.748549e+09
# 39                  20.130741  1.757549e+09       1.753906e+09
# 40                  42.627407  1.753229e+09       1.747253e+09
# 41                 -10.884357  1.753229e+09       1.753965e+09
# 42                 -45.753117  1.746403e+09       1.753792e+09
# 43                  13.020838  1.747267e+09       1.753360e+09
# 44                   3.795552  1.752710e+09       1.748981e+09
# 45                  38.880610  1.748736e+09       1.760445e+09
# 46                   7.458222  1.754006e+09       1.761050e+09
# 47                  12.160408  1.751933e+09       1.753360e+09
# 48                   3.941560  1.751328e+09       1.750968e+09
# 49                  17.579723           NaN       1.754510e+09
# 50                  12.393677  1.757894e+09       1.760618e+09
# 51                  -6.599623  1.743638e+09       1.753992e+09
# 52                   1.981354  1.757894e+09       1.753301e+09
# 53                  27.233350           NaN       1.753965e+09
# 54                  -2.486533  1.529971e+09       1.749586e+09
# 55                  49.920260           NaN       1.754510e+09
# 56                  63.298070           NaN       1.753992e+09
# 57                 342.877700           NaN       1.754597e+09
# 58                  58.303930  1.752106e+09       1.747302e+09
# 59                 100.722460           NaN       1.754483e+09
# 60                  46.348570  1.755821e+09       1.760445e+09
# 61                 218.789810           NaN       1.747082e+09
# 62                  -8.207905           NaN       1.753301e+09
# 63                  -0.933331  1.754006e+09       1.753274e+09
# 64                 -33.544613  1.750810e+09       1.748516e+09
# 65                  74.685270  1.753315e+09       1.749676e+09
# 66                 136.730550  1.747872e+09       1.753992e+09
# 67                  31.628502  1.750378e+09       1.753387e+09
# 68                  22.144700  1.752019e+09       1.753360e+09
# 69                  49.191060  1.759968e+09       1.752755e+09
# 70                 -52.572834  1.749773e+09       1.753360e+09
# 71                 -22.422117  1.751414e+09       1.760618e+09
# 72                  -8.038515           NaN       1.754597e+09
# 73                  -0.323623           NaN       1.748549e+09
# 74                   0.319576           NaN       1.754597e+09
# 75                  23.974620  1.755734e+09       1.752151e+09
# 76                  49.355793           NaN       1.754424e+09
# 77                  26.016570  1.745885e+09       1.747127e+09
# 78                  18.631004  1.750291e+09       1.761050e+09
#
#     earningsTimestampStart  earningsTimestampEnd  earningsCallTimestampStart  \
# 0               1756324800            1756324800                1.748466e+09
# 1               1754424000            1754424000                1.754429e+09
# 2               1754483400            1754915400                1.741095e+09
# 3               1761163200            1761163200                1.753306e+09
# 4               1753905600            1753905600                1.753909e+09
# 5               1754337600            1754337600                1.754341e+09
# 6               1753387200            1753387200                1.753391e+09
# 7               1753792200            1753792200                1.753790e+09
# 8               1753360200            1753360200                1.753360e+09
# 9               1753992000            1753992000                1.753996e+09
# 10              1753905600            1753905600                1.753909e+09
# 11              1753819200            1753819200                1.753823e+09
# 12              1754424000            1754424000                1.754428e+09
# 13              1754424000            1754424000                1.754428e+09
# 14              1753905600            1753905600                1.753909e+09
# 15              1756902600            1757334600                1.748952e+09
# 16              1753992000            1753992000                1.753996e+09
# 17              1753300800            1753300800                1.753303e+09
# 18              1760531400            1760531400                1.760531e+09
# 19              1753992000            1753992000                1.753994e+09
# 20              1754424000            1754424000                1.754428e+09
# 21              1753297200            1753729200                1.745590e+09
# 22              1761163200            1761163200                1.753304e+09
# 23              1753101000            1753101000                1.746707e+09
# 24              1755547200            1755547200                1.747404e+09
# 25              1755201600            1755201600                1.746049e+09
# 26              1761136200            1761136200                1.753274e+09
# 27              1754424000            1754424000                1.754478e+09
# 28              1755201600            1755201600                1.747341e+09
# 29              1760704200            1760704200                1.760706e+09
# 30              1754564340            1754913600                1.746736e+09
# 31              1750768200            1750768200                1.750774e+09
# 32              1754510400            1754510400                1.754512e+09
# 33              1754510400            1754510400                1.746194e+09
# 34              1758744000            1758744000                1.750883e+09
# 35              1755201600            1755201600                         NaN
# 36              1754483400            1754483400                1.754482e+09
# 37              1756897140            1757332800                1.756327e+09
# 38              1756411200            1756411200                1.748552e+09
# 39              1753905600            1753905600                1.753911e+09
# 40              1754996340            1755518400                1.755117e+09
# 41              1753101000            1753446600                1.753965e+09
# 42              1753792200            1753792200                1.753819e+09
# 43              1753360200            1753360200                1.753346e+09
# 44              1756929600            1756929600                1.748984e+09
# 45              1760445000            1760445000                1.760450e+09
# 46              1761049800            1761049800                1.761050e+09
# 47              1753360200            1753360200                1.753366e+09
# 48              1759262400            1759262400                1.750972e+09
# 49              1754510400            1754510400                1.754514e+09
# 50              1760617800            1760617800                1.760623e+09
# 51              1753992000            1753992000                1.753994e+09
# 52              1760558400            1760558400                1.753303e+09
# 53              1753965000            1753965000                1.753963e+09
# 54              1757329140            1757678400                         NaN
# 55              1754510400            1754510400                1.746716e+09
# 56              1753992000            1753992000                1.753997e+09
# 57              1754596800            1754596800                1.754600e+09
# 58              1755088200            1755520200                1.747309e+09
# 59              1754483400            1754483400                1.754483e+09
# 60              1760445000            1760445000                1.760454e+09
# 61              1754996340            1755518400                1.741126e+09
# 62              1753300800            1753300800                1.753303e+09
# 63              1761049800            1761049800                1.753279e+09
# 64              1756297800            1756297800                1.748524e+09
# 65              1757361600            1757361600                1.749676e+09
# 66              1753992000            1753992000                1.746133e+09
# 67              1753387200            1753387200                1.753393e+09
# 68              1761163200            1761163200                1.761237e+09
# 69              1760617800            1760617800                1.752732e+09
# 70              1753360200            1753360200                1.761221e+09
# 71              1760617800            1760617800                1.753272e+09
# 72              1754596800            1754596800                1.754600e+09
# 73              1756897140            1757332800                1.748552e+09
# 74              1754596800            1754596800                1.754599e+09
# 75              1760013000            1760013000                1.752156e+09
# 76              1754424000            1754424000                1.754429e+09
# 77              1755088200            1755520200                1.747138e+09
# 78              1761049800            1761049800                1.746103e+09
#
#     earningsCallTimestampEnd  isEarningsDateEstimate  \
# 0               1.748466e+09                   False
# 1               1.754429e+09                   False
# 2               1.741095e+09                    True
# 3               1.753306e+09                    True
# 4               1.753909e+09                   False
# 5               1.754341e+09                   False
# 6               1.753391e+09                   False
# 7               1.753790e+09                   False
# 8               1.753360e+09                   False
# 9               1.753996e+09                   False
# 10              1.753909e+09                   False
# 11              1.753823e+09                   False
# 12              1.754428e+09                   False
# ...
# 70  -0.000008   0.024257                          3.333333
# 71   0.007064   0.072139                               0.0
# 72  -0.000486   0.029127                               0.0
# 73  -0.140406   0.109971                               0.0
# 74   0.033624   0.107177                               0.0
# 75    0.05036   0.119264                          3.333333
# 76   0.057262   0.077295                               0.0
# 77  -0.006371  31.622777                               0.0
# 78  -0.012113   0.079758                          6.666667
#
#    highest_stdev_state pct_regimes_last30_higher_than_avg_iv  ShannonEntropy  \
# 0                    2                                 100.0        0.506789
# 1                    2                              3.333333        0.135699
# 2                    1                                   0.0        1.026211
# 3                    2                                   0.0        0.047729
# 4                    2                                   0.0        1.030650
# 5                    1                                 100.0        1.691583
# 6                    2                                   0.0        0.590678
# 7                    1                                   0.0        0.803897
# 8                    2                              6.666667        0.318337
# 9                    1                                   0.0        1.307438
# 10                   2                                   0.0        0.956499
# 11                   2                                  50.0        0.549462
# 12                   2                                 100.0        0.890397
# 13                   1                                 100.0        0.956797
# 14                   1                                   0.0        0.494574
# 15                   2                                   0.0        1.063394
# 16                   0                                   0.0        1.317435
# 17                   2                                  50.0        0.151339
# 18                   0                                 100.0        0.709896
# 19                   2                                  50.0        1.413922
# 20                   2                                  50.0        1.133038
# 21                   2                                   0.0        0.418946
# 22                   1                             53.333333        1.004355
# 23                   1                                   0.0        0.432037
# 24                   2                             26.666667        1.495994
# 25                   2                                 100.0        0.990812
# 26                   2                                 100.0        0.138744
# 27                   2                                   0.0        1.173782
# 28                   1                                  30.0        1.372199
# 29                   0                                 100.0        1.248095
# 30                   1                                  50.0        1.373852
# 31                   2                                 100.0        1.011342
# 32                   1                              6.666667        0.632116
# 33                   0                             13.333333        0.620262
# 34                   1                                 100.0        1.047195
# 35                   1                              3.333333        0.953326
# 36                   2                                 100.0        0.576973
# 37                   2                                  50.0        0.339045
# 38                   2                                 100.0        0.731974
# 39                   2                                  50.0        0.651612
# 40                   0                                 100.0        0.943010
# 41                   2                                   0.0        1.390419
# 42                   2                              6.666667        0.047805
# 43                   2                                   0.0        0.197087
# 44                   2                              3.333333        0.513903
# 45                   0                                 100.0        0.892222
# 46                   0                                 100.0        0.088222
# 47                   2                                   0.0        1.134174
# 48                   2                                 100.0        1.152586
# 49                   1                                 100.0        1.298792
# 50                   2                                   0.0        0.977566
# 51                   2                                   0.0        0.835827
# 52                   2                                   0.0        0.949248
# 53                   2                                   0.0        1.079895
# 54                   2                             53.333333        1.343606
# 55                   0                                   0.0        0.835734
# 56                   2                                  50.0        1.033780
# 57                   2                             63.333333        1.149483
# 58                   2                                 100.0        1.031564
# 59                   2                                   0.0        0.753441
# 60                   2                                 100.0        0.703217
# 61                   2                                  50.0        0.910499
# 62                   0                              3.333333        0.009456
# 63                   0                                 100.0        0.329078
# 64                   2                                   0.0        0.684873
# 65                   0                                 100.0        1.397445
# 66                   2                                 100.0        1.098609
# 67                   2                                   0.0        0.342143
# 68                   2                              3.333333        0.601024
# 69                   2                                 100.0        0.120700
# 70                   1                                   0.0        0.068243
# 71                   2                                 100.0        0.127074
# 72                   1                                 100.0        1.019870
# 73                   2                                   0.0        1.127910
# 74                   2                                 100.0        0.163366
# 75                   2                                 100.0        1.095961
# 76                   2                                   0.0        1.276314
# 77                   2                                 100.0        0.604404
# 78                   2                                 100.0        0.352931
#
#     Regimeswitchprob  Regimeswitchcount  ADF_Pvalue  \
# 0               0.06                  4    0.446920
# 1               0.58                 20    0.155076
# 2               1.89                 37    0.309914
# 3               0.10                  6    0.607585
# 4               0.08                  5    0.075679
# 5               0.00                  0    0.498230
# 6               0.12                  6    0.400942
# 7               0.21                 11    0.234365
# 8               0.17                  8    0.574482
# 9               0.00                  0    0.452373
# 10              0.57                 25    0.279035
# 11              0.06                  3    0.812914
# 12              0.06                  2    0.361897
# 13              0.08                  4    0.386579
# 14              0.18                  9    0.455966
# 15              0.44                 15    0.585130
# 16              0.00                  0    0.876614
# 17              0.11                  6    0.755308
# 18              0.01                  0    0.806709
# 19              0.20                 11    0.489575
# 20              0.08                  2    0.116375
# 21              0.08                  4    0.620926
# 22              0.29                 13    0.083093
# 23              0.23                  8    0.617333
# 24              0.44                 13    0.805828
# 25              0.02                  0    0.832597
# 26              0.09                  4    0.768925
# 27              0.03                  2    0.077495
# 28              0.32                 15    0.868084
# 29              0.00                  0    0.124804
# 30              0.24                  5    0.034337
# 31              0.09                  4    0.530675
# 32              0.24                  8    0.334489
# 33              0.21                 10    0.507915
# 34              0.07                  5    0.227091
# 35              1.00                 29    0.823650
# 36              0.05                  2    0.003703
# 37              0.08                  4    0.271273
# 38              0.05                  3    0.084729
# 39              0.00                  0    0.370918
# 40              0.00                  0    0.120070
# 41              0.00                  0    0.717186
# 42              0.20                 10    0.506828
# 43              0.13                  6    0.939018
# 44              0.08                  4    0.175700
# 45              0.02                  0    0.925818
# 46              0.08                  4    0.823432
# 47              0.05                  2    0.219307
# 48              0.08                  4    0.762651
# 49              0.04                  3    0.310112
# 50              0.01                  0    0.396762
# 51              0.29                 12    0.606905
# 52              0.20                  8    0.353430
# 53              0.11                  6    0.447822
# 54              0.13                  4    0.244017
# 55              0.20                 10    0.537830
# 56              0.28                 12    0.411076
# 57              0.55                 19    0.330357
# 58              0.08                  4    0.325517
# 59              0.49                 23    0.431181
# 60              0.01                  0    0.533822
# 61              0.31                 12    0.235259
# 62              0.05                  2    0.879034
# 63              0.13                  6    0.514188
# 64              0.79                 32    0.651717
# 65              0.00                  0    0.275324
# 66              0.16                  8    0.763969
# 67              0.16                  8    0.795685
# 68              0.16                  8    0.903437
# 69              0.08                  4    0.291877
# 70              0.13                  6    0.808712
# 71              0.10                  4    0.800234
# 72              0.10                  4    0.868269
# 73              0.04                  3    0.135585
# 74              0.07                  3    0.570636
# 75              0.18                  8    0.037907
# 76              0.00                  1    0.870499
# 77              0.08                  5    0.276544
# 78              0.08                  5    0.410077
#
#                                AvgReturn_7d  Shannon/IV
# 0    Ticker
# NVDA    0.000005
# dtype: float64    1.417876
# 1    Ticker
# LCID    0.000113
# dtype: float64    0.131837
# 2    Ticker
# PLUG    0.000061
# dtype: float64    0.548454
# 3    Ticker
# TSLA   -0.000008
# dtype: float64    0.062997
# 4       Ticker
# F   -0.000003
# dtype: float64    2.127771
# 5    Ticker
# PLTR    0.000014
# dtype: float64    3.987127
# 6    Ticker
# INTC   -0.000006
# dtype: float64    0.426554
# 7    Ticker
# SOFI    0.000007
# dtype: float64    1.140148
# 8     Ticker
# AAL   -0.000023
# dtype: float64    0.431184
# 9    Ticker
# AAPL    0.000005
# dtype: float64    4.200115
# 10   Ticker
# APLD    0.000041
# dtype: float64    0.863715
# 11   Ticker
# MARA   -0.000043
# dtype: float64    0.680760
# 12    Ticker
# AMD    0.000016
# dtype: float64    1.913192
# 13   Ticker
# SMCI   -0.000002
# dtype: float64    1.571378
# 14   Ticker
# HOOD    0.000008
# dtype: float64    0.698600
# 15    Ticker
# NIO    0.000057
# dtype: float64    1.207221
# 16   Ticker
# AMZN    0.000012
# dtype: float64    3.112859
# 17  Ticker
# GOOGL    0.000017
# dtype: float64    0.408147
# 18    Ticker
# BAC    0.000019
# dtype: float64    3.065513
# 19   Ticker
# RIOT    0.000062
# dtype: float64    1.625889
# 20    Ticker
# SNAP    0.00001
# dtype: float64    1.821388
# 21   Ticker
# VALE    0.000019
# dtype: float64    0.993045
# 22     Ticker
# QS    0.000075
# dtype: float64    0.765221
# 23     Ticker
# CLF    0.00007
# dtype: float64    0.603553
# 24   Ticker
# BTBT   -0.000024
# dtype: float64    1.103670
# 25   Ticker
# AMCR    0.000012
# dtype: float64    3.131388
# 26      Ticker
# T    0.000013
# dtype: float64    0.485712
# 27   Ticker
# ITUB    0.000003
# dtype: float64    3.283965
# 28   Ticker
# QUBT   -0.000023
# dtype: float64    1.495613
# 29   Ticker
# HBAN    0.000001
# dtype: float64    4.500055
# 30   Ticker
# CLSK   -0.000006
# dtype: float64    1.503012
# 31    Ticker
# CCL    0.000008
# dtype: float64    2.301335
# 32    Ticker
# RUN   -0.000006
# dtype: float64    0.623989
# 33     Ticker
# HL    0.000004
# dtype: float64    1.051563
# 34     Ticker
# MU   -0.000021
# dtype: float64    2.370738
# 35   Ticker
# SBET   -0.000103
# dtype: float64    0.244663
# 36   Ticker
# UBER   -0.000004
# dtype: float64    1.671019
# 37   Ticker
# AVGO    0.000013
# dtype: float64    0.786804
# 38   Ticker
# MRVL    0.000025
# dtype: float64    1.418565
# 39   Ticker
# MSFT    0.000005
# dtype: float64    2.242567
# 40   Ticker
# CSCO    0.000005
# dtype: float64    5.283711
# 41  Ticker
# CMCSA    0.000006
# dtype: float64    2.681311
# 42   Ticker
# STLA    0.000007
# dtype: float64    0.037772
# 43    Ticker
# NOK   -0.000031
# dtype: float64    0.277220
# 44    Ticker
# HPE    0.000002
# dtype: float64    0.944761
# 45    Ticker
# WFC    0.000023
# dtype: float64    3.992441
# 46     Ticker
# VZ    0.000017
# dtype: float64    0.478282
# 47    Ticker
# ADT    0.000014
# dtype: float64    2.399548
# 48    Ticker
# NKE    0.000015
# dtype: float64    3.233499
# 49   Ticker
# LYFT   -0.000014
# dtype: float64    2.942359
# 50    Ticker
# KEY    0.000012
# dtype: float64    2.560131
# 51     Ticker
# RKT    0.00004
# dtype: float64    0.879635
# 52    Ticker
# CSX    0.000016
# dtype: float64    2.283516
# 53   Ticker
# NCLH    0.000009
# dtype: float64    1.843008
# 54    Ticker
# GME    0.000001
# dtype: float64    2.536112
# 55    Ticker
# CDE    0.000007
# dtype: float64    1.466223
# 56   Ticker
# COIN    0.000005
# dtype: float64    1.639628
# 57     Ticker
# MP    0.000011
# dtype: float64    1.500085
# 58   Ticker
# BABA    0.000018
# dtype: float64    2.348221
# 59      Ticker
# U    0.000013
# dtype: float64    0.979087
# 60      Ticker
# C    0.000017
# dtype: float64    2.883172
# 61   Ticker
# ASTS    0.000057
# dtype: float64    1.066761
# 62    Ticker
# CMG   -0.000057
# dtype: float64    0.010479
# 63    Ticker
# FCX    0.000005
# dtype: float64    0.884437
# 64    Ticker
# KSS    0.000241
# dtype: float64    0.459875
# 65   Ticker
# ORCL    0.000013
# dtype: float64    3.931204
# 66   Ticker
# MSTR   -0.000027
# dtype: float64    2.205721
# 67    Ticker
# NEM    0.000022
# dtype: float64    0.332456
# 68    Ticker
# LUV   -0.000042
# dtype: float64    0.509476
# 69    Ticker
# TSM    0.000009
# dtype: float64    0.366781
# 70    Ticker
# DOW   -0.000039
# dtype: float64    0.021383
# 71   Ticker
# INFY   -0.000016
# dtype: float64    0.491329
# 72    Ticker
# TTD    0.000014
# dtype: float64    2.323323
# 73   Ticker
# PATH   -0.000002
# dtype: float64    2.110176
# 74   Ticker
# PINS    0.000012
# dtype: float64    0.433942
# 75     Ticker
# DAL   -0.00001
# dtype: float64    2.765857
# 76   Ticker
# CPNG   -0.000012
# dtype: float64    2.711474
# 77     Ticker
# JD    0.000021
# dtype: float64    1.357985
# 78     Ticker
# GM   -0.000003
# dtype: float64    1.082829

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio
from ib_insync import *
import pandas as pd
import numpy as np
import ta
import plotly.graph_objects as go

"""
Filter parameters
-----------------
VOL_WINDOW:       ATR period (bars) for volatility calculation (consider higher for daily)
VOL_THRESHOLD:    Minimum ATR percent (ATR/close) for a bar to be considered volatile enough for trading (e.g., 0.01 = 1%)
REGIME_THRESHOLD: Rolling mean of returns must be above this (e.g., -0.1) to be considered "trending" regime
ADX_PERIOD:       ADX calculation period (bars)
ADX_THRESHOLD:    Minimum ADX value to confirm market is trending (20 = classic)
SMA_PERIOD:       SMA bars for trend filter (only long if above, short if below)
"""

# ========= CHART SETTINGS =========
BAR_SIZE = '1 day'      # IBKR bar size for daily candles
DURATION = '5 Y'        # How far back to get data (e.g., '5 Y' = 5 years)
NUM_BARS = 2000         # Approximate daily bars in 5 years
# ================================

# Filter tuning (adjust to your needs)
VOL_WINDOW       = 30        # ATR lookback period (bars); for daily, 14-30 is common
VOL_THRESHOLD    = 0.001     # Minimum ATR% for volatility filter (e.g., 0.01=1%)
REGIME_THRESHOLD = -0.1      # Regime filter threshold
ADX_PERIOD       = 14        # ADX lookback window (bars)
ADX_THRESHOLD    = 20        # Minimum ADX to allow signals (trend filter)
SMA_PERIOD       = 200       # SMA filter period (bars)

EXCHANGE    = 'SMART'
CURRENCY    = 'USD'
LOOKAHEAD   = 4
K_NEIGHBORS = 8

FEATURES = ['RSI', 'ADX', 'CCI', 'MACD']


# ==== Data Fetch Function ====
async def fetch_ibkr_stock(symbol, exchange, currency, bar_size, duration, num_bars):
    """Fetches OHLCV bars from IBKR using specified bar size/duration."""
    ib = IB()
    await ib.connectAsync('127.0.0.1', 7497, clientId=np.random.randint(1000, 10000))
    contract = Stock(symbol, exchange, currency)
    await ib.qualifyContractsAsync(contract)
    bars = await ib.reqHistoricalDataAsync(
        contract=contract,
        endDateTime='',
        durationStr=duration,
        barSizeSetting=bar_size,
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1,
        keepUpToDate=False
    )
    df = util.df(bars)
    df.set_index('date', inplace=True)
    df = df.tail(num_bars)
    ib.disconnect()
    return df


# ==== ML Functions and Filters ====
def lorentzian_distance(a, b):
    return np.sum(np.log(1 + np.abs(a - b)))


def volatility_filter(df, vol_window, vol_thresh):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=vol_window).average_true_range()
    atr_pct = atr / df['close']
    return atr_pct > vol_thresh


def regime_filter(df, threshold):
    close_returns = df['close'].pct_change()
    regime = close_returns.rolling(window=20).mean()
    return regime > threshold


def adx_filter(df, adx_period, adx_threshold):
    adx = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=adx_period).adx()
    return adx > adx_threshold


def classify_lorentzian_knn_with_filters(
        df, features, sma_period,
        vol_window, vol_thresh,
        regime_thresh, adx_period, adx_thresh,
        n_neighbors=8, lookahead=4, max_bars_back=500):
    pred = np.full(len(df), np.nan)
    neighbors_info = {}

    closes = df['close'].values
    feature_mat = df[features].values
    sma = df['SMA'].values

    vol_filter = volatility_filter(df, vol_window, vol_thresh)
    regime_filt = regime_filter(df, regime_thresh)
    adx_filt = adx_filter(df, adx_period, adx_thresh)

    length = len(df)

    # Main loop - exclude last 'lookahead' bars
    for idx in range(max_bars_back, length - lookahead):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    # Explicit classification for last 'lookahead' bars
    for idx in range(length - lookahead, length):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    return pred, neighbors_info


# ==== Process symbols from filterdf ====
async def process_symbols_with_knn(filterdf):
    filterdf['pct_buy_last_8d'] = np.nan
    filterdf['pct_sell_last_8d'] = np.nan

    for i, row in filterdf.iterrows():
        symbol = row['symbol']  # Adjust if your symbol column is named differently
        print(f"Processing {symbol} ...")

        df = await fetch_ibkr_stock(symbol, EXCHANGE, CURRENCY, BAR_SIZE, DURATION, NUM_BARS)

        # Feature Engineering
        df['RSI'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
        df['ADX'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
        df['CCI'] = ta.trend.CCIIndicator(df['high'], df['low'], df['close'], window=20).cci()
        df['SMA'] = ta.trend.SMAIndicator(df['close'], window=SMA_PERIOD).sma_indicator()
        macd_ind = ta.trend.MACD(df['close'], window_slow=26, window_fast=12, window_sign=9)
        df['MACD'] = macd_ind.macd()
        df['MACD_signal'] = macd_ind.macd_signal()
        df['MACD_hist'] = macd_ind.macd_diff()
        df = df.dropna().reset_index()

        preds, _ = classify_lorentzian_knn_with_filters(
            df, FEATURES, SMA_PERIOD, VOL_WINDOW, VOL_THRESHOLD,
            REGIME_THRESHOLD, ADX_PERIOD, ADX_THRESHOLD,
            n_neighbors=K_NEIGHBORS, lookahead=LOOKAHEAD, max_bars_back=500
        )
        df['raw_pred'] = preds

        # Calculate % buy and sell signals in the last 8 days of predictions
        last_8 = df['raw_pred'].tail(8)
        pct_buy = (last_8 == 1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0
        pct_sell = (last_8 == -1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0

        filterdf.at[i, 'pct_buy_last_8d'] = pct_buy
        filterdf.at[i, 'pct_sell_last_8d'] = pct_sell

    return filterdf


# --- Example usage ---
# Make sure you have your filter dataframe loaded with a 'symbol' column
# Example:
# filterdf = pd.DataFrame({'symbol': ['GOOG', 'AAPL', 'MSFT']})

if __name__ == '__main__':
    import sys

    # Replace or load your filter dataframe here
    # For demo, you can define it manually or read from CSV

    df_results = asyncio.run(process_symbols_with_knn(filterdf))
    print(df_results[['symbol', 'pct_buy_last_8d', 'pct_sell_last_8d']])
# Out:
# Processing NVDA ...
# Processing LCID ...
# Processing PLUG ...
# Processing TSLA ...
# Processing F ...
# Processing PLTR ...
# Processing INTC ...
# Processing SOFI ...
# Processing AAL ...
# Processing AAPL ...
# Processing APLD ...
# Processing MARA ...
# Processing AMD ...
# Processing SMCI ...
# Processing HOOD ...
# Processing NIO ...
# Processing AMZN ...
# Processing GOOGL ...
# Processing BAC ...
# Processing RIOT ...
# Processing SNAP ...
# Processing VALE ...
# Processing QS ...
# Processing CLF ...
# Processing BTBT ...
# Processing AMCR ...
# Processing T ...
# Processing ITUB ...
# Processing QUBT ...
# Processing HBAN ...
# Processing CLSK ...
# Processing CCL ...
# Processing RUN ...
# Processing HL ...
# Processing MU ...
# Processing SBET ...
# Processing UBER ...
# Processing AVGO ...
# Processing MRVL ...
# Processing MSFT ...
# Processing CSCO ...
# Processing CMCSA ...
# Processing STLA ...
# Processing NOK ...
# Processing HPE ...
# Processing WFC ...
# Processing VZ ...
# Processing ADT ...
# Processing NKE ...
# Processing LYFT ...
# Processing KEY ...
# Processing RKT ...
# Processing CSX ...
# Processing NCLH ...
# Processing GME ...
# Processing CDE ...
# Processing COIN ...
# Processing MP ...

# %%
filterdf
# Out:
#   language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 5    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#   customPriceAlertConfidence  hasPrePostMarketData  \
# 0                       HIGH                  True
# 1                       HIGH                  True
# 2                        LOW                  True
# 3                       HIGH                  True
# 4                        LOW                  True
# 5                       HIGH                  True
# 6                       HIGH                  True
# 7                       HIGH                  True
# 8                       HIGH                  True
# 9                       HIGH                  True
#
#    firstTradeDateMilliseconds  priceHint  postMarketChangePercent  \
# 0                917015400000          2                -0.089213
# 1               1600435800000          4                -0.334448
# 2                941203800000          4                -0.016945
# 3               1277818200000          2                 0.569938
# 4                 76253400000          2                 0.177615
# 5               1601472600000          2                -0.051661
# 6                322151400000          2                -4.595670
# 7               1609770600000          2                 0.140395
# 8               1127827800000          2                 0.698080
# 9                345479400000          2                 0.135670
#
#    postMarketTime  postMarketPrice  postMarketChange  regularMarketChange  \
# 0      1753401598         173.5850         -0.154999             2.960010
# 1      1753401588           2.9800         -0.010000            -0.090000
# 2      1753401569           1.7697         -0.000300            -0.040000
# 3      1753401597         307.0400          1.740020           -27.260000
# 4      1753401598          11.2800          0.019999            -0.120000
# 5      1753401599         154.7800         -0.080002             0.240997
# 6      1753401597          21.5900         -1.040000            -0.860001
# 7      1753401597          21.5402          0.030199            -0.049999
# 8      1753401598          11.5400          0.080000            -1.220000
# 9      1753401580         214.0500          0.290009            -0.389999
#
#    regularMarketTime  regularMarketPrice  regularMarketDayHigh  \
# 0         1753387200              173.74              173.8300
# 1         1753387202                2.99                3.0700
# 2         1753387200                1.77                1.9900
# 3         1753387201              305.30              310.0650
# 4         1753387202               11.26               11.4275
# 5         1753387200              154.86              155.6300
# 6         1753387201               22.63               23.5748
# 7         1753387201               21.51               22.0100
# 8         1753387201               11.46               11.8400
# 9         1753387201              213.76              215.6900
#
#   regularMarketDayRange  regularMarketDayLow  regularMarketVolume  \
# 0        171.3 - 173.83              171.300            127727175
# 1           2.91 - 3.07                2.910             92868184
# 2           1.74 - 1.99                1.740            102148398
# 3      300.41 - 310.065              300.410            156024571
# 4       11.23 - 11.4275               11.230             55759288
# 5      152.575 - 155.63              152.575             38335911
# 6        22.6 - 23.5748               22.600            113262008
# 7         21.37 - 22.01               21.370             45691842
# 8         11.33 - 11.84               11.330            119355100
# 9       213.53 - 215.69              213.530             45773373
#
#    regularMarketPreviousClose  bidSize  askSize     market   messageBoardId  \
# 0                     170.780        3        1  us_market      finmb_32307
# 1                       3.080       67      120  us_market   finmb_83747444
# 2                       1.810       25        4  us_market     finmb_405483
# 3                     332.560        1        2  us_market   finmb_27444752
# 4                      11.380      240      603  us_market     finmb_106335
# 5                     154.619        2        2  us_market   finmb_43580005
# 6                      23.490       10       12  us_market      finmb_21127
# 7                      21.560        4        2  us_market  finmb_141582707
# 8                      12.680        1        4  us_market     finmb_168569
# 9                     214.150        1        1  us_market      finmb_24937
#
#   fullExchangeName                      longName financialCurrency  \
# 0         NasdaqGS            NVIDIA Corporation               USD
# 1         NasdaqGS             Lucid Group, Inc.               USD
# 2         NasdaqCM               Plug Power Inc.               USD
# 3         NasdaqGS                   Tesla, Inc.               USD
# 4             NYSE            Ford Motor Company               USD
# 5         NasdaqGS    Palantir Technologies Inc.               USD
# 6         NasdaqGS             Intel Corporation               USD
# 7         NasdaqGS       SoFi Technologies, Inc.               USD
# 8         NasdaqGS  American Airlines Group Inc.               USD
# 9         NasdaqGS                    Apple Inc.               USD
#
#    regularMarketOpen  averageDailyVolume3Month  averageDailyVolume10Day  \
# 0            172.450                 196315659                162624090
# 1              3.030                 153236545                234252100
# 2              1.810                 124092575                 79213890
# 3            310.065                 109067524                 90238430
# 4             11.310                  93631736                 72427910
# 5            153.980                  83587919                 53835260
# 6             23.490                  77592257                 64334660
# 7             21.710                  68585716                 59838940
# 8             11.800                  60525829                 72956480
# 9            213.900                  53248283                 45619320
#
#   corporateActions  fiftyTwoWeekLowChange  fiftyTwoWeekLowChangePercent  \
# 0               []              87.120000                      1.005772
# 1               []               1.060000                      0.549223
# 2               []               1.080000                      1.565217
# 3               []             123.299990                      0.677473
# 4               []               2.820001                      0.334123
# 5               []             133.630000                      6.294395
# 6               []               4.959999                      0.280702
# 7               []              15.500000                      2.579035
# 8               []               2.960000                      0.348235
# 9               []              44.549988                      0.263282
#
#   fiftyTwoWeekRange  fiftyTwoWeekHighChange  fiftyTwoWeekHighChangePercent  \
# 0    86.62 - 174.25               -0.509995                      -0.002927
# 1       1.93 - 4.43               -1.440000                      -0.325056
# 2       0.69 - 3.32               -1.550000                      -0.466867
# 3    182.0 - 488.54             -183.240020                      -0.375077
# 4      8.44 - 11.97               -0.710000                      -0.059315
# 5    21.23 - 155.68               -0.819992                      -0.005267
# 6     17.67 - 31.56               -8.930000                      -0.282953
# 7      6.01 - 22.74               -1.229999                      -0.054090
# 8        8.5 - 19.1               -7.640000                      -0.400000
# 9    169.21 - 260.1              -46.340010                      -0.178162
#
#    fiftyTwoWeekChangePercent  dividendDate  earningsTimestamp  \
# 0                  53.670620  1.751501e+09         1756324800
# 1                 -11.538464           NaN         1754424000
# 2                 -28.915660           NaN         1745843400
# 3                  38.899006           NaN         1753300800
# 4                   0.625563  1.748822e+09         1753905600
# 5                 469.757170           NaN         1754337600
# 6                 -27.814991  1.725149e+09         1753387200
# 7                 190.283390           NaN         1753792200
# 8                   7.909608  1.582070e+09         1753360200
# 9                  -1.926959  1.747267e+09         1753992000
#
#    earningsTimestampStart  earningsTimestampEnd  earningsCallTimestampStart  \
# 0              1756324800            1756324800                  1748466000
# 1              1754424000            1754424000                  1754429400
# 2              1754483400            1754915400                  1741095000
# 3              1761163200            1761163200                  1753306200
# 4              1753905600            1753905600                  1753909200
# 5              1754337600            1754337600                  1754341200
# 6              1753387200            1753387200                  1753390800
# 7              1753792200            1753792200                  1753790400
# 8              1753360200            1753360200                  1753360200
# 9              1753992000            1753992000                  1753995600
#
#    earningsCallTimestampEnd  isEarningsDateEstimate  \
# 0                1748466000                   False
# 1                1754429400                   False
# 2                1741095000                    True
# 3                1753306200                    True
# 4                1753909200                   False
# 5                1754341200                   False
# 6                1753390800                   False
# 7                1753790400                   False
# 8                1753360200                   False
# 9                1753995600                   False
#
#    trailingAnnualDividendRate  trailingPE  dividendRate  \
# 0                       0.040   55.864956          0.04
# 1                       0.000         NaN           NaN
# 2                       0.000         NaN           NaN
# 3                       0.000  173.465900           NaN
# 4                       0.600    9.008000          0.75
# 5                       0.000  673.304300           NaN
# 6                       0.245         NaN           NaN
# 7                       0.000   50.023254           NaN
# 8                       0.000   11.460000           NaN
# 9                       1.000   33.295948          1.04
#
#    trailingAnnualDividendYield marketState  epsTrailingTwelveMonths  \
# 0                     0.000234    POSTPOST                     3.11
# 1                     0.000000    POSTPOST                    -1.19
# 2                     0.000000    POSTPOST                    -2.43
# 3                     0.000000    POSTPOST                     1.76
# 4                     0.052724    POSTPOST                     1.25
# 5                     0.000000    POSTPOST                     0.23
# 6                     0.010430    POSTPOST                    -4.48
# 7                     0.000000    POSTPOST                     0.43
# 8                     0.000000    POSTPOST                     1.00
# 9                     0.004670    POSTPOST                     6.42
#
#    epsForward  epsCurrentYear  priceEpsCurrentYear  sharesOutstanding  \
# 0        4.12         4.31755            40.240414        24387600384
# 1       -0.88        -0.89314            -3.347739         3050259968
# 2       -0.57        -0.61081            -2.897792         1147340032
# 3        3.24         1.72259           177.233110         3220960000
# 4        1.75         1.12505            10.008445         3905700096
# 5        0.47         0.58178           266.183070         2262909952
# 6        0.97         0.27347            82.751300         4361999872
# 7        0.29         0.28256            76.125430         1105360000
# 8        2.02         0.78348            14.627049          659512000
# 9        8.31         7.20281            29.677307        14935799808
#
#    bookValue  fiftyDayAverage  fiftyDayAverageChange  \
# 0      3.438         149.4882              24.251800
# 1      1.044           2.4094               0.580600
# 2      1.900           1.2170               0.553000
# 3     22.672         326.3512             -21.051208
# 4     11.225          10.8424               0.417601
# 5      2.299         136.3284              18.531600
# 6     22.869          21.7000               0.929998
# 7      6.049          16.4870               5.023001
# 8     -6.048          11.5848              -0.124800
# 9      4.471         205.3852               8.374802
#
#    fiftyDayAverageChangePercent  twoHundredDayAverage  \
# 0                      0.162232            133.420650
# 1                      0.240973              2.540325
# 2                      0.454396              1.683650
# 3                     -0.064505            319.291600
# 4                      0.038516             10.320500
# 5                      0.135934             93.127450
# 6                      0.042857             21.819450
# 7                      0.304664             14.195200
# 8                     -0.010773             13.301550
# 9                      0.040776            222.090650
#
#    twoHundredDayAverageChange  twoHundredDayAverageChangePercent  \
# 0                   40.319350                           0.302197
# 1                    0.449675                           0.177015
# 2                    0.086350                           0.051287
# 3                  -13.991608                          -0.043821
# 4                    0.939500                           0.091032
# 5                   61.732550                           0.662882
# 6                    0.810549                           0.037148
# 7                    7.314800                           0.515301
# 8                   -1.841550                          -0.138446
# 9                   -8.330658                          -0.037510
#
#        marketCap   forwardPE  priceToBook  sourceInterval  \
# 0  4237101891584   42.169907    50.535200              15
# 1     9120277504   -3.397727     2.863985              15
# 2     2030791808   -3.105263     0.931579              15
# 3   983359029248   94.228390    13.465948              15
# 4    44775952384    6.434286     1.003118              15
# 5   365455638528  329.489350    67.359720              15
# 6    98712051712   23.329895     0.989549              15
# 7    23776292864   74.172420     3.555960              15
# 8     7558007296    5.673267    -1.894841              15
# 9  3192676417536   25.723223    47.810330              15
#
#    exchangeDataDelayedBy exchangeTimezoneName exchangeTimezoneShortName  \
# 0                      0     America/New_York                       EDT
# 1                      0     America/New_York                       EDT
# 2                      0     America/New_York                       EDT
# 3                      0     America/New_York                       EDT
# 4                      0     America/New_York                       EDT
# 5                      0     America/New_York                       EDT
# 6                      0     America/New_York                       EDT
# 7                      0     America/New_York                       EDT
# 8                      0     America/New_York                       EDT
# 9                      0     America/New_York                       EDT
#
#    gmtOffSetMilliseconds                                    prevName  \
# 0              -14400000                            Usual Stablecoin
# 1              -14400000                                         NaN
# 2              -14400000                                         NaN
# 3              -14400000                                         NaN
# 4              -14400000                                         NaN
# 5              -14400000                                         NaN
# 6              -14400000                                         NaN
# 7              -14400000  Social Capital Hedosophia Holdings Corp. V
# 8              -14400000                                         NaN
# 9              -14400000                                         NaN
#
#   nameChangeDate  esgPopulated  tradeable  cryptoTradeable currency     bid  \
# 0     2025-07-24         False      False            False      USD  172.00
# 1            NaN         False      False            False      USD    2.95
# 2            NaN         False      False            False      USD    1.74
# 3            NaN         False      False            False      USD  305.15
# 4            NaN         False      False            False      USD   11.27
# 5            NaN         False      False            False      USD  154.68
# 6            NaN         False      False            False      USD   22.52
# 7     2025-07-24         False      False            False      USD   21.00
# 8            NaN         False      False            False      USD   11.44
# 9            NaN         False      False            False      USD  203.20
#
#       ask exchange  fiftyTwoWeekHigh  fiftyTwoWeekLow averageAnalystRating  \
# 0  175.00      NMS            174.25            86.62     1.4 - Strong Buy
# 1    2.99      NMS              4.43             1.93           3.1 - Hold
# 2    1.90      NCM              3.32             0.69           2.9 - Hold
# 3  310.00      NMS            488.54           182.00           2.6 - Hold
# 4   11.28      NYQ             11.97             8.44           3.0 - Hold
# 5  155.13      NMS            155.68            21.23           3.0 - Hold
# 6   23.17      NMS             31.56            17.67           3.0 - Hold
# 7   21.52      NMS             22.74             6.01           2.8 - Hold
# 8   11.95      NMS             19.10             8.50            2.1 - Buy
# 9  224.70      NMS            260.10           169.21            2.0 - Buy
#
#    dividendYield                      shortName  regularMarketChangePercent  \
# 0           0.02             NVIDIA Corporation                    1.733230
# 1            NaN              Lucid Group, Inc.                   -2.922080
# 2            NaN               Plug Power, Inc.                   -2.209940
# 3            NaN                    Tesla, Inc.                   -8.197020
# 4           6.59             Ford Motor Company                   -1.054480
# 5            NaN     Palantir Technologies Inc.                    0.155865
# 6            NaN              Intel Corporation                   -3.661140
# 7            NaN        SoFi Technologies, Inc.                   -0.231907
# 8            NaN  American Airlines Group, Inc.                   -9.621450
# 9           0.49                     Apple Inc.                   -0.182115
#
#          displayName symbol ipoExpectedDate prev_day_price prev_day_volume  \
# 0             NVIDIA   NVDA             NaN     170.779999       154082200
# 1              Lucid   LCID      2021-07-26           3.08       181511400
# 2         Plug Power   PLUG             NaN           1.81        68101300
# 3              Tesla   TSLA             NaN     332.559998        92553800
# 4                NaN      F             NaN          11.38        76163200
# 5           Palantir   PLTR      2024-11-26     154.630005        48062000
# 6              Intel   INTC             NaN          23.49        68711700
# 7               SoFi   SOFI      2021-06-01      21.559999        49653700
# 8  American Airlines    AAL             NaN          12.68        75685400
# 9              Apple   AAPL             NaN     214.149994        46989300
#
#          price_volume historical_volatility    avg_iv iv/hv_ratio hmm_mean_0  \
# 0  26314157927.911377              0.260627  0.357428    1.371416   0.000174
# 1    559055098.151779              1.286375  1.029299    0.800155  -0.008318
# 2    123263349.103212              1.409719  1.871097    1.327284  -0.034128
# 3  30779691502.038574              0.553936  0.757633    1.367727  -0.007668
# 4    866737224.716187              0.297705  0.484380    1.627045   0.001211
# 5   7431827294.677734              0.515426  0.424261    0.823128  -0.018809
# 6    1614037817.27314              0.390701  1.384767    3.544311  -0.011668
# 7   1070533745.482063              0.394418  0.705081     1.78765  -0.027911
# 8    959690895.097351              0.635021  0.738285    1.162615   0.002299
# 9  10062758308.200073              0.147295  0.311286    2.113346  -0.058443
#
#   hmm_std_0 hmm_mean_1 hmm_std_1 hmm_mean_2 hmm_std_2  \
# 0  0.033218   0.008021  0.024142  -0.011813  0.083891
# 1   0.03996   0.004575  0.051109   0.302688  0.106872
# 2   0.08256   0.106846   0.08976  -0.014782  0.044449
# 3  0.043542   0.002891  0.040313  -0.003716  0.141254
# 4  0.021062   0.002663  0.025357  -0.010268  0.063482
# 5  0.058961   0.014972  0.088652   0.008437   0.03426
# 6  0.031183   0.005961  0.031274   0.025305  0.083247
# 7   0.04994  -0.003732  0.078049   0.008171  0.032218
# 8  0.029387   -0.01069  0.036393   0.020434  0.116457
# 9   0.05445   0.077986  0.102169   0.000149  0.019172
#
#   pct_last30_in_highest_stdev_state highest_stdev_state  \
# 0                               0.0                   2
# 1                          3.333333                   2
# 2                         16.666667                   1
# 3                               0.0                   2
# 4                               0.0                   2
# 5                               0.0                   1
# 6                               0.0                   2
# 7                               0.0                   1
# 8                          6.666667                   2
# 9                               0.0                   1
#
#   pct_regimes_last30_higher_than_avg_iv  ShannonEntropy  Regimeswitchprob  \
# 0                                 100.0        0.506789              0.07
# 1                              3.333333        0.135699              0.58
# 2                                   0.0        1.026211              0.48
# 3                                   0.0        0.047729              0.10
# 4                                   0.0        1.030650              0.06
# 5                                 100.0        1.691583              0.00
# 6                                   0.0        0.590678              0.12
# 7                                   0.0        0.803897              0.21
# 8                              6.666667        0.318337              0.17
# 9                                   0.0        1.307438              0.00
#
#    Regimeswitchcount  ADF_Pvalue                            AvgReturn_7d  \
# 0                  4    0.446920  Ticker
# NVDA    0.000005
# dtype: float64
# 1                 20    0.155076  Ticker
# LCID    0.000113
# dtype: float64
# 2                 17    0.309914  Ticker
# PLUG    0.000061
# dtype: float64
# 3                  6    0.607585  Ticker
# TSLA   -0.000008
# dtype: float64
# 4                  5    0.075679     Ticker
# F   -0.000003
# dtype: float64
# 5                  0    0.498230  Ticker
# PLTR    0.000014
# dtype: float64
# 6                  6    0.400942  Ticker
# INTC   -0.000006
# dtype: float64
# 7                 11    0.234365  Ticker
# SOFI    0.000007
# dtype: float64
# 8                  8    0.574482   Ticker
# AAL   -0.000023
# dtype: float64
# 9                  0    0.452373  Ticker
# AAPL    0.000005
# dtype: float64
#
#    Shannon/IV  pct_buy_last_8d  pct_sell_last_8d
# 0    1.417876             62.5               0.0
# 1    0.131837             50.0               0.0
# 2    0.548454             12.5              12.5
# 3    0.062997              0.0               0.0
# 4    2.127771             12.5               0.0
# 5    3.987127             12.5               0.0
# 6    0.426554              0.0               0.0
# 7    1.140148             50.0               0.0
# 8    0.431184              0.0              62.5
# 9    4.200115              0.0               0.0

# %%
import datetime

today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-07-24.csv
