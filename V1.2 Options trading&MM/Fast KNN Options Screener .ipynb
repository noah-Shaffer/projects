# %% [markdown]
# Do a random forest return predictor for long time equity screens, maybe including rates/ sectors / commodities / geoploitic indicators.
# Find the % of regimes in the last 30 days that have a higher volatility than the current IV
# Add trend in shannon entropy or/and regime percentages to evaluate recessions / hostile environments beginning. could also look at earnings timestamps affecting options prices

# %% [markdown]
# Want to find stocks with a low hv/iv high regime % in highest stdev state, and high # of days with stdev above avg iv on options

# %%
import yfinance as yf 
from yfinance import EquityQuery
import numpy as np
import pandas as pd
import time

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
from hmmlearn.hmm import GaussianHMM
from scipy.stats import entropy
from statsmodels.tsa.stattools import adfuller
from yfinance import EquityQuery, screen
from tqdm import tqdm

# ---------------- CONFIG ----------------
num_stocks = 250
max_workers = 6  # To reduce rate limit risk
hv_window = 20
price_volume_threshold = 100_000_000
batch_delay = 1.0  # seconds between batches
option_retry_delay = 5  # seconds retry delay for options fetch
N = 252  # annualization factor for volatility

# ---------------- HELPERS ----------------

def find_closest_value(data_list, target_value):
    if len(data_list) == 0:
        return None
    return min(data_list, key=lambda x: abs(x - target_value))

def filter_special_expiry(expiry_list):
    return sorted(expiry_list)[:2]

def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]
    return entropy(hist, base=2)

def hmm_regime_switch_prob_and_count(returns, n_states=2):
    returns = returns.values.reshape(-1, 1)
    model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=100)
    model.fit(returns)
    hidden_states = model.predict(returns)
    last_state = hidden_states[-1]
    transmat = model.transmat_
    switch_prob = 1 - transmat[last_state, last_state]
    regime_switch_count = np.sum(hidden_states[1:] != hidden_states[:-1])
    return switch_prob, regime_switch_count

def fit_hmm_and_stats(returns, n_states=3):
    model = GaussianHMM(
        n_components=n_states,
        covariance_type="diag",
        n_iter=500,
        tol=1e-2,
        random_state=42,
        verbose=False
    )
    X = returns.values.reshape(-1, 1)
    model.fit(X)
    hidden_states = model.predict(X)
    means = model.means_.flatten()
    stds = np.sqrt(np.array([np.diag(cov)[0] for cov in model.covars_]))
    return hidden_states, means, stds

def pct_regimes_higher_than_iv(hidden_states, stds, avg_iv):
    last30 = hidden_states[-30:]
    stds_annualized = stds * np.sqrt(N)
    last30_vols_annualized = stds_annualized[last30]
    pct_higher = np.mean(last30_vols_annualized > avg_iv) * 100
    return pct_higher

def hmm_analysis(returns, avg_iv):
    if returns is None or avg_iv is None:
        return {
            "hmm_mean_0": None, "hmm_std_0": None,
            "hmm_mean_1": None, "hmm_std_1": None,
            "hmm_mean_2": None, "hmm_std_2": None,
            "pct_last30_in_highest_stdev_state": None,
            "highest_stdev_state": None,
            "pct_regimes_last30_higher_than_avg_iv": None
        }
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    high_stdev_state = int(np.argmax(stds))
    last30 = hidden_states[-30:]
    pct_high = np.mean(last30 == high_stdev_state) * 100
    pct_regimes_higher = pct_regimes_higher_than_iv(hidden_states, stds, avg_iv)
    return {
        "hmm_mean_0": means[0], "hmm_std_0": stds[0],
        "hmm_mean_1": means[1], "hmm_std_1": stds[1],
        "hmm_mean_2": means[2], "hmm_std_2": stds[2],
        "pct_last30_in_highest_stdev_state": pct_high,
        "highest_stdev_state": high_stdev_state,
        "pct_regimes_last30_higher_than_avg_iv": pct_regimes_higher
    }

def hmm_regime_minute_analysis(ticker):
    # Download last 7 days 1-min data
    try:
        df = yf.download(ticker, period="7d", interval="1m", progress=False)
        closes = df['Close'].dropna()
        if len(closes) < 1000:
            return np.nan, np.nan, np.nan, np.nan, np.nan
        log_returns = np.log(closes).diff().dropna()
        simple_returns = closes.pct_change().dropna()

        ent = shannon_entropy(log_returns)
        switch_prob, switch_count = hmm_regime_switch_prob_and_count(log_returns)
        adf_pvalue = adfuller(closes)[1]
        avg_return = simple_returns.mean()
        return ent, switch_prob*100, switch_count, adf_pvalue, avg_return
    except Exception:
        return np.nan, np.nan, np.nan, np.nan, np.nan

def get_options(symbol, current_price, max_retries=2, retry_delay=option_retry_delay):
    for attempt in range(max_retries):
        try:
            stock = yf.Ticker(symbol)
            options_chain = stock.options
            if not options_chain:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            expiries = filter_special_expiry(options_chain)
            options_data = []
            if current_price is None:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            for expiry in expiries:
                chain = stock.option_chain(expiry)
                for opt_type, df in [('call', chain.calls), ('put', chain.puts)]:
                    if not df.empty:
                        closest_strike = find_closest_value(df['strike'], current_price)
                        filtered = df[df['strike'] == closest_strike].copy()
                        filtered['type'] = opt_type
                        filtered['expiry'] = expiry
                        filtered['symbol'] = symbol
                        options_data.append(filtered)
            if options_data:
                result = pd.concat(options_data, ignore_index=True)
                result = result[result['openInterest'] > 500]
                return result[['strike', 'impliedVolatility', 'openInterest', 'symbol']]
            return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
        except Exception:
            if attempt < max_retries - 1:
                time.sleep(retry_delay)
                continue
            else:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
    return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])

def fetch_symbol_data_all(symbol):
    try:
        ticker = yf.Ticker(symbol)
        hist = ticker.history(period="130d")  # 130d covers all needed windows + 7d intraday fetches separately handled
        closes = hist['Close'].dropna()
        volumes = hist['Volume'].dropna()
        if len(closes) < hv_window + 1 or len(closes) < 121 or len(volumes) < 2:
            return None
        # Previous day
        prev_day = hist.iloc[-2]
        price = float(prev_day['Close'])
        volume = int(prev_day['Volume'])
        if price * volume < price_volume_threshold:
            return None

        # Historical volatility (20 days)
        log_returns = np.log(closes / closes.shift(1)).dropna()
        hv = log_returns[-hv_window:].std() * np.sqrt(252)

        # Last 120 returns for HMM
        returns_120 = np.log(closes / closes.shift(1)).dropna()[-120:]
        if len(returns_120) < 120:
            returns_120 = None

        # Options data
        options_df = get_options(symbol, price)
        if options_df.empty:
            return None
        avg_iv = options_df['impliedVolatility'].mean()
        ratio = avg_iv / hv if hv > 0 else None
        mean_oi = options_df['openInterest'].mean()

        # Apply HMM for returns
        hmm_stats = hmm_analysis(returns_120, avg_iv)

        # 7-day 1m intraday regime analysis
        ent, switch_prob, switch_count, adf_pvalue, avg_return = hmm_regime_minute_analysis(symbol)

        return {
            'symbol': symbol.upper(),
            'price': price,
            'volume': volume,
            'historical_volatility': hv,
            'avg_iv': avg_iv,
            'iv/hv_ratio': ratio,
            'mean_openInterest': mean_oi,
            # HMM daily regimes stats
            **hmm_stats,
            # Intraday minute data stats
            'ShannonEntropy': ent,
            'Regimeswitchprob': switch_prob,
            'Regimeswitchcount': switch_count,
            'ADF_Pvalue': adf_pvalue,
            'AvgReturn_7d': avg_return,
            # Store returns for reference (optional, can be removed to reduce memory)
            #'returns_120': returns_120,
        }
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

# ---------------- YFINANCE SCREENER QUERY ----------------
screen_query = EquityQuery("and", [
    EquityQuery("is-in", ["region", "us"]),
    EquityQuery("is-in", ["sector",
        "Technology", "Financial Services", "Consumer Cyclical",
        "Communication Services", "Basic Materials", "Industrials"
    ]),
    EquityQuery("GTE", ["eodprice", 0.50]),
    EquityQuery("GTE", ["avgdailyvol3m", 100000]),
    EquityQuery("LTE", ["short_percentage_of_float.value", 100])
])

# ---------------- BATCH PROCESS ----------------
def process_batch(offset, filterdf, options):
    screener = screen(
        screen_query,
        sortField="avgdailyvol3m",
        sortAsc=False,
        size=num_stocks,
        offset=offset
    )
    stocks = screener.get('quotes', [])
    if not stocks:
        return filterdf, options, offset, False

    symbols = [s['symbol'] for s in stocks]
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(fetch_symbol_data_all, sym): sym for sym in symbols}
        for future in as_completed(futures):
            data = future.result()
            if data:
                results.append(data)

    if not results:
        return filterdf, options, offset + num_stocks, True

    # Build DataFrame for symbol data (excluding options which is kept separate)
    batch_df = pd.DataFrame([{k:v for k,v in r.items() if k != "options_df"} for r in results])

    # Concatenate all options data into options DataFrame
    options_dfs = [r.get('options_df') for r in results if r.get('options_df') is not None]
    if options_dfs:
        all_options = pd.concat(options_dfs, ignore_index=True)
        options = pd.concat([options, all_options], ignore_index=True)

    filterdf = pd.concat([filterdf, batch_df], ignore_index=True)

    # Pause between batches to reduce rate limiting
    time.sleep(batch_delay)

    return filterdf, options, offset + num_stocks, True

# ---------------- MAIN ----------------
offset = 0
filterdf = pd.DataFrame()
options = pd.DataFrame()

while True:
    try:
        filterdf, options, offset, has_more = process_batch(offset, filterdf, options)
        print(f"Processed batch, total rows so far: {len(filterdf)}")
        if not has_more:
            break
    except Exception as e:
        if e.__class__.__name__ == "YFRateLimitError":
            print("Rate limit reached. Ending batch processing loop early.")
            break
        else:
            raise  # re-raise unknown exceptions



print("\nFinal results:")
print(filterdf)
# Out:
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14118.92868313863 is not greater than 14121.723691475716. Delta is -2.7950083370851644
# Model is not converging.  Current: 14119.231218238974 is not greater than 14121.73907270127. Delta is -2.5078544622956542
# Model is not converging.  Current: 14119.083992568101 is not greater than 14121.694030093648. Delta is -2.6100375255464314
# Model is not converging.  Current: 14120.533357183856 is not greater than 14121.21657769436. Delta is -0.6832205105038156
# Model is not converging.  Current: 14118.680847180081 is not greater than 14121.673123718501. Delta is -2.992276538419901
# Model is not converging.  Current: 14119.730559821657 is not greater than 14121.674938138518. Delta is -1.9443783168608206
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 298.4569676973775 is not greater than 298.4593014959766. Delta is -0.002333798599124748
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13794.55049104004 is not greater than 13795.121973715995. Delta is -0.5714826759558491
# Model is not converging.  Current: 13794.889547525432 is not greater than 13798.088099076787. Delta is -3.1985515513551945
# Model is not converging.  Current: 13794.002552783837 is not greater than 13795.767437810055. Delta is -1.7648850262175984
# Model is not converging.  Current: 13793.982060235083 is not greater than 13794.851553411194. Delta is -0.8694931761110638
# Model is not converging.  Current: 13793.764975481316 is not greater than 13795.19998200408. Delta is -1.4350065227645246
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14168.968588924527 is not greater than 14169.2874452045. Delta is -0.3188562799732608
# Model is not converging.  Current: 14167.652205722638 is not greater than 14167.696247484439. Delta is -0.044041761801054236
# Model is not converging.  Current: 14168.34504360585 is not greater than 14169.743901342974. Delta is -1.3988577371237625
# Model is not converging.  Current: 14167.96575227252 is not greater than 14169.042161019552. Delta is -1.076408747032474
# Model is not converging.  Current: 14168.694814662565 is not greater than 14169.49251717397. Delta is -0.7977025114050775
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 310.94513232429665 is not greater than 310.9570672130822. Delta is -0.011934888785560815
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13661.519049279263 is not greater than 13665.178913856907. Delta is -3.6598645776448393
# Model is not converging.  Current: 13658.287496956455 is not greater than 13663.175673264876. Delta is -4.888176308420952
# Model is not converging.  Current: 13657.274882759299 is not greater than 13661.788139864067. Delta is -4.513257104768854
# Model is not converging.  Current: 13657.499983576783 is not greater than 13661.627523771487. Delta is -4.127540194704125
# Model is not converging.  Current: 310.02200200022287 is not greater than 310.0850323226655. Delta is -0.0630303224426143
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13972.080768368638 is not greater than 13974.599542232447. Delta is -2.5187738638087467
# Model is not converging.  Current: 13974.601147717427 is not greater than 13975.10115466314. Delta is -0.500006945712812
# Model is not converging.  Current: 13974.439892648503 is not greater than 13976.302981647099. Delta is -1.8630889985961403
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14059.57518287527 is not greater than 14061.704843562933. Delta is -2.129660687664
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13217.85923082012 is not greater than 13226.198878781874. Delta is -8.339647961753144
# Model is not converging.  Current: 13209.616397151758 is not greater than 13210.934171575407. Delta is -1.317774423649098
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14208.92061840753 is not greater than 14216.309945366169. Delta is -7.389326958638776
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 12758.35245645695 is not greater than 12761.547223889136. Delta is -3.194767432185472
# Model is not converging.  Current: 12744.740668112412 is not greater than 12745.376229031339. Delta is -0.6355609189267852
# Model is not converging.  Current: 236.91717544447482 is not greater than 236.92415455375007. Delta is -0.006979109275249584
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14012.532646119305 is not greater than 14018.331127537682. Delta is -5.798481418376468
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13942.896398580975 is not greater than 13943.517613955852. Delta is -0.6212153748765559
# Model is not converging.  Current: 13942.977700210275 is not greater than 13943.477515965655. Delta is -0.4998157553800411
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13400.566073712343 is not greater than 13403.311828716638. Delta is -2.7457550042945513
# Model is not converging.  Current: 13394.9842110828 is not greater than 13398.960154196267. Delta is -3.97594311346802
# Model is not converging.  Current: 13393.515483411235 is not greater than 13397.527611097486. Delta is -4.012127686251915
# Model is not converging.  Current: 13391.91882188676 is not greater than 13393.964104740136. Delta is -2.045282853376193
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13777.57916154309 is not greater than 13780.430397767906. Delta is -2.8512362248166028
# Model is not converging.  Current: 13778.042702424327 is not greater than 13779.38378144091. Delta is -1.3410790165835351
# Model is not converging.  Current: 183.40773075138904 is not greater than 183.4082402136205. Delta is -0.000509462231462976
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 12482.908372230728 is not greater than 12483.858023680343. Delta is -0.9496514496149757
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 258.59191247564297 is not greater than 258.6083562502335. Delta is -0.016443774590527482
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13220.045363134424 is not greater than 13223.781297941794. Delta is -3.735934807369631
# Model is not converging.  Current: 13215.253483030068 is not greater than 13217.271076617788. Delta is -2.0175935877196025
# Model is not converging.  Current: 13219.583307647355 is not greater than 13220.090029600153. Delta is -0.5067219527973066
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13310.862285520647 is not greater than 13313.416250924045. Delta is -2.5539654033982515
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13235.500984931326 is not greater than 13236.797258966988. Delta is -1.296274035661554
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 12896.190129381337 is not greater than 12897.264676207406. Delta is -1.0745468260683992
# Model is not converging.  Current: 12893.486844188665 is not greater than 12898.185692224173. Delta is -4.69884803550849
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14154.232300284415 is not greater than 14155.874624792197. Delta is -1.6423245077821775
# Model is not converging.  Current: 14153.96987320235 is not greater than 14154.046049375038. Delta is -0.07617617268806498
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14211.24082293038 is not greater than 14211.240925091328. Delta is -0.00010216094779025298
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13190.673187988408 is not greater than 13192.068574840006. Delta is -1.3953868515982322
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14240.499280165786 is not greater than 14240.553502647. Delta is -0.05422248121431039
# Model is not converging.  Current: 14240.500715500968 is not greater than 14240.536846830179. Delta is -0.03613132921054785
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 261.1838472673242 is not greater than 261.19900677159717. Delta is -0.015159504272958202
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 12906.264811913512 is not greater than 12906.331340823468. Delta is -0.06652890995610505
# Model is not converging.  Current: 12906.231475697356 is not greater than 12906.353410029187. Delta is -0.12193433183165325
# Model is not converging.  Current: 12906.251514666918 is not greater than 12906.342168315854. Delta is -0.0906536489364953
# Model is not converging.  Current: 267.83964367463676 is not greater than 267.86967673791645. Delta is -0.030033063279688577
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13635.992425709266 is not greater than 13638.95658976183. Delta is -2.9641640525642288
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14199.728715599818 is not greater than 14199.750140529088. Delta is -0.02142492926941486
# Model is not converging.  Current: 13714.886406904203 is not greater than 13715.898253056577. Delta is -1.0118461523743463
# Model is not converging.  Current: 238.81331860957096 is not greater than 238.8188575752745. Delta is -0.0055389657035505024
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13962.515407331299 is not greater than 13964.22563160001. Delta is -1.71022426871059
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 246.25436373346153 is not greater than 246.28796111920929. Delta is -0.03359738574775406
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 288.87570909217305 is not greater than 288.9261160915217. Delta is -0.05040699934863824
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13593.508618567317 is not greater than 13595.324190734678. Delta is -1.815572167361097
# Model is not converging.  Current: 28555.176934759427 is not greater than 28575.287831236696. Delta is -20.110896477268398
# Model is not converging.  Current: 28546.927171907344 is not greater than 28558.485693516497. Delta is -11.558521609153104
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 292.1985436957973 is not greater than 292.2010255692997. Delta is -0.0024818735024041416
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14156.896663710913 is not greater than 14159.141341518465. Delta is -2.2446778075518523
# Model is not converging.  Current: 14158.708405827192 is not greater than 14161.109792346513. Delta is -2.401386519321022
# Model is not converging.  Current: 14158.173107430499 is not greater than 14159.7444592149. Delta is -1.571351784401486
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14227.375976196472 is not greater than 14227.644974278965. Delta is -0.2689980824925442
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 278.20915512122843 is not greater than 278.22108341515485. Delta is -0.0119282939264167
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 12841.649458880162 is not greater than 12848.691210466623. Delta is -7.041751586461032
# Model is not converging.  Current: 12822.830080430516 is not greater than 12824.379274729381. Delta is -1.549194298864677
# Model is not converging.  Current: 12819.769230709067 is not greater than 12819.921834275536. Delta is -0.15260356646831497
# Model is not converging.  Current: 14193.311974041995 is not greater than 14196.202018236474. Delta is -2.8900441944788327
# Model is not converging.  Current: 308.8181690038784 is not greater than 308.82189108756376. Delta is -0.003722083685374855
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 259.9529652454965 is not greater than 259.95348349861575. Delta is -0.0005182531192531314
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14275.450354231663 is not greater than 14278.93577870379. Delta is -3.4854244721263967
# Model is not converging.  Current: 13838.955056217179 is not greater than 13843.585800418896. Delta is -4.63074420171688
# Model is not converging.  Current: 13837.064661084187 is not greater than 13840.36742622912. Delta is -3.302765144933801
# Model is not converging.  Current: 13836.743833495531 is not greater than 13842.482224672704. Delta is -5.738391177172161
# Model is not converging.  Current: 13836.428758943055 is not greater than 13839.152135580041. Delta is -2.723376636986359
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14246.76694210924 is not greater than 14246.803259555696. Delta is -0.03631744645645085
# Model is not converging.  Current: 28477.470693917756 is not greater than 28486.025832400515. Delta is -8.555138482759503
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14016.195636629527 is not greater than 14020.05422108834. Delta is -3.858584458812402
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 270.2171941082439 is not greater than 270.31419131184435. Delta is -0.09699720360043784
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13973.48272799461 is not greater than 13973.540200101112. Delta is -0.05747210650224588
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14008.308280377641 is not greater than 14009.145052379896. Delta is -0.8367720022542926
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 304.2081559351761 is not greater than 304.21090461607594. Delta is -0.0027486808998560264
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14155.13951315628 is not greater than 14158.519271535612. Delta is -3.3797583793311787
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 27036.79400961418 is not greater than 27052.68824845816. Delta is -15.89423884397911
# Model is not converging.  Current: 26988.957942885118 is not greater than 26991.258392006082. Delta is -2.300449120964913
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 26681.00766735652 is not greater than 26683.333976200673. Delta is -2.3263088441526634
# Model is not converging.  Current: 26677.208991685653 is not greater than 26683.990343001235. Delta is -6.78135131558156
# Model is not converging.  Current: 26638.447813229726 is not greater than 26646.231650057405. Delta is -7.783836827678897
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13792.014973097497 is not greater than 13792.356436988208. Delta is -0.3414638907106564
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13791.997531927474 is not greater than 13792.251415768938. Delta is -0.2538838414639031
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13453.79352631273 is not greater than 13456.898228635768. Delta is -3.1047023230385093
# Model is not converging.  Current: 13457.887259194908 is not greater than 13461.918112074496. Delta is -4.030852879588565
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 245.9670639087502 is not greater than 245.98009118008946. Delta is -0.013027271339268509
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13787.646556309977 is not greater than 13788.140645405487. Delta is -0.4940890955094801
# Model is not converging.  Current: 13787.828088440683 is not greater than 13789.07527915944. Delta is -1.247190718757338
# Model is not converging.  Current: 260.2739450780839 is not greater than 260.3011569998755. Delta is -0.027211921791604254
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14187.595268201592 is not greater than 14188.136480517876. Delta is -0.5412123162841453
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14161.182261638118 is not greater than 14163.724657881517. Delta is -2.5423962433997076
# Model is not converging.  Current: 14160.056255259633 is not greater than 14163.810739852677. Delta is -3.7544845930442534
# Model is not converging.  Current: 14161.405541107359 is not greater than 14163.681080228156. Delta is -2.2755391207974753
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 334.4820729119267 is not greater than 334.4991060134647. Delta is -0.017033101538004303
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14150.5729386787 is not greater than 14151.03729987373. Delta is -0.4643611950286868
# Model is not converging.  Current: 14151.061591398508 is not greater than 14157.96161321927. Delta is -6.900021820762049
# Model is not converging.  Current: 14150.631394104577 is not greater than 14152.532957351901. Delta is -1.901563247323793
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14245.686633775653 is not greater than 14245.791664811346. Delta is -0.10503103569317318
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13888.691403288705 is not greater than 13889.04626696605. Delta is -0.3548636773448379
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14169.219413350422 is not greater than 14169.446918324285. Delta is -0.22750497386368806
# Processed batch, total rows so far: 133
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 248.63020257530323 is not greater than 248.63291733598487. Delta is -0.002714760681641337
# Model is not converging.  Current: 323.36532438568594 is not greater than 323.51399071866723. Delta is -0.14866633298129273
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13248.958365662758 is not greater than 13250.404745703914. Delta is -1.4463800411558623
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14124.84824042614 is not greater than 14126.103888294514. Delta is -1.2556478683745809
# Model is not converging.  Current: 338.23075167390994 is not greater than 338.25733665211567. Delta is -0.026584978205733023
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14077.581471990916 is not greater than 14079.596782794399. Delta is -2.015310803482862
# Model is not converging.  Current: 323.753115599927 is not greater than 323.7887179127643. Delta is -0.03560231283728399
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 201.56855309141895 is not greater than 201.61288922659233. Delta is -0.04433613517338131
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 14238.992095908923 is not greater than 14239.004276229865. Delta is -0.01218032094220689
# Model is not converging.  Current: 14238.601635088884 is not greater than 14238.615609968825. Delta is -0.013974879941088147
# Model is not converging.  Current: 257.130164522415 is not greater than 257.1336239293946. Delta is -0.0034594069796298754
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 279.6419385121463 is not greater than 279.64546065395405. Delta is -0.003522141807764001
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, period="7d", interval="1m", progress=False)
# Model is not converging.  Current: 13611.203097142292 is not greater than 13613.877654502976. Delta is -2.674557360684048
# Model is not converging.  Current: 13610.960240147791 is not greater than 13612.073982365602. Delta is -1.1137422178107954
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_50345/1176544893.py:97: FutureWarning: YF.download() has changed argument auto_adjust default to True
# ...
# 252        1.198901      2.020606e-12                0.0    0.272829
# 253        0.162002      1.196278e-01                6.0    0.346440
# 254        0.845350      4.264658e-02                2.0    0.485653
# 255        1.142491      4.796746e-02                2.0    0.779787
# 256        1.237105      8.845547e-05                0.0    0.876983
# 257        0.027994      2.189881e-01                8.0    0.541114
# 258        0.027994      2.189884e-01                8.0    0.541114
# 259        0.581173      5.283763e-01               25.0    0.047528
# 260        1.003125      3.442050e-02                2.0    0.835375
# 261        0.948611      2.911887e-01               10.0    0.462386
# 262        1.109230      9.647838e-12                0.0    0.175782
# 263        1.680200      9.425056e-05                0.0    0.478615
# 264        0.739967      4.420725e-02                2.0    0.729656
# 265        0.974137      4.767501e-02                2.0    0.587907
# 266        0.974137      4.769859e-02                2.0    0.587907
# 267        1.418727      9.953612e+01             1973.0    0.604414
# 268        0.086747      1.527529e-01                4.0    0.350379
# 269        0.086747      1.039327e-01                4.0    0.350379
# 270        1.059036      8.175289e-02                4.0    0.373174
# 271        1.293888      2.164935e-12                0.0    0.449795
# 272        0.113806      1.846143e-01                8.0    0.250701
# 273        0.620664      1.421895e-01                6.0    0.053822
# 274        0.966262      5.966723e-02                2.0    0.631105
# 275        0.966262      6.540231e-02                2.0    0.631105
# 276        1.150573      2.130587e-01                6.0    0.317339
# 277        0.233242      2.868394e-01               10.0    0.537699
# 278        1.330524      7.585248e-02                2.0    0.582222
#
#                                    AvgReturn_7d
# 0        Ticker
# NVDA   -0.000001
# dtype: float64
# 1        Ticker
# NVDA   -0.000001
# dtype: float64
# 2        Ticker
# NVDA   -0.000001
# dtype: float64
# 3        Ticker
# NVDA   -0.000001
# dtype: float64
# 4        Ticker
# NVDA   -0.000001
# dtype: float64
# 5        Ticker
# NVDA   -0.000001
# dtype: float64
# 6         Ticker
# AAL    0.000043
# dtype: float64
# 7         Ticker
# AAL    0.000043
# dtype: float64
# 8         Ticker
# AAL    0.000043
# dtype: float64
# 9         Ticker
# AAL    0.000043
# dtype: float64
# 10        Ticker
# AAL    0.000043
# dtype: float64
# 11        Ticker
# AAL    0.000043
# dtype: float64
# 12      Ticker
# GOOGL    0.000013
# dtype: float64
# 13      Ticker
# GOOGL    0.000013
# dtype: float64
# 14      Ticker
# GOOGL    0.000013
# dtype: float64
# 15      Ticker
# GOOGL    0.000013
# dtype: float64
# 16      Ticker
# GOOGL    0.000013
# dtype: float64
# 17      Ticker
# GOOGL    0.000013
# dtype: float64
# 18       Ticker
# SNAP   -0.000031
# dtype: float64
# 19       Ticker
# SNAP   -0.000031
# dtype: float64
# 20       Ticker
# SNAP   -0.000031
# dtype: float64
# 21       Ticker
# SNAP   -0.000031
# dtype: float64
# 22       Ticker
# ITUB    0.000016
# dtype: float64
# 23       Ticker
# ITUB    0.000016
# dtype: float64
# 24       Ticker
# ITUB    0.000016
# dtype: float64
# 25        Ticker
# RUN    0.000101
# dtype: float64
# 26        Ticker
# RUN    0.000101
# dtype: float64
# 27        Ticker
# CCL    0.000002
# dtype: float64
# 28         Ticker
# HL    0.000034
# dtype: float64
# 29         Ticker
# HL    0.000034
# dtype: float64
# 30         Ticker
# HL    0.000034
# dtype: float64
# 31        Ticker
# KEY    0.000008
# dtype: float64
# 32       Ticker
# CLSK   -0.000049
# dtype: float64
# 33       Ticker
# CLSK   -0.000049
# dtype: float64
# 34       Ticker
# STLA    0.000026
# dtype: float64
# 35       Ticker
# UBER    0.000007
# dtype: float64
# 36       Ticker
# UBER    0.000007
# dtype: float64
# 37       Ticker
# CSCO   -0.000019
# dtype: float64
# 38         Ticker
# RKT    0.00001
# dtype: float64
# 39         Ticker
# RKT    0.00001
# dtype: float64
# 40         Ticker
# RKT    0.00001
# dtype: float64
# 41         Ticker
# RKT    0.00001
# dtype: float64
# 42       Ticker
# MRVL   -0.000002
# dtype: float64
# 43       Ticker
# MRVL   -0.000002
# dtype: float64
# 44         Ticker
# MP    0.000028
# dtype: float64
# 45       Ticker
# COIN    0.000007
# dtype: float64
# 46       Ticker
# COIN    0.000007
# dtype: float64
# 47       Ticker
# COIN    0.000007
# dtype: float64
# 48       Ticker
# INFY    0.000007
# dtype: float64
# 49       Ticker
# INFY    0.000007
# dtype: float64
# 50       Ticker
# INFY    0.000007
# dtype: float64
# 51       Ticker
# LYFT    0.000053
# dtype: float64
# 52        Ticker
# CDE    0.000054
# dtype: float64
# 53        Ticker
# CDE    0.000054
# dtype: float64
# 54        Ticker
# CDE    0.000054
# dtype: float64
# 55        Ticker
# GME    0.000001
# dtype: float64
# 56        Ticker
# GME    0.000001
# dtype: float64
# 57        Ticker
# KSS    0.000057
# dtype: float64
# 58        Ticker
# KSS    0.000057
# dtype: float64
# 59        Ticker
# NEM    0.000006
# dtype: float64
# 60        Ticker
# NEM    0.000006
# dtype: float64
# 61         Ticker
# RF    0.000007
# dtype: float64
# 62        Ticker
# AEO    0.000012
# dtype: float64
# 63        Ticker
# TSM   -0.000007
# dtype: float64
# 64        Ticker
# TSM   -0.000007
# dtype: float64
# 65         Ticker
# USB    0.00001
# dtype: float64
# 66        Ticker
# UAA   -0.000091
# dtype: float64
# 67        Ticker
# UAA   -0.000091
# dtype: float64
# 68        Ticker
# UAA   -0.000091
# dtype: float64
# 69   Ticker
# DKNG    9.293180e-07
# dtype: float64
# 70   Ticker
# DKNG    9.293180e-07
# dtype: float64
# 71         Ticker
# GM    0.000023
# dtype: float64
# 72       Ticker
# MCHP   -0.000011
# dtype: float64
# 73       Ticker
# MCHP   -0.000011
# dtype: float64
# 74        Ticker
# DAL    0.000039
# dtype: float64
# 75                                          NaN
# 76                                          NaN
# 77        Ticker
# YMM   -0.000011
# dtype: float64
# 78         Ticker
# AI   -0.000074
# dtype: float64
# 79        Ticker
# APH   -0.000003
# dtype: float64
# 80        Ticker
# APH   -0.000003
# dtype: float64
# 81        Ticker
# APH   -0.000003
# dtype: float64
# 82       Ticker
# QCOM    0.000025
# dtype: float64
# 83         Ticker
# BE    0.000055
# dtype: float64
# 84         Ticker
# BE    0.000055
# dtype: float64
# 85         Ticker
# BE    0.000055
# dtype: float64
# 86        Ticker
# STM    0.000011
# dtype: float64
# 87         Ticker
# TFC    0.00001
# dtype: float64
# 88       Ticker
# CHWY    0.000057
# dtype: float64
# 89       Ticker
# CHWY    0.000057
# dtype: float64
# 90       Ticker
# CHWY    0.000057
# dtype: float64
# 91       Ticker
# CHWY    0.000057
# dtype: float64
# 92                                          NaN
# 93       Ticker
# SCHW   -0.000004
# dtype: float64
# 94        Ticker
# HBI    0.000105
# dtype: float64
# 95       Ticker
# PANW    0.000013
# dtype: float64
# 96       Ticker
# XPEV    0.000006
# dtype: float64
# 97       Ticker
# XPEV    0.000006
# dtype: float64
# 98       Ticker
# XPEV    0.000006
# dtype: float64
# 99        Ticker
# WDC    0.000006
# dtype: float64
# 100       Ticker
# TME    0.000056
# dtype: float64
# 101       Ticker
# TME    0.000056
# dtype: float64
# 102       Ticker
# UPS    0.000007
# dtype: float64
# 103                                         NaN
# 104                                         NaN
# 105                                         NaN
# 106                                         NaN
# 107                                         NaN
# 108        Ticker
# AA    0.000016
# dtype: float64
# 109        Ticker
# AA    0.000016
# dtype: float64
# 110      Ticker
# ETSY    0.000049
# dtype: float64
# 111      Ticker
# ETSY    0.000049
# dtype: float64
# 112       Ticker
# CZR    0.000004
# dtype: float64
# 113       Ticker
# CZR    0.000004
# dtype: float64
# 114   Ticker
# RTX    3.008339e-07
# dtype: float64
# 115   Ticker
# RTX    3.008339e-07
# dtype: float64
# 116   Ticker
# RTX    3.008339e-07
# dtype: float64
# 117   Ticker
# GLW    7.087459e-07
# dtype: float64
# 118      Ticker
# FITB    0.000008
# dtype: float64
# 119      Ticker
# FITB    0.000008
# dtype: float64
# 120       Ticker
# LVS    0.000006
# dtype: float64
# 121       Ticker
# LVS    0.000006
# dtype: float64
# 122       Ticker
# LVS    0.000006
# dtype: float64
# 123       Ticker
# JCI   -0.000007
# dtype: float64
# 124      Ticker
# CARR   -0.000007
# dtype: float64
# 125      Ticker
# CARR   -0.000007
# dtype: float64
# 126      Ticker
# CARR   -0.000007
# dtype: float64
# 127       Ticker
# IBM   -0.000019
# dtype: float64
# 128       Ticker
# LYB    0.000017
# dtype: float64
# 129      Ticker
# TMUS    0.000024
# dtype: float64
# 130      Ticker
# TMUS    0.000024
# dtype: float64
# 131   Ticker
# FTV    6.914245e-07
# dtype: float64
# 132   Ticker
# FTV    6.914245e-07
# dtype: float64
# 133       Ticker
# ALB    0.000058
# dtype: float64
# 134                                         NaN
# 135                                         NaN
# 136                                         NaN
# 137       Ticker
# OMC    0.000015
# dtype: float64
# 138      Ticker
# CTVA    0.000007
# dtype: float64
# 139       Ticker
# AIG    0.000015
# dtype: float64
# 140       Ticker
# AIG    0.000015
# dtype: float64
# 141       Ticker
# AIG    0.000015
# dtype: float64
# 142      Ticker
# OKTA   -0.000022
# dtype: float64
# 143      Ticker
# OKTA   -0.000022
# dtype: float64
# 144      Ticker
# OKTA   -0.000022
# dtype: float64
# 145       Ticker
# UNP   -0.000011
# dtype: float64
# 146       Ticker
# TER    0.000005
# dtype: float64
# 147       Ticker
# TER    0.000005
# dtype: float64
# 148        Ticker
# BX    0.000002
# dtype: float64
# 149        Ticker
# BX    0.000002
# dtype: float64
# 150      Ticker
# SIRI    0.000031
# dtype: float64
# 151       Ticker
# PGR    0.000001
# dtype: float64
# 152       Ticker
# PGR    0.000001
# dtype: float64
# 153      Ticker
# LULU    0.000002
# dtype: float64
# 154   Ticker
# MMM    3.531202e-07
# dtype: float64
# 155   Ticker
# MMM    3.531202e-07
# dtype: float64
# 156       Ticker
# NDAQ   -0.00001
# dtype: float64
# 157       Ticker
# NDAQ   -0.00001
# dtype: float64
# 158         Ticker
# HD    0.00001
# dtype: float64
# 159      Ticker
# ROST    0.000004
# dtype: float64
# 160      Ticker
# ROST    0.000004
# dtype: float64
# 161      Ticker
# ENTG    0.000012
# dtype: float64
# 162      Ticker
# ENTG    0.000012
# dtype: float64
# 163                                         NaN
# 164                                         NaN
# 165       Ticker
# HWM   -0.000022
# dtype: float64
# 166       Ticker
# HWM   -0.000022
# dtype: float64
# 167       Ticker
# BHP    0.000012
# dtype: float64
# 168       Ticker
# BHP    0.000012
# dtype: float64
# 169       Ticker
# BHP    0.000012
# dtype: float64
# 170       Ticker
# NET   -0.000028
# dtype: float64
# 171       Ticker
# MET    0.000025
# dtype: float64
# 172        Ticker
# ZM   -0.000001
# dtype: float64
# 173        Ticker
# ZM   -0.000001
# dtype: float64
# 174        Ticker
# IR    0.000007
# dtype: float64
# 175        Ticker
# CP   -0.000012
# dtype: float64
# 176        Ticker
# CP   -0.000012
# dtype: float64
# 177       Ticker
# LOW    0.000019
# dtype: float64
# 178       Ticker
# LOW    0.000019
# dtype: float64
# 179       Ticker
# GPN    0.000005
# dtype: float64
# 180       Ticker
# GPN    0.000005
# dtype: float64
# 181       Ticker
# GPN    0.000005
# dtype: float64
# 182       Ticker
# CAT   -0.000016
# dtype: float64
# 183        Ticker
# MA    0.000006
# dtype: float64
# 184        Ticker
# MA    0.000006
# dtype: float64
# 185      Ticker
# PSTG    0.000006
# dtype: float64
# 186      Ticker
# PSTG    0.000006
# dtype: float64
# 187       Ticker
# EQH    0.000015
# dtype: float64
# 188      Ticker
# METC    0.000049
# dtype: float64
# 189      Ticker
# METC    0.000049
# dtype: float64
# 190       Ticker
# ANF   -0.000041
# dtype: float64
# 191        Ticker
# SGI    0.00003
# dtype: float64
# 192        Ticker
# AXP    0.00001
# dtype: float64
# 193        Ticker
# AXP    0.00001
# dtype: float64
# 194        Ticker
# AXP    0.00001
# dtype: float64
# 195      Ticker
# FUTU    0.000039
# dtype: float64
# 196         Ticker
# Z    0.000007
# dtype: float64
# 197         Ticker
# Z    0.000007
# dtype: float64
# 198       Ticker
# SWK    0.000025
# dtype: float64
# 199        Ticker
# CME   -0.00001
# dtype: float64
# 200        Ticker
# CME   -0.00001
# dtype: float64
# 201       Ticker
# MMC    0.000005
# dtype: float64
# 202       Ticker
# MMC    0.000005
# dtype: float64
# 203      Ticker
# VIAV    0.000028
# dtype: float64
# 204       Ticker
# MAS    0.000019
# dtype: float64
# 205      Ticker
# DOCN   -0.000064
# dtype: float64
# 206      Ticker
# BILL   -0.000019
# dtype: float64
# 207      Ticker
# BILL   -0.000019
# dtype: float64
# 208       Ticker
# HAS    0.000019
# dtype: float64
# 209       Ticker
# HAS    0.000019
# dtype: float64
# 210      Ticker
# ACGL    0.000003
# dtype: float64
# 211    Ticker
# GS    9.045764e-08
# dtype: float64
# 212                                         NaN
# 213                                         NaN
# 214                                         NaN
# 215                                         NaN
# 216        Ticker
# EMN    0.00002
# dtype: float64
# 217       Ticker
# ERJ    0.000002
# dtype: float64
# 218       Ticker
# ERJ    0.000002
# dtype: float64
# 219       Ticker
# HLT    0.000005
# dtype: float64
# 220       Ticker
# HLT    0.000005
# dtype: float64
# 221      Ticker
# NTAP    0.000017
# dtype: float64
# 222       Ticker
# QRVO    0.00002
# dtype: float64
# 223      Ticker
# ESTC   -0.000022
# dtype: float64
# 224        Ticker
# CB    0.000007
# dtype: float64
# 225        Ticker
# CB    0.000007
# dtype: float64
# 226       Ticker
# LIN    0.000007
# dtype: float64
# 227       Ticker
# SHW    0.000011
# dtype: float64
# 228       Ticker
# TOL    0.000009
# dtype: float64
# 229       Ticker
# JEF    0.000012
# dtype: float64
# 230       Ticker
# JEF    0.000012
# dtype: float64
# 231       Ticker
# DLO    0.000177
# dtype: float64
# 232       Ticker
# DLO    0.000177
# dtype: float64
# 233       Ticker
# LMT    0.000006
# dtype: float64
# 234      Ticker
# ASML    0.000017
# dtype: float64
# 235      Ticker
# FTAI    0.000016
# dtype: float64
# 236      Ticker
# FTAI    0.000016
# dtype: float64
# 237       Ticker
# PII    0.000032
# dtype: float64
# 238       Ticker
# PII    0.000032
# dtype: float64
# 239       Ticker
# ALL   -0.000005
# dtype: float64
# 240       Ticker
# ALL   -0.000005
# dtype: float64
# 241      Ticker
# TROW    0.000004
# dtype: float64
# 242      Ticker
# TROW    0.000004
# dtype: float64
# 243       Ticker
# LHX   -0.000005
# dtype: float64
# 244       Ticker
# JBL   -0.000013
# dtype: float64
# 245       Ticker
# NOW   -0.000023
# dtype: float64
# 246                                         NaN
# 247                                         NaN
# 248       Ticker
# HIG    0.000004
# dtype: float64
# 249      Ticker
# FIVE   -0.000001
# dtype: float64
# 250       Ticker
# EAT   -0.000004
# dtype: float64
# 251       Ticker
# DRI    0.000004
# dtype: float64
# 252       Ticker
# AON    0.000006
# dtype: float64
# 253       Ticker
# SAP   -0.000028
# dtype: float64
# 254      Ticker
# BWXT   -0.000015
# dtype: float64
# 255       Ticker
# HRB   -0.000034
# dtype: float64
# 256      Ticker
# CHRW    0.000009
# dtype: float64
# 257      Ticker
# AAON    0.000003
# dtype: float64
# 258      Ticker
# AAON    0.000003
# dtype: float64
# 259      Ticker
# DUOL   -0.000095
# dtype: float64
# 260       Ticker
# GPC    0.000013
# dtype: float64
# 261       Ticker
# MOD    0.000004
# dtype: float64
# 262        Ticker
# XYL   -0.00001
# dtype: float64
# 263        Ticker
# IT   -0.000011
# dtype: float64
# 264   Ticker
# DOV    3.882405e-07
# dtype: float64
# 265      Ticker
# JBHT   -0.000002
# dtype: float64
# 266      Ticker
# JBHT   -0.000002
# dtype: float64
# 267       Ticker
# CRS   -0.000026
# dtype: float64
# 268      Ticker
# NTES   -0.000007
# dtype: float64
# 269      Ticker
# NTES   -0.000007
# dtype: float64
# 270      Ticker
# GNRC    0.000006
# dtype: float64
# 271      Ticker
# VRSN   -0.000008
# dtype: float64
# 272      Ticker
# MNDY   -0.000137
# dtype: float64
# 273      Ticker
# RGLD    0.000024
# dtype: float64
# 274      Ticker
# LPLA   -0.000041
# dtype: float64
# 275      Ticker
# LPLA   -0.000041
# dtype: float64
# 276       Ticker
# WWD   -0.000015
# dtype: float64
# 277      Ticker
# NICE   -0.000069
# dtype: float64
# 278      Ticker
# ZBRA    0.000013
# dtype: float64

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
filterdf["Shannon/IV"] = filterdf["ShannonEntropy"] / filterdf["avg_iv"]
display(filterdf)
# Out:
#     symbol        price     volume  historical_volatility    avg_iv  \
# 0     PLTR   181.020004   53472900               0.431344  0.335212
# 1        F    11.440000   52469200               0.219591  0.241707
# 2     NVDA   182.020004  129554000               0.247410  0.310615
# 3     TSLA   335.579987   75000700               0.442691  0.270698
# 4     SOFI    23.290001   52370500               0.472104  0.309821
# 5     INTC    23.860001  188052500               0.561838  0.495122
# 6      AMD   180.949997   66308800               0.473977  0.280891
# 7     APLD    14.550000   20751300               1.192506  0.595707
# 8      NIO     4.450000   43446300               0.805140  0.658207
# 9     AAPL   232.779999   51916300               0.289689  0.170571
# 10    MARA    15.750000   45222400               0.571889  0.452642
# 11     AAL    12.820000   58323100               0.617733  0.333991
# 12    SMCI    45.490002   22948700               0.905954  0.302375
# 13    VALE     9.910000   23363600               0.272467  0.246101
# 14      QS     9.090000   27697800               1.120362  0.413092
# 15    HOOD   110.709999   34395300               0.504291  0.460882
# 16   GOOGL   202.940002   25230400               0.211585  0.375891
# 17    AMZN   230.979996   61545800               0.386930  0.156258
# 18    SBET    23.490000   46458200               1.259351  1.723311
# 19     BAC    47.709999   21073800               0.218065  0.188485
# 20    RIOT    12.250000   34334800               0.875741  0.734378
# 21    SNAP     7.080000   58598100               0.754762  0.340827
# 22    HBAN    16.809999   21390800               0.209997  0.541020
# 23    ITUB     6.970000   29162400               0.257682  0.488937
# 24    QUBT    15.380000   20320600               0.654220  0.531255
# 25    AMCR     8.760000   93209900               0.498560  0.422857
# 26     RUN    10.480000   12232000               1.528539  2.815433
# 27     CCL    30.250000   15950600               0.303209  0.318366
# 28     CLF    10.560000   17101700               0.664066  0.595056
# 29       T    28.750000   24530200               0.141398  0.215584
# 30      HL     7.660000   21170500               0.692434  0.453130
# 31     KEY    18.299999   24619700               0.224472  0.373053
# 32   CMCSA    32.900002   14579800               0.289158  0.503911
# 33    CLSK     9.950000   25428700               0.471855  0.522466
# 34    STLA     9.740000   12587700               0.627902  0.748700
# 35    CSCO    69.300003   39317300               0.266964  0.377936
# 36    UBER    91.400002   14525100               0.281045  0.309699
# 37    MSFT   522.479980   20269100               0.209739  0.130578
# 38     HPE    21.320000    7800500               0.276055  0.279304
# 39     CSX    36.349998   23862100               0.183602  0.196297
# 40     RKT    18.719999   22158200               0.788671  0.420904
# 41      VZ    43.500000   10582800               0.183317  0.247078
# 42    MRVL    79.040001   10127800               0.456403  0.432623
# 43    AVGO   311.230011   15717600               0.305848  0.249723
# 44      MP    76.580002   11179600               0.514441  0.464198
# 45    PTON     8.490000   12950900               0.908235  0.465826
# 46    COIN   324.890015    9403600               0.722289  0.372117
# 47     FCX    42.279999   11933400               0.433771  0.287117
# 48    INFY    16.360001   18675100               0.220428  0.261726
# 49       C    95.459999   13288800               0.245253  0.315925
# 50     DOW    23.370001   11822600               0.857855  0.346686
# 51    LYFT    14.620000   13072500               0.491640  0.802087
# 52    ORCL   244.960007   10285600               0.294184  0.322089
# 53     NKE    76.389999    7990500               0.277588  0.263069
# 54     CDE    11.590000   17614500               0.613339  0.737307
# 55     GME    22.889999    4780000               0.243840  0.224617
# 56    BABA   122.279999   15045600               0.329819  0.283760
# 57     KSS    14.460000    9272600               1.547692  0.695967
# 58     TTD    50.759998   34084000               1.795687  0.463628
# 59     NEM    68.480003    5387300               0.360157  0.436529
# 60    MSTR   372.940002   16461700               0.521842  0.260261
# 61      RF    26.049999   17438000               0.205755  0.323493
# 62     AEO    12.640000   16452200               1.027029  0.604822
# 63    PYPL    69.379997   10695400               0.417102  0.164193
# 64     TSM   241.000000   11040500               0.277805  0.199623
# 65     USB    46.830002    6181100               0.203020  0.497319
# 66    PINS    36.349998   10089500               0.472561  0.234383
# 67     UAA     4.920000   20825500               0.816036  0.655277
# 68      ON    51.619999    7110100               0.762378  0.481450
# 69      JD    31.580000   24556800               0.253786  0.237312
# 70    DKNG    43.669998    6984800               0.356711  0.496099
# 71      GM    56.419998    6647600               0.477676  0.249845
# 72    LRCX   107.379997   11163800               0.430678  0.648441
# 73    MCHP    65.989998    6843000               0.476041  0.485031
# 74     DAL    58.959999    4300300               0.411910  0.446295
# 75     DIS   116.309998    6800900               0.211857  0.151701
# 76     HPQ    26.930000    6544500               0.283441  0.218758
# 77     YMM    10.770000   11830200               0.453272  0.521001
# 78      AI    17.959999   12387200               1.204234  0.355475
# 79    RBLX   125.279999    6504200               0.692447  0.654300
# 80     APH   110.739998    6247100               0.275537  0.278083
# 81     JPM   294.160004    6322400               0.175257  0.214974
# 82    QCOM   158.089996    6294800               0.369105  0.108163
# 83      BE    45.110001    9761100               0.855035  0.248054
# 84     CRM   233.369995    7544800               0.295880  0.530115
# 85      BA   233.190002    5320800               0.248384  0.199878
# 86     STM    25.870001    5408300               0.687376  0.539393
# 87     TFC    44.950001    4967300               0.199748  0.259773
# 88     PDD   114.739998    5151700               0.299423  0.478033
# 89    CHWY    38.939999    7521600               0.453653  0.533208
# 90     OWL    19.660000    8633100               0.330269  0.880863
# 91    CPRT    46.860001    4933100               0.186091  0.295112
# 92    SCHW    97.779999   11310500               0.218625  0.303108
# 93    CFLT    17.850000   12976100               1.466931  0.799809
# 94     HBI     6.450000   34961600               1.015171  0.654953
# 95    PANW   173.550003    8784600               0.427305  0.492254
# 96    XPEV    19.379999    9048100               0.450552  0.407558
# 97    AMAT   188.240005   10992400               0.612430  1.121096
# 98     VRT   132.520004    8129200               0.383730  0.305061
# 99     WDC    76.239998    6621400               0.432013  0.309089
# 100    TME    25.520000   10221200               0.455392  0.746099
# 101      V   345.489990    6224000               0.176840  0.152027
# 102    UPS    88.550003   12487300               0.467031  0.078460
# 103   UPST    63.830002    7310900               0.922963  0.139169
# 104   DDOG   124.519997    6438900               0.400267  0.357795
# 105    JHX    29.270000    3558800               0.309979  0.487798
# 106    HUT    23.799999    9120200               0.658628  0.570317
# 107    TXN   193.710007    3917300               0.581680  0.186532
# 108   FAST    48.689999    5337800               0.196184  0.570482
# 109     AA    31.330000    4725700               0.414572  0.397792
# 110   ETSY    68.209999    3926000               0.589290  0.234383
# 111   FTNT    77.250000   11823100               0.929905  0.745120
# 112    CZR    25.530001    5457000               0.369215  0.279304
# 113    APP   433.339996    5005100               0.647644  0.444464
# 114   IBKR    63.919998    3688200               0.351149  0.373786
# 115    RTX   155.080002    2766600               0.202321  0.220711
# 116    MOS    32.099998    3417000               0.596960  0.425787
# 117    GLW    65.760002    3608900               0.427678  0.105478
# 118   FITB    43.180000    2903900               0.172173  0.332526
# 119    CFG    49.209999    3696800               0.199742  0.432623
# 120   DELL   138.860001    3813800               0.343718  0.080087
# 121   ABNB   124.639999    4706500               0.406538  0.057627
# 122    LVS    54.119999    3812600               0.208929  0.136727
# 123    JCI   105.019997    5250400               0.315888  0.255684
# 124   CARR    65.760002    3743200               0.487729  0.187386
# 125  BRK-B   479.220001    4187100               0.172856  0.135730
# 126   SNOW   194.899994    2791000               0.460444  0.343960
# 127    IBM   237.110001    4556700               0.334282  0.168893
# 128    LYB    53.310001    4033400               0.685473  0.457362
# 129   TMUS   250.309998    2951500               0.271791  0.329108
# 130   ORLY   101.500000    7244200               0.198472  0.441290
# 131    FLR    41.549999    3880600               1.202978  0.482122
# 132    FTV    47.799999    4464300               0.275473  0.251961
# 133    ALB    81.430000    3495700               0.772002  0.156258
# 134     SE   174.009995    3556300               0.740463  0.250252
# 135    COF   221.080002    3032900               0.298807  0.445074
# 136    SKX    63.020000    2457800               0.022105  0.278328
# 137    OMC    75.410004    2246800               0.346264  0.884767
# 138   CTVA    71.870003    3242800               0.179910  0.225594
# 139   VSAT    27.350000    3989000               1.289725  0.434820
# 140   CART    43.875000    7325300               0.545312  0.935548
# 141    AIG    80.309998    2524100               0.215203  0.418951
# 142    DHI   163.899994    3796600               0.639384  0.557622
# 143    TPR    95.690002   13353200               0.728904  1.222660
# 144   OKTA    88.610001    3523900               0.389268  0.304694
# 145    UNP   221.520004    6245600               0.263401  0.642093
# 146   ROKU    87.510002    2955500               0.740994  0.681644
# 147    TER   111.820000    2431000               0.708288  0.561528
# 148    RIO    62.520000    2377700               0.284234  0.375556
# 149     BX   174.679993    2834800               0.235245  0.341559
# 150   SIRI    23.490000    5219800               0.496432  0.312507
# 151   BIDU    88.730003    2621700               0.328475  0.372809
# 152    PGR   250.949997    4574100               0.203815  0.672611
# 153   LULU   195.190002    4102400               0.350630  0.304857
# 154    MMM   156.649994    6344900               0.279124  0.419928
# 155    HON   218.199997    2972400               0.263801  0.060068
# 156   NDAQ    95.400002    2459300               0.234553  0.191170
# 157   OUST    35.049999    4486700               1.069123  0.367194
# 158     HD   400.320007    3600200               0.199815  0.206917
# 159    SYF    72.830002    2589700               0.280486  0.771487
# 160   ROST   147.380005    3247300               0.247362  0.726565
# 161   NFLX  1230.560059    3904700               0.262380  0.198746
# 162   ENTG    78.870003    1821600               0.654855  0.931641
# 163    FUN    26.709999    5681200               0.954492  0.789718
# 164     AU    54.709999    2037400               0.563220  0.365403
# 165    HWM   175.990005    2004000               0.326987  0.679937
# 166    LEN   130.449997    3549200               0.411246  0.877931
# 167    BHP    53.820000    1954400               0.283269  0.302985
# 168    FIS    71.580002    3490300               0.393537  0.303718
# 169   SWKS    75.360001    2206900               0.269912  0.259163
# 170    NET   195.380005    2535700               0.392803  0.451177
# 171    MET    77.919998    2314300               0.283313  0.193428
# 172     CF    85.269997    2755600               0.418683  0.398444
# 173     ZM    71.860001    1932500               0.275212  0.519780
# 174     IR    80.199997    3142200               0.525494  0.746096
# 175     CP    73.879997    2539600               0.215205  0.202156
# 176   TCOM    60.310001    3597400               0.350156  0.520635
# 177    LOW   253.050003    3635000               0.257693  0.359381
# 178     EA   179.009995    3751000               0.369779  0.815920
# 179   PCAR    99.690002    2214600               0.289191  0.831548
# 180    GPN    87.190002    3256000               0.469913  0.406805
# 181    ALK    56.869999    1783800               0.501881  0.351813
# 182    CAT   417.500000    3676000               0.225606  0.354987
# 183   AXTA    30.620001    4307400               0.261677  0.675784
# 184     MA   583.760010    2642300               0.152664  0.061533
# 185   PSTG    57.849998    2393900               0.446906  0.507166
# 186   WDAY   221.919998    3272600               0.344840  0.402838
# 187    EQH    54.639999    2266500               0.277865  0.308601
# 188    ICE   182.679993    6079900               0.140486  0.175118
# 189   METC    26.950001    3905400               1.082225  1.134524
# 190    ANF    97.320000    2089300               0.533407  0.541508
# 191    SGI    79.419998    4296800               0.240979  0.536626
# 192    AFL   105.300003    2575000               0.214915  0.166756
# 193    AXP   307.730011    2108300               0.183974  0.064462
# 194   APTV    74.290001    2727400               0.409881  0.189461
# 195   FUTU   174.750000    2040800               0.551687  0.700198
# 196   LITE   114.620003    5324000               0.417164  0.418585
# 197      Z    85.269997    4300700               0.368484  0.158212
# 198    SWK    74.419998    1728000               0.452323  0.263679
# 199    ETN   355.100006    1895500               0.320163  0.314857
# 200    CME   274.700012    1971000               0.196555  0.192493
# 201    MMC   206.990005    1677100               0.171686  0.167001
# 202    TRU    90.059998    1362000               0.402564  1.007327
# 203   VIAV    10.800000   13646100               0.326186  0.465826
# 204    MAS    73.570000    2144400               0.277183  0.281990
# 205   DOCN    30.540001    3314900               1.147207  0.714604
# 206   BILL    39.480000    3401300               0.370653  0.494959
# 207    FDX   231.070007    1616800               0.337795  0.245369
# 208    HAS    80.550003    1944800               0.192282  0.494390
# 209     ZS   270.989990    1014800               0.299906  0.393805
# 210   ACGL    91.459999    2019800               0.222565  0.239265
# 211     GS   747.200012    1371200               0.222399  0.403570
# 212    HDB    73.849998    1387800               0.203137  1.789064
# 213     CE    42.619999    3401000               0.643591  0.876713
# 214    YUM   146.770004    1832900               0.281708  0.528325
# 215   NTRS   128.490005    1396900               0.243911  0.419928
# 216    EMN    66.400002    1613900               0.828383  0.325446
# 217   CGNX    43.520000    3109700               0.730475  0.593754
# 218    ERJ    59.779999    1829700               0.504198  0.668137
# 219    HLT   270.339996    1065100               0.232924  0.426764
# 220    IFF    65.720001    2029800               0.345644  0.985352
# 221   NTAP   109.559998    1965300               0.236051  0.215462
# 222   QRVO    90.660004    1200300               0.281749  0.330817
# 223   ESTC    76.419998    1603100               0.394998  0.568364
# 224     CB   275.739990    1054400               0.168521  0.312263
# 225   GLBE    30.600000    3319900               0.554595  0.443609
# 226    LIN   477.630005    1545400               0.123871  0.222893
# 227    SHW   365.570007    2615100               0.204637  0.205147
# 228    TOL   131.009995    1504300               0.415974  0.376837
# 229   SNPS   616.359985     954200               0.354755  0.279731
# 230    JEF    61.700001    1707000               0.278446  0.754278
# 231    PRU   106.820000    1156500               0.264702  0.376512
# 232    DLO    15.350000   20049400               1.042230  0.492518
# 233    LMT   437.320007    1733600               0.446379  0.166268
# 234   ASML   755.210022    1577400               0.302354  0.272468
# 235     WM   226.149994    3253000               0.196300  0.314704
# 236   FTAI   144.899994     864200               0.923879  0.723147
# 237    PII    58.820000    3236900               0.916248  0.812342
# 238   FOUR    89.110001    1289300               0.686231  0.705081
# 239   TRMB    83.669998    1283900               0.217984  0.414068
# 240    ALL   208.699997     879300               0.283098  0.193306
# 241    PNR   106.629997    1162600               0.236880  0.325751
# 242   TROW   109.059998     948100               0.229489  0.635016
# 243    LHX   271.049988     984700               0.141815  0.210335
# 244    JBL   217.399994    1654000               0.369950  0.840334
# 245    NOW   850.859985    1787900               0.330276  0.239754
# 246    AJG   293.410004    1280200               0.295146  0.500982
# 247   STLD   127.480003    1048900               0.309137  0.359626
# 248    HIG   131.339996     885800               0.191623  0.941407
# 249   FIVE   134.360001    1006000               0.296677  0.721682
# 250    EAT   158.080002    1812300               0.397726  0.426153
# 251    DRI   206.059998     744400               0.179859  0.285041
# 252    AON   366.350006    1292900               0.266312  0.099618
# 253    SAP   278.910004     954600               0.296837  0.533696
# 254   BWXT   174.699997     837700               0.620955  0.321906
# 255    HRB    49.369999    3343400               0.255770  0.313911
# 256   CHRW   121.519997    1375900               0.621278  0.187752
# 257   AAON    83.110001    1280500               0.846832  0.497319
# 258     DE   478.839996    5100700               0.367750  0.285896
# 259   DUOL   329.880005    1804000               0.725096  0.455226
# 260    GPC   137.770004     968700               0.308678  0.208992
# 261    MOD   139.509995     741300               0.736011  0.480474
# 262    XYL   141.839996     779100               0.386561  0.584965
# 263     IT   243.070007    1982500               1.184931  0.418219
# 264    DOV   179.399994     772100               0.231738  0.397894
# 265   JBHT   144.449997     745000               0.270932  0.154305
# 266    EFX   248.070007    1088400               0.419316  0.120126
# 267    CRS   246.470001     514900               0.544876  0.480352
# 268    MTZ   178.000000     640300               0.420942  0.345954
# 269   NTES   129.669998    2169400               0.287624  0.325996
# 270   GNRC   198.970001     789800               0.706759  0.092783
# 271   VRSN   266.820007     859700               0.476409  0.320075
# 272   MNDY   176.919998    2358600               1.285238  0.410610
# 273   RGLD   169.610001     652500               0.209465  0.558598
# 274   LPLA   355.959991    1027600               0.366925  0.699222
# 275     RL   290.390015     752100               0.378956  0.261726
# 276    WWD   245.330002     469700               0.237646  0.308295
# 277   NICE   127.849998    2770900               0.666196  0.425543
# 278   ZBRA   327.709991     604800               0.548166  0.418402
#
#      iv/hv_ratio  mean_openInterest  hmm_mean_0  hmm_std_0  hmm_mean_1  \
# 0       0.777133       10985.000000    0.016163   0.028561    0.001052
# 1       1.100714       12697.250000    0.001775   0.021355    0.003446
# 2       1.255466       35840.500000    0.009817   0.060145   -0.022765
# 3       0.611484        9084.000000    0.000377   0.039570    0.003978
# 4       0.656257        4887.250000    0.012986   0.034474    0.001962
# 5       0.881254       19366.250000    0.004966   0.030052   -0.007702
# 6       0.592626       11897.250000    0.007949   0.033387   -0.003158
# 7       0.499542        2259.000000   -0.444996   0.100522    0.209798
# 8       0.817506       19078.500000    0.008070   0.041421   -0.012753
# 9       0.588807        9604.750000   -0.050356   0.062713    0.010414
# 10      0.791486        8212.750000   -0.000102   0.065249    0.003981
# 11      0.540672        7098.500000    0.005590   0.029840   -0.008819
# 12      0.333764        1868.000000    0.039361   0.082370   -0.050491
# 13      0.903232        6908.000000   -0.001149   0.023120    0.004408
# 14      0.368713        8534.750000   -0.004415   0.039682   -0.000047
# 15      0.913920        2847.750000    0.005411   0.093803   -0.014276
# 16      1.776546        5652.250000   -0.001636   0.025090    0.002331
# 17      0.403842       18948.000000    0.003392   0.024000    0.000443
# 18      1.368412        1064.000000   -0.001886   0.102313    0.218027
# 19      0.864349        3893.250000    0.005293   0.024010   -0.000679
# 20      0.838579        7698.500000   -0.004749   0.040644    0.011712
# 21      0.451569        7079.750000    0.006619   0.035060   -0.007457
# 22      2.576323        1527.000000   -0.007304   0.105520   -0.047302
# 23      1.897447        2840.333333   -0.001143   0.021931    0.006300
# 24      0.812043        1412.000000    0.030509   0.064240    0.098669
# 25      0.848158        6750.000000   -0.003998   0.019164    0.003895
# 26      1.841911        3209.250000   -0.057844   0.074178   -0.487196
# 27      1.049988        3400.750000   -0.002232   0.030066    0.007855
# 28      0.896080        4525.666667   -0.008276   0.039087    0.011712
# 29      1.524657        3606.250000    0.002555   0.018356    0.000179
# 30      0.654403        1452.666667   -0.004528   0.028380    0.010946
# 31      1.661912         715.500000   -0.002903   0.023319    0.006668
# 32      1.742682         583.000000    0.001816   0.018701   -0.001991
# 33      1.107259        5716.500000   -0.005064   0.043693    0.003980
# 34      1.192385        2096.666667    0.028437   0.084700   -0.037137
# 35      1.415682        2313.000000   -0.001063   0.018903    0.003136
# 36      1.101957        3787.000000   -0.003078   0.022199    0.006653
# 37      0.622574        1967.500000    0.051090  31.622777    0.062994
# 38      1.011771        1038.000000   -0.003980   0.021946    0.007726
# 39      1.069146        1289.333333   -0.002616   0.017954    0.004978
# 40      0.533688        2257.500000   -0.000366   0.048670    0.009764
# 41      1.347816        4424.000000    0.002303   0.017259   -0.001419
# 42      0.947897        1168.500000    0.016386   0.104932   -0.075364
# 43      0.816492        3598.000000    0.008741   0.026142   -0.001561
# 44      0.902334        1295.000000   -0.006813   0.064817    0.083965
# 45      0.512891        2688.000000    0.010221   0.062606   -0.010684
# 46      0.515191        4676.333333    0.004617   0.037680   -0.001184
# 47      0.661907        1827.000000    0.015841   0.093753   -0.053259
# 48      1.187357        3232.000000   -0.001823   0.024667   -0.001767
# 49      1.288157        9640.000000   -0.001457   0.022743    0.008285
# 50      0.404132        1342.500000    0.005620   0.107692   -0.101002
# 51      1.631454        5207.333333    0.004507   0.028892   -0.005893
# 52      1.094855        1654.000000   -0.002875   0.028520    0.004143
# 53      0.947694        2563.000000   -0.005071   0.022218    0.004466
# 54      1.202120        5693.500000   -0.002199   0.034994    0.005111
# 55      0.921166       10892.000000    0.026683   0.077124   -0.060168
# 56      0.860350        2195.750000    0.008502   0.027018   -0.004857
# 57      0.449680        2940.000000   -0.006674   0.055211    0.018326
# 58      0.258190        3967.500000   -0.004266   0.042702    0.006441
# 59      1.212052         908.000000    0.003497   0.023210    0.001494
# 60      0.498736         711.500000    0.004464   0.033382   -0.000133
# 61      1.572224         681.750000   -0.000757   0.019885    0.005134
# 62      0.588904        1711.666667   -0.005661   0.032835    0.004072
# 63      0.393652        2045.000000    0.006227   0.021110   -0.005269
# 64      0.718575        4900.000000    0.008193   0.025385   -0.002209
# 65      2.449612         753.500000    0.005151   0.018809   -0.002234
# 66      0.495984        3224.000000   -0.000598   0.093282   -0.028370
# 67      0.803000        1250.750000    0.069308   0.088901   -0.110836
# 68      0.631512        1085.000000   -0.006308   0.031055    0.009621
# 69      0.935087        2770.000000   -0.000771   0.028320   -0.002004
# 70      1.390757         917.000000   -0.004547   0.029163    0.002854
# 71      0.523043        3343.000000    0.003687   0.026059    0.000065
# 72      1.505629        1362.000000    0.005839   0.029150   -0.000515
# 73      1.018885        1091.666667   -0.004547   0.032512    0.004630
# 74      1.083476        2094.000000   -0.038962   0.061687    0.033156
# 75      0.716056        2126.000000    0.028224   0.104191   -0.030436
# 76      0.771794        3479.500000   -0.017812   0.088668   -0.045635
# 77      1.149421        2611.000000   -0.003418   0.027750    0.005920
# 78      0.295188        2022.000000   -0.013247   0.033376    0.011253
# 79      0.944911        2209.500000    0.006760   0.032334    0.006201
# 80      1.009242        2679.500000    0.002720   0.021375    0.004039
# 81      1.226621        1856.750000    0.002257   0.020845    0.000580
# 82      0.293042        1563.500000    0.000304   0.021709    0.004720
# 83      0.290110         830.000000    0.009251   0.040258   -0.001133
# 84      1.791658         953.333333    0.001766   0.026967   -0.005720
# 85      0.804712        1622.000000    0.004129   0.023642    0.001852
# 86      0.784713        1108.000000   -0.083142   0.070169    0.018588
# 87      1.300504        5380.500000    0.002891   0.021467   -0.000117
# 88      1.596512        5210.500000    0.007109   0.024916    0.001083
# 89      1.175365        1324.333333    0.006608   0.029847   -0.003883
# 90      2.667110       11700.333333   -0.007357   0.027489    0.010035
# 91      1.585852        4337.250000   -0.002873   0.016469    0.000618
# 92      1.386427         698.250000    0.003459   0.022647    0.001878
# 93      0.545226        2061.333333    0.004260   0.025031   -0.006534
# 94      0.645165        1389.000000    0.012182   0.120922    0.020148
# 95      1.151995        1960.500000   -0.000248   0.024884   -0.002933
# 96      0.904574         785.000000   -0.016052   0.036330    0.007359
# 97      1.830570        1876.000000    0.010281   0.096796   -0.049516
# 98      0.794988        1756.000000    0.008975   0.070268   -0.011761
# 99      0.715463        1769.000000    0.001104   0.022270    0.009362
# 100     1.638366         805.000000    0.027891  31.622778    0.043325
# 101     0.859684         884.666667    0.003060   0.018131   -0.002558
# 102     0.167997        3136.666667   -0.004828   0.018926    0.004037
# 103     0.150785        2394.500000    0.007991   0.045484   -0.000979
# 104     0.893890        1649.250000    0.001058   0.029448   -0.003804
# 105     1.573647        3283.000000    0.037053   0.087803   -0.075415
# 106     0.865917        1659.500000   -0.007785   0.041493    0.019511
# 107     0.320677         742.000000    0.000318   0.021754    0.004900
# 108     2.907888        4169.333333    0.006522   0.023334   -0.001977
# 109     0.959527        1102.000000   -0.002353   0.027684    0.004884
# 110     0.397737         562.000000    0.008361   0.034175   -0.004672
# 111     0.801286         765.000000   -0.031905   0.126129   -0.061270
# 112     0.756482        1109.500000    0.000260   0.034617   -0.007263
# 113     0.686277        1044.000000    0.011746   0.072709   -0.063655
# 114     1.064463        1495.500000    0.005585   0.084638   -0.038404
# 115     1.090897        3965.500000   -0.053051   0.081901    0.034789
# 116     0.713259         622.000000    0.008666   0.022288   -0.001059
# 117     0.246629        1468.000000    0.002444   0.021321    0.001778
# 118     1.931353         784.666667    0.004096   0.020748   -0.001247
# 119     2.165909        3983.500000   -0.004075   0.023651    0.008147
# 120     0.233003         539.000000   -0.000253   0.030245    0.007143
# 121     0.141750        1413.500000    0.000943   0.024238   -0.003632
# 122     0.654420        1681.000000    0.008090   0.027797   -0.001158
# 123     0.809411        5481.000000    0.001339   0.020052    0.004442
# 124     0.384201        4314.500000   -0.010846   0.092667   -0.007884
# 125     0.785221        3164.333333   -0.002681   0.019636    0.002038
# 126     0.747019        1521.333333    0.004416   0.020771    0.001956
# 127     0.505239         570.500000   -0.002353  31.622777   -0.024084
# 128     0.667221        3030.000000    0.006311   0.026267   -0.002714
# 129     1.210886        1558.000000    0.003872   0.019746   -0.001365
# 130     2.223437         506.000000    0.002536   0.018744   -0.000087
# 131     0.400774        2696.500000    0.004437   0.034360    0.002885
# 132     0.914646        1195.000000    0.001753   0.020371   -0.003121
# 133     0.202407         744.000000   -0.104639   0.063237    0.015639
# 134     0.337966        2154.500000   -0.004215   0.030430    0.006544
# 135     1.489503        4451.000000    0.004203   0.027463   -0.000752
# 136    12.591013        1059.500000    0.000598   0.013964   -0.011780
# 137     2.555177        1631.000000    0.004204   0.026907   -0.005450
# 138     1.253923        1095.500000   -0.008559   0.083248   -0.009837
# 139     0.337142        1321.500000    0.011601   0.048539    0.076712
# 140     1.715618         603.000000    0.000615   0.028626    0.000238
# 141     1.946769         890.500000   -0.002374   0.019030    0.003939
# 142     0.872123        1062.000000   -0.002279   0.022756    0.004122
# 143     1.677395         909.000000    0.000870   0.027135    0.007519
# 144     0.782738         668.000000    0.002114   0.063238    0.001872
# 145     2.437704        1037.000000    0.001602   0.022925   -0.002962
# 146     0.919905         507.000000   -0.001793   0.099427   -0.025527
# 147     0.792795        1704.000000    0.008691   0.028050   -0.005844
# 148     1.321291        4158.250000    0.002246   0.021586   -0.002018
# 149     1.451928        1949.500000   -0.003861   0.027024    0.007999
# 150     0.629506        1080.000000   -0.005964   0.032486    0.005017
# 151     1.134970         847.500000   -0.005450   0.027324    0.005793
# 152     3.300111         901.000000    0.000565   0.020533   -0.000379
# 153     0.869455        1326.000000   -0.082216   0.111609   -0.005905
# 154     1.504451        1467.000000    0.004787   0.026665   -0.001374
# 155     0.227702         503.000000   -0.027088   0.075151   -0.008229
# 156     0.815039        1378.000000    0.003740   0.019952    0.000773
# 157     0.343453         829.000000    0.031841   0.055554    0.124920
# 158     1.035543        1993.500000   -0.002272   0.018972    0.003204
# 159     2.750536         911.000000    0.005857   0.025886    0.000019
# 160     2.937250        1202.000000    0.000736   0.018421    0.002426
# 161     0.757475         921.750000    0.009819   0.023256   -0.003202
# 162     1.422667        1314.000000   -0.005968   0.036001    0.007067
# 163     0.827370        2179.666667   -0.007970   0.034923    0.004522
# 164     0.648776        1556.666667    0.000280   0.039266    0.009270
# 165     2.079404         659.500000    0.002472   0.024802    0.003437
# 166     2.134809        1105.000000   -0.002918   0.023946    0.004676
# 167     1.069603        2119.000000   -0.000067   0.020773    0.002571
# 168     0.771764        1149.000000    0.003395   0.024061   -0.001657
# 169     0.960175         591.500000   -0.006306   0.031277    0.007185
# 170     1.148609         633.000000    0.008505   0.026051    0.002551
# 171     0.682737         901.250000   -0.004793   0.021780    0.006526
# 172     0.951659        1712.000000    0.006774   0.021645   -0.000709
# 173     1.888651         701.500000    0.002819   0.022285   -0.001835
# 174     1.419800         546.000000   -0.036599   0.093434   -0.007751
# 175     0.939367        5905.000000    0.001179   0.021655   -0.002859
# 176     1.486863        2150.250000   -0.011696   0.077269   -0.039953
# 177     1.394609         941.000000    0.003906   0.022507   -0.002709
# 178     2.206506         609.000000    0.005510   0.021029   -0.001053
# 179     2.875425         687.500000   -0.004723   0.020782    0.003525
# 180     0.865704        1246.500000   -0.002299   0.024287    0.004581
# 181     0.700988        6405.000000    0.001319   0.038823   -0.005264
# 182     1.573479         600.000000    0.002063   0.019679    0.003601
# 183     2.582516        1005.000000    0.004008   0.021271   -0.005307
# 184     0.403059         644.000000    0.003660   0.018259   -0.001577
# 185     1.134838        1540.333333    0.005835   0.082337   -0.044984
# 186     1.168189        1132.000000   -0.004317   0.023000    0.003553
# 187     1.110615        6313.000000   -0.005001   0.023451    0.008187
# 188     1.246513        1047.000000    0.001174   0.016885    0.000147
# 189     1.048326         769.500000   -0.186178   0.129627    0.119543
# 190     1.015188         701.000000   -0.009271   0.031852    0.009527
# 191     2.226861         797.000000   -0.002675   0.024331    0.004833
# 192     0.775919        1045.000000   -0.002550   0.018305    0.004346
# 193     0.350389         742.000000   -0.001074   0.022672    0.003458
# 194     0.462235        2151.000000    0.005867   0.026464   -0.000369
# 195     1.269194        1356.000000   -0.004432   0.046742    0.011622
# 196     1.003405        2716.333333    0.015963   0.031188    0.000885
# 197     0.429358         693.000000    0.004961   0.026461   -0.002700
# 198     0.582945         878.000000    0.010652   0.131812   -0.042504
# 199     0.983425         524.000000   -0.002571   0.026231    0.005720
# 200     0.979334         689.000000   -0.000025   0.017780    0.001857
# 201     0.972706        1446.000000    0.000506   0.018924   -0.002200
# 202     2.502279        1853.000000    0.012408   0.131301   -0.064823
# 203     1.428099        1234.500000   -0.036831   0.089519   -0.014605
# 204     1.017343        2075.000000    0.002988   0.020904   -0.004319
# 205     0.622908        2815.750000   -0.007765   0.038261   -0.004227
# 206     1.335371        1834.000000   -0.004707   0.032408    0.001247
# 207     0.726383        1130.000000   -0.005489   0.022068    0.005927
# 208     2.571175        3745.000000   -0.000363   0.019404    0.004786
# 209     1.313094        1600.000000    0.001547   0.023703    0.003206
# 210     1.075035         718.000000   -0.003384   0.018908    0.005385
# 211     1.814626         983.000000   -0.003641   0.073551   -0.031210
# 212     8.807171        3852.000000    0.002593   0.019925    0.001268
# 213     1.362222        1009.000000   -0.004200   0.126847   -0.075569
# 214     1.875435         600.000000    0.003468   0.018550   -0.001953
# 215     1.721644         887.000000    0.005187   0.024405   -0.001165
# 216     0.392869        1901.000000   -0.045177   0.132549   -0.025872
# 217     0.812833        1187.000000    0.000746   0.023448    0.005228
# 218     1.325148        8199.000000    0.011326   0.029215   -0.006835
# 219     1.832205         841.000000    0.001544   0.024272   -0.001243
# 220     2.850773         521.000000    0.002886   0.021167   -0.005968
# 221     0.912775         750.500000    0.000029   0.021863    0.003654
# 222     1.174156         828.000000    0.004826   0.023029    0.000697
# 223     1.438904         653.000000    0.001323   0.024565   -0.030278
# 224     1.852958        1208.000000    0.003564   0.017658   -0.002203
# 225     0.799879         933.000000   -0.005351   0.062895   -0.018968
# 226     1.799392         721.500000    0.001384   0.016041   -0.001747
# 227     1.002494         756.000000    0.003730   0.021480   -0.002691
# 228     0.905916        2322.000000   -0.002527   0.022953    0.007222
# 229     0.788520        1381.000000    0.002843   0.024015    0.003103
# 230     2.708887         841.500000   -0.000921   0.024292    0.006106
# 231     1.422400        1074.333333   -0.004260   0.021448    0.005852
# 232     0.472562        1608.333333    0.001229   0.028087    0.043222
# 233     0.372482         599.000000   -0.019932   0.071396   -0.032955
# 234     0.901158         849.000000   -0.004375   0.028269    0.002147
# 235     1.603178        1316.666667    0.000203   0.017430   -0.000291
# 236     0.782729        1378.000000   -0.001417   0.035805    0.004196
# 237     0.886595         950.333333   -0.001331   0.028738    0.008167
# 238     1.027470        1581.000000   -0.001194   0.025140    0.004969
# 239     1.899538        1509.000000    0.000588   0.021964    0.004301
# 240     0.682826        2601.000000   -0.068336   0.104293   -0.028554
# 241     1.375175        3118.000000   -0.012530   0.060366    0.014082
# 242     2.767089        1559.000000   -0.005288   0.023914    0.003787
# 243     1.483161         578.000000    0.000497   0.016943    0.003734
# 244     2.271478        1304.000000   -0.002442   0.025535    0.006773
# 245     0.725919         559.000000   -0.002733   0.029242   -0.003803
# 246     1.697404         611.000000    0.001614   0.019455   -0.003471
# 247     1.163323         548.000000   -0.004614   0.081148    0.012688
# 248     4.912795         911.000000    0.005025   0.019062   -0.001196
# 249     2.432553        2449.000000    0.013439   0.043338   -0.000472
# 250     1.071475        3435.000000   -0.021805   0.073980   -0.001820
# 251     1.584805         978.000000   -0.003620   0.018398    0.004884
# 252     0.374067        1061.000000    0.002711   0.017731   -0.003746
# 253     1.797942         907.000000   -0.002002   0.023025   -0.000485
# 254     0.518405        1119.000000    0.019186   0.078845    0.045243
# 255     1.227318         985.000000    0.001380   0.021625   -0.002244
# 256     0.302204         731.000000   -0.045333   0.114391    0.047247
# 257     0.587271         903.000000   -0.009935   0.076035   -0.034971
# 258     0.777419         664.000000   -0.001295   0.022585    0.000214
# 259     0.627815         990.666667   -0.008250   0.034118   -0.002489
# 260     0.677056         862.000000   -0.003181   0.019310    0.005460
# 261     0.652808         756.000000    0.006603   0.028085    0.008710
# 262     1.513252        1052.000000    0.003659   0.093010    0.002542
# 263     0.352948         647.000000    0.025851   0.107190   -0.314410
# 264     1.717000        1417.500000    0.001566   0.022050   -0.001681
# 265     0.569535        2014.000000    0.003276   0.022096   -0.006247
# 266     0.286480         957.000000    0.004245   0.019331   -0.003377
# 267     0.881580        1154.333333    0.004275   0.026336    0.003695
# 268     0.821855        1081.000000    0.006182   0.025395    0.004339
# 269     1.133408         925.500000   -0.001019   0.021477    0.003545
# 270     0.131279        1703.000000    0.033189   0.143699    0.003474
# 271     0.671849         816.000000    0.001184   0.018017    0.001715
# 272     0.319481         519.000000   -0.008382   0.067266   -0.350589
# 273     2.666783        1360.000000    0.001075   0.024547    0.001278
# 274     1.905624         908.000000   -0.002523   0.029737    0.002678
# 275     0.690651        2695.000000   -0.018684   0.130352   -0.035452
# 276     1.297287         562.000000    0.003193   0.022342    0.004201
# 277     0.638765        2517.000000    0.000746   0.026592   -0.001606
# 278     0.763275         608.000000    0.001213   0.023484    0.003280
#
#      hmm_std_1  hmm_mean_2  hmm_std_2  pct_last30_in_highest_stdev_state  \
# 0     0.042268   -0.033786   0.108194                           0.000000
# 1     0.023175   -0.009879   0.063742                           0.000000
# 2     0.042011    0.007424   0.021780                           0.000000
# 3     0.037661   -0.026392   0.118798                           0.000000
# 4     0.033463   -0.024042   0.090830                           0.000000
# 5     0.043408    0.126959   0.109599                           0.000000
# 6     0.034929    0.168632   0.123665                           0.000000
# 7     0.114317   -0.004794   0.058884                           3.333333
# 8     0.035139    0.095685   0.071445                           6.666667
# 9     0.100058    0.000481   0.019666                           0.000000
# 10    0.039203   -0.111153   0.100010                           0.000000
# 11    0.031299    0.003928   0.118376                          10.000000
# 12    0.097574    0.001547   0.043308                           3.333333
# 13    0.020401   -0.021607   0.064885                           0.000000
# 14    0.033226    0.027435   0.119017                          53.333333
# 15    0.053356    0.012176   0.035940                           0.000000
# 16    0.021028    0.074942   0.101865                           0.000000
# 17    0.021203   -0.016028   0.072821                           3.333333
# 18    0.567129   -1.261873   0.101774                           0.000000
# 19    0.017806   -0.086610   0.074811                           0.000000
# 20    0.055850   -0.096327   0.093616                           3.333333
# 21    0.027887   -0.032901   0.121264                           3.333333
# 22    0.062747    0.001915   0.018449                           0.000000
# 23    0.021049    0.009507   0.157593                           0.000000
# 24    0.105536   -0.026217   0.048830                           6.666667
# 25    0.020276   -0.122036   0.100604                           3.333333
# 26    0.074799    0.013661   0.071531                           0.000000
# 27    0.028064   -0.025686   0.124848                           0.000000
# 28    0.046948   -0.024743   0.114835                           3.333333
# 29    0.019861   -0.057854   0.097373                           0.000000
# 30    0.028566   -0.002591   0.120576                           6.666667
# 31    0.022812   -0.112638   0.103127                           0.000000
# 32    0.020577   -0.011155   0.063821                           0.000000
# 33    0.061297    0.069178   0.110111                           0.000000
# 34    0.056767   -0.000566   0.027107                          10.000000
# 35    0.017828   -0.010747   0.066196                           0.000000
# 36    0.025690   -0.001418   0.075887                           0.000000
# 37    0.071807    0.000695   0.016186                           0.000000
# 38    0.024353   -0.015548   0.096429                           0.000000
# 39    0.022313    0.003887  31.622777                           0.000000
# 40    0.038263   -0.088277   0.118643                           0.000000
# 41    0.021817    0.000654  31.622777                           0.000000
# 42    0.074580    0.002926   0.032759                           0.000000
# 43    0.028339    0.002164   0.079710                           0.000000
# 44    0.116254   -0.002972   0.035308                           6.666667
# 45    0.041430    0.024759  10.116756                           0.000000
# 46    0.036569    0.012429   0.127709                           3.333333
# 47    0.062847    0.003940   0.023980                           3.333333
# 48    0.019004    0.037278  31.622777                           0.000000
# 49    0.022706   -0.089519   0.076360                           0.000000
# 50    0.073909   -0.000389   0.026638                           3.333333
# 51    0.031239    0.073412   0.144984                           0.000000
# 52    0.026543    0.080196   0.071722                           0.000000
# 53    0.024677   -0.000913   0.096719                           0.000000
# 54    0.036484    0.127474   0.071372                           3.333333
# 55    0.137974    0.001550   0.023975                           0.000000
# 56    0.029825   -0.081200   0.062468                           0.000000
# 57    0.065792   -0.263342   0.073243                           0.000000
# 58    0.042998   -0.487776   0.100124                           3.333333
# 59    0.030118    0.050344   0.065344                           0.000000
# 60    0.036518    0.002213   0.085730                           0.000000
# 61    0.021290   -0.022725   0.072097                           0.000000
# 62    0.036380    0.003924   0.122321                           6.666667
# 63    0.024545   -0.019412   0.072973                           3.333333
# 64    0.025351   -0.014266   0.073143                           0.000000
# 65    0.020550   -0.021919   0.067080                           0.000000
# 66    0.057010    0.002163   0.022386                           3.333333
# 67    0.102693   -0.001057   0.027003                           3.333333
# 68    0.033799   -0.028145   0.117814                           3.333333
# 69    0.028255   -0.009063   0.076824                           0.000000
# 70    0.031960    0.102248   0.103891                           0.000000
# 71    0.024243   -0.005671   0.085836                           6.666667
# 72    0.026052   -0.017385   0.102070                           0.000000
# 73    0.024468    0.006957   0.131325                           0.000000
# 74    0.093666   -0.000333   0.027841                           3.333333
# 75    0.069760    0.000437   0.016859                           0.000000
# 76    0.047646    0.001907   0.019585                           0.000000
# 77    0.036032   -0.042007   0.066274                           0.000000
# 78    0.046799   -0.269916   0.118073                           3.333333
# 79    0.024726   -0.003308   0.070919                          10.000000
# 80    0.021989    0.012082   0.064867                           0.000000
# 81    0.017094   -0.006765   0.066932                           0.000000
# 82    0.021092   -0.033216   0.081256                           3.333333
# 83    0.044824    0.031055   0.120786                           6.666667
# 84    0.021906    0.037598  31.622801                           0.000000
# 85    0.024721   -0.010184   0.089864                           0.000000
# 86    0.112786    0.000908   0.026269                           3.333333
# 87    0.018875   -0.024063   0.074454                           0.000000
# 88    0.024063   -0.053798   0.056089                           0.000000
# 89    0.030820   -0.101810   0.661694                           0.000000
# 90    0.030363   -0.129538   0.083271                           0.000000
# 91    0.019083   -0.024707   0.113785                           0.000000
# 92    0.017007   -0.055392   0.073162                           0.000000
# 93    0.044539   -0.101623   0.162035                           3.333333
# 94    0.110206   -0.001305   0.023892                           6.666667
# 95    0.027929    0.078111   0.107678                           0.000000
# ...
# 21       Ticker
# SNAP   -0.000031
# dtype: float64    4.147472
# 22       Ticker
# ITUB    0.000016
# dtype: float64    2.080793
# 23       Ticker
# ITUB    0.000016
# dtype: float64    2.302445
# 24       Ticker
# ITUB    0.000016
# dtype: float64    2.119043
# 25        Ticker
# RUN    0.000101
# dtype: float64    2.355234
# 26        Ticker
# RUN    0.000101
# dtype: float64    0.353739
# 27        Ticker
# CCL    0.000002
# dtype: float64    2.038695
# 28         Ticker
# HL    0.000034
# dtype: float64    1.827363
# 29         Ticker
# HL    0.000034
# dtype: float64    5.043896
# 30         Ticker
# HL    0.000034
# dtype: float64    2.399714
# 31        Ticker
# KEY    0.000008
# dtype: float64    2.676470
# 32       Ticker
# CLSK   -0.000049
# dtype: float64    1.877353
# 33       Ticker
# CLSK   -0.000049
# dtype: float64    1.810682
# 34       Ticker
# STLA    0.000026
# dtype: float64    1.217075
# 35       Ticker
# UBER    0.000007
# dtype: float64    2.345060
# 36       Ticker
# UBER    0.000007
# dtype: float64    2.861751
# 37       Ticker
# CSCO   -0.000019
# dtype: float64    1.843410
# 38         Ticker
# RKT    0.00001
# dtype: float64    1.073954
# 39         Ticker
# RKT    0.00001
# dtype: float64    1.528091
# 40         Ticker
# RKT    0.00001
# dtype: float64    0.712656
# 41         Ticker
# RKT    0.00001
# dtype: float64    1.214029
# 42       Ticker
# MRVL   -0.000002
# dtype: float64    0.840942
# 43       Ticker
# MRVL   -0.000002
# dtype: float64    1.456859
# 44         Ticker
# MP    0.000028
# dtype: float64    0.895085
# 45       Ticker
# COIN    0.000007
# dtype: float64    1.065865
# 46       Ticker
# COIN    0.000007
# dtype: float64    1.334277
# 47       Ticker
# COIN    0.000007
# dtype: float64    1.729289
# 48       Ticker
# INFY    0.000007
# dtype: float64    4.628192
# 49       Ticker
# INFY    0.000007
# dtype: float64    3.834200
# 50       Ticker
# INFY    0.000007
# dtype: float64    3.493992
# 51       Ticker
# LYFT    0.000053
# dtype: float64    1.468788
# 52        Ticker
# CDE    0.000054
# dtype: float64    0.954971
# 53        Ticker
# CDE    0.000054
# dtype: float64    1.169222
# 54        Ticker
# CDE    0.000054
# dtype: float64    0.417175
# 55        Ticker
# GME    0.000001
# dtype: float64    6.356850
# 56        Ticker
# GME    0.000001
# dtype: float64    5.031927
# 57        Ticker
# KSS    0.000057
# dtype: float64    1.070001
# 58        Ticker
# KSS    0.000057
# dtype: float64    1.606211
# 59        Ticker
# NEM    0.000006
# dtype: float64    0.880824
# 60        Ticker
# NEM    0.000006
# dtype: float64    1.477382
# 61         Ticker
# RF    0.000007
# dtype: float64    2.843686
# 62        Ticker
# AEO    0.000012
# dtype: float64    1.531635
# 63        Ticker
# TSM   -0.000007
# dtype: float64    4.236679
# 64        Ticker
# TSM   -0.000007
# dtype: float64    3.484724
# 65         Ticker
# USB    0.00001
# dtype: float64    1.380871
# 66        Ticker
# UAA   -0.000091
# dtype: float64    0.262510
# 67        Ticker
# UAA   -0.000091
# dtype: float64    0.093896
# 68        Ticker
# UAA   -0.000091
# dtype: float64    0.127797
# 69   Ticker
# DKNG    9.293180e-07
# dtype: float64    0.778600
# 70   Ticker
# DKNG    9.293180e-07
# dtype: float64    0.372449
# 71         Ticker
# GM    0.000023
# dtype: float64    3.587222
# 72       Ticker
# MCHP   -0.000011
# dtype: float64    0.108025
# 73       Ticker
# MCHP   -0.000011
# dtype: float64    0.144419
# 74        Ticker
# DAL    0.000039
# dtype: float64    1.410397
# 75                                          NaN         NaN
# 76                                          NaN         NaN
# 77        Ticker
# YMM   -0.000011
# dtype: float64    1.113723
# 78         Ticker
# AI   -0.000074
# dtype: float64    0.048231
# 79        Ticker
# APH   -0.000003
# dtype: float64    1.400778
# 80        Ticker
# APH   -0.000003
# dtype: float64    3.295880
# 81        Ticker
# APH   -0.000003
# dtype: float64    4.263450
# 82       Ticker
# QCOM    0.000025
# dtype: float64    5.405504
# 83         Ticker
# BE    0.000055
# dtype: float64    3.212957
# 84         Ticker
# BE    0.000055
# dtype: float64    1.503424
# 85         Ticker
# BE    0.000055
# dtype: float64    3.987377
# 86        Ticker
# STM    0.000011
# dtype: float64    1.635466
# 87         Ticker
# TFC    0.00001
# dtype: float64    2.943410
# 88       Ticker
# CHWY    0.000057
# dtype: float64    1.506898
# 89       Ticker
# CHWY    0.000057
# dtype: float64    1.350967
# 90       Ticker
# CHWY    0.000057
# dtype: float64    0.817773
# 91       Ticker
# CHWY    0.000057
# dtype: float64    2.440925
# 92                                          NaN         NaN
# 93       Ticker
# SCHW   -0.000004
# dtype: float64    0.440846
# 94        Ticker
# HBI    0.000105
# dtype: float64    0.021698
# 95       Ticker
# PANW    0.000013
# dtype: float64    0.929509
# 96       Ticker
# XPEV    0.000006
# dtype: float64    0.162642
# 97       Ticker
# XPEV    0.000006
# dtype: float64    0.059126
# 98       Ticker
# XPEV    0.000006
# dtype: float64    0.217288
# 99        Ticker
# WDC    0.000006
# dtype: float64    3.145520
# 100       Ticker
# TME    0.000056
# dtype: float64    0.219539
# 101       Ticker
# TME    0.000056
# dtype: float64    1.077426
# 102       Ticker
# UPS    0.000007
# dtype: float64   14.004630
# 103                                         NaN         NaN
# 104                                         NaN         NaN
# 105                                         NaN         NaN
# 106                                         NaN         NaN
# 107                                         NaN         NaN
# 108        Ticker
# AA    0.000016
# dtype: float64    1.793588
# 109        Ticker
# AA    0.000016
# dtype: float64    2.572218
# 110      Ticker
# ETSY    0.000049
# dtype: float64    3.008104
# 111      Ticker
# ETSY    0.000049
# dtype: float64    0.946220
# 112       Ticker
# CZR    0.000004
# dtype: float64    2.718082
# 113       Ticker
# CZR    0.000004
# dtype: float64    1.708062
# 114   Ticker
# RTX    3.008339e-07
# dtype: float64    2.820990
# 115   Ticker
# RTX    3.008339e-07
# dtype: float64    4.777495
# 116   Ticker
# RTX    3.008339e-07
# dtype: float64    2.476462
# 117   Ticker
# GLW    7.087459e-07
# dtype: float64    7.905380
# 118      Ticker
# FITB    0.000008
# dtype: float64    3.497485
# 119      Ticker
# FITB    0.000008
# dtype: float64    2.688266
# 120       Ticker
# LVS    0.000006
# dtype: float64    9.635604
# 121       Ticker
# LVS    0.000006
# dtype: float64   13.391204
# 122       Ticker
# LVS    0.000006
# dtype: float64    5.644003
# 123       Ticker
# JCI   -0.000007
# dtype: float64    4.302670
# 124      Ticker
# CARR   -0.000007
# dtype: float64    6.218076
# 125      Ticker
# CARR   -0.000007
# dtype: float64    8.584518
# 126      Ticker
# CARR   -0.000007
# dtype: float64    3.387547
# 127       Ticker
# IBM   -0.000019
# dtype: float64    6.382121
# 128       Ticker
# LYB    0.000017
# dtype: float64    1.747802
# 129      Ticker
# TMUS    0.000024
# dtype: float64    4.330462
# 130      Ticker
# TMUS    0.000024
# dtype: float64    3.229603
# 131   Ticker
# FTV    6.914245e-07
# dtype: float64    2.138188
# 132   Ticker
# FTV    6.914245e-07
# dtype: float64    4.091382
# 133       Ticker
# ALB    0.000058
# dtype: float64    0.535593
# 134                                         NaN         NaN
# 135                                         NaN         NaN
# 136                                         NaN         NaN
# 137       Ticker
# OMC    0.000015
# dtype: float64    0.841975
# 138      Ticker
# CTVA    0.000007
# dtype: float64    2.990395
# 139       Ticker
# AIG    0.000015
# dtype: float64    3.023939
# 140       Ticker
# AIG    0.000015
# dtype: float64    1.405455
# 141       Ticker
# AIG    0.000015
# dtype: float64    3.138480
# 142      Ticker
# OKTA   -0.000022
# dtype: float64    1.423229
# 143      Ticker
# OKTA   -0.000022
# dtype: float64    0.649096
# 144      Ticker
# OKTA   -0.000022
# dtype: float64    2.604653
# 145       Ticker
# UNP   -0.000011
# dtype: float64    1.195197
# 146       Ticker
# TER    0.000005
# dtype: float64    1.550024
# 147       Ticker
# TER    0.000005
# dtype: float64    1.881588
# 148        Ticker
# BX    0.000002
# dtype: float64    2.322980
# 149        Ticker
# BX    0.000002
# dtype: float64    2.554191
# 150      Ticker
# SIRI    0.000031
# dtype: float64    2.331287
# 151       Ticker
# PGR    0.000001
# dtype: float64    3.393483
# 152       Ticker
# PGR    0.000001
# dtype: float64    1.880911
# 153      Ticker
# LULU    0.000002
# dtype: float64    0.937181
# 154   Ticker
# MMM    3.531202e-07
# dtype: float64    3.066993
# 155   Ticker
# MMM    3.531202e-07
# dtype: float64   21.440954
# 156       Ticker
# NDAQ   -0.00001
# dtype: float64    7.957401
# 157       Ticker
# NDAQ   -0.00001
# dtype: float64    4.142820
# 158         Ticker
# HD    0.00001
# dtype: float64    4.840110
# 159      Ticker
# ROST    0.000004
# dtype: float64    1.358485
# 160      Ticker
# ROST    0.000004
# dtype: float64    1.442476
# 161      Ticker
# ENTG    0.000012
# dtype: float64    5.709232
# 162      Ticker
# ENTG    0.000012
# dtype: float64    1.217945
# 163                                         NaN         NaN
# 164                                         NaN         NaN
# 165       Ticker
# HWM   -0.000022
# dtype: float64    2.035859
# 166       Ticker
# HWM   -0.000022
# dtype: float64    1.576726
# 167       Ticker
# BHP    0.000012
# dtype: float64    0.456656
# 168       Ticker
# BHP    0.000012
# dtype: float64    0.455555
# 169       Ticker
# BHP    0.000012
# dtype: float64    0.533873
# 170       Ticker
# NET   -0.000028
# dtype: float64    2.058841
# 171       Ticker
# MET    0.000025
# dtype: float64    3.007261
# 172        Ticker
# ZM   -0.000001
# dtype: float64    2.205825
# 173        Ticker
# ZM   -0.000001
# dtype: float64    1.690901
# 174        Ticker
# IR    0.000007
# dtype: float64    1.109868
# 175        Ticker
# CP   -0.000012
# dtype: float64    5.280622
# 176        Ticker
# CP   -0.000012
# dtype: float64    2.050404
# 177       Ticker
# LOW    0.000019
# dtype: float64    2.879318
# 178       Ticker
# LOW    0.000019
# dtype: float64    1.268229
# 179       Ticker
# GPN    0.000005
# dtype: float64    1.320818
# 180       Ticker
# GPN    0.000005
# dtype: float64    2.699877
# 181       Ticker
# GPN    0.000005
# dtype: float64    3.121896
# 182       Ticker
# CAT   -0.000016
# dtype: float64    2.125109
# 183        Ticker
# MA    0.000006
# dtype: float64    2.134588
# 184        Ticker
# MA    0.000006
# dtype: float64   23.443125
# 185      Ticker
# PSTG    0.000006
# dtype: float64    2.380667
# 186      Ticker
# PSTG    0.000006
# dtype: float64    2.997221
# 187       Ticker
# EQH    0.000015
# dtype: float64    3.818934
# 188      Ticker
# METC    0.000049
# dtype: float64    5.277906
# 189      Ticker
# METC    0.000049
# dtype: float64    0.814665
# 190       Ticker
# ANF   -0.000041
# dtype: float64    1.864227
# 191        Ticker
# SGI    0.00003
# dtype: float64    0.988351
# 192        Ticker
# AXP    0.00001
# dtype: float64    5.508376
# 193        Ticker
# AXP    0.00001
# dtype: float64   14.249480
# 194        Ticker
# AXP    0.00001
# dtype: float64    4.848257
# 195      Ticker
# FUTU    0.000039
# dtype: float64    1.571919
# 196         Ticker
# Z    0.000007
# dtype: float64    2.869910
# 197         Ticker
# Z    0.000007
# dtype: float64    7.593006
# 198       Ticker
# SWK    0.000025
# dtype: float64    2.648026
# 199        Ticker
# CME   -0.00001
# dtype: float64    3.985779
# 200        Ticker
# CME   -0.00001
# dtype: float64    6.519468
# 201       Ticker
# MMC    0.000005
# dtype: float64    8.346133
# 202       Ticker
# MMC    0.000005
# dtype: float64    1.383670
# 203      Ticker
# VIAV    0.000028
# dtype: float64    1.022270
# 204       Ticker
# MAS    0.000019
# dtype: float64    1.903892
# 205      Ticker
# DOCN   -0.000064
# dtype: float64    0.598874
# 206      Ticker
# BILL   -0.000019
# dtype: float64    1.882497
# 207      Ticker
# BILL   -0.000019
# dtype: float64    3.797384
# 208       Ticker
# HAS    0.000019
# dtype: float64    1.926005
# 209       Ticker
# HAS    0.000019
# dtype: float64    2.417942
# 210      Ticker
# ACGL    0.000003
# dtype: float64    4.707643
# 211    Ticker
# GS    9.045764e-08
# dtype: float64    2.821378
# 212                                         NaN         NaN
# 213                                         NaN         NaN
# 214                                         NaN         NaN
# 215                                         NaN         NaN
# 216        Ticker
# EMN    0.00002
# dtype: float64    3.507495
# 217       Ticker
# ERJ    0.000002
# dtype: float64    2.073161
# 218       Ticker
# ERJ    0.000002
# dtype: float64    1.842360
# 219       Ticker
# HLT    0.000005
# dtype: float64    2.307698
# 220       Ticker
# HLT    0.000005
# dtype: float64    0.999482
# 221      Ticker
# NTAP    0.000017
# dtype: float64    5.349362
# 222       Ticker
# QRVO    0.00002
# dtype: float64    2.783936
# 223      Ticker
# ESTC   -0.000022
# dtype: float64    2.230218
# 224        Ticker
# CB    0.000007
# dtype: float64    5.245908
# 225        Ticker
# CB    0.000007
# dtype: float64    3.692669
# 226       Ticker
# LIN    0.000007
# dtype: float64    4.474515
# 227       Ticker
# SHW    0.000011
# dtype: float64    5.820880
# 228       Ticker
# TOL    0.000009
# dtype: float64    2.458757
# 229       Ticker
# JEF    0.000012
# dtype: float64    4.409830
# 230       Ticker
# JEF    0.000012
# dtype: float64    1.635428
# 231       Ticker
# DLO    0.000177
# dtype: float64    0.797568
# 232       Ticker
# DLO    0.000177
# dtype: float64    0.609711
# 233       Ticker
# LMT    0.000006
# dtype: float64    8.959245
# 234      Ticker
# ASML    0.000017
# dtype: float64    2.710096
# 235      Ticker
# FTAI    0.000016
# dtype: float64    3.147754
# 236      Ticker
# FTAI    0.000016
# dtype: float64    1.369861
# 237       Ticker
# PII    0.000032
# dtype: float64    0.806956
# 238       Ticker
# PII    0.000032
# dtype: float64    0.929714
# 239       Ticker
# ALL   -0.000005
# dtype: float64    3.072690
# 240       Ticker
# ALL   -0.000005
# dtype: float64    6.581798
# 241      Ticker
# TROW    0.000004
# dtype: float64    3.424905
# 242      Ticker
# TROW    0.000004
# dtype: float64    1.756912
# 243       Ticker
# LHX   -0.000005
# dtype: float64    5.896201
# 244       Ticker
# JBL   -0.000013
# dtype: float64    1.124648
# 245       Ticker
# NOW   -0.000023
# dtype: float64    6.290799
# 246                                         NaN         NaN
# 247                                         NaN         NaN
# 248       Ticker
# HIG    0.000004
# dtype: float64    0.961842
# 249      Ticker
# FIVE   -0.000001
# dtype: float64    1.068256
# 250       Ticker
# EAT   -0.000004
# dtype: float64    3.251558
# 251       Ticker
# DRI    0.000004
# dtype: float64    4.190001
# 252       Ticker
# AON    0.000006
# dtype: float64   12.034939
# 253       Ticker
# SAP   -0.000028
# dtype: float64    0.303547
# 254      Ticker
# BWXT   -0.000015
# dtype: float64    2.626074
# 255       Ticker
# HRB   -0.000034
# dtype: float64    3.639540
# 256      Ticker
# CHRW    0.000009
# dtype: float64    6.589026
# 257      Ticker
# AAON    0.000003
# dtype: float64    0.056290
# 258      Ticker
# AAON    0.000003
# dtype: float64    0.097917
# 259      Ticker
# DUOL   -0.000095
# dtype: float64    1.276670
# 260       Ticker
# GPC    0.000013
# dtype: float64    4.799817
# 261       Ticker
# MOD    0.000004
# dtype: float64    1.974324
# 262        Ticker
# XYL   -0.00001
# dtype: float64    1.896232
# 263        Ticker
# IT   -0.000011
# dtype: float64    4.017516
# 264   Ticker
# DOV    3.882405e-07
# dtype: float64    1.859707
# 265      Ticker
# JBHT   -0.000002
# dtype: float64    6.313046
# 266      Ticker
# JBHT   -0.000002
# dtype: float64    8.109292
# 267       Ticker
# CRS   -0.000026
# dtype: float64    2.953516
# 268      Ticker
# NTES   -0.000007
# dtype: float64    0.250746
# 269      Ticker
# NTES   -0.000007
# dtype: float64    0.266097
# 270      Ticker
# GNRC    0.000006
# dtype: float64   11.414176
# 271      Ticker
# VRSN   -0.000008
# dtype: float64    4.042451
# 272      Ticker
# MNDY   -0.000137
# dtype: float64    0.277164
# 273      Ticker
# RGLD    0.000024
# dtype: float64    1.111110
# 274      Ticker
# LPLA   -0.000041
# dtype: float64    1.381911
# 275      Ticker
# LPLA   -0.000041
# dtype: float64    3.691884
# 276       Ticker
# WWD   -0.000015
# dtype: float64    3.732047
# 277      Ticker
# NICE   -0.000069
# dtype: float64    0.548105
# 278      Ticker
# ZBRA    0.000013
# dtype: float64    3.180015

# %%
import datetime
filterdf["AvgReturn_7d"] = 0 
today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-08-15.csv

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio
from ib_insync import *
import pandas as pd
import numpy as np
import ta

# ===== CONFIG =====
BAR_SIZE = '1 day'
DURATION = '5 Y'
NUM_BARS = 2000
VOL_WINDOW = 30
VOL_THRESHOLD = 0.001
REGIME_THRESHOLD = -0.1
ADX_PERIOD = 14
ADX_THRESHOLD = 20
SMA_PERIOD = 200
EXCHANGE = 'SMART'
CURRENCY = 'USD'
LOOKAHEAD = 4
K_NEIGHBORS = 8
FEATURES = ['RSI', 'ADX', 'CCI', 'MACD']


# Preload IBKR connection for reuse
ib = IB()

async def fetch_ibkr_stock(symbol):
    contract = Stock(symbol, EXCHANGE, CURRENCY)
    await ib.qualifyContractsAsync(contract)
    bars = await ib.reqHistoricalDataAsync(
        contract=contract,
        endDateTime='',
        durationStr=DURATION,
        barSizeSetting=BAR_SIZE,
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1
    )
    df = util.df(bars).set_index('date').tail(NUM_BARS)
    return symbol, df


def lorentzian_distance_matrix(target, anchors):
    """Vectorized Lorentzian distance calculation."""
    return np.sum(np.log1p(np.abs(anchors - target)), axis=1)


def volatility_filter(df):
    atr = ta.volatility.AverageTrueRange(
        df['high'], df['low'], df['close'], window=VOL_WINDOW
    ).average_true_range()
    return (atr / df['close']).to_numpy() > VOL_THRESHOLD


def regime_filter(df):
    returns = df['close'].pct_change()
    return returns.rolling(window=20).mean().to_numpy() > REGIME_THRESHOLD


def adx_filter(df):
    adx = ta.trend.ADXIndicator(
        df['high'], df['low'], df['close'], window=ADX_PERIOD
    ).adx()
    return adx.to_numpy() > ADX_THRESHOLD


def classify_lorentzian_knn_with_filters(df):
    closes = df['close'].values
    feature_mat = df[FEATURES].values
    sma = df['SMA'].values

    vol_mask = volatility_filter(df)
    regime_mask = regime_filter(df)
    adx_mask = adx_filter(df)

    valid_filter = vol_mask & regime_mask & adx_mask

    pred = np.full(len(df), np.nan)
    length = len(df)

    for idx in range(500, length):
        if not valid_filter[idx] or np.isnan(sma[idx]) or closes[idx] == 0:
            continue

        anchor_start = max(0, idx - 500)
        anchors = feature_mat[anchor_start:idx]
        if anchors.shape[0] < K_NEIGHBORS:
            continue

        dists = lorentzian_distance_matrix(feature_mat[idx], anchors)
        knn_indices = np.argsort(dists)[:K_NEIGHBORS]
        anchor_indices = np.arange(anchor_start, idx)[knn_indices]

        valid_idx = anchor_indices + LOOKAHEAD < length
        selected = anchor_indices[valid_idx]
        if len(selected) == 0:
            continue

        y_train = np.sign(closes[selected + LOOKAHEAD] - closes[selected])
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0

        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0

    return pred


async def process_symbols_with_knn(filterdf):
    await ib.connectAsync('127.0.0.1', 7497, clientId=np.random.randint(1000, 10000))
    
    # Fetch all data concurrently
    tasks = [fetch_ibkr_stock(sym) for sym in filterdf['symbol']]
    results = await asyncio.gather(*tasks)

    for symbol, df in results:
        print(f"Processing {symbol}...")
        df['RSI'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
        df['ADX'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
        df['CCI'] = ta.trend.CCIIndicator(df['high'], df['low'], df['close'], window=20).cci()
        df['SMA'] = ta.trend.SMAIndicator(df['close'], window=SMA_PERIOD).sma_indicator()
        macd_ind = ta.trend.MACD(df['close'])
        df['MACD'] = macd_ind.macd()

        df = df.dropna().reset_index(drop=True)

        preds = classify_lorentzian_knn_with_filters(df)
        last_8 = preds[-8:]
        
        pct_buy = np.sum(last_8 == 1) / len(last_8) * 100
        pct_sell = np.sum(last_8 == -1) / len(last_8) * 100

        filterdf.loc[filterdf['symbol'] == symbol, 'pct_buy_last_8d'] = pct_buy
        filterdf.loc[filterdf['symbol'] == symbol, 'pct_sell_last_8d'] = pct_sell

    ib.disconnect()
    return filterdf


if __name__ == '__main__':
    # Example dataframe

    df_results = asyncio.run(process_symbols_with_knn(filterdf))
    print(df_results)
# Out:
# API connection failed: ConnectionRefusedError(61, "Connect call failed ('127.0.0.1', 7497)")
# Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[7], line 149
#     143     return filterdf
#     146 if __name__ == '__main__':
#     147     # Example dataframe
# --> 149     df_results = asyncio.run(process_symbols_with_knn(filterdf))
#     150     print(df_results)
#
# File /opt/anaconda3/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/anaconda3/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/anaconda3/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /opt/anaconda3/lib/python3.12/asyncio/tasks.py:316, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     314         result = coro.send(None)
#     315     else:
# --> 316         result = coro.throw(exc)
#     317 except StopIteration as exc:
#     318     if self._must_cancel:
#     319         # Task is cancelled right before coro stops.
#
# Cell In[7], line 116, in process_symbols_with_knn(filterdf)
#     115 async def process_symbols_with_knn(filterdf):
# --> 116     await ib.connectAsync('127.0.0.1', 7497, clientId=np.random.randint(1000, 10000))
#     118     # Fetch all data concurrently
#     119     tasks = [fetch_ibkr_stock(sym) for sym in filterdf['symbol']]
#
# File /opt/anaconda3/lib/python3.12/site-packages/ib_insync/ib.py:1748, in IB.connectAsync(self, host, port, clientId, timeout, readonly, account)
#    1745 timeout = timeout or None
#    1746 try:
#    1747     # establish API connection
# -> 1748     await self.client.connectAsync(host, port, clientId, timeout)
#    1750     # autobind manual orders
#    1751     if clientId == 0:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ib_insync/client.py:211, in Client.connectAsync(self, host, port, clientId, timeout)
#     209 self.connState = Client.CONNECTING
#     210 timeout = timeout or None
# --> 211 await asyncio.wait_for(self.conn.connectAsync(host, port), timeout)
#     212 self._logger.info('Connected')
#     213 msg = b'API\0' + self._prefix(b'v%d..%d%s' % (
#     214     self.MinClientVersion, self.MaxClientVersion,
#     215     b' ' + self.connectOptions if self.connectOptions else b''))
#
# File /opt/anaconda3/lib/python3.12/asyncio/tasks.py:520, in wait_for(fut, timeout)
#     517         raise TimeoutError from exc
#     519 async with timeouts.timeout(timeout):
# --> 520     return await fut
#
# File /opt/anaconda3/lib/python3.12/site-packages/ib_insync/connection.py:39, in Connection.connectAsync(self, host, port)
#      37 self.reset()
#      38 loop = getLoop()
# ---> 39 self.transport, _ = await loop.create_connection(
#      40     lambda: self, host, port)
#
# File /opt/anaconda3/lib/python3.12/asyncio/base_events.py:1121, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1119     raise ExceptionGroup("create_connection failed", exceptions)
#    1120 if len(exceptions) == 1:
# -> 1121     raise exceptions[0]
#    1122 else:
#    1123     # If they all have the same str(), raise one.
#    1124     model = str(exceptions[0])
#
# File /opt/anaconda3/lib/python3.12/asyncio/base_events.py:1103, in BaseEventLoop.create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname, ssl_handshake_timeout, ssl_shutdown_timeout, happy_eyeballs_delay, interleave, all_errors)
#    1101 for addrinfo in infos:
#    1102     try:
# -> 1103         sock = await self._connect_sock(
#    1104             exceptions, addrinfo, laddr_infos)
#    1105         break
#    1106     except OSError:
#
# File /opt/anaconda3/lib/python3.12/asyncio/base_events.py:1006, in BaseEventLoop._connect_sock(self, exceptions, addr_info, local_addr_infos)
#    1004             else:
#    1005                 raise OSError(f"no matching local address with {family=} found")
# -> 1006     await self.sock_connect(sock, address)
#    1007     return sock
#    1008 except OSError as exc:
#
# File /opt/anaconda3/lib/python3.12/asyncio/selector_events.py:651, in BaseSelectorEventLoop.sock_connect(self, sock, address)
#     649 self._sock_connect(fut, sock, address)
#     650 try:
# --> 651     return await fut
#     652 finally:
#     653     # Needed to break cycles when an exception occurs.
#     654     fut = None
#
# File /opt/anaconda3/lib/python3.12/asyncio/futures.py:291, in Future.__await__(self)
#     289 if not self.done():
#     290     self._asyncio_future_blocking = True
# --> 291     yield self  # This tells Task to wait for completion.
#     292 if not self.done():
#     293     raise RuntimeError("await wasn't used with future")
#
# File /opt/anaconda3/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File /opt/anaconda3/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /opt/anaconda3/lib/python3.12/asyncio/selector_events.py:691, in BaseSelectorEventLoop._sock_connect_cb(self, fut, sock, address)
#     688     err = sock.getsockopt(socket.SOL_SOCKET, socket.SO_ERROR)
#     689     if err != 0:
#     690         # Jump to any except clause below.
# --> 691         raise OSError(err, f'Connect call failed {address}')
#     692 except (BlockingIOError, InterruptedError):
#     693     # socket is still registered, the callback will be retried later
#     694     pass
#
# ConnectionRefusedError: [Errno 61] Connect call failed ('127.0.0.1', 7497)

# %%
filterdf
# Out:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 5      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8      en-US     US    EQUITY   Equity           Delayed Quote         True
# 9      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12     en-US     US    EQUITY   Equity           Delayed Quote        False
# 13     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 16     en-US     US    EQUITY   Equity           Delayed Quote         True
# 17     en-US     US    EQUITY   Equity           Delayed Quote        False
# 18     en-US     US    EQUITY   Equity           Delayed Quote        False
# 19     en-US     US    EQUITY   Equity           Delayed Quote        False
# 20     en-US     US    EQUITY   Equity           Delayed Quote        False
# 21     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 22     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23     en-US     US    EQUITY   Equity           Delayed Quote        False
# 24     en-US     US    EQUITY   Equity           Delayed Quote        False
# 25     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 26     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 27     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 28     en-US     US    EQUITY   Equity           Delayed Quote        False
# 29     en-US     US    EQUITY   Equity           Delayed Quote        False
# 30     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31     en-US     US    EQUITY   Equity           Delayed Quote        False
# 32     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33     en-US     US    EQUITY   Equity           Delayed Quote        False
# 34     en-US     US    EQUITY   Equity           Delayed Quote         True
# 35     en-US     US    EQUITY   Equity           Delayed Quote         True
# 36     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 37     en-US     US    EQUITY   Equity           Delayed Quote        False
# 38     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39     en-US     US    EQUITY   Equity           Delayed Quote         True
# 40     en-US     US    EQUITY   Equity           Delayed Quote        False
# 41     en-US     US    EQUITY   Equity           Delayed Quote        False
# 42     en-US     US    EQUITY   Equity           Delayed Quote        False
# 43     en-US     US    EQUITY   Equity           Delayed Quote        False
# 44     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 45     en-US     US    EQUITY   Equity           Delayed Quote        False
# 46     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 47     en-US     US    EQUITY   Equity           Delayed Quote        False
# 48     en-US     US    EQUITY   Equity           Delayed Quote        False
# 49     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 50     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 51     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52     en-US     US    EQUITY   Equity           Delayed Quote        False
# 53     en-US     US    EQUITY   Equity           Delayed Quote        False
# 54     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 56     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 57     en-US     US    EQUITY   Equity           Delayed Quote        False
# 58     en-US     US    EQUITY   Equity           Delayed Quote        False
# 59     en-US     US    EQUITY   Equity           Delayed Quote        False
# 60     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61     en-US     US    EQUITY   Equity           Delayed Quote        False
# 62     en-US     US    EQUITY   Equity           Delayed Quote        False
# 63     en-US     US    EQUITY   Equity           Delayed Quote        False
# 64     en-US     US    EQUITY   Equity           Delayed Quote        False
# 65     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 66     en-US     US    EQUITY   Equity           Delayed Quote        False
# 67     en-US     US    EQUITY   Equity           Delayed Quote        False
# 68     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 69     en-US     US    EQUITY   Equity           Delayed Quote         True
# 70     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 71     en-US     US    EQUITY   Equity           Delayed Quote        False
# 72     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 73     en-US     US    EQUITY   Equity           Delayed Quote        False
# 74     en-US     US    EQUITY   Equity           Delayed Quote         True
# 75     en-US     US    EQUITY   Equity           Delayed Quote        False
# 76     en-US     US    EQUITY   Equity           Delayed Quote        False
# 77     en-US     US    EQUITY   Equity           Delayed Quote         True
# 78     en-US     US    EQUITY   Equity           Delayed Quote        False
# 79     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 80     en-US     US    EQUITY   Equity           Delayed Quote        False
# 81     en-US     US    EQUITY   Equity           Delayed Quote        False
# 82     en-US     US    EQUITY   Equity           Delayed Quote        False
# 83     en-US     US    EQUITY   Equity           Delayed Quote        False
# 84     en-US     US    EQUITY   Equity           Delayed Quote         True
# 85     en-US     US    EQUITY   Equity           Delayed Quote        False
# 86     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 87     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 88     en-US     US    EQUITY   Equity           Delayed Quote        False
# 89     en-US     US    EQUITY   Equity           Delayed Quote        False
# 90     en-US     US    EQUITY   Equity           Delayed Quote        False
# 91     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 92     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 93     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 94     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 95     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 96     en-US     US    EQUITY   Equity           Delayed Quote        False
# 97     en-US     US    EQUITY   Equity           Delayed Quote        False
# 98     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 99     en-US     US    EQUITY   Equity           Delayed Quote        False
# 100    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 101    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 102    en-US     US    EQUITY   Equity           Delayed Quote        False
# 103    en-US     US    EQUITY   Equity           Delayed Quote        False
# 104    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 105    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 106    en-US     US    EQUITY   Equity           Delayed Quote        False
# 107    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 108    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 109    en-US     US    EQUITY   Equity           Delayed Quote         True
# 110    en-US     US    EQUITY   Equity           Delayed Quote        False
# 111    en-US     US    EQUITY   Equity           Delayed Quote        False
# 112    en-US     US    EQUITY   Equity           Delayed Quote         True
# 113    en-US     US    EQUITY   Equity           Delayed Quote        False
# 114    en-US     US    EQUITY   Equity           Delayed Quote        False
# 115    en-US     US    EQUITY   Equity           Delayed Quote        False
# 116    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 117    en-US     US    EQUITY   Equity           Delayed Quote        False
# 118    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 119    en-US     US    EQUITY   Equity           Delayed Quote        False
# 120    en-US     US    EQUITY   Equity           Delayed Quote        False
# 121    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 122    en-US     US    EQUITY   Equity           Delayed Quote        False
# 123    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 124    en-US     US    EQUITY   Equity           Delayed Quote        False
# 125    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 126    en-US     US    EQUITY   Equity           Delayed Quote         True
# 127    en-US     US    EQUITY   Equity           Delayed Quote        False
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity           Delayed Quote         True
# 131    en-US     US    EQUITY   Equity           Delayed Quote        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
# 133    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 134    en-US     US    EQUITY   Equity           Delayed Quote        False
# 135    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 136    en-US     US    EQUITY   Equity           Delayed Quote        False
# 137    en-US     US    EQUITY   Equity           Delayed Quote        False
# 138    en-US     US    EQUITY   Equity           Delayed Quote        False
# 139    en-US     US    EQUITY   Equity           Delayed Quote         True
# 140    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 141    en-US     US    EQUITY   Equity           Delayed Quote        False
# 142    en-US     US    EQUITY   Equity           Delayed Quote        False
# 143    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 144    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 145    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 146    en-US     US    EQUITY   Equity           Delayed Quote        False
# 147    en-US     US    EQUITY   Equity           Delayed Quote        False
# 148    en-US     US    EQUITY   Equity           Delayed Quote        False
# 149    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 150    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 151    en-US     US    EQUITY   Equity           Delayed Quote        False
# 152    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 153    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote         True
# 156    en-US     US    EQUITY   Equity           Delayed Quote        False
# 157    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 158    en-US     US    EQUITY   Equity           Delayed Quote        False
# 159    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 160    en-US     US    EQUITY   Equity           Delayed Quote        False
# 161    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 162    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 163    en-US     US    EQUITY   Equity           Delayed Quote        False
# 164    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 165    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 166    en-US     US    EQUITY   Equity           Delayed Quote        False
# 167    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 168    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 169    en-US     US    EQUITY   Equity           Delayed Quote        False
# 170    en-US     US    EQUITY   Equity           Delayed Quote        False
# 171    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 172    en-US     US    EQUITY   Equity           Delayed Quote        False
# 173    en-US     US    EQUITY   Equity           Delayed Quote        False
# 174    en-US     US    EQUITY   Equity           Delayed Quote        False
# 175    en-US     US    EQUITY   Equity           Delayed Quote        False
# 176    en-US     US    EQUITY   Equity           Delayed Quote        False
# 177    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 178    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 179    en-US     US    EQUITY   Equity           Delayed Quote        False
# 180    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 181    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 182    en-US     US    EQUITY   Equity           Delayed Quote        False
# 183    en-US     US    EQUITY   Equity           Delayed Quote        False
# 184    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 185    en-US     US    EQUITY   Equity           Delayed Quote        False
# 186    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 187    en-US     US    EQUITY   Equity           Delayed Quote         True
# 188    en-US     US    EQUITY   Equity           Delayed Quote        False
# 189    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 190    en-US     US    EQUITY   Equity           Delayed Quote         True
# 191    en-US     US    EQUITY   Equity           Delayed Quote        False
# 192    en-US     US    EQUITY   Equity           Delayed Quote        False
# 193    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 194    en-US     US    EQUITY   Equity           Delayed Quote        False
# 195    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 196    en-US     US    EQUITY   Equity           Delayed Quote        False
# 197    en-US     US    EQUITY   Equity           Delayed Quote        False
# 198    en-US     US    EQUITY   Equity           Delayed Quote         True
# 199    en-US     US    EQUITY   Equity           Delayed Quote        False
# 200    en-US     US    EQUITY   Equity           Delayed Quote        False
# 201    en-US     US    EQUITY   Equity           Delayed Quote        False
# 202    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 203    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 204    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 205    en-US     US    EQUITY   Equity           Delayed Quote        False
# 206    en-US     US    EQUITY   Equity           Delayed Quote        False
# 207    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 208    en-US     US    EQUITY   Equity           Delayed Quote         True
# 209    en-US     US    EQUITY   Equity           Delayed Quote        False
# 210    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 211    en-US     US    EQUITY   Equity           Delayed Quote        False
# 212    en-US     US    EQUITY   Equity           Delayed Quote        False
# 213    en-US     US    EQUITY   Equity           Delayed Quote        False
# 214    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 215    en-US     US    EQUITY   Equity           Delayed Quote        False
# 216    en-US     US    EQUITY   Equity           Delayed Quote        False
# 217    en-US     US    EQUITY   Equity           Delayed Quote        False
# 218    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 219    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 220    en-US     US    EQUITY   Equity           Delayed Quote        False
# 221    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 222    en-US     US    EQUITY   Equity           Delayed Quote        False
# 223    en-US     US    EQUITY   Equity           Delayed Quote         True
# 224    en-US     US    EQUITY   Equity           Delayed Quote        False
# 225    en-US     US    EQUITY   Equity           Delayed Quote        False
# 226    en-US     US    EQUITY   Equity           Delayed Quote        False
# 227    en-US     US    EQUITY   Equity           Delayed Quote        False
# 228    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 229    en-US     US    EQUITY   Equity           Delayed Quote        False
# 230    en-US     US    EQUITY   Equity           Delayed Quote        False
# 231    en-US     US    EQUITY   Equity           Delayed Quote        False
# 232    en-US     US    EQUITY   Equity           Delayed Quote        False
# 233    en-US     US    EQUITY   Equity           Delayed Quote         True
# 234    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 235    en-US     US    EQUITY   Equity           Delayed Quote        False
# 236    en-US     US    EQUITY   Equity           Delayed Quote         True
# 237    en-US     US    EQUITY   Equity           Delayed Quote        False
# 238    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 239    en-US     US    EQUITY   Equity           Delayed Quote        False
# 240    en-US     US    EQUITY   Equity           Delayed Quote        False
# 241    en-US     US    EQUITY   Equity           Delayed Quote        False
# 242    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 243    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 244    en-US     US    EQUITY   Equity           Delayed Quote        False
# 245    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 246    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 247    en-US     US    EQUITY   Equity           Delayed Quote        False
# 248    en-US     US    EQUITY   Equity           Delayed Quote        False
# 249    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 250    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 251    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#     customPriceAlertConfidence currency                        shortName  \
# 0                         HIGH      USD               NVIDIA Corporation
# 1                         HIGH      USD                Lucid Group, Inc.
# 2                         HIGH      USD                      Tesla, Inc.
# 3                          LOW      USD               Ford Motor Company
# 4                         HIGH      USD                Intel Corporation
# 5                         HIGH      USD       Palantir Technologies Inc.
# 6                         HIGH      USD          SoFi Technologies, Inc.
# 7                         HIGH      USD    American Airlines Group, Inc.
# 8                         HIGH      USD                       Apple Inc.
# 9                         HIGH      USD     Advanced Micro Devices, Inc.
# 10                        HIGH      USD      Applied Digital Corporation
# 11                         LOW      USD              MARA Holdings, Inc.
# 12                         LOW      USD                         NIO Inc.
# 13                        HIGH      USD       Super Micro Computer, Inc.
# 14                        HIGH      USD          Robinhood Markets, Inc.
# 15                        HIGH      USD                 Amazon.com, Inc.
# 16                        HIGH      USD                    Alphabet Inc.
# 17                         LOW      USD                        VALE S.A.
# 18                         LOW      USD                Banco Bradesco Sa
# 19                         LOW      USD         QuantumScape Corporation
# 20                         LOW      USD      Bank of America Corporation
# 21                         LOW      USD             Riot Platforms, Inc.
# 22                         LOW      USD                        Snap Inc.
# 23                         LOW      USD            Cleveland-Cliffs Inc.
# 24                         LOW      USD                        AT&T Inc.
# 25                         LOW      USD   Itau Unibanco Banco Holding SA
# 26                        HIGH      USD  Huntington Bancshares Incorpora
# 27                         LOW      USD           Quantum Computing Inc.
# 28                         LOW      USD                 CleanSpark, Inc.
# 29                         LOW      USD                        Amcor plc
# 30                         LOW      USD           SharpLink Gaming, Inc.
# 31                         LOW      USD             Carnival Corporation
# 32                        HIGH      USD          Micron Technology, Inc.
# 33                         LOW      USD          Uber Technologies, Inc.
# 34                        HIGH      USD         Marvell Technology, Inc.
# 35                        HIGH      USD                    Broadcom Inc.
# 36                        HIGH      USD              Comcast Corporation
# 37                         LOW      USD                  Stellantis N.V.
# 38                        HIGH      USD              Cisco Systems, Inc.
# 39                        HIGH      USD            Microsoft Corporation
# 40                         LOW      USD                          KeyCorp
# 41                         LOW      USD                         ADT Inc.
# 42                         LOW      USD      Verizon Communications Inc.
# 43                         LOW      USD            Wells Fargo & Company
# 44                        HIGH      USD                       Lyft, Inc.
# 45                         LOW      USD           Rocket Companies, Inc.
# 46                         LOW      USD                       Nike, Inc.
# 47                         LOW      USD                      fuboTV Inc.
# 48                         LOW      USD     Eos Energy Enterprises, Inc.
# 49                         LOW      USD  Norwegian Cruise Line Holdings
# 50                        HIGH      USD            Coinbase Global, Inc.
# 51                         LOW      USD     Chipotle Mexican Grill, Inc.
# 52                         LOW      USD             GameStop Corporation
# 53                         LOW      USD           Freeport-McMoRan, Inc.
# 54                         LOW      USD               MP Materials Corp.
# 55                        HIGH      USD        Peloton Interactive, Inc.
# 56                         LOW      USD              Unity Software Inc.
# 57                         LOW      USD                  Citigroup, Inc.
# 58                         LOW      USD    Alibaba Group Holding Limited
# 59                         LOW      USD                         Dow Inc.
# 60                         LOW      USD               Oracle Corporation
# 61                         LOW      USD              Newmont Corporation
# 62                         LOW      USD                  Infosys Limited
# 63                         LOW      USD  Taiwan Semiconductor Manufactur
# 64                         LOW      USD                    Coupang, Inc.
# 65                        HIGH      USD                     Shopify Inc.
# 66                         LOW      USD            Delta Air Lines, Inc.
# 67                         LOW      USD    Regions Financial Corporation
# 68                        HIGH      USD                     JD.com, Inc.
# 69                        HIGH      USD         Lam Research Corporation
# 70                        HIGH      USD            PayPal Holdings, Inc.
# 71                         LOW      USD                     U.S. Bancorp
# 72                        HIGH      USD            Starbucks Corporation
# 73                         LOW      USD           General Motors Company
# 74                        HIGH      USD                  DraftKings Inc.
# 75                         LOW      USD            Arista Networks, Inc.
# 76                         LOW      USD  American Eagle Outfitters, Inc.
# 77                        HIGH      USD  Microchip Technology Incorporat
# 78                         LOW      USD             Enphase Energy, Inc.
# 79                         LOW      USD                          HP Inc.
# 80                         LOW      USD                 V.F. Corporation
# 81                         LOW      USD            JP Morgan Chase & Co.
# 82                         LOW      USD             Amphenol Corporation
# 83                         LOW      USD             Boeing Company (The)
# 84                        HIGH      USD            QUALCOMM Incorporated
# 85                         LOW      USD  Charles Schwab Corporation (The
# 86                        HIGH      USD                PDD Holdings Inc.
# 87                        HIGH      USD   United Airlines Holdings, Inc.
# 88                         LOW      USD         Bloom Energy Corporation
# 89                         LOW      USD            Blue Owl Capital Inc.
# 90                         LOW      USD             Vertiv Holdings, LLC
# 91                        HIGH      USD                     Copart, Inc.
# 92                         LOW      USD            Skechers U.S.A., Inc.
# 93                        HIGH      USD          Applied Materials, Inc.
# 94                        HIGH      USD   Texas Instruments Incorporated
# 95                        HIGH      USD                    Datadog, Inc.
# 96                         LOW      USD                SentinelOne, Inc.
# 97                         LOW      USD  Tencent Music Entertainment Gro
# 98                        HIGH      USD                  Confluent, Inc.
# 99                         LOW      USD                     GE Aerospace
# 100                       HIGH      USD                      Hut 8 Corp.
# 101                        LOW      USD                        Visa Inc.
# 102                        LOW      USD        First Horizon Corporation
# 103                        LOW      USD                Alcoa Corporation
# 104                       HIGH      USD           Upstart Holdings, Inc.
# 105                       HIGH      USD         Palo Alto Networks, Inc.
# 106                        LOW      USD                      Invesco Ltd
# 107                       HIGH      USD                 Fastenal Company
# 108                        LOW      USD      United Parcel Service, Inc.
# 109                       HIGH      USD             Applovin Corporation
# 110                        LOW      USD           Dell Technologies Inc.
# 111                        LOW      USD                   Morgan Stanley
# 112                       HIGH      USD                        eBay Inc.
# 113                        LOW      USD            Las Vegas Sands Corp.
# 114                        LOW      USD                  RTX Corporation
# 115                        LOW      USD        TJX Companies, Inc. (The)
# 116                       HIGH      USD        O'Reilly Automotive, Inc.
# 117                        LOW      USD   Citizens Financial Group, Inc.
# 118                       HIGH      USD              Fifth Third Bancorp
# 119                        LOW      USD       Carrier Global Corporation
# 120                        LOW      USD  Mitsubishi UFJ Financial Group,
# 121                        LOW      USD             Corning Incorporated
# 122                        LOW      USD  Johnson Controls International
# 123                       HIGH      USD                First Solar, Inc.
# 124                        LOW      USD    Applied Optoelectronics, Inc.
# 125                        LOW      USD         Franklin Resources, Inc.
# 126                       HIGH      USD                     Li Auto Inc.
# 127                        LOW      USD               ICICI Bank Limited
# 128                       HIGH      USD                   Fortinet, Inc.
# 129                        LOW      USD  Capital One Financial Corporati
# 130                       HIGH      USD                        Flex Ltd.
# 131                        LOW      USD                   Snowflake Inc.
# 132                        LOW      USD      International Paper Company
# 133                       HIGH      USD                Match Group, Inc.
# 134                        LOW      USD             Huntsman Corporation
# 135                        LOW      USD  International Business Machines
# 136                        LOW      USD     LyondellBasell Industries NV
# 137                        LOW      USD  Cinemark Holdings Inc Cinemark
# 138                        LOW      USD                Fluor Corporation
# 139                       HIGH      USD                   DoorDash, Inc.
# 140                       HIGH      USD             EchoStar Corporation
# 141                        LOW      USD                    Corteva, Inc.
# 142                        LOW      USD      Deckers Outdoor Corporation
# 143                       HIGH      USD                       Okta, Inc.
# 144                       HIGH      USD         Ares Capital Corporation
# 145                       HIGH      USD                       Roku, Inc.
# 146                        LOW      USD                      Carvana Co.
# 147                        LOW      USD                  Celestica, Inc.
# 148                        LOW      USD        Union Pacific Corporation
# 149                       HIGH      USD                     Nasdaq, Inc.
# 150                       HIGH      USD                   Maplebear Inc.
# 151                        LOW      USD               Best Buy Co., Inc.
# 152                       HIGH      USD                   Teradyne, Inc.
# 153                       HIGH      USD                       Adobe Inc.
# 154                       HIGH      USD                   Entegris, Inc.
# 155                       HIGH      USD     Honeywell International Inc.
# 156                        LOW      USD              Synchrony Financial
# 157                        LOW      USD                    Rio Tinto Plc
# 158                        LOW      USD            AngloGold Ashanti PLC
# 159                        LOW      USD              Brown & Brown, Inc.
# 160                        LOW      USD                       CarMax Inc
# 161                       HIGH      USD                  Freshworks Inc.
# 162                       HIGH      USD                      Baidu, Inc.
# 163                        LOW      USD           McDonald's Corporation
# 164                       HIGH      USD                    Netflix, Inc.
# 165                       HIGH      USD           SiriusXM Holdings Inc.
# 166                        LOW      USD            Howmet Aerospace Inc.
# 167                       HIGH      USD         Skyworks Solutions, Inc.
# 168                       HIGH      USD         lululemon athletica inc.
# 169                        LOW      USD                BHP Group Limited
# 170                        LOW      USD  Apollo Global Management, Inc.
# 171                       HIGH      USD                      PACCAR Inc.
# 172                        LOW      USD                    MetLife, Inc.
# 173                        LOW      USD             Global Payments Inc.
# 174                        LOW      USD  Knight-Swift Transportation Hol
# 175                        LOW      USD      Axalta Coating Systems Ltd.
# 176                        LOW      USD         American Express Company
# 177                       HIGH      USD           Trip.com Group Limited
# 178                        LOW      USD                  Dynatrace, Inc.
# 179                        LOW      USD               Pure Storage, Inc.
# 180                        LOW      USD                    Innodata Inc.
# 181                       HIGH      USD                    Nutanix, Inc.
# 182                        LOW      USD                Caterpillar, Inc.
# 183                        LOW      USD      Abercrombie & Fitch Company
# 184                       HIGH      USD           The Carlyle Group Inc.
# 185                        LOW      USD   Intercontinental Exchange Inc.
# 186                       HIGH      USD                  LKQ Corporation
# 187                       HIGH      USD       Allegro MicroSystems, Inc.
# 188                        LOW      USD  Brookfield Asset Management Inc
# 189                       HIGH      USD  Lattice Semiconductor Corporati
# 190                       HIGH      USD                   CME Group Inc.
# 191                        LOW      USD         Equitable Holdings, Inc.
# 192                        LOW      USD                        Aptiv PLC
# 193                       HIGH      USD           Lumentum Holdings Inc.
# 194                        LOW      USD               AFLAC Incorporated
# 195                       HIGH      USD                    Workday, Inc.
# 196                        LOW      USD       Builders FirstSource, Inc.
# 197                        LOW      USD                Masco Corporation
# 198                       HIGH      USD                     Hasbro, Inc.
# 199                        LOW      USD  PNC Financial Services Group, I
# 200                        LOW      USD  Goldman Sachs Group, Inc. (The)
# 201                        LOW      USD                       TransUnion
# 202                       HIGH      USD                    Paychex, Inc.
# 203                       HIGH      USD  Take-Two Interactive Software,
# 204                       HIGH      USD               Zillow Group, Inc.
# 205                        LOW      USD              BILL Holdings, Inc.
# 206                        LOW      USD                Core & Main, Inc.
# 207                       HIGH      USD                 Tetra Tech, Inc.
# 208                       HIGH      USD          Arch Capital Group Ltd.
# 209                        LOW      USD         State Street Corporation
# 210                       HIGH      USD       Northern Trust Corporation
# 211                        LOW      USD     Floor & Decor Holdings, Inc.
# 212                        LOW      USD     Lincoln National Corporation
# 213                        LOW      USD             Celanese Corporation
# 214                       HIGH      USD                      Qorvo, Inc.
# 215                        LOW      USD                  FMC Corporation
# 216                        LOW      USD         Eastman Chemical Company
# 217                        LOW      USD            Comerica Incorporated
# 218                       HIGH      USD           TTM Technologies, Inc.
# 219                       HIGH      USD               Cognex Corporation
# 220                        LOW      USD              TE Connectivity plc
# 221                       HIGH      USD              Expedia Group, Inc.
# 222                        LOW      USD                     Embraer S.A.
# 223                       HIGH      USD               FTAI Aviation Ltd.
# 224                        LOW      USD              Toll Brothers, Inc.
# 225                        LOW      USD      Lockheed Martin Corporation
# 226                        LOW      USD           A.O. Smith Corporation
# 227                        LOW      USD           Waste Management, Inc.
# 228                        LOW      USD  International Flavors & Fragran
# 229                        LOW      USD                     Polaris Inc.
# 230                        LOW      USD       Prudential Financial, Inc.
# 231                        LOW      USD        Magna International, Inc.
# 232                        LOW      USD   Sherwin-Williams Company (The)
# 233                       HIGH      USD                 Five Below, Inc.
# 234                       HIGH      USD        T. Rowe Price Group, Inc.
# 235                        LOW      USD            Whirlpool Corporation
# 236                       HIGH      USD                     Trimble Inc.
# 237                        LOW      USD      Ares Management Corporation
# 238                       HIGH      USD            Varonis Systems, Inc.
# 239                        LOW      USD             Planet Fitness, Inc.
# 240                        LOW      USD      Southern Copper Corporation
# 241                        LOW      USD                Shake Shack, Inc.
# 242                       HIGH      USD             Steel Dynamics, Inc.
# 243                        LOW      USD                       Jabil Inc.
# 244                        LOW      USD                        XPO, Inc.
# 245                       HIGH      USD          Avis Budget Group, Inc.
# 246                        LOW      USD                     GoDaddy Inc.
# 247                        LOW      USD            Shift4 Payments, Inc.
# 248                        LOW      USD                          Aon plc
# 249                        LOW      USD       Procore Technologies, Inc.
# 250                       HIGH      USD    C.H. Robinson Worldwide, Inc.
# 251                        LOW      USD                         GMS Inc.
#
#          bid      ask  regularMarketChangePercent exchange  fiftyTwoWeekHigh  \
# 0     173.61   182.83                   -2.333160      NMS        183.300000
# 1       2.40     2.47                   -1.626010      NMS          4.430000
# 2     302.56   302.84                   -1.829560      NMS        488.540000
# 3      10.79    10.81                   -2.258360      NYQ         11.970000
# 4      19.28    19.34                   -2.474750      NMS         27.550000
# 5     154.12   154.42                   -2.576572      NMS        160.890000
# 6      21.00    22.79                   -5.978740      NMS         25.110000
# 7      11.01    11.07                   -4.003480      NMS         19.100000
# 8     192.07   213.25                   -2.500362      NMS        260.100000
# 9     171.58   171.83                   -2.614710      NMS        182.500000
# 10     12.46    12.54                   -4.718420      NMS         15.420000
# 11     15.44    15.55                   -3.606960      NCM         30.280000
# 12      4.93     4.94                    2.874750      NYQ          7.710000
# 13     56.51    56.77                   -3.951160      NMS         66.440000
# 14     99.87   108.34                   -3.056770      NMS        113.439000
# 15    206.15   217.50                   -8.269617      NMS        242.520000
# 16    179.46   198.61                   -1.443454      NMS        207.050000
# 17      9.67     9.75                    1.888780      NYQ         12.050000
# 18      2.80     2.81                    1.444040      NYQ          3.130000
# 19      8.28     8.23                   -3.953490      NYQ         15.030000
# 20     45.68    45.75                   -3.405970      NYQ         49.310000
# 21     11.00    11.15                  -17.747952      NCM         15.870000
# 22      9.02     9.07                   -4.029690      NYQ         13.281000
# 23     10.07    10.09                   -4.372620      NYQ         14.340000
# 24     27.75    27.80                    1.240420      NYQ         29.190000
# 25      6.30     6.31                    0.318979      NYQ          6.950000
# 26     15.98    16.04                   -2.373700      NMS         18.450000
# 27     14.77    14.86                   -0.269542      NCM         27.150000
# 28      9.40    10.80                   -8.179420      NCM         17.970000
# 29      9.29     9.49                   -0.534761      NYQ         11.480000
# 30     13.52    22.10                   -8.878257      NCM        124.120000
# 31     29.10    29.08                   -2.351360      NYQ         31.010000
# 32    104.78   104.95                   -3.903250      NMS        129.850000
# 33     86.80    86.85                   -0.957261      NYQ         97.715000
# 34     74.34    74.70                   -7.365940      NMS        127.480000
# 35    288.35   306.56                   -1.722846      NMS        306.950000
# 36     30.96    34.52                   -2.136621      NMS         45.310000
# 37      8.76     8.77                   -1.124860      NYQ         16.920000
# 38     67.03    67.15                   -1.424796      NMS         69.780000
# 39    523.77   524.40                   -1.760078      NMS        555.450000
# 40     17.60    17.74                   -1.506700      NYQ         20.040000
# 41      8.10     8.45                   -0.598805      NYQ          8.800000
# 42     42.86    42.90                    0.280643      NYQ         47.360000
# 43     77.85    78.09                   -3.534660      NYQ         84.830000
# 44     13.57    13.65                   -3.129449      NMS         19.065000
# 45     16.54    16.58                   11.983800      NYQ         21.380000
# 46     74.41    74.60                   -0.093720      NYQ         90.620000
# 47      3.78     3.79                   -5.778890      NYQ          6.450000
# 48      5.36     5.69                   -3.333330      NCM          7.360000
# 49     24.36    24.37                   -4.147100      NYQ         29.290000
# 50    314.28   316.19                  -16.695800      NMS        444.650000
# 51     42.52    42.50                   -0.839554      NYQ         66.740000
# 52     22.16    22.22                   -1.559020      NYQ         35.810000
# 53     40.08    40.06                   -0.521876      NYQ         52.610000
# 54     63.55    64.00                    3.560970      NYQ         65.840000
# 55      5.59     7.55                   -7.563025      NMS         10.895000
# 56     31.80    31.77                   -4.586330      NYQ         38.960000
# 57     91.83    91.91                   -1.995730      NYQ         96.910000
# 58    116.95   117.00                   -2.951170      NYQ        148.430000
# 59     21.86    21.90                   -6.440530      NYQ         55.670000
# 60    244.20   244.00                   -3.684440      NYQ        260.870000
# 61     62.52    62.63                    0.789053      NYQ         66.570000
# 62     16.37    16.64                   -1.854060      NYQ         23.630000
# 63    234.10   235.00                   -2.652920      NYQ        248.280000
# 64     28.74    28.90                   -2.344550      NYQ         31.645000
# 65    118.45   118.78                   -2.953932      NMS        129.380000
# 66     50.97    51.22                   -3.871450      NYQ         69.980000
# 67     24.50    25.02                   -1.737070      NYQ         27.960000
# 68     30.78    35.49                   -1.841850      NMS         47.820000
# 69     89.93   100.16                    1.613250      NMS        102.590000
# 70     64.54    67.14                   -2.399650      NMS         93.660000
# 71     43.87    43.86                   -2.268680      NYQ         53.980000
# 72     82.21    91.31                   -2.579640      NMS        117.460000
# 73     52.26    52.58                   -1.518560      NYQ         61.240000
# 74     43.71    47.15                   -2.908529      NMS         53.610000
# 75    116.32   117.50                   -4.585300      NYQ        133.575000
# 76     10.75    11.05                   -0.555559      NYQ         22.830000
# 77     66.27    66.42                   -1.819790      NMS         82.870000
# 78     31.39    31.50                   -2.873920      NGM        130.080000
# 79     24.36    24.70                   -1.411280      NYQ         39.800000
# 80     11.55    11.70                   -0.511949      NYQ         29.020000
# 81    289.51   289.99                   -2.319060      NYQ        301.290000
# 82    103.76   107.86                   -2.065540      NYQ        108.850000
# 83    221.60   222.43                    0.027045      NYQ        242.690000
# 84    138.90   148.31                    0.974385      NMS        182.100000
# 85     95.54    96.20                   -2.251100      NYQ         99.590000
# 86     95.57   110.16                   -2.988100      NMS        155.670000
# 87     84.44    84.61                   -4.235080      NMS        116.000000
# 88     36.75    37.20                   -1.791920      NYQ         39.090000
# 89     18.75    19.00                   -2.635660      NYQ         26.725000
# 90    140.00   142.20                   -2.754130      NYQ        155.840000
# 91     45.00    48.91                    0.397080      NMS         64.380000
# 92     63.06    63.04                   -0.395257      NYQ         78.850000
# 93    179.91   180.08                   -0.038872      NMS        215.700000
# 94    170.05   190.15                   -0.110459      NMS        221.690000
# 95    135.43   135.73                   -3.129010      NMS        170.080000
# 96     17.92    17.95                   -2.181020      NYQ         29.290000
# 97     20.42    20.66                   -2.143870      NYQ         22.500000
# 98     17.08    17.26                   -2.961920      NMS         37.900000
# 99    269.40   269.70                   -0.627114      NYQ        274.940000
# 100    14.51    19.78                   -6.829950      NMS         31.950000
# 101   338.55   339.35                   -1.771500      NYQ        375.510000
# 102    21.31    21.45                   -2.154970      NYQ         23.000000
# 103    28.56    28.37                   -5.238570      NYQ         47.770000
# 104    79.07    79.38                   -3.082942      NMS         96.429000
# 105   172.73   173.08                   -0.414747      NMS        210.390000
# 106    20.62    20.61                   -1.903850      NYQ         21.850000
# 107    45.40    45.47                   -1.495778      NMS         48.100000
# ...
# 128      Ticker
# FTNT   -0.000031
# dtype: float64    1.615815              0.0
# 129       Ticker
# COF   -0.000022
# dtype: float64    2.849155             37.5
# 130      Ticker
# FLEX   -0.000008
# dtype: float64    1.095971             50.0
# 131      Ticker
# SNOW   -0.000019
# dtype: float64    0.327423             12.5
# 132        Ticker
# IP   -0.000057
# dtype: float64    1.657184             12.5
# 133      Ticker
# MTCH   -0.000004
# dtype: float64    1.558384             12.5
# 134       Ticker
# HUN   -0.000077
# dtype: float64    2.144639              0.0
# 135       Ticker
# IBM   -0.000012
# dtype: float64    2.291569             62.5
# 136       Ticker
# LYB   -0.000059
# dtype: float64    2.187533              0.0
# 137       Ticker
# CNK   -0.000056
# dtype: float64    0.341727              0.0
# 138       Ticker
# FLR   -0.000086
# dtype: float64    0.006299             87.5
# 139      Ticker
# DASH    0.000012
# dtype: float64    1.267602             75.0
# 140      Ticker
# SATS   -0.000035
# dtype: float64    0.744667             75.0
# 141      Ticker
# CTVA   -0.000011
# dtype: float64    2.796596             50.0
# 142       Ticker
# DECK   -0.00001
# dtype: float64    0.250523              0.0
# 143      Ticker
# OKTA   -0.000003
# dtype: float64    2.609618             50.0
# 144      Ticker
# ARCC   -0.000011
# dtype: float64    1.528537             50.0
# 145      Ticker
# ROKU   -0.000039
# dtype: float64    0.072778             62.5
# 146      Ticker
# CVNA    0.000034
# dtype: float64    0.128288             50.0
# 147       Ticker
# CLS    0.000054
# dtype: float64    1.655174             50.0
# 148        Ticker
# UNP   -0.00001
# dtype: float64    3.037533              0.0
# 149      Ticker
# NDAQ    0.000014
# dtype: float64    2.822511             50.0
# 150      Ticker
# CART   -0.000019
# dtype: float64    1.599033              0.0
# 151       Ticker
# BBY   -0.000027
# dtype: float64    1.881988              0.0
# 152        Ticker
# TER    0.00005
# dtype: float64    0.741850              0.0
# 153      Ticker
# ADBE   -0.000025
# dtype: float64    1.452512              0.0
# 154      Ticker
# ENTG   -0.000065
# dtype: float64    0.306563              0.0
# 155       Ticker
# HON   -0.000011
# dtype: float64    2.936993             50.0
# 156       Ticker
# SYF   -0.000023
# dtype: float64    1.579440             25.0
# 157       Ticker
# RIO   -0.000027
# dtype: float64    3.013255             25.0
# 158        Ticker
# AU   -0.000005
# dtype: float64    1.748825             37.5
# 159       Ticker
# BRO   -0.000038
# dtype: float64    0.465468              0.0
# 160       Ticker
# KMX   -0.000037
# dtype: float64    3.284281              0.0
# 161      Ticker
# FRSH   -0.000037
# dtype: float64    2.204779              0.0
# 162      Ticker
# BIDU   -0.000025
# dtype: float64    2.531101              0.0
# 163       Ticker
# MCD    0.000009
# dtype: float64    2.402695              0.0
# 164      Ticker
# NFLX   -0.000005
# dtype: float64    4.182965             50.0
# 165      Ticker
# SIRI   -0.000048
# dtype: float64    1.905813              0.0
# 166       Ticker
# HWM   -0.000004
# dtype: float64    1.330543              0.0
# 167      Ticker
# SWKS   -0.000026
# dtype: float64    1.667574              0.0
# 168      Ticker
# LULU   -0.000051
# dtype: float64    1.933001              0.0
# 169       Ticker
# BHP   -0.000027
# dtype: float64    1.989188             25.0
# 170       Ticker
# APO   -0.000036
# dtype: float64    0.556588             37.5
# 171      Ticker
# PCAR   -0.000016
# dtype: float64    3.693437              0.0
# 172       Ticker
# MET   -0.000019
# dtype: float64    2.396034              0.0
# 173       Ticker
# GPN   -0.000028
# dtype: float64    1.372171              0.0
# 174       Ticker
# KNX   -0.000042
# dtype: float64    3.780765              0.0
# 175      Ticker
# AXTA   -0.000027
# dtype: float64    0.802876              0.0
# 176       Ticker
# AXP   -0.000016
# dtype: float64    3.570496              0.0
# 177      Ticker
# TCOM   -0.000026
# dtype: float64    1.973621              0.0
# 178        Ticker
# DT   -0.000022
# dtype: float64    1.581372              0.0
# 179      Ticker
# PSTG   -0.000017
# dtype: float64    1.923487              0.0
# 180      Ticker
# INOD   -0.000015
# dtype: float64    0.263992             12.5
# 181      Ticker
# NTNX   -0.000012
# dtype: float64    1.742047              0.0
# 182       Ticker
# CAT    0.000002
# dtype: float64    0.866908             87.5
# 183       Ticker
# ANF   -0.000015
# dtype: float64    0.819466              0.0
# 184        Ticker
# CG   -0.000013
# dtype: float64    0.872496             87.5
# 185       Ticker
# ICE    0.000007
# dtype: float64    1.493106              0.0
# 186       Ticker
# LKQ   -0.000039
# dtype: float64    3.403965              0.0
# 187      Ticker
# ALGM   -0.000029
# dtype: float64    1.807565             12.5
# 188       Ticker
# BAM   -0.000017
# dtype: float64    0.796087              0.0
# 189      Ticker
# LSCC   -0.000032
# dtype: float64    1.797464              0.0
# 190       Ticker
# CME    0.000005
# dtype: float64    6.144409              0.0
# 191       Ticker
# EQH   -0.000019
# dtype: float64    2.323269             12.5
# 192      Ticker
# APTV   -0.000026
# dtype: float64    1.107466              0.0
# 193      Ticker
# LITE    0.000016
# dtype: float64    0.206864             50.0
# 194       Ticker
# AFL   -0.000018
# dtype: float64    3.804740              0.0
# 195      Ticker
# WDAY   -0.000032
# dtype: float64    2.268091              0.0
# 196       Ticker
# BLDR   -0.00001
# dtype: float64    1.971139              0.0
# 197       Ticker
# MAS    0.000008
# dtype: float64    0.595544              0.0
# 198       Ticker
# HAS   -0.000008
# dtype: float64    2.724084             37.5
# 199       Ticker
# PNC   -0.000024
# dtype: float64    2.095633             50.0
# 200        Ticker
# GS   -0.000005
# dtype: float64    1.208871             12.5
# 201       Ticker
# TRU   -0.000022
# dtype: float64    1.996805             62.5
# 202      Ticker
# PAYX   -0.000014
# dtype: float64    3.397244             25.0
# 203      Ticker
# TTWO   -0.000015
# dtype: float64    2.375300             12.5
# 204         Ticker
# Z    0.000004
# dtype: float64    2.148141             12.5
# 205      Ticker
# BILL   -0.000039
# dtype: float64    2.314646              0.0
# 206       Ticker
# CNM   -0.000013
# dtype: float64    1.552045             75.0
# 207      Ticker
# TTEK   -0.000027
# dtype: float64    1.869450             37.5
# 208      Ticker
# ACGL   -0.000002
# dtype: float64    2.666334              0.0
# 209       Ticker
# STT   -0.000007
# dtype: float64    2.866618             37.5
# 210      Ticker
# NTRS    0.000007
# dtype: float64    2.396887             50.0
# 211       Ticker
# FND   -0.000011
# dtype: float64    1.417247              0.0
# 212        Ticker
# LNC    0.00002
# dtype: float64    0.534111              0.0
# 213        Ticker
# CE   -0.000068
# dtype: float64    1.202438              0.0
# 214      Ticker
# QRVO   -0.000015
# dtype: float64    2.563788              0.0
# 215       Ticker
# FMC   -0.000049
# dtype: float64    1.324017              0.0
# 216        Ticker
# EMN   -0.00011
# dtype: float64    0.061638              0.0
# 217   Ticker
# CMA    1.027902e-07
# dtype: float64    2.821861             50.0
# 218      Ticker
# TTMI   -0.000021
# dtype: float64    0.815864             87.5
# 219      Ticker
# CGNX    0.000069
# dtype: float64    0.092741             50.0
# 220       Ticker
# TEL    0.000002
# dtype: float64    3.144406              0.0
# 221      Ticker
# EXPE   -0.000032
# dtype: float64    1.098373             62.5
# 222       Ticker
# ERJ    0.000058
# dtype: float64    1.176119             50.0
# 223      Ticker
# FTAI    0.000092
# dtype: float64    0.639408             12.5
# 224       Ticker
# TOL   -0.000011
# dtype: float64    1.589178             12.5
# 225       Ticker
# LMT   -0.000003
# dtype: float64    3.499639              0.0
# 226       Ticker
# AOS   -0.000011
# dtype: float64    2.860414             62.5
# 227        Ticker
# WM    0.000002
# dtype: float64    1.766312             37.5
# 228       Ticker
# IFF   -0.000038
# dtype: float64    2.220214              0.0
# 229       Ticker
# PII   -0.000019
# dtype: float64    1.860218             25.0
# 230       Ticker
# PRU   -0.000015
# dtype: float64    2.959227              0.0
# 231       Ticker
# MGA   -0.000015
# dtype: float64    1.820640             50.0
# 232       Ticker
# SHW    0.000005
# dtype: float64    5.323254              0.0
# 233      Ticker
# FIVE   -0.000017
# dtype: float64    1.701376             75.0
# 234      Ticker
# TROW   -0.000015
# dtype: float64    2.317809              0.0
# 235       Ticker
# WHR   -0.000062
# dtype: float64    0.399878              0.0
# 236      Ticker
# TRMB   -0.000003
# dtype: float64    2.133075             87.5
# 237      Ticker
# ARES    0.000004
# dtype: float64    1.191437              0.0
# 238      Ticker
# VRNS    0.000014
# dtype: float64    2.261223             37.5
# 239      Ticker
# PLNT   -0.000018
# dtype: float64    2.247772              0.0
# 240      Ticker
# SCCO   -0.000031
# dtype: float64    1.891820              0.0
# 241       Ticker
# SHAK   -0.00007
# dtype: float64    0.727275             62.5
# 242      Ticker
# STLD   -0.000024
# dtype: float64    1.116123              0.0
# 243       Ticker
# JBL   -0.000012
# dtype: float64    1.138034             12.5
# 244       Ticker
# XPO   -0.000047
# dtype: float64    0.975542             12.5
# 245       Ticker
# CAR   -0.000096
# dtype: float64    0.337026             62.5
# 246      Ticker
# GDDY   -0.000027
# dtype: float64    1.579594              0.0
# 247      Ticker
# FOUR   -0.000015
# dtype: float64    2.050726             75.0
# 248       Ticker
# AON   -0.000004
# dtype: float64    0.694225              0.0
# 249       Ticker
# PCOR   -0.00007
# dtype: float64    0.764631             37.5
# 250      Ticker
# CHRW    0.000052
# dtype: float64    3.369410             12.5
# 251   Ticker
# GMS    4.334801e-07
# dtype: float64    8.623325             50.0
#
#      pct_sell_last_8d
# 0                 0.0
# 1                25.0
# 2                 0.0
# 3                 0.0
# 4                62.5
# 5                 0.0
# 6                 0.0
# 7                37.5
# 8                37.5
# 9                 0.0
# 10                0.0
# 11                0.0
# 12                0.0
# 13                0.0
# 14                0.0
# 15                0.0
# 16                0.0
# 17                0.0
# 18                0.0
# 19                0.0
# 20                0.0
# 21                0.0
# 22               50.0
# 23                0.0
# 24                0.0
# 25                0.0
# 26                0.0
# 27                0.0
# 28               12.5
# 29                0.0
# 30                0.0
# 31                0.0
# 32                0.0
# 33                0.0
# 34                0.0
# 35                0.0
# 36               50.0
# 37                0.0
# 38                0.0
# 39                0.0
# 40                0.0
# 41                0.0
# 42                0.0
# 43                0.0
# 44                0.0
# 45                0.0
# 46                0.0
# 47                0.0
# 48                0.0
# 49                0.0
# 50                0.0
# 51                0.0
# 52                0.0
# 53               37.5
# 54                0.0
# 55                0.0
# 56                0.0
# 57                0.0
# 58                0.0
# 59               12.5
# 60                0.0
# 61                0.0
# 62                0.0
# 63                0.0
# 64                0.0
# 65                0.0
# 66                0.0
# 67                0.0
# 68                0.0
# 69                0.0
# 70               12.5
# 71                0.0
# 72               37.5
# 73                0.0
# 74                0.0
# 75                0.0
# 76               12.5
# 77                0.0
# 78                0.0
# 79                0.0
# 80                0.0
# 81                0.0
# 82                0.0
# 83                0.0
# 84                0.0
# 85                0.0
# 86                0.0
# 87                0.0
# 88                0.0
# 89                0.0
# 90                0.0
# 91               75.0
# 92                0.0
# 93                0.0
# 94               75.0
# 95                0.0
# 96               75.0
# 97                0.0
# 98                0.0
# 99                0.0
# 100               0.0
# 101               0.0
# 102               0.0
# 103               0.0
# 104               0.0
# 105               0.0
# 106               0.0
# 107               0.0
# 108              12.5
# 109               0.0
# 110               0.0
# 111               0.0
# 112               0.0
# 113               0.0
# 114               0.0
# 115               0.0
# 116               0.0
# 117               0.0
# 118              25.0
# 119              12.5
# 120               0.0
# 121               0.0
# 122               0.0
# 123               0.0
# 124               0.0
# 125               0.0
# 126               0.0
# 127               0.0
# 128               0.0
# 129               0.0
# 130               0.0
# 131               0.0
# 132              12.5
# 133               0.0
# 134               0.0
# 135               0.0
# 136              12.5
# 137              25.0
# 138               0.0
# 139               0.0
# 140               0.0
# 141               0.0
# 142               0.0
# 143               0.0
# 144               0.0
# 145               0.0
# 146               0.0
# 147               0.0
# 148              12.5
# 149               0.0
# 150               0.0
# 151               0.0
# 152              12.5
# 153              62.5
# 154               0.0
# 155               0.0
# 156               0.0
# 157              12.5
# 158               0.0
# 159               0.0
# 160              37.5
# 161               0.0
# 162               0.0
# 163               0.0
# 164               0.0
# 165               0.0
# 166               0.0
# 167               0.0
# 168              87.5
# 169               0.0
# 170               0.0
# 171              50.0
# 172              25.0
# 173               0.0
# 174               0.0
# 175              12.5
# 176               0.0
# 177               0.0
# 178               0.0
# 179               0.0
# 180               0.0
# 181               0.0
# 182               0.0
# 183              12.5
# 184               0.0
# 185               0.0
# 186              25.0
# 187               0.0
# 188               0.0
# 189               0.0
# 190               0.0
# 191               0.0
# 192               0.0
# 193               0.0
# 194               0.0
# 195               0.0
# 196              12.5
# 197               0.0
# 198               0.0
# 199              12.5
# 200               0.0
# 201               0.0
# 202               0.0
# 203               0.0
# 204               0.0
# 205               0.0
# 206               0.0
# 207              12.5
# 208               0.0
# 209               0.0
# 210               0.0
# 211               0.0
# 212               0.0
# 213               0.0
# 214               0.0
# 215               0.0
# 216               0.0
# 217               0.0
# 218               0.0
# 219               0.0
# 220               0.0
# 221               0.0
# 222               0.0
# 223               0.0
# 224              37.5
# 225              62.5
# 226               0.0
# 227               0.0
# 228               0.0
# 229              12.5
# 230              25.0
# 231               0.0
# 232               0.0
# 233               0.0
# 234              25.0
# 235              75.0
# 236               0.0
# 237               0.0
# 238               0.0
# 239               0.0
# 240               0.0
# 241              12.5
# 242               0.0
# 243               0.0
# 244              12.5
# 245               0.0
# 246              75.0
# 247               0.0
# 248              12.5
# 249               0.0
# 250               0.0
# 251               0.0

# %%
import datetime
filterdf["AvgReturn_7d"] = 0 
today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-08-02.csv
