# %% [markdown]
# Do a random forest return predictor for long time equity screens, maybe including rates/ sectors / commodities / geoploitic indicators.
# Find the % of regimes in the last 30 days that have a higher volatility than the current IV
# Add trend in shannon entropy or/and regime percentages to evaluate recessions / hostile environments beginning. could also look at earnings timestamps affecting options prices

# %% [markdown]
# Want to find stocks with a low hv/iv high regime % in highest stdev state, and high # of days with stdev above avg iv on options

# %%
import yfinance as yf 
from yfinance import EquityQuery
import numpy as np
import pandas as pd
import time

# %%
from yfinance import EquityQuery, screen
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time
num_stocks = 250  # Number of stocks to process in each batch

# --- Helper Functions ---


def find_closest_value(data_list, target_value):
    if len(data_list) == 0:
        return None
    return min(data_list, key=lambda x: abs(x - target_value))


def filter_special_expiry(expiry_list):
    """Return the two soonest (earliest) expiry dates from the list."""
    sorted_expiries = sorted(expiry_list)
    return sorted_expiries[:2]


def get_prev_day_price_volume(symbol):
    """Fetch the most recent full day's close price and volume for the symbol."""
    try:
        data = yf.Ticker(symbol).history(period="5d")
        if data.shape[0] < 2:
            return None, None
        prev_day = data.iloc[-2]
        price = float(prev_day['Close'])
        volume = int(prev_day['Volume'])
        return price, volume
    except Exception as e:
        print(f"Error fetching previous day price/volume for {symbol}: {e}")
        return None, None


def get_historical_volatility(symbol, window=20):
    try:
        data = yf.Ticker(symbol).history(period=f"{window*2}d")
        if data.shape[0] < window + 1:
            return None
        data = data['Close'].dropna()
        log_returns = np.log(data / data.shift(1)).dropna()
        vol = log_returns[-window:].std() * np.sqrt(252)
        return vol
    except Exception as e:
        print(f"Error calculating historical volatility for {symbol}: {e}")
        return None


def get_options(symbol, max_retries=3, retry_delay=60):
    for attempt in range(max_retries):
        try:
            stock = yf.Ticker(symbol)
            options_chain = stock.options
            if not options_chain:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            filtered_expiries = filter_special_expiry(options_chain)
            options_data = []
            current_price, _ = get_prev_day_price_volume(symbol)
            if current_price is None:
                continue
            for expiry in filtered_expiries:
                chain = stock.option_chain(expiry)
                for opt_type, df in [('call', chain.calls), ('put', chain.puts)]:
                    if not df.empty:
                        closest_strike = find_closest_value(df['strike'], current_price)
                        filtered = df[df['strike'] == closest_strike].copy()
                        filtered['type'] = opt_type
                        filtered['expiry'] = expiry
                        filtered['symbol'] = symbol
                        options_data.append(filtered)
            if options_data:
                result = pd.concat(options_data, ignore_index=True)
                result = result[result['openInterest'] > 500]
                return result[['strike', 'impliedVolatility', 'openInterest', 'symbol']]
            else:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
        except Exception as e:
            print(f"Error fetching options for {symbol}: {e}")
            if attempt < max_retries - 1:
                time.sleep(retry_delay)
                continue
            else:
                print(f"Max retries reached for {symbol}.")
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
    return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])


# --- Screen Query ---
screen_query = EquityQuery("and", [
    EquityQuery("is-in", ["region", "us"]),
    EquityQuery("is-in", ["sector",
        "Technology",
        "Financial Services",
        "Consumer Cyclical",
        "Communication Services",
        "Basic Materials",
        "Industrials"
    ]),
    EquityQuery("GTE", ["eodprice", 0.50]),
    EquityQuery("GTE", ["avgdailyvol3m", 100000]),
    EquityQuery("LTE", ["short_percentage_of_float.value", 100])
])


# --- Batch Processing Function ---
def process_batch(offset, filterdf, options):
    batch_size = num_stocks
    screener = screen(
        screen_query,
        sortField="avgdailyvol3m",
        sortAsc=False,
        size=batch_size,
        offset=offset
    )
    stocks = screener.get('quotes', [])
    if not stocks:
        print("No more stocks to load.")
        return filterdf, options, offset


    current_filterdf = pd.DataFrame(stocks)


    # --- Add price*volume filter for most recent full day ---
    current_filterdf['prev_day_price'] = None
    current_filterdf['prev_day_volume'] = None
    current_filterdf['price_volume'] = None


    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        price, volume = get_prev_day_price_volume(symbol)
        current_filterdf.at[idx, 'prev_day_price'] = price
        current_filterdf.at[idx, 'prev_day_volume'] = volume
        if price is not None and volume is not None:
            current_filterdf.at[idx, 'price_volume'] = price * volume


    current_filterdf = current_filterdf[current_filterdf['price_volume'] > 100_000_000]


    if current_filterdf.empty:
        print("No stocks passed the price*volume filter in this batch.")
        offset += batch_size
        return filterdf, options, offset


    current_filterdf['historical_volatility'] = None
    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        hv = get_historical_volatility(symbol, window=20)
        current_filterdf.at[idx, 'historical_volatility'] = hv


    filterstocks = current_filterdf['symbol'].tolist()
    options_list = []
    for symbol in filterstocks:
        options_data = get_options(symbol)
        options_list.append(options_data)


    if options_list:
        current_options = pd.concat(options_list, ignore_index=True)
        options = pd.concat([options, current_options], ignore_index=True)
    else:
        current_options = pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])


    if not current_options.empty:
        qualifying_symbols = set(current_options['symbol'].str.upper().unique())
        current_filterdf = current_filterdf[current_filterdf['symbol'].str.upper().isin(qualifying_symbols)]
    else:
        current_filterdf = current_filterdf.iloc[0:0]


    if current_filterdf.empty:
        print("No stocks passed the open interest filter in this batch.")
        offset += batch_size
        return filterdf, options, offset


    if not options.empty and 'symbol' in options.columns and 'impliedVolatility' in options.columns:
        avg_iv = options.groupby('symbol')['impliedVolatility'].mean().reset_index()
        avg_iv.columns = ['symbol', 'avg_iv']
    else:
        avg_iv = pd.DataFrame(columns=['symbol', 'avg_iv'])


    current_filterdf['symbol'] = current_filterdf['symbol'].astype(str).str.upper()
    avg_iv['symbol'] = avg_iv['symbol'].astype(str).str.upper()
    current_filterdf = current_filterdf.merge(avg_iv, on='symbol', how='left')


    if 'avg_iv' in current_filterdf.columns and 'historical_volatility' in current_filterdf.columns:
        current_filterdf["iv/hv_ratio"] = current_filterdf["avg_iv"] / current_filterdf["historical_volatility"]
    else:
        current_filterdf["iv/hv_ratio"] = None


    filterdf = pd.concat([filterdf, current_filterdf], ignore_index=True)

    # --- ADD: Append mean openInterest per symbol ---
    if not options.empty and 'symbol' in options.columns and 'openInterest' in options.columns:
        mean_open_interest = options.groupby('symbol')['openInterest'].mean().reset_index()
        mean_open_interest.rename(columns={'openInterest': 'mean_openInterest'}, inplace=True)
        mean_open_interest['symbol'] = mean_open_interest['symbol'].astype(str).str.upper()
        filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()
        filterdf = filterdf.merge(mean_open_interest, on='symbol', how='left')

    offset += batch_size
    return filterdf, options, offset


# --- Main loop ---
offset = 0
filterdf = pd.DataFrame()
options = pd.DataFrame()


filterdf, options, offset = process_batch(offset, filterdf, options)
print("Initial batch:")
print(filterdf)


while True:
    user_input = input("Process next 100 stocks? (y/n): ")
    if user_input.lower() != 'y':
        break
    filterdf, options, offset = process_batch(offset, filterdf, options)
    print("Updated results:")
    print(filterdf)
# Out:
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_73270/439954546.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   current_options = pd.concat(options_list, ignore_index=True)
# Initial batch:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# ..       ...    ...       ...      ...                     ...          ...
# 152    en-US     US    EQUITY   Equity           Delayed Quote        False
# 153    en-US     US    EQUITY   Equity           Delayed Quote        False
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote        False
# 156    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#     customPriceAlertConfidence currency  regularMarketChangePercent  \
# 0                         HIGH      USD                    1.733230
# 1                         HIGH      USD                   -2.922080
# 2                          LOW      USD                   -2.209940
# 3                         HIGH      USD                   -8.197020
# 4                          LOW      USD                   -1.054480
# ..                         ...      ...                         ...
# 152                        LOW      USD                   -0.464981
# 153                        LOW      USD                   -0.099882
# 154                       HIGH      USD                   -7.676580
# 155                        LOW      USD                   -3.704550
# 156                       HIGH      USD                    5.800880
#
#      hasPrePostMarketData  ...            displayName  symbol  \
# 0                    True  ...                 NVIDIA    NVDA
# 1                    True  ...                  Lucid    LCID
# 2                    True  ...             Plug Power    PLUG
# 3                    True  ...                  Tesla    TSLA
# 4                    True  ...                    NaN       F
# ..                    ...  ...                    ...     ...
# 152                  True  ...             ICICI Bank     IBN
# 153                  True  ...       Johnson Controls     JCI
# 154                  True  ...                   Flex    FLEX
# 155                  True  ...  Capital One Financial     COF
# 156                  True  ...            T-Mobile US    TMUS
#
#      ipoExpectedDate  prev_day_price  prev_day_volume        price_volume  \
# 0                NaN      170.779999        154082200  26314157927.911377
# 1         2021-07-26            3.08        181511400    559055098.151779
# 2                NaN            1.81         68101300    123263349.103212
# 3                NaN      332.559998         92553800  30779691502.038574
# 4                NaN           11.38         76163200    866737224.716187
# ..               ...             ...              ...                 ...
# 152              NaN           34.41          5039000     173391989.23111
# 153              NaN      110.129997          6925100    762661243.979645
# 154              NaN       53.799999          5876600     316161075.51651
# 155              NaN      219.460007          9069600    1990414476.89209
# 156              NaN      233.929993          5621000   1314920488.830566
#
#      historical_volatility    avg_iv  iv/hv_ratio  mean_openInterest
# 0                 0.260627  0.357428     1.371416           29729.50
# 1                 1.286375  1.029299     0.800155           17285.75
# 2                 1.409719  1.871097     1.327284           23284.75
# 3                 0.553936  0.757633     1.367727            4015.75
# 4                 0.297705  0.484380     1.627045           12370.25
# ..                     ...       ...          ...                ...
# 152               0.149064  0.205818     1.380734            5633.00
# 153               0.126902  0.354529     2.793716            2228.50
# 154               0.397599  0.346686      0.87195            3441.00
# 155               0.214457  0.442877      2.06511            1488.00
# 156               0.274898  0.614262     2.234507            2016.00
#
# [157 rows x 96 columns]

# %%
import yfinance as yf
import numpy as np
from hmmlearn.hmm import GaussianHMM
from tqdm import tqdm

def get_last_120_returns(symbol):
    """Get last 120 days of daily log returns for a symbol."""
    try:
        data = yf.Ticker(symbol).history(period="130d")
        closes = data['Close'].dropna()
        if len(closes) < 121:
            return None
        returns = np.log(closes / closes.shift(1)).dropna()
        return returns[-120:]
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

def fit_hmm_and_stats(returns, n_states=3):
    """Fit HMM to returns, return means, stds, and state sequence."""
    model = GaussianHMM(
        n_components=n_states,
        covariance_type="diag",
        n_iter=500,
        tol=1e-2,
        random_state=42,
        verbose=False
    )
    X = returns.values.reshape(-1, 1)
    model.fit(X)
    hidden_states = model.predict(X)
    means = model.means_.flatten()
    stds = np.sqrt(np.array([np.diag(cov)[0] for cov in model.covars_]))
    return hidden_states, means, stds

def hmm_analysis(symbol):
    returns = get_last_120_returns(symbol)
    if returns is None:
        return {
            "hmm_mean_0": None,
            "hmm_std_0": None,
            "hmm_mean_1": None,
            "hmm_std_1": None,
            "hmm_mean_2": None,
            "hmm_std_2": None,
            "pct_last30_in_highest_stdev_state": None,
            "highest_stdev_state": None
        }
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    # Identify the state with the highest stdev
    high_stdev_state = int(np.argmax(stds))
    last30 = hidden_states[-30:]
    pct_high = np.mean(last30 == high_stdev_state) * 100
    return {
        "hmm_mean_0": means[0],
        "hmm_std_0": stds[0],
        "hmm_mean_1": means[1],
        "hmm_std_1": stds[1],
        "hmm_mean_2": means[2],
        "hmm_std_2": stds[2],
        "pct_last30_in_highest_stdev_state": pct_high,
        "highest_stdev_state": high_stdev_state
    }

# --- Apply to filterdf ---

filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()

for col in [
    'hmm_mean_0','hmm_std_0',
    'hmm_mean_1','hmm_std_1',
    'hmm_mean_2','hmm_std_2',
    'pct_last30_in_highest_stdev_state',
    'highest_stdev_state'
]:
    filterdf[col] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    hmm_stats = hmm_analysis(symbol)
    for col in hmm_stats:
        filterdf.at[idx, col] = hmm_stats[col]

# filterdf now has the HMM columns for states 0, 1, 2, and the % of last 30 closes in the highest stdev state.
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]Model is not converging.  Current: 250.28804324156005 is not greater than 250.29019346407003. Delta is -0.0021502225099823136
#   3%|▎         | 5/157 [00:01<00:36,  4.20it/s]Model is not converging.  Current: 198.38908695714406 is not greater than 198.4211117851402. Delta is -0.03202482799613904
#   4%|▍         | 7/157 [00:01<00:30,  4.88it/s]Model is not converging.  Current: 221.22709121808649 is not greater than 221.24990603266616. Delta is -0.022814814579675158
#   8%|▊         | 13/157 [00:02<00:24,  5.79it/s]Model is not converging.  Current: 168.49629344990134 is not greater than 168.49702392631966. Delta is -0.0007304764183118095
#  11%|█         | 17/157 [00:03<00:22,  6.26it/s]Model is not converging.  Current: 287.05052753781473 is not greater than 287.05997251384684. Delta is -0.009444976032114027
#  17%|█▋        | 27/157 [00:05<00:30,  4.22it/s]Model is not converging.  Current: 310.3270827443521 is not greater than 310.6392399908393. Delta is -0.31215724648723153
#  19%|█▉        | 30/157 [00:05<00:28,  4.52it/s]Model is not converging.  Current: 181.07943395791276 is not greater than 181.0869929050101. Delta is -0.007558947097351165
#  25%|██▌       | 40/157 [00:08<00:25,  4.52it/s]Model is not converging.  Current: 343.4561635222556 is not greater than 343.47957090942197. Delta is -0.02340738716634405
#  27%|██▋       | 43/157 [00:08<00:26,  4.26it/s]Model is not converging.  Current: 301.5520438802553 is not greater than 301.7362838227309. Delta is -0.1842399424755854
#  29%|██▉       | 46/157 [00:09<00:26,  4.18it/s]Model is not converging.  Current: 337.81916032414114 is not greater than 337.95733937719024. Delta is -0.13817905304910028
#  40%|████      | 63/157 [00:13<00:19,  4.82it/s]Model is not converging.  Current: 258.9526848415027 is not greater than 259.034253311938. Delta is -0.08156847043534299
#  43%|████▎     | 67/157 [00:14<00:20,  4.47it/s]Model is not converging.  Current: 271.83889270439255 is not greater than 271.85334118177514. Delta is -0.014448477382586589
#  44%|████▍     | 69/157 [00:14<00:20,  4.27it/s]Model is not converging.  Current: 270.5454708098928 is not greater than 270.56801512409487. Delta is -0.022544314202093574
#  45%|████▌     | 71/157 [00:15<00:20,  4.14it/s]Model is not converging.  Current: 313.15658123538935 is not greater than 313.3775412739705. Delta is -0.2209600385811541
#  53%|█████▎    | 83/157 [00:17<00:16,  4.52it/s]Model is not converging.  Current: 306.7011420781078 is not greater than 306.72164243076776. Delta is -0.020500352659951204
#  59%|█████▊    | 92/157 [00:19<00:13,  4.65it/s]Model is not converging.  Current: 295.4471308268845 is not greater than 295.50568102993606. Delta is -0.058550203051538574
#  62%|██████▏   | 97/157 [00:20<00:13,  4.58it/s]Model is not converging.  Current: 321.0022021448788 is not greater than 321.0567966976304. Delta is -0.05459455275155278
#  66%|██████▌   | 104/157 [00:22<00:10,  5.24it/s]Model is not converging.  Current: 202.08838610168763 is not greater than 202.10987869196404. Delta is -0.021492590276409373
#  69%|██████▉   | 108/157 [00:22<00:09,  4.91it/s]Model is not converging.  Current: 266.51837726409127 is not greater than 266.54975581524644. Delta is -0.03137855115517141
#  81%|████████  | 127/157 [00:27<00:07,  3.85it/s]Model is not converging.  Current: 322.15521900429775 is not greater than 322.1899319218676. Delta is -0.03471291756983419
#  83%|████████▎ | 130/157 [00:28<00:05,  4.78it/s]Model is not converging.  Current: 301.0083196379535 is not greater than 301.0260538505179. Delta is -0.017734212564391783
#  86%|████████▌ | 135/157 [00:29<00:05,  4.23it/s]Model is not converging.  Current: 253.7475715088459 is not greater than 253.78426159413536. Delta is -0.03669008528945028
#  90%|████████▉ | 141/157 [00:30<00:03,  4.72it/s]Model is not converging.  Current: 242.67098734417482 is not greater than 242.67556935059844. Delta is -0.004582006423618168
#  96%|█████████▌| 151/157 [00:32<00:01,  4.80it/s]Model is not converging.  Current: 278.9463147022994 is not greater than 278.9546810394437. Delta is -0.008366337144309455
#  98%|█████████▊| 154/157 [00:33<00:00,  3.05it/s]Model is not converging.  Current: 262.59445425243376 is not greater than 262.60322902141684. Delta is -0.0087747689830735
# 100%|██████████| 157/157 [00:34<00:00,  4.57it/s]

# %%
N = 252  # Or use 261, depending on your convention

def pct_regimes_higher_than_iv(hidden_states, stds, avg_iv):
    """% of regimes in last 30 days with annualized stdev higher than avg_iv."""
    last30 = hidden_states[-30:]
    # Annualize regime stdevs
    stds_annualized = stds * np.sqrt(N)
    last30_vols_annualized = stds_annualized[last30]
    pct_higher = np.mean(last30_vols_annualized > avg_iv) * 100
    return pct_higher

filterdf['pct_regimes_last30_higher_than_avg_iv'] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    avg_iv = row['avg_iv']
    returns = get_last_120_returns(symbol)
    if returns is None or avg_iv is None:
        filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = None
        continue
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    pct_higher = pct_regimes_higher_than_iv(hidden_states, stds, avg_iv)
    filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = pct_higher
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]Model is not converging.  Current: 250.28804324156005 is not greater than 250.29019346407003. Delta is -0.0021502225099823136
#   3%|▎         | 5/157 [00:00<00:30,  4.92it/s]Model is not converging.  Current: 198.38908695714406 is not greater than 198.4211117851402. Delta is -0.03202482799613904
#   4%|▍         | 7/157 [00:01<00:30,  4.98it/s]Model is not converging.  Current: 221.22709121808649 is not greater than 221.24990603266616. Delta is -0.022814814579675158
#   8%|▊         | 13/157 [00:02<00:28,  4.97it/s]Model is not converging.  Current: 168.49629344990134 is not greater than 168.49702392631966. Delta is -0.0007304764183118095
#  11%|█         | 17/157 [00:03<00:25,  5.53it/s]Model is not converging.  Current: 287.050518141094 is not greater than 287.059963634226. Delta is -0.0094454931319774
#  17%|█▋        | 27/157 [00:05<00:31,  4.07it/s]Model is not converging.  Current: 310.32707350910545 is not greater than 310.6392304277918. Delta is -0.3121569186863553
#  19%|█▉        | 30/157 [00:06<00:30,  4.11it/s]Model is not converging.  Current: 181.07943395791276 is not greater than 181.0869929050101. Delta is -0.007558947097351165
#  25%|██▌       | 40/157 [00:08<00:28,  4.13it/s]Model is not converging.  Current: 343.45614486534004 is not greater than 343.4795521479177. Delta is -0.02340728257763658
#  27%|██▋       | 43/157 [00:09<00:26,  4.38it/s]Model is not converging.  Current: 301.5520438802553 is not greater than 301.7362838227309. Delta is -0.1842399424755854
#  29%|██▉       | 46/157 [00:10<00:27,  4.02it/s]Model is not converging.  Current: 337.81916032414114 is not greater than 337.95733937719024. Delta is -0.13817905304910028
#  40%|████      | 63/157 [00:14<00:19,  4.70it/s]Model is not converging.  Current: 258.9526917009864 is not greater than 259.03425961035333. Delta is -0.0815679093669246
#  43%|████▎     | 67/157 [00:15<00:23,  3.91it/s]Model is not converging.  Current: 271.8388914588745 is not greater than 271.85334034929946. Delta is -0.014448890424944238
#  44%|████▍     | 69/157 [00:15<00:21,  4.08it/s]Model is not converging.  Current: 270.5454708098928 is not greater than 270.56801512409487. Delta is -0.022544314202093574
#  45%|████▌     | 71/157 [00:15<00:19,  4.40it/s]Model is not converging.  Current: 313.15658123538935 is not greater than 313.3775412739705. Delta is -0.2209600385811541
#  53%|█████▎    | 83/157 [00:18<00:15,  4.77it/s]Model is not converging.  Current: 306.7011420781078 is not greater than 306.72164243076776. Delta is -0.020500352659951204
#  59%|█████▊    | 92/157 [00:20<00:14,  4.38it/s]Model is not converging.  Current: 295.4471344601489 is not greater than 295.50568392415977. Delta is -0.05854946401086636
#  62%|██████▏   | 97/157 [00:21<00:14,  4.07it/s]Model is not converging.  Current: 321.0022021448788 is not greater than 321.0567966976304. Delta is -0.05459455275155278
#  66%|██████▌   | 104/157 [00:23<00:10,  4.90it/s]Model is not converging.  Current: 202.08838610168763 is not greater than 202.10987869196404. Delta is -0.021492590276409373
#  69%|██████▉   | 108/157 [00:24<00:10,  4.62it/s]Model is not converging.  Current: 266.51837726409127 is not greater than 266.54975581524644. Delta is -0.03137855115517141
#  81%|████████  | 127/157 [00:28<00:08,  3.48it/s]Model is not converging.  Current: 322.15521900429775 is not greater than 322.1899319218676. Delta is -0.03471291756983419
#  83%|████████▎ | 130/157 [00:29<00:06,  4.19it/s]Model is not converging.  Current: 301.0083009107661 is not greater than 301.0260350895274. Delta is -0.01773417876131589
#  86%|████████▌ | 135/157 [00:30<00:05,  3.92it/s]Model is not converging.  Current: 253.7475715088459 is not greater than 253.78426159413536. Delta is -0.03669008528945028
#  90%|████████▉ | 141/157 [00:31<00:03,  4.23it/s]Model is not converging.  Current: 242.67098734417482 is not greater than 242.67556935059844. Delta is -0.004582006423618168
#  96%|█████████▌| 151/157 [00:34<00:01,  4.13it/s]Model is not converging.  Current: 278.9463147022994 is not greater than 278.9546810394437. Delta is -0.008366337144309455
#  98%|█████████▊| 154/157 [00:34<00:00,  4.61it/s]Model is not converging.  Current: 262.59445425243376 is not greater than 262.60322902141684. Delta is -0.0087747689830735
# 100%|██████████| 157/157 [00:35<00:00,  4.45it/s]

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import entropy
from hmmlearn.hmm import GaussianHMM
from statsmodels.tsa.stattools import adfuller

def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]
    return entropy(hist, base=2)

def hmm_regime_switch_prob_and_count(returns, n_states=2):
    returns = returns.values.reshape(-1, 1)
    model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=100)
    model.fit(returns)
    hidden_states = model.predict(returns)
    last_state = hidden_states[-1]
    transmat = model.transmat_
    switch_prob = 1 - transmat[last_state, last_state]
    regime_switch_count = np.sum(hidden_states[1:] != hidden_states[:-1])
    return switch_prob, regime_switch_count

entropy_list = []
regimeswitchprob_list = []
regimeswitchcount_list = []
adf_pvalue_list = []
avg_return_list = []

for ticker in filterdf['symbol']:
    try:
        # Download last 7 days of 1-minute data
        df = yf.download(ticker, period="7d", interval="1m", progress=False)
        closes = df['Close'].dropna()
        # Make sure you have enough data (e.g., at least 1000 minutes)
        if len(closes) < 1000:
            entropy_list.append(np.nan)
            regimeswitchprob_list.append(np.nan)
            regimeswitchcount_list.append(np.nan)
            adf_pvalue_list.append(np.nan)
            avg_return_list.append(np.nan)
            continue
        log_returns = np.log(closes).diff().dropna()         # For entropy, HMM, etc.
        simple_returns = closes.pct_change().dropna()        # For avg return only

        # Shannon entropy (log returns)
        ent = shannon_entropy(log_returns)
        entropy_list.append(ent)
        # HMM regime switch probability and count (log returns)
        switch_prob, switch_count = hmm_regime_switch_prob_and_count(log_returns)
        regimeswitchprob_list.append(round(switch_prob * 100, 2))  # as percentage
        regimeswitchcount_list.append(int(switch_count))
        # ADF test p-value on last 7 days of prices (not returns)
        adf_pvalue = adfuller(closes)[1]
        adf_pvalue_list.append(adf_pvalue)
        # Average return over last 7 days (mean of simple returns)
        avg_return = simple_returns.mean()
        avg_return_list.append(avg_return)
    except Exception as e:
        entropy_list.append(np.nan)
        regimeswitchprob_list.append(np.nan)
        regimeswitchcount_list.append(np.nan)
        adf_pvalue_list.append(np.nan)
        avg_return_list.append(np.nan)


filterdf['ShannonEntropy'] = entropy_list
filterdf['Regimeswitchprob'] = regimeswitchprob_list
filterdf['Regimeswitchcount'] = regimeswitchcount_list
filterdf['ADF_Pvalue'] = adf_pvalue_list
filterdf['AvgReturn_7d'] = avg_return_list
# Out:
# YF.download() has changed argument auto_adjust default to True
# Model is not converging.  Current: 14163.771529176507 is not greater than 14165.006372575901. Delta is -1.234843399393867
# Model is not converging.  Current: 11309.80509802127 is not greater than 11310.100712580148. Delta is -0.2956145588777872
# Model is not converging.  Current: 13774.06404038472 is not greater than 13775.425921758102. Delta is -1.3618813733828574
# Model is not converging.  Current: 14023.723309287681 is not greater than 14025.516195252154. Delta is -1.792885964472589
# Model is not converging.  Current: 13951.312490033002 is not greater than 13951.324138499846. Delta is -0.011648466843325878
# Model is not converging.  Current: 13916.813216548564 is not greater than 13919.183835138572. Delta is -2.3706185900082346
# Model is not converging.  Current: 13528.437621538493 is not greater than 13529.756563839037. Delta is -1.3189423005442222
# Model is not converging.  Current: 12427.745212967964 is not greater than 12427.877790511027. Delta is -0.13257754306323477
# Model is not converging.  Current: 12945.56068756466 is not greater than 12945.621874325267. Delta is -0.061186760605778545
# Model is not converging.  Current: 13863.665033454145 is not greater than 13867.503111644783. Delta is -3.8380781906380435
# Model is not converging.  Current: 13513.650556232215 is not greater than 13516.775344379072. Delta is -3.1247881468570995
# Model is not converging.  Current: 13358.550638537212 is not greater than 13362.11676872294. Delta is -3.56613018572898
# Model is not converging.  Current: 12850.947987972653 is not greater than 12852.209844126715. Delta is -1.2618561540621158
# Model is not converging.  Current: 14122.965130904378 is not greater than 14123.058389673826. Delta is -0.09325876944785705
# Model is not converging.  Current: 14237.521414093675 is not greater than 14240.040009245777. Delta is -2.518595152101625
# Model is not converging.  Current: 12685.555743731979 is not greater than 12688.081028449471. Delta is -2.525284717492468
# Model is not converging.  Current: 13606.5319191941 is not greater than 13611.396235064476. Delta is -4.864315870376231
# Model is not converging.  Current: 14088.254522524701 is not greater than 14089.596466980298. Delta is -1.3419444555966038
# Model is not converging.  Current: 12945.69319627315 is not greater than 12947.066375231334. Delta is -1.3731789581834164
# Model is not converging.  Current: 11672.386693047081 is not greater than 11672.411256236699. Delta is -0.0245631896177656
# Model is not converging.  Current: 14241.559605690818 is not greater than 14244.309689841326. Delta is -2.7500841505079734
# Model is not converging.  Current: 14134.523926639038 is not greater than 14135.70653884556. Delta is -1.1826122065212985
# Model is not converging.  Current: 14057.699289738794 is not greater than 14058.243493348611. Delta is -0.5442036098174867
# Model is not converging.  Current: 14033.753070536706 is not greater than 14037.619455694728. Delta is -3.86638515802224
# Model is not converging.  Current: 12807.52974122572 is not greater than 12807.742315023856. Delta is -0.21257379813505395
# Model is not converging.  Current: 14063.265860235824 is not greater than 14065.46505206276. Delta is -2.1991918269359303
# Model is not converging.  Current: 12560.44945877315 is not greater than 12561.080631568899. Delta is -0.6311727957490803
# Model is not converging.  Current: 13493.720648121818 is not greater than 13496.167531850197. Delta is -2.4468837283784524
# Model is not converging.  Current: 13935.396153849224 is not greater than 13936.56177165954. Delta is -1.1656178103166894
# Model is not converging.  Current: 10182.83077552632 is not greater than 10182.860048908185. Delta is -0.029273381866005366
# Model is not converging.  Current: 14064.92999128914 is not greater than 14066.191969194664. Delta is -1.2619779055239633
# Model is not converging.  Current: 13970.577031884653 is not greater than 13971.822507320696. Delta is -1.2454754360423976
# Model is not converging.  Current: 13809.601650912939 is not greater than 13811.823196015303. Delta is -2.2215451023639616
# Model is not converging.  Current: 13839.165838765668 is not greater than 13844.306031510134. Delta is -5.140192744465821
# Model is not converging.  Current: 13725.059825133461 is not greater than 13725.16239831943. Delta is -0.10257318596814002
# Model is not converging.  Current: 14074.622526715526 is not greater than 14075.175793172828. Delta is -0.5532664573020156
# Model is not converging.  Current: 14216.273238824062 is not greater than 14218.536926969424. Delta is -2.2636881453618116
# Model is not converging.  Current: 13978.78672792397 is not greater than 13982.09393006324. Delta is -3.307202139269066
# Model is not converging.  Current: 14164.903364605141 is not greater than 14166.245976915763. Delta is -1.3426123106219165
# Model is not converging.  Current: 14068.990548234638 is not greater than 14073.285679760716. Delta is -4.2951315260779666
# Model is not converging.  Current: 13099.907016888803 is not greater than 13100.027842639953. Delta is -0.12082575114982319
# Model is not converging.  Current: 14086.06051648893 is not greater than 14087.100677114084. Delta is -1.0401606251543853
# Model is not converging.  Current: 13967.068556347107 is not greater than 13968.357232746594. Delta is -1.288676399486576
# Model is not converging.  Current: 13735.472448533357 is not greater than 13744.498955423443. Delta is -9.026506890086239
# Model is not converging.  Current: 13537.731869918762 is not greater than 13539.309724710658. Delta is -1.5778547918962431
# Model is not converging.  Current: 13126.17266737204 is not greater than 13127.248886033549. Delta is -1.076218661508392
# Model is not converging.  Current: 12459.801760880326 is not greater than 12468.369626314818. Delta is -8.567865434491978
# Model is not converging.  Current: 14127.908374981555 is not greater than 14128.010622040143. Delta is -0.10224705858854577
# Model is not converging.  Current: 12865.026844711814 is not greater than 12865.963871718775. Delta is -0.9370270069612161
# Model is not converging.  Current: 14211.055476119613 is not greater than 14217.732344288055. Delta is -6.676868168442525
# Model is not converging.  Current: 14013.243869951724 is not greater than 14014.358889903107. Delta is -1.1150199513831467
# Model is not converging.  Current: 13554.799320225588 is not greater than 13556.76337874997. Delta is -1.9640585243832902
# Model is not converging.  Current: 14044.137353537775 is not greater than 14045.64446710765. Delta is -1.507113569874491
# Model is not converging.  Current: 13776.371502871194 is not greater than 13781.505607016587. Delta is -5.1341041453924845
# Model is not converging.  Current: 13677.831200912795 is not greater than 13678.783584152385. Delta is -0.9523832395898353
# Model is not converging.  Current: 14238.89755423073 is not greater than 14240.81581617707. Delta is -1.9182619463390438
# Model is not converging.  Current: 13727.796918042884 is not greater than 13731.107389625175. Delta is -3.31047158229012
# Model is not converging.  Current: 13881.8765311557 is not greater than 13882.177074855703. Delta is -0.30054370000289055
# Model is not converging.  Current: 14007.670350824725 is not greater than 14013.825515513687. Delta is -6.1551646889620315
# Model is not converging.  Current: 13859.416055415762 is not greater than 13863.800210551964. Delta is -4.3841551362020255
# Model is not converging.  Current: 14152.10529347139 is not greater than 14155.655510459654. Delta is -3.5502169882638555
# Model is not converging.  Current: 14151.741277693809 is not greater than 14152.67836481508. Delta is -0.9370871212704515
# Model is not converging.  Current: 13923.5277786985 is not greater than 13924.947295913866. Delta is -1.4195172153649764
# Model is not converging.  Current: 14166.988035787843 is not greater than 14167.904932440719. Delta is -0.9168966528759483
# Model is not converging.  Current: 14054.16370560584 is not greater than 14057.029286511868. Delta is -2.8655809060273896
# Model is not converging.  Current: 14123.473902878375 is not greater than 14125.496061200844. Delta is -2.0221583224683854
# Model is not converging.  Current: 13918.604047244673 is not greater than 13923.196920266217. Delta is -4.59287302154371
# Model is not converging.  Current: 14189.095782890827 is not greater than 14195.770825565929. Delta is -6.675042675102304
# Model is not converging.  Current: 14043.136431842315 is not greater than 14043.219878960703. Delta is -0.08344711838799412
# Model is not converging.  Current: 12332.502636178137 is not greater than 12335.19140798386. Delta is -2.6887718057241727
# Model is not converging.  Current: 13066.251514841657 is not greater than 13066.676932544568. Delta is -0.42541770291063585
# Model is not converging.  Current: 13692.298272689499 is not greater than 13708.005920821453. Delta is -15.707648131954556
# Model is not converging.  Current: 14281.06337315566 is not greater than 14281.100292367366. Delta is -0.0369192117050261
# Model is not converging.  Current: 14135.689578747944 is not greater than 14136.190626220141. Delta is -0.5010474721966602
# Model is not converging.  Current: 13218.627273918235 is not greater than 13220.413977425043. Delta is -1.7867035068084078
# Model is not converging.  Current: 13905.011150402237 is not greater than 13906.873212119968. Delta is -1.8620617177311942
# Model is not converging.  Current: 14144.127526815913 is not greater than 14145.36628709599. Delta is -1.2387602800772584
# Model is not converging.  Current: 14195.90100757082 is not greater than 14197.479568685361. Delta is -1.5785611145420262
# Model is not converging.  Current: 14191.99232388061 is not greater than 14192.072471921292. Delta is -0.08014804068261583
# Model is not converging.  Current: 13535.830874199233 is not greater than 13537.75854575088. Delta is -1.927671551646199
# Model is not converging.  Current: 13863.584409901632 is not greater than 13868.180967240085. Delta is -4.59655733845284
# Model is not converging.  Current: 13545.759960951007 is not greater than 13548.36030560316. Delta is -2.6003446521535807
# Model is not converging.  Current: 14021.399469964634 is not greater than 14021.421371993622. Delta is -0.02190202898782445
# Model is not converging.  Current: 13915.099073076388 is not greater than 13915.985880478267. Delta is -0.8868074018791958
# Model is not converging.  Current: 13134.185428189354 is not greater than 13138.120116113309. Delta is -3.934687923954698
# Model is not converging.  Current: 14258.108730359038 is not greater than 14260.178790714726. Delta is -2.070060355688838
# Model is not converging.  Current: 13935.517167548704 is not greater than 13935.796506722312. Delta is -0.27933917360860505
# Model is not converging.  Current: 13604.105553047284 is not greater than 13607.509205793496. Delta is -3.403652746212174
# Model is not converging.  Current: 13978.972948304669 is not greater than 13983.882630813512. Delta is -4.909682508843616
# Model is not converging.  Current: 14235.546966488908 is not greater than 14235.548465489333. Delta is -0.001499000425610575
# Model is not converging.  Current: 14096.334597619505 is not greater than 14097.37908253665. Delta is -1.0444849171453825
# Model is not converging.  Current: 13598.81906896522 is not greater than 13600.518570903656. Delta is -1.6995019384357875
# Model is not converging.  Current: 13921.701171443006 is not greater than 13923.702687814617. Delta is -2.0015163716107054
# Model is not converging.  Current: 13493.323698059183 is not greater than 13493.729019141489. Delta is -0.405321082305818
# Model is not converging.  Current: 13910.531688507717 is not greater than 13911.542835583103. Delta is -1.011147075385452
# Model is not converging.  Current: 13903.90839473811 is not greater than 13904.243944088534. Delta is -0.3355493504241167
# Model is not converging.  Current: 14060.426944584135 is not greater than 14062.231609200811. Delta is -1.804664616676746
# Model is not converging.  Current: 13269.654935117509 is not greater than 13275.754391054317. Delta is -6.099455936808226
# Model is not converging.  Current: 13129.447459500321 is not greater than 13129.870259821237. Delta is -0.4228003209154849
# Model is not converging.  Current: 13490.45005189252 is not greater than 13494.47080383525. Delta is -4.020751942729476
# Model is not converging.  Current: 14270.516699616242 is not greater than 14272.693987755263. Delta is -2.177288139020675
# Model is not converging.  Current: 13592.172089541948 is not greater than 13594.969496234495. Delta is -2.797406692547156
# Model is not converging.  Current: 13579.606505612313 is not greater than 13580.683357751725. Delta is -1.0768521394111303
# Model is not converging.  Current: 13817.693048626254 is not greater than 13820.236316683451. Delta is -2.543268057197565
# Model is not converging.  Current: 13966.297116243262 is not greater than 13968.23993960962. Delta is -1.9428233663584251
# Model is not converging.  Current: 13923.773613948233 is not greater than 13923.774225485582. Delta is -0.0006115373489592457
# Model is not converging.  Current: 13990.497088637545 is not greater than 13991.142592146967. Delta is -0.6455035094222694
# Model is not converging.  Current: 14206.586159327797 is not greater than 14210.705892296352. Delta is -4.119732968554672
# Model is not converging.  Current: 13693.744621894131 is not greater than 13696.212438820885. Delta is -2.467816926753585
# Model is not converging.  Current: 14077.173504552124 is not greater than 14077.176030148496. Delta is -0.002525596371924621
# Model is not converging.  Current: 13257.766625885835 is not greater than 13262.2666248908. Delta is -4.4999990049655025
# Model is not converging.  Current: 14061.93317645144 is not greater than 14072.302906008614. Delta is -10.369729557172832
# Model is not converging.  Current: 14202.397462492825 is not greater than 14202.792564893802. Delta is -0.39510240097661153
# Model is not converging.  Current: 14199.285607402948 is not greater than 14202.779233318328. Delta is -3.4936259153801075
# Model is not converging.  Current: 14025.352256840984 is not greater than 14028.007438029355. Delta is -2.655181188370989
# Model is not converging.  Current: 14185.192598212458 is not greater than 14187.263003798209. Delta is -2.0704055857513595
# Model is not converging.  Current: 13853.125225695378 is not greater than 13855.154991899197. Delta is -2.0297662038192357
# Model is not converging.  Current: 14051.913859071616 is not greater than 14055.43023344928. Delta is -3.5163743776647607

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
filterdf["Shannon/IV"] = filterdf["ShannonEntropy"] / filterdf["avg_iv"]
display(filterdf)
# Out:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 5      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15     en-US     US    EQUITY   Equity           Delayed Quote        False
# 16     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 17     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 18     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 21     en-US     US    EQUITY   Equity           Delayed Quote        False
# 22     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 24     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 25     en-US     US    EQUITY   Equity           Delayed Quote        False
# 26     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27     en-US     US    EQUITY   Equity           Delayed Quote        False
# 28     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 29     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 30     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33     en-US     US    EQUITY   Equity           Delayed Quote        False
# 34     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 35     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 36     en-US     US    EQUITY   Equity           Delayed Quote        False
# 37     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 40     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 41     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 42     en-US     US    EQUITY   Equity           Delayed Quote        False
# 43     en-US     US    EQUITY   Equity           Delayed Quote        False
# 44     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 45     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46     en-US     US    EQUITY   Equity           Delayed Quote        False
# 47     en-US     US    EQUITY   Equity           Delayed Quote        False
# 48     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 49     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 50     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52     en-US     US    EQUITY   Equity           Delayed Quote         True
# 53     en-US     US    EQUITY   Equity           Delayed Quote        False
# 54     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55     en-US     US    EQUITY   Equity           Delayed Quote        False
# 56     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 58     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 59     en-US     US    EQUITY   Equity           Delayed Quote        False
# 60     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 62     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 63     en-US     US    EQUITY   Equity           Delayed Quote        False
# 64     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 65     en-US     US    EQUITY   Equity           Delayed Quote        False
# 66     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 67     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 68     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 69     en-US     US    EQUITY   Equity           Delayed Quote        False
# 70     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 71     en-US     US    EQUITY   Equity           Delayed Quote        False
# 72     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 73     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 74     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 75     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 76     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 77     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 78     en-US     US    EQUITY   Equity           Delayed Quote        False
# 79     en-US     US    EQUITY   Equity           Delayed Quote        False
# 80     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 81     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 82     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 83     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 84     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 85     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 86     en-US     US    EQUITY   Equity           Delayed Quote        False
# 87     en-US     US    EQUITY   Equity           Delayed Quote         True
# 88     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 89     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 90     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 91     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 92     en-US     US    EQUITY   Equity           Delayed Quote        False
# 93     en-US     US    EQUITY   Equity           Delayed Quote        False
# 94     en-US     US    EQUITY   Equity           Delayed Quote        False
# 95     en-US     US    EQUITY   Equity           Delayed Quote        False
# 96     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 97     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 98     en-US     US    EQUITY   Equity           Delayed Quote        False
# 99     en-US     US    EQUITY   Equity           Delayed Quote        False
# 100    en-US     US    EQUITY   Equity           Delayed Quote        False
# 101    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 102    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 103    en-US     US    EQUITY   Equity           Delayed Quote        False
# 104    en-US     US    EQUITY   Equity           Delayed Quote        False
# 105    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 106    en-US     US    EQUITY   Equity           Delayed Quote        False
# 107    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 108    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 109    en-US     US    EQUITY   Equity           Delayed Quote        False
# 110    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 111    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 112    en-US     US    EQUITY   Equity           Delayed Quote        False
# 113    en-US     US    EQUITY   Equity           Delayed Quote        False
# 114    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 115    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 116    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 117    en-US     US    EQUITY   Equity           Delayed Quote        False
# 118    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 119    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 120    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 121    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 122    en-US     US    EQUITY   Equity           Delayed Quote        False
# 123    en-US     US    EQUITY   Equity           Delayed Quote        False
# 124    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 125    en-US     US    EQUITY   Equity           Delayed Quote        False
# 126    en-US     US    EQUITY   Equity           Delayed Quote        False
# 127    en-US     US    EQUITY   Equity           Delayed Quote         True
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 131    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
# 133    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 134    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 135    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 136    en-US     US    EQUITY   Equity           Delayed Quote        False
# 137    en-US     US    EQUITY   Equity           Delayed Quote        False
# 138    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 139    en-US     US    EQUITY   Equity           Delayed Quote        False
# 140    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 141    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 142    en-US     US    EQUITY   Equity           Delayed Quote        False
# 143    en-US     US    EQUITY   Equity           Delayed Quote         True
# 144    en-US     US    EQUITY   Equity           Delayed Quote         True
# 145    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 146    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 147    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 148    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 149    en-US     US    EQUITY   Equity           Delayed Quote        False
# 150    en-US     US    EQUITY   Equity           Delayed Quote        False
# 151    en-US     US    EQUITY   Equity           Delayed Quote         True
# 152    en-US     US    EQUITY   Equity           Delayed Quote        False
# 153    en-US     US    EQUITY   Equity           Delayed Quote        False
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote        False
# 156    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#     customPriceAlertConfidence currency  regularMarketChangePercent  \
# 0                         HIGH      USD                    1.733230
# 1                         HIGH      USD                   -2.922080
# 2                          LOW      USD                   -2.209940
# 3                         HIGH      USD                   -8.197020
# 4                          LOW      USD                   -1.054480
# 5                         HIGH      USD                    0.155865
# 6                         HIGH      USD                   -3.661140
# 7                         HIGH      USD                   -0.231907
# 8                         HIGH      USD                   -9.621450
# 9                         HIGH      USD                   -0.182115
# 10                        HIGH      USD                    2.470260
# 11                         LOW      USD                   -1.764370
# 12                        HIGH      USD                    2.187210
# 13                        HIGH      USD                    1.586070
# 14                        HIGH      USD                   -0.146945
# 15                         LOW      USD                   -1.829270
# 16                        HIGH      USD                    1.725880
# 17                        HIGH      USD                    1.019820
# 18                         LOW      USD                    0.519319
# 19                         LOW      USD                    2.440720
# 20                         LOW      USD                   -3.277060
# 21                         LOW      USD                   -1.634620
# 22                         LOW      USD                   -1.558840
# 23                         LOW      USD                   -3.194330
# 24                         LOW      USD                   -3.869040
# 25                         LOW      USD                   -0.509686
# 26                         LOW      USD                    0.612613
# 27                         LOW      USD                   -1.550390
# 28                         LOW      USD                   -2.976520
# 29                        HIGH      USD                   -1.070160
# 30                         LOW      USD                   -0.883531
# 31                         LOW      USD                   -3.122960
# 32                        HIGH      USD                   -0.479726
# 33                         LOW      USD                   -1.592360
# 34                        HIGH      USD                    1.729950
# 35                         LOW      USD                   -9.647420
# 36                         LOW      USD                    1.034020
# 37                        HIGH      USD                    1.769530
# 38                        HIGH      USD                    1.050910
# 39                        HIGH      USD                    0.990375
# 40                        HIGH      USD                   -0.480912
# 41                        HIGH      USD                   -1.173520
# 42                         LOW      USD                   -7.350100
# 43                         LOW      USD                   -3.982300
# 44                         LOW      USD                   -1.204240
# 45                         LOW      USD                    0.203113
# 46                         LOW      USD                    0.560228
# 47                         LOW      USD                    2.846970
# 48                         LOW      USD                   -1.732900
# 49                        HIGH      USD                   -2.376100
# 50                         LOW      USD                   -1.595740
# 51                         LOW      USD                   -8.328190
# 52                        HIGH      USD                    0.085784
# 53                         LOW      USD                   -3.371710
# 54                         LOW      USD                   -1.794650
# 55                         LOW      USD                   -1.156680
# 56                        HIGH      USD                   -0.279024
# 57                         LOW      USD                    0.686951
# 58                         LOW      USD                   -1.166590
# 59                         LOW      USD                   -0.209517
# 60                         LOW      USD                   -0.625064
# 61                        HIGH      USD                    1.934830
# 62                         LOW      USD                  -13.338400
# 63                         LOW      USD                   -0.579836
# 64                         LOW      USD                   10.813000
# 65                         LOW      USD                    0.384460
# 66                        HIGH      USD                    0.545230
# 67                         LOW      USD                    0.146532
# 68                         LOW      USD                  -11.164500
# 69                         LOW      USD                    0.528442
# 70                         LOW      USD                  -17.451400
# 71                         LOW      USD                   -4.173440
# 72                         LOW      USD                    0.437200
# 73                         LOW      USD                   -2.377180
# 74                         LOW      USD                   -0.317552
# 75                         LOW      USD                   -2.268670
# 76                         LOW      USD                   -1.309760
# 77                        HIGH      USD                   -1.355730
# 78                         LOW      USD                   -1.486920
# 79                         LOW      USD                   -0.496867
# 80                        HIGH      USD                    0.700309
# 81                        HIGH      USD                   -2.314430
# 82                        HIGH      USD                   -6.995470
# 83                         LOW      USD                   -0.805275
# 84                        HIGH      USD                   -1.740290
# 85                        HIGH      USD                    1.513170
# 86                         LOW      USD                   -0.265459
# 87                        HIGH      USD                   -3.164560
# 88                         LOW      USD                   -2.645290
# 89                        HIGH      USD                   -4.545450
# 90                         LOW      USD                   -0.429903
# 91                         LOW      USD                   -0.070772
# 92                         LOW      USD                   -0.734152
# 93                         LOW      USD                    4.251390
# 94                         LOW      USD                    3.723560
# 95                         LOW      USD                   -1.115960
# 96                        HIGH      USD                   -0.650493
# 97                         LOW      USD                    1.418810
# 98                         LOW      USD                   -5.584510
# 99                         LOW      USD                   -0.742034
# 100                        LOW      USD                   -0.907029
# 101                       HIGH      USD                   -0.774076
# 102                       HIGH      USD                   -0.211042
# 103                        LOW      USD                   -0.538691
# 104                        LOW      USD                   -4.045890
# 105                        LOW      USD                    0.179631
# 106                        LOW      USD                  -15.864000
# 107                        LOW      USD                   -0.625978
# 108                        LOW      USD                    0.215232
# 109                        LOW      USD                   -0.158150
# 110                       HIGH      USD                   -1.195820
# 111                       HIGH      USD                    0.593551
# 112                        LOW      USD                    0.522308
# 113                        LOW      USD                    1.593200
# 114                       HIGH      USD                   -0.300670
# 115                       HIGH      USD                    0.274224
# 116                       HIGH      USD                    1.777780
# 117                        LOW      USD                   22.945300
# 118                        LOW      USD                    1.835250
# 119                        LOW      USD                   -1.576260
# 120                       HIGH      USD                   -0.432780
# 121                       HIGH      USD                   -5.742050
# 122                        LOW      USD                   -0.102619
# 123                        LOW      USD                  -10.836800
# 124                       HIGH      USD                   -1.699750
# 125                        LOW      USD                   -0.747657
# 126                        LOW      USD                   -0.371530
# 127                       HIGH      USD                    1.054190
# 128                       HIGH      USD                    0.948767
# 129                        LOW      USD                   -0.046643
# 130                       HIGH      USD                   -0.469639
# 131                        LOW      USD                    0.203919
# 132                        LOW      USD                   -1.507090
# 133                       HIGH      USD                    1.781740
# 134                        LOW      USD                   -0.811556
# 135                       HIGH      USD                    2.179400
# 136                        LOW      USD                    4.313010
# 137                        LOW      USD                    0.564817
# 138                       HIGH      USD                    2.871520
# 139                        LOW      USD                   -0.965904
# 140                        LOW      USD                   -0.079138
# 141                       HIGH      USD                   -4.050890
# 142                        LOW      USD                   -1.202890
# 143                       HIGH      USD                    0.528451
# 144                       HIGH      USD                   -0.116994
# 145                       HIGH      USD                    1.280120
# 146                        LOW      USD                   -2.530660
# 147                       HIGH      USD                    0.973799
# 148                        LOW      USD                   -0.420612
# 149                        LOW      USD                   -0.213539
# 150                        LOW      USD                   -0.143366
# 151                       HIGH      USD                   -0.276034
# 152                        LOW      USD                   -0.464981
# 153                        LOW      USD                   -0.099882
# 154                       HIGH      USD                   -7.676580
# 155                        LOW      USD                   -3.704550
# 156                       HIGH      USD                    5.800880
#
#      hasPrePostMarketData  firstTradeDateMilliseconds  priceHint  \
# 0                    True                917015400000          2
# 1                    True               1600435800000          4
# 2                    True                941203800000          4
# 3                    True               1277818200000          2
# 4                    True                 76253400000          2
# 5                    True               1601472600000          2
# 6                    True                322151400000          2
# 7                    True               1609770600000          2
# 8                    True               1127827800000          2
# 9                    True                345479400000          2
# 10                   True               1649856600000          2
# 11                   True               1336138200000          2
# 12                   True                322151400000          2
# 13                   True               1175175000000          2
# 14                   True               1627565400000          2
# 15                   True               1536759000000          4
# 16                   True                863703000000          2
# 17                   True               1092922200000          2
# 18                   True                 99153000000          2
# 19                   True               1459431000000          2
# 20                   True               1488465000000          2
# 21                   True               1016721000000          2
# 22                   True               1597671000000          2
# 23                   True                 99153000000          2
# 24                   True               1521552600000          4
# 25                   True               1337088600000          2
# 26                   True                438273000000          2
# 27                   True               1014647400000          2
# 28                   True               1170340200000          2
# 29                   True                322151400000          2
# 30                   True               1479306600000          2
# 31                   True                554131800000          2
# 32                   True               1438781400000          2
# 33                   True                322151400000          2
# 34                   True                454944600000          2
# 35                   True                864221400000          2
# 36                   True               1557495000000          2
# 37                   True               1249565400000          2
# 38                   True                962371800000          2
# 39                   True                511108200000          2
# 40                   True                635178600000          2
# 41                   True                322151400000          2
# 42                   True               1276090200000          2
# 43                   True                773069400000          4
# 44                   True               1445261400000          2
# 45                   True                 76253400000          2
# 46                   True                438273000000          2
# 47                   True               1516372200000          2
# 48                   True                344615400000          2
# 49                   True               1553866200000          2
# 50                   True                563121000000          2
# 51                   True               1596720600000          2
# 52                   True                342109800000          2
# 53                   True               1358519400000          2
# 54                   True               1013610600000          2
# 55                   True                322151400000          2
# 56                   True               1618407000000          2
# 57                   True               1592832600000          2
# 58                   True               1411133400000          2
# 59                   True               1600435800000          2
# 60                   True                221149800000          2
# 61                   True               1572615000000          2
# 62                   True               1138285800000          2
# 63                   True                805383000000          2
# 64                   True                706282200000          2
# 65                   True                511021800000          2
# 66                   True                897571800000          2
# 67                   True                322151400000          2
# 68                   True                315671400000          2
# 69                   True                876403800000          2
# 70                   True               1553088600000          2
# 71                   True                921162600000          2
# 72                   True               1474464600000          2
# 73                   True               1619011800000          2
# 74                   True               1555594200000          2
# 75                   True               1178199000000          2
# 76                   True               1615473000000          2
# 77                   True               1400765400000          2
# 78                   True               1290090600000          2
# 79                   True                105283800000          2
# 80                   True                452525400000          2
# 81                   True                709565400000          2
# 82                   True                957274200000          2
# 83                   True               -252322200000          2
# 84                   True               1564061400000          2
# 85                   True               1436189400000          2
# 86                   True                322151400000          2
# 87                   True               1625146200000          2
# 88                   True               1333114200000          2
# 89                   True               1403789400000          4
# 90                   True               1615386600000          2
# 91                   True                322151400000          2
# 92                   True               -252322200000          2
# 93                   True                766330200000          2
# 94                   True                689610600000          2
# 95                   True               -252322200000          2
# 96                   True                692634600000          2
# 97                   True                559315800000          2
# 98                   True                322151400000          2
# 99                   True                322237800000          2
# 100                  True               1159795800000          2
# 101                  True               1139236200000          2
# 102                  True               1532611800000          2
# 103                  True               1607956200000          2
# 104                  True               1623331800000          2
# 105                  True               1087997400000          2
# 106                  True                786897000000          2
# 107                  True                697300200000          2
# 108                  True               1560519000000          2
# 109                  True                928935000000          2
# 110                  True                763914600000          2
# 111                  True                322151400000          2
# 112                  True               1533216600000          2
# 113                  True               1598535000000          2
# 114                  True                 76253400000          2
# 115                  True               1610548200000          2
# 116                  True               1568899800000          2
# 117                  True               1532525400000          2
# 118                  True               -252322200000          2
# 119                  True               1544625000000          2
# 120                  True                278692200000          2
# 121                  True                326467800000          2
# 122                  True               1625059800000          2
# 123                  True               1607524200000          2
# 124                  True               1608129000000          2
# 125                  True               -252322200000          2
# 126                  True               1205933400000          2
# 127                  True                556464600000          2
# 128                  True               1624541400000          2
# 129                  True                809357400000          2
# 130                  True                761495400000          2
# 131                  True                730477800000          2
# 132                  True                322151400000          2
# 133                  True               1429191000000          2
# 134                  True               -244546200000          2
# 135                  True               1178285400000          2
# 136                  True               1103121000000          2
# 137                  True                570205800000          2
# 138                  True                735571800000          2
# 139                  True                942244200000          2
# 140                  True                551712600000          2
# 141                  True               1411392600000          2
# 142                  True               1411565400000          2
# 143                  True               1163773800000          2
# 144                  True                322151400000          2
# 145                  True               1607610600000          2
# 146                  True                578583000000          2
# 147                  True               1342791000000          2
# 148                  True                831648600000          2
# 149                  True               1584624600000          2
# 150                  True                378657000000          2
# 151                  True               1258554600000          2
# 152                  True                954253800000          2
# 153                  True                559834200000          2
# 154                  True                764001000000          2
# 155                  True                784996200000          2
# 156                  True               1176989400000          2
#
#      postMarketChangePercent  postMarketTime  postMarketPrice  \
# 0                  -0.089213      1753401598         173.5850
# 1                  -0.334448      1753401588           2.9800
# 2                  -0.016945      1753401569           1.7697
# 3                   0.569938      1753401597         307.0400
# 4                   0.177615      1753401598          11.2800
# 5                  -0.051661      1753401599         154.7800
# 6                  -4.595670      1753401597          21.5900
# 7                   0.140395      1753401597          21.5402
# 8                   0.698080      1753401598          11.5400
# 9                   0.135670      1753401580         214.0500
# 10                  0.089288      1753401599          11.2100
# 11                  0.062569      1753401594          17.2708
# 12                  1.431100      1753401597         164.4400
# 13                  0.038082      1753401598          52.5400
# 14                  0.058959      1753401591         101.9900
# 15                  0.000000      1753401598           4.8300
# 16                  0.150715      1753401592         232.5800
# 17                  0.145704      1753401594         192.4500
# 18                 -0.010335      1753401586          48.3850
# 19                  0.204225      1753401568          14.7200
# 20                  0.512321      1753401559           9.7899
# 21                  0.000000      1753401600          10.2300
# 22                 -0.514652      1753401590          12.5650
# 23                  0.458297      1753401596          10.9600
# 24                  0.619194      1753401534           3.2500
# 25                  0.000000      1753401482           9.7600
# 26                 -0.107452      1753401570          27.8900
# 27                  0.629921      1753400446           6.3900
# 28                  0.294981      1753401589          17.0000
# 29                  0.360585      1753401536          16.7000
# 30                  0.323337      1753401520          12.3799
# 31                  0.235056      1753401586          29.8500
# 32                 -0.189031      1753401594          10.5600
# 33                  0.161816      1753401508           6.1900
# 34                  0.465493      1753401597         112.2500
# 35                  2.744420      1753401591          23.9600
# 36                  0.231098      1753401599          91.0800
# 37                  0.084140      1753401588         288.9530
# 38                  0.351164      1753401593          74.3000
# 39                  0.178848      1753401595         511.7940
# 40                  0.232245      1753401479          68.4486
# 41                 -0.197907      1753401571          35.3000
# 42                  0.939459      1753401597           9.6700
# 43                  0.691238      1753401583           4.3700
# 44                  0.290101      1753401539          20.5695
# 45                  0.154999      1753401434          84.0000
# 46                  0.069635      1753401600          43.1100
# 47                 -3.229524      1753401300           8.3900
# 48                  0.197563      1753401585          75.5690
# 49                  0.417242      1753401564          14.4400
# 50                 -0.214592      1753397070          18.4603
# 51                 -0.201882      1753401565          14.8300
# 52                  0.028861      1753401489          35.0101
# 53                  0.000000      1753401479          23.5000
# 54                 -0.114749      1753401590          23.5030
# 55                  0.744688      1753401594           9.4700
# 56                 -0.103354      1753401599         396.2900
# 57                  0.031027      1753401574          61.5791
# 58                  0.049523      1753401584         121.2100
# 59                  0.419914      1753401600          33.4800
# 60                  0.062897      1753401536          95.4500
# 61                 -7.342660      1753401594          55.6500
# 62                  0.024486      1753401592          45.7512
# 63                  0.000000      1753401061          44.5800
# 64                  0.217169      1753401597          13.6596
# 65                  0.020592      1753401575         242.8800
# 66                 -0.416950      1753401599         413.1900
# 67                  3.968140      1753401594          63.9508
# 68                  0.270596      1753401507          33.3500
# 69                  0.765725      1753401588         243.4500
# 70                  0.358995      1753401581          25.1600
# 71                  0.169676      1753401152          17.7100
# 72                  0.117645      1753401497          85.1000
# 73                  0.081171      1753401550          12.3300
# 74                  1.008760      1753401582          38.0500
# 75                  0.073114      1753401593          54.7500
# 76                  0.033515      1753401239          30.1501
# 77                  0.028676      1753401594          33.4796
# 78                  0.095528      1753401570          52.3900
# 79                  0.434210      1753401449          46.2600
# 80                 -0.818159      1753401513          96.9800
# 81                  0.245468      1753401388          93.9300
# 82                  0.551411      1753401403          55.7457
# 83                  0.008202      1753401588         121.9600
# 84                  0.000000      1753401554          44.0400
# 85                  0.693910      1753401441          78.3600
# 86                  0.456277      1753399690          26.4200
# 87                  0.368623      1753400770           7.6782
# 88                 -0.041955      1753401592          35.5001
# 89                 -2.721090      1753401576           1.4300
# 90                  0.237046      1753401596         118.4000
# 91                  0.050590      1753401541         296.7000
# 92                  0.622810      1753400545          25.8500
# 93                  2.393621      1753401600          11.5500
# 94                  0.995597      1753401600         105.5000
# 95                  0.445366      1753401600         232.3000
# 96                  0.076688      1753401201         158.9620
# 97                  1.409330      1753401586          97.8600
# 98                  0.946371      1753401600          12.8000
# 99                  0.791558      1753396879          45.8400
# 100                -0.328374      1753400490           8.7113
# 101                 0.033543      1753401483          89.7601
# 102                 0.077746      1753401544         118.3020
# 103                 0.000000      1753401399          20.3100
# 104                 0.692257      1753401580          16.0000
# 105                 0.183037      1753401595         268.1900
# 106                 0.598578      1753401552          26.8900
# 107                 0.000000      1753401598          12.7000
# 108                 0.134226      1753401559          37.3000
# 109                 0.586090      1753400399          63.5000
# 110                 0.551115      1753400705          46.5250
# 111                -0.823936      1753401423         186.5700
# 112                 0.596010      1753401600         131.6500
# 113                 0.235233      1753401600          19.1750
# 114                -0.032417      1753401566         185.6300
# 115                 0.531751      1753401502          66.1700
# 116                 0.211516      1753401462         146.8700
# 117                 0.120983      1753401600          33.1000
# 118                 0.186560      1753401584         268.5100
# 119                 0.141313      1753401229          21.2600
# 120                 0.688071      1753399943          69.4949
# 121                 0.562319      1753401113          10.7300
# 122                 0.564975      1753401495          19.5800
# 123                 1.153843      1753401600          26.3000
# 124                 0.347649      1753401512          82.9875
# 125                -0.156940      1753401600          31.8100
# 126                 0.011303      1753401600         354.0100
# 127                 0.187774      1753401313          48.0200
# 128                -2.048119      1753401221          26.0552
# 129                 0.326181      1753400779          21.4999
# 130                 1.584090      1753401566          60.2800
# 131                -0.456136      1753401572         141.8500
# 132                -2.700263      1753400844          21.6200
# 133                 0.656458      1753401063          64.4000
# 134                 0.000000      1753401599         155.2200
# 135                 0.309126      1753401490          64.9000
# 136                -0.157515      1753401261          50.7100
# 137                -0.775611      1753396878          37.1000
# 138                 0.397310      1753401564          98.5500
# 139                 0.013945      1753401600         102.5443
# 140                 0.190082      1753401572         126.5000
# 141                 0.767618      1753400985          28.8800
# 142                 0.426142      1753400365          49.4900
# 143                 0.320939      1753401391         181.3000
# 144                 0.000000      1753400689          42.6900
# 145                 0.197711      1753399860         141.9000
# 146                 0.133831      1753401411          37.4100
# 147                 0.019881      1753401550         201.2000
# 148                 0.276735      1753401590         481.9300
# 149                 0.704931      1753399371          80.0000
# 150                -0.305100      1753401097          55.5500
# 151                -0.257704      1753401010         104.5000
# 152                 0.000000      1753400548          34.2500
# 153                 0.436287      1753401099         110.5000
# 154                 1.671030      1753400980          50.5000
# 155                 0.444803      1753401469         212.2700
# 156                -0.197939      1753401399         247.0100
#
#      postMarketChange  regularMarketChange  regularMarketTime  \
# 0           -0.154999             2.960010         1753387200
# 1           -0.010000            -0.090000         1753387202
# 2           -0.000300            -0.040000         1753387200
# 3            1.740020           -27.260000         1753387201
# 4            0.019999            -0.120000         1753387202
# 5           -0.080002             0.240997         1753387200
# 6           -1.040000            -0.860001         1753387201
# 7            0.030199            -0.049999         1753387201
# 8            0.080000            -1.220000         1753387201
# 9            0.290009            -0.389999         1753387201
# 10           0.010000             0.270000         1753387201
# 11           0.010799            -0.309999         1753387201
# 12           2.320100             3.470000         1753387201
# 13           0.020001             0.820000         1753387201
# 14           0.060097            -0.150002         1753387200
# 15           0.000000            -0.090000         1753387202
# 16           0.350006             3.940000         1753387201
# 17           0.279999             1.940000         1753387201
# 18          -0.005001             0.250000         1753387202
# 19           0.030001             0.349999         1753387200
# 20           0.049900            -0.330000         1753387202
# 21           0.000000            -0.170000         1753387202
# 22          -0.065001            -0.200000         1753387202
# 23           0.050000            -0.360001         1753387202
# 24           0.020000            -0.130000         1753387201
# 25           0.000000            -0.050000         1753387202
# 26          -0.030001             0.170000         1753387294
# 27           0.040000            -0.100000         1753387202
# 28           0.049999            -0.519999         1753387201
# 29           0.060001            -0.180000         1753387201
# 30           0.039900            -0.110000         1753387202
# 31           0.070000            -0.959999         1753387202
# 32          -0.019999            -0.051000         1753387200
# 33           0.010000            -0.100000         1753387202
# 34           0.520096             1.900000         1753387201
# 35           0.639999            -2.490000         1753387201
# 36           0.209999             0.930000         1753387202
# 37           0.242920             5.019990         1753387201
# 38           0.260002             0.770004         1753387201
# 39           0.913696             5.010010         1753387200
# 40           0.158600            -0.330002         1753387200
# 41          -0.070000            -0.420002         1753387201
# 42           0.090000            -0.760000         1753387202
# 43           0.030000            -0.180000         1753387202
# 44           0.059500            -0.250000         1753387298
# 45           0.129997             0.170006         1753387231
# 46           0.029999             0.240002         1753387202
# 47          -0.280000             0.240000         1753387202
# 48           0.149002            -1.330000         1753387202
# ...
# 47               0.05                  2    0.219307
# 48               0.08                  4    0.762651
# 49              85.71               2719    0.310112
# 50               0.00                  0    0.396762
# 51               0.30                 14    0.606905
# 52               0.20                  8    0.353430
# 53               0.12                  6    0.447822
# 54               0.11                  4    0.244017
# 55               0.22                 10    0.537830
# 56               0.28                 12    0.411076
# 57               0.47                 19    0.330357
# 58               0.08                  4    0.325517
# 59               0.57                 23    0.431181
# 60               0.01                  0    0.533822
# 61               0.31                 12    0.235259
# 62               0.05                  2    0.879034
# 63               0.20                 12    0.514188
# 64               0.79                 32    0.651717
# 65               0.00                  0    0.275324
# 66               0.16                  8    0.763969
# 67               0.16                  8    0.795685
# 68               0.16                  8    0.903437
# 69               0.08                  4    0.291877
# 70               0.12                  6    0.808712
# 71               0.11                  6    0.800234
# 72               0.09                  4    0.868269
# 73               0.03                  2    0.135585
# 74               0.06                  3    0.570636
# 75               0.18                  8    0.037907
# 76               0.00                  1    0.870499
# 77               0.08                  5    0.276544
# 78               0.09                  5    0.410077
# 79               0.04                  2    0.604480
# 80               0.08                  5    0.543563
# 81               0.04                  2    0.436443
# 82               0.13                  6    0.728620
# 83               0.00                  0    0.241590
# 84               0.05                  3    0.252979
# 85               0.03                  0    0.850386
# 86               0.04                  2    0.574004
# 87               0.78                 14    0.236296
# 88               0.24                 10    0.832406
# 89              23.73                 93    0.666131
# 90               0.12                  5    0.246650
# 91               0.00                  0    0.784622
# 92               0.00                  0    0.741341
# 93               0.40                 18    0.954132
# 94               0.15                  6    0.015592
# 95               0.03                  2    0.321145
# 96               0.05                  2    0.719947
# 97               0.07                  4    0.563898
# 98               0.33                 17    0.593995
# 99               0.00                  0    0.511034
# 100              0.10                  6    0.933868
# 101              0.18                 10    0.022752
# 102              0.15                  9    0.653566
# 103              0.04                  2    0.072717
# 104              0.21                  6    0.148112
# 105              0.00                  0    0.807958
# 106              0.14                  8    0.916929
# 107              0.09                  4    0.769025
# 108              0.01                  0    0.738334
# 109              0.00                  0    0.145753
# 110              0.00                  0    0.065317
# 111              0.10                  7    0.594795
# 112              0.16                  8    0.306024
# 113              0.19                 10    0.375407
# 114              0.04                  2    0.913730
# 115              0.12                  7    0.452538
# 116              0.08                  5    0.364845
# 117              0.28                 14    0.982116
# 118              0.12                  6    0.160747
# 119              0.15                  9    0.464411
# 120              0.03                  2    0.410555
# 121              0.08                  4    0.654929
# 122              0.25                 12    0.403831
# 123              0.35                 14    0.675624
# 124              0.15                  8    0.623967
# 125              0.29                 16    0.439567
# 126              0.00                  0    0.443456
# 127              0.00                  0    0.924606
# 128              0.15                  9    0.607012
# 129              0.16                  8    0.675507
# 130              0.15                  8    0.484022
# 131              0.00                  1    0.581492
# 132              0.00                  1    0.401816
# 133              0.22                 11    0.710979
# 134              0.04                  2    0.482830
# 135              0.08                  4    0.557659
# 136              0.04                  2    0.722778
# 137              0.08                  4    0.789614
# 138              0.04                  2    0.903833
# 139              0.03                  0    0.877395
# 140              0.00                  0    0.850295
# 141              0.10                  2    0.833878
# 142              0.04                  2    0.301257
# 143              0.05                  3    0.568868
# 144              0.08                  4    0.129508
# 145              0.00                  0    0.468061
# 146              0.10                  4    0.450334
# 147              0.08                  4    0.546440
# 148              0.00                  0    0.664860
# 149              0.04                  2    0.619476
# 150              0.01                  0    0.754989
# 151              0.05                  0    0.406149
# 152              0.08                  4    0.746497
# 153              0.00                  0    0.218403
# 154              0.10                  6    0.457124
# 155              0.05                  2    0.269998
# 156              0.08                  4    0.862482
#
#                                    AvgReturn_7d  Shannon/IV
# 0        Ticker
# NVDA    0.000005
# dtype: float64    1.417876
# 1        Ticker
# LCID    0.000113
# dtype: float64    0.131837
# 2        Ticker
# PLUG    0.000061
# dtype: float64    0.548454
# 3        Ticker
# TSLA   -0.000008
# dtype: float64    0.062997
# 4           Ticker
# F   -0.000003
# dtype: float64    2.127771
# 5        Ticker
# PLTR    0.000014
# dtype: float64    3.987127
# 6        Ticker
# INTC   -0.000006
# dtype: float64    0.426554
# 7        Ticker
# SOFI    0.000007
# dtype: float64    1.140148
# 8         Ticker
# AAL   -0.000023
# dtype: float64    0.431184
# 9        Ticker
# AAPL    0.000005
# dtype: float64    4.200115
# 10       Ticker
# APLD    0.000041
# dtype: float64    0.863715
# 11       Ticker
# MARA   -0.000043
# dtype: float64    0.680760
# 12        Ticker
# AMD    0.000016
# dtype: float64    1.913192
# 13       Ticker
# SMCI   -0.000002
# dtype: float64    1.571378
# 14       Ticker
# HOOD    0.000008
# dtype: float64    0.698600
# 15        Ticker
# NIO    0.000057
# dtype: float64    1.207221
# 16       Ticker
# AMZN    0.000012
# dtype: float64    3.112859
# 17      Ticker
# GOOGL    0.000017
# dtype: float64    0.408147
# 18        Ticker
# BAC    0.000019
# dtype: float64    3.065513
# 19       Ticker
# RIOT    0.000062
# dtype: float64    1.625889
# 20        Ticker
# SNAP    0.00001
# dtype: float64    1.821388
# 21       Ticker
# VALE    0.000019
# dtype: float64    0.993045
# 22         Ticker
# QS    0.000075
# dtype: float64    0.765221
# 23         Ticker
# CLF    0.00007
# dtype: float64    0.603553
# 24       Ticker
# BTBT   -0.000024
# dtype: float64    1.103670
# 25       Ticker
# AMCR    0.000012
# dtype: float64    3.131388
# 26          Ticker
# T    0.000013
# dtype: float64    0.485712
# 27       Ticker
# ITUB    0.000003
# dtype: float64    3.283965
# 28       Ticker
# QUBT   -0.000023
# dtype: float64    1.495613
# 29       Ticker
# HBAN    0.000001
# dtype: float64    4.500055
# 30       Ticker
# CLSK   -0.000006
# dtype: float64    1.503012
# 31        Ticker
# CCL    0.000008
# dtype: float64    2.301335
# 32        Ticker
# RUN   -0.000006
# dtype: float64    0.623989
# 33         Ticker
# HL    0.000004
# dtype: float64    1.051563
# 34         Ticker
# MU   -0.000021
# dtype: float64    2.370738
# 35       Ticker
# SBET   -0.000103
# dtype: float64    0.244663
# 36       Ticker
# UBER   -0.000004
# dtype: float64    1.671019
# 37       Ticker
# AVGO    0.000013
# dtype: float64    0.786804
# 38       Ticker
# MRVL    0.000025
# dtype: float64    1.418565
# 39       Ticker
# MSFT    0.000005
# dtype: float64    2.242567
# 40       Ticker
# CSCO    0.000005
# dtype: float64    5.283711
# 41      Ticker
# CMCSA    0.000006
# dtype: float64    2.681311
# 42       Ticker
# STLA    0.000007
# dtype: float64    0.037772
# 43        Ticker
# NOK   -0.000031
# dtype: float64    0.277220
# 44        Ticker
# HPE    0.000002
# dtype: float64    0.944761
# 45        Ticker
# WFC    0.000023
# dtype: float64    3.992441
# 46         Ticker
# VZ    0.000017
# dtype: float64    0.478282
# 47        Ticker
# ADT    0.000014
# dtype: float64    2.399548
# 48        Ticker
# NKE    0.000015
# dtype: float64    3.233499
# 49       Ticker
# LYFT   -0.000014
# dtype: float64    2.942359
# 50        Ticker
# KEY    0.000012
# dtype: float64    2.560131
# 51         Ticker
# RKT    0.00004
# dtype: float64    0.879635
# 52        Ticker
# CSX    0.000016
# dtype: float64    2.283516
# 53       Ticker
# NCLH    0.000009
# dtype: float64    1.843008
# 54        Ticker
# GME    0.000001
# dtype: float64    2.536112
# 55        Ticker
# CDE    0.000007
# dtype: float64    1.466223
# 56       Ticker
# COIN    0.000005
# dtype: float64    1.639628
# 57         Ticker
# MP    0.000011
# dtype: float64    1.500085
# 58       Ticker
# BABA    0.000018
# dtype: float64    2.348221
# 59          Ticker
# U    0.000013
# dtype: float64    0.979087
# 60          Ticker
# C    0.000017
# dtype: float64    2.883172
# 61       Ticker
# ASTS    0.000057
# dtype: float64    1.066761
# 62        Ticker
# CMG   -0.000057
# dtype: float64    0.010479
# 63        Ticker
# FCX    0.000005
# dtype: float64    0.884437
# 64        Ticker
# KSS    0.000241
# dtype: float64    0.459875
# 65       Ticker
# ORCL    0.000013
# dtype: float64    3.931204
# 66       Ticker
# MSTR   -0.000027
# dtype: float64    2.205721
# 67        Ticker
# NEM    0.000022
# dtype: float64    0.332456
# 68        Ticker
# LUV   -0.000042
# dtype: float64    0.509476
# 69        Ticker
# TSM    0.000009
# dtype: float64    0.366781
# 70        Ticker
# DOW   -0.000039
# dtype: float64    0.021383
# 71       Ticker
# INFY   -0.000016
# dtype: float64    0.491329
# 72        Ticker
# TTD    0.000014
# dtype: float64    2.323323
# 73       Ticker
# PATH   -0.000002
# dtype: float64    2.110176
# 74       Ticker
# PINS    0.000012
# dtype: float64    0.433942
# 75         Ticker
# DAL   -0.00001
# dtype: float64    2.765857
# 76       Ticker
# CPNG   -0.000012
# dtype: float64    2.711474
# 77         Ticker
# JD    0.000021
# dtype: float64    1.357985
# 78         Ticker
# GM   -0.000003
# dtype: float64    1.082829
# 79        Ticker
# USB    0.000002
# dtype: float64    2.694916
# 80   Ticker
# LRCX    4.387284e-07
# dtype: float64    2.046476
# 81       Ticker
# SBUX    0.000004
# dtype: float64    2.012133
# 82          Ticker
# ON   -0.00002
# dtype: float64    0.220217
# 83        Ticker
# DIS    0.000008
# dtype: float64    5.691157
# 84   Ticker
# DKNG   -2.938981e-07
# dtype: float64    2.456464
# 85       Ticker
# PYPL    0.000023
# dtype: float64    2.621720
# 86         Ticker
# RF    0.000033
# dtype: float64    1.466650
# 87        Ticker
# HTZ   -0.000007
# dtype: float64    1.158059
# 88       Ticker
# ENPH   -0.000045
# dtype: float64    0.460155
# 89       Ticker
# GPRO    0.000338
# dtype: float64    0.113061
# 90       Ticker
# RBLX    0.000017
# dtype: float64    3.212210
# 91        Ticker
# JPM    0.000011
# dtype: float64    5.130328
# 92        Ticker
# HPQ    0.000018
# dtype: float64    3.865950
# 93        Ticker
# AEO    0.000041
# dtype: float64    0.293044
# 94        Ticker
# APH    0.000018
# dtype: float64    2.765765
# 95         Ticker
# BA   -0.000002
# dtype: float64    2.529938
# 96       Ticker
# QCOM    0.000011
# dtype: float64    1.448709
# 97       Ticker
# SCHW    0.000019
# dtype: float64    1.620047
# 98        Ticker
# VFC    0.000025
# dtype: float64    0.431900
# 99        Ticker
# TFC    0.000007
# dtype: float64    5.399839
# 100        Ticker
# WU    0.000028
# dtype: float64    1.939999
# 101       Ticker
# UAL    0.000009
# dtype: float64    0.976167
# 102       Ticker
# PDD    0.000048
# dtype: float64    0.406891
# 103       Ticker
# OWL    0.000025
# dtype: float64    2.138932
# 104      Ticker
# ZETA    0.000037
# dtype: float64    1.458503
# 105       Ticker
# CRM    0.000013
# dtype: float64    3.636508
# 106       Ticker
# STM   -0.000054
# dtype: float64    0.103931
# 107         Ticker
# M    0.000019
# dtype: float64    0.264806
# 108      Ticker
# CHWY   -0.000011
# dtype: float64    2.796286
# 109   Ticker
# SKX    5.355872e-07
# dtype: float64   17.169827
# 110  Ticker
# CPRT    9.986030e-07
# dtype: float64    3.509847
# 111       Ticker
# AMAT   -0.00001
# dtype: float64    1.679231
# 112       Ticker
# VRT    0.000009
# dtype: float64    1.680711
# 113      Ticker
# XPEV    0.000027
# dtype: float64    1.133678
# 114       Ticker
# TXN   -0.000057
# dtype: float64    0.055577
# 115      Ticker
# AFRM   -0.000009
# dtype: float64    1.156986
# 116      Ticker
# DDOG    0.000019
# dtype: float64    2.344699
# 117        Ticker
# BE    0.000105
# dtype: float64    0.047863
# 118        Ticker
# GE    0.000006
# dtype: float64    2.496172
# 119       Ticker
# TME   -0.000005
# dtype: float64    1.174687
# 120       Ticker
# WDC    0.000009
# dtype: float64    2.116060
# 121       Ticker
# WEN    0.000007
# dtype: float64    0.237026
# 122         Ticker
# S    0.000037
# dtype: float64    0.253314
# 123        Ticker
# AI   -0.000014
# dtype: float64    0.226879
# 124      Ticker
# UPST    0.000038
# dtype: float64    1.291586
# 125         Ticker
# AA    0.00004
# dtype: float64    0.794894
# 126         Ticker
# V    0.000007
# dtype: float64    4.841256
# 127      Ticker
# FAST    0.000021
# dtype: float64    4.849200
# 128      Ticker
# CFLT    0.000028
# dtype: float64    1.267576
# 129        Ticker
# IVZ    0.00009
# dtype: float64    1.711892
# 130      Ticker
# TSCO    0.000019
# dtype: float64    0.878261
# 131         Ticker
# MS    0.00001
# dtype: float64    3.598833
# 132       Ticker
# FHN    0.000012
# dtype: float64    3.882617
# 133      Ticker
# ETSY    0.000048
# dtype: float64    0.545412
# 134       Ticker
# RTX    0.000015
# dtype: float64    1.441593
# 135       Ticker
# IBKR    0.00003
# dtype: float64    0.790865
# 136       Ticker
# LVS    0.000009
# dtype: float64    0.665032
# 137       Ticker
# MOS    0.000015
# dtype: float64    1.585658
# 138      Ticker
# ORLY    0.000025
# dtype: float64    2.202384
# 139        Ticker
# UPS    0.00001
# dtype: float64    1.464246
# 140       Ticker
# TJX    0.000013
# dtype: float64    5.193793
# 141       Ticker
# CZR   -0.000021
# dtype: float64    1.048126
# 142       Ticker
# CFG    0.000018
# dtype: float64    4.906574
# 143      Ticker
# FSLR    0.000019
# dtype: float64    2.697374
# 144      Ticker
# FITB   -0.000002
# dtype: float64    3.627260
# 145      Ticker
# ABNB    0.000014
# dtype: float64    2.957013
# 146       Ticker
# MGM   -0.000004
# dtype: float64    1.499817
# 147      Ticker
# PANW    0.000016
# dtype: float64    2.773169
# 148     Ticker
# BRK-B    0.000009
# dtype: float64    5.361256
# 149      Ticker
# CARR    0.000019
# dtype: float64    2.269269
# 150       Ticker
# GLW    0.000021
# dtype: float64    2.822978
# 151  Ticker
# FTNT    1.678167e-07
# dtype: float64    2.888507
# 152       Ticker
# IBN    0.000011
# dtype: float64    0.412327
# 153       Ticker
# JCI    0.000012
# dtype: float64    3.139509
# 154      Ticker
# FLEX   -0.000012
# dtype: float64    2.591483
# 155       Ticker
# COF   -0.000008
# dtype: float64    0.269768
# 156      Ticker
# TMUS    0.000032
# dtype: float64    0.226838

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio
from ib_insync import *
import pandas as pd
import numpy as np
import ta
import plotly.graph_objects as go

"""
Filter parameters
-----------------
VOL_WINDOW:       ATR period (bars) for volatility calculation (consider higher for daily)
VOL_THRESHOLD:    Minimum ATR percent (ATR/close) for a bar to be considered volatile enough for trading (e.g., 0.01 = 1%)
REGIME_THRESHOLD: Rolling mean of returns must be above this (e.g., -0.1) to be considered "trending" regime
ADX_PERIOD:       ADX calculation period (bars)
ADX_THRESHOLD:    Minimum ADX value to confirm market is trending (20 = classic)
SMA_PERIOD:       SMA bars for trend filter (only long if above, short if below)
"""

# ========= CHART SETTINGS =========
BAR_SIZE = '1 day'      # IBKR bar size for daily candles
DURATION = '5 Y'        # How far back to get data (e.g., '5 Y' = 5 years)
NUM_BARS = 2000         # Approximate daily bars in 5 years
# ================================

# Filter tuning (adjust to your needs)
VOL_WINDOW       = 30        # ATR lookback period (bars); for daily, 14-30 is common
VOL_THRESHOLD    = 0.001     # Minimum ATR% for volatility filter (e.g., 0.01=1%)
REGIME_THRESHOLD = -0.1      # Regime filter threshold
ADX_PERIOD       = 14        # ADX lookback window (bars)
ADX_THRESHOLD    = 20        # Minimum ADX to allow signals (trend filter)
SMA_PERIOD       = 200       # SMA filter period (bars)

EXCHANGE    = 'SMART'
CURRENCY    = 'USD'
LOOKAHEAD   = 4
K_NEIGHBORS = 8

FEATURES = ['RSI', 'ADX', 'CCI', 'MACD']

filterdf['symbol'] = filterdf['symbol'].str.replace('-', ' ')

# ==== Data Fetch Function ====
async def fetch_ibkr_stock(symbol, exchange, currency, bar_size, duration, num_bars):
    """Fetches OHLCV bars from IBKR using specified bar size/duration."""
    ib = IB()
    await ib.connectAsync('127.0.0.1', 7497, clientId=np.random.randint(1000, 10000))
    contract = Stock(symbol, exchange, currency)
    await ib.qualifyContractsAsync(contract)
    bars = await ib.reqHistoricalDataAsync(
        contract=contract,
        endDateTime='',
        durationStr=duration,
        barSizeSetting=bar_size,
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1,
        keepUpToDate=False
    )
    df = util.df(bars)
    df.set_index('date', inplace=True)
    df = df.tail(num_bars)
    ib.disconnect()
    return df


# ==== ML Functions and Filters ====
def lorentzian_distance(a, b):
    return np.sum(np.log(1 + np.abs(a - b)))


def volatility_filter(df, vol_window, vol_thresh):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=vol_window).average_true_range()
    atr_pct = atr / df['close']
    return atr_pct > vol_thresh


def regime_filter(df, threshold):
    close_returns = df['close'].pct_change()
    regime = close_returns.rolling(window=20).mean()
    return regime > threshold


def adx_filter(df, adx_period, adx_threshold):
    adx = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=adx_period).adx()
    return adx > adx_threshold


def classify_lorentzian_knn_with_filters(
        df, features, sma_period,
        vol_window, vol_thresh,
        regime_thresh, adx_period, adx_thresh,
        n_neighbors=8, lookahead=4, max_bars_back=500):
    pred = np.full(len(df), np.nan)
    neighbors_info = {}

    closes = df['close'].values
    feature_mat = df[features].values
    sma = df['SMA'].values

    vol_filter = volatility_filter(df, vol_window, vol_thresh)
    regime_filt = regime_filter(df, regime_thresh)
    adx_filt = adx_filter(df, adx_period, adx_thresh)

    length = len(df)

    # Main loop - exclude last 'lookahead' bars
    for idx in range(max_bars_back, length - lookahead):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    # Explicit classification for last 'lookahead' bars
    for idx in range(length - lookahead, length):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    return pred, neighbors_info


# ==== Process symbols from filterdf ====
async def process_symbols_with_knn(filterdf):
    filterdf['pct_buy_last_8d'] = np.nan
    filterdf['pct_sell_last_8d'] = np.nan

    for i, row in filterdf.iterrows():
        symbol = row['symbol']  # Adjust if your symbol column is named differently
        print(f"Processing {symbol} ...")

        df = await fetch_ibkr_stock(symbol, EXCHANGE, CURRENCY, BAR_SIZE, DURATION, NUM_BARS)

        # Feature Engineering
        df['RSI'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
        df['ADX'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
        df['CCI'] = ta.trend.CCIIndicator(df['high'], df['low'], df['close'], window=20).cci()
        df['SMA'] = ta.trend.SMAIndicator(df['close'], window=SMA_PERIOD).sma_indicator()
        macd_ind = ta.trend.MACD(df['close'], window_slow=26, window_fast=12, window_sign=9)
        df['MACD'] = macd_ind.macd()
        df['MACD_signal'] = macd_ind.macd_signal()
        df['MACD_hist'] = macd_ind.macd_diff()
        df = df.dropna().reset_index()

        preds, _ = classify_lorentzian_knn_with_filters(
            df, FEATURES, SMA_PERIOD, VOL_WINDOW, VOL_THRESHOLD,
            REGIME_THRESHOLD, ADX_PERIOD, ADX_THRESHOLD,
            n_neighbors=K_NEIGHBORS, lookahead=LOOKAHEAD, max_bars_back=500
        )
        df['raw_pred'] = preds

        # Calculate % buy and sell signals in the last 8 days of predictions
        last_8 = df['raw_pred'].tail(8)
        pct_buy = (last_8 == 1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0
        pct_sell = (last_8 == -1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0

        filterdf.at[i, 'pct_buy_last_8d'] = pct_buy
        filterdf.at[i, 'pct_sell_last_8d'] = pct_sell

    return filterdf


# --- Example usage ---
# Make sure you have your filter dataframe loaded with a 'symbol' column
# Example:
# filterdf = pd.DataFrame({'symbol': ['GOOG', 'AAPL', 'MSFT']})

if __name__ == '__main__':
    import sys

    # Replace or load your filter dataframe here
    # For demo, you can define it manually or read from CSV

    df_results = asyncio.run(process_symbols_with_knn(filterdf))
    print(df_results[['symbol', 'pct_buy_last_8d', 'pct_sell_last_8d']])
# Out:
# Processing NVDA ...
# Processing LCID ...
# Processing PLUG ...
# Processing TSLA ...
# Processing F ...
# Processing PLTR ...
# Processing INTC ...
# Processing SOFI ...
# Processing AAL ...
# Processing AAPL ...
# Processing APLD ...
# Processing MARA ...
# Processing AMD ...
# Processing SMCI ...
# Processing HOOD ...
# Processing NIO ...
# Processing AMZN ...
# Processing GOOGL ...
# Processing BAC ...
# Processing RIOT ...
# Processing SNAP ...
# Processing VALE ...
# Processing QS ...
# Processing CLF ...
# Processing BTBT ...
# Processing AMCR ...
# Processing T ...
# Processing ITUB ...
# Processing QUBT ...
# Processing HBAN ...
# Processing CLSK ...
# Processing CCL ...
# Processing RUN ...
# Processing HL ...
# Processing MU ...
# Processing SBET ...
# Processing UBER ...
# Processing AVGO ...
# Processing MRVL ...
# Processing MSFT ...
# Processing CSCO ...
# Processing CMCSA ...
# Processing STLA ...
# Processing NOK ...
# Processing HPE ...
# Processing WFC ...
# Processing VZ ...
# Processing ADT ...
# Processing NKE ...
# Processing LYFT ...
# Processing KEY ...
# Processing RKT ...
# Processing CSX ...
# Processing NCLH ...
# Processing GME ...
# Processing CDE ...
# Processing COIN ...
# Processing MP ...
# Processing BABA ...
# Processing U ...
# Processing C ...
# Processing ASTS ...
# Processing CMG ...
# Processing FCX ...
# Processing KSS ...
# Processing ORCL ...
# Processing MSTR ...
# Processing NEM ...
# Processing LUV ...
# Processing TSM ...
# Processing DOW ...
# Processing INFY ...
# Processing TTD ...
# Processing PATH ...
# Processing PINS ...
# Processing DAL ...
# Processing CPNG ...
# Processing JD ...
# Processing GM ...
# Processing USB ...
# Processing LRCX ...
# Processing SBUX ...
# Processing ON ...
# Processing DIS ...
# Processing DKNG ...
# Processing PYPL ...
# Processing RF ...
# Processing HTZ ...
# Processing ENPH ...
# Processing GPRO ...
# Processing RBLX ...
# Processing JPM ...
# Processing HPQ ...
# Processing AEO ...
# Processing APH ...
# Processing BA ...
# Processing QCOM ...
# Processing SCHW ...
# Processing VFC ...
# Processing TFC ...
# Processing WU ...
# Processing UAL ...
# Processing PDD ...
# Processing OWL ...
# Processing ZETA ...
# Processing CRM ...
# Processing STM ...
# Processing M ...
# Processing CHWY ...
# Processing SKX ...
# Processing CPRT ...
# Processing AMAT ...
# Processing VRT ...
# Processing XPEV ...
# Processing TXN ...
# Processing AFRM ...
# Processing DDOG ...
# Processing BE ...
# Processing GE ...
# Processing TME ...
# Processing WDC ...
# Processing WEN ...
# Processing S ...
# Processing AI ...
# Processing UPST ...
# Processing AA ...
# Processing V ...
# Processing FAST ...
# Processing CFLT ...
# Processing IVZ ...
# Processing TSCO ...
# Processing MS ...
# Processing FHN ...
# Processing ETSY ...
# Processing RTX ...
# Processing IBKR ...
# Processing LVS ...
# Processing MOS ...
# Processing ORLY ...
# Processing UPS ...
# Processing TJX ...
# Processing CZR ...
# Processing CFG ...
# Processing FSLR ...
# Processing FITB ...
# Processing ABNB ...
# Processing MGM ...
# Processing PANW ...
# Processing BRK B ...
# Processing CARR ...
# Processing GLW ...
# Processing FTNT ...
# Processing IBN ...
# Processing JCI ...
# Processing FLEX ...
# Processing COF ...
# Processing TMUS ...
#     symbol  pct_buy_last_8d  pct_sell_last_8d
# 0     NVDA             62.5               0.0
# 1     LCID             50.0               0.0
# 2     PLUG             25.0              12.5
# 3     TSLA              0.0               0.0
# 4        F             12.5               0.0
# 5     PLTR             12.5               0.0
# 6     INTC              0.0              12.5
# 7     SOFI             37.5               0.0
# 8      AAL              0.0              75.0
# 9     AAPL              0.0              12.5
# 10    APLD             37.5               0.0
# 11    MARA             12.5               0.0
# 12     AMD             87.5               0.0
# 13    SMCI             25.0               0.0
# 14    HOOD             87.5               0.0
# 15     NIO              0.0               0.0
# 16    AMZN             25.0               0.0
# 17   GOOGL             12.5               0.0
# 18     BAC             12.5               0.0
# 19    RIOT             25.0               0.0
# 20    SNAP              0.0              37.5
# 21    VALE              0.0               0.0
# 22      QS             25.0               0.0
# 23     CLF              0.0              25.0
# 24    BTBT             12.5               0.0
# 25    AMCR              0.0              37.5
# 26       T             37.5               0.0
# 27    ITUB              0.0               0.0
# 28    QUBT             25.0               0.0
# 29    HBAN             75.0               0.0
# 30    CLSK             25.0               0.0
# 31     CCL             75.0               0.0
# 32     RUN             75.0               0.0
# 33      HL              0.0               0.0
# 34      MU             75.0               0.0
# 35    SBET              0.0               0.0
# 36    UBER              0.0               0.0
# 37    AVGO             50.0               0.0
# 38    MRVL              0.0              12.5
# 39    MSFT             87.5               0.0
# 40    CSCO             62.5               0.0
# 41   CMCSA              0.0               0.0
# 42    STLA              0.0               0.0
# 43     NOK              0.0              12.5
# 44     HPE            100.0               0.0
# 45     WFC             50.0               0.0
# 46      VZ              0.0               0.0
# 47     ADT              0.0               0.0
# 48     NKE             37.5               0.0
# 49    LYFT              0.0               0.0
# 50     KEY             37.5               0.0
# 51     RKT             25.0               0.0
# 52     CSX             37.5               0.0
# 53    NCLH              0.0               0.0
# 54     GME              0.0              37.5
# 55     CDE             37.5               0.0
# 56    COIN             75.0               0.0
# 57      MP              0.0               0.0
# 58    BABA              0.0               0.0
# 59       U              0.0               0.0
# 60       C             75.0               0.0
# 61    ASTS             87.5               0.0
# 62     CMG              0.0               0.0
# 63     FCX             62.5               0.0
# 64     KSS             12.5               0.0
# 65    ORCL             75.0               0.0
# 66    MSTR             37.5               0.0
# 67     NEM             25.0               0.0
# 68     LUV              0.0               0.0
# 69     TSM             62.5               0.0
# 70     DOW              0.0               0.0
# 71    INFY              0.0               0.0
# 72     TTD              0.0              37.5
# 73    PATH              0.0               0.0
# 74    PINS              0.0               0.0
# 75     DAL             25.0               0.0
# 76    CPNG             50.0               0.0
# 77      JD              0.0               0.0
# 78      GM              0.0               0.0
# 79     USB             25.0              12.5
# 80    LRCX             37.5               0.0
# 81    SBUX              0.0              25.0
# 82      ON             50.0               0.0
# 83     DIS             37.5               0.0
# 84    DKNG             62.5               0.0
# 85    PYPL              0.0               0.0
# 86      RF             62.5               0.0
# 87     HTZ             37.5               0.0
# 88    ENPH              0.0               0.0
# 89    GPRO             12.5              25.0
# 90    RBLX             87.5               0.0
# 91     JPM             62.5               0.0
# 92     HPQ              0.0               0.0
# 93     AEO              0.0               0.0
# 94     APH             75.0               0.0
# 95      BA             25.0               0.0
# 96    QCOM              0.0               0.0
# 97    SCHW             75.0               0.0
# 98     VFC              0.0               0.0
# 99     TFC             62.5               0.0
# 100     WU              0.0              50.0
# 101    UAL             12.5               0.0
# 102    PDD              0.0               0.0
# 103    OWL              0.0               0.0
# 104   ZETA              0.0              37.5
# 105    CRM              0.0               0.0
# 106    STM             62.5               0.0
# 107      M              0.0              12.5
# 108   CHWY             37.5               0.0
# 109    SKX             75.0               0.0
# 110   CPRT              0.0              25.0
# 111   AMAT             75.0               0.0
# 112    VRT             25.0               0.0
# 113   XPEV              0.0               0.0
# 114    TXN             25.0              37.5
# 115   AFRM             25.0               0.0
# 116   DDOG             50.0               0.0
# 117     BE             25.0               0.0
# 118     GE             37.5               0.0
# 119    TME             37.5               0.0
# 120    WDC            100.0               0.0
# 121    WEN              0.0              25.0
# 122      S              0.0              62.5
# 123     AI              0.0               0.0
# 124   UPST             12.5               0.0
# 125     AA              0.0               0.0
# 126      V              0.0               0.0
# 127   FAST             37.5               0.0
# 128   CFLT              0.0               0.0
# 129    IVZ             50.0               0.0
# 130   TSCO             62.5               0.0
# 131     MS             50.0               0.0
# 132    FHN             75.0               0.0
# 133   ETSY             37.5               0.0
# 134    RTX              0.0               0.0
# 135   IBKR             50.0               0.0
# 136    LVS             50.0               0.0
# 137    MOS             25.0               0.0
# 138   ORLY              0.0               0.0
# 139    UPS              0.0               0.0
# 140    TJX             12.5               0.0
# 141    CZR              0.0              62.5
# 142    CFG             62.5               0.0
# 143   FSLR              0.0               0.0
# 144   FITB             25.0               0.0
# 145   ABNB              0.0               0.0
# 146    MGM             50.0               0.0
# 147   PANW              0.0               0.0
# 148  BRK B              0.0              50.0
# 149   CARR             87.5               0.0
# 150    GLW             37.5               0.0
# 151   FTNT              0.0               0.0
# 152    IBN              0.0               0.0
# 153    JCI             50.0               0.0
# 154   FLEX             75.0               0.0
# 155    COF             37.5               0.0
# 156   TMUS              0.0               0.0

# %%
filterdf
# Out:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 3      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 5      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 9      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 13     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15     en-US     US    EQUITY   Equity           Delayed Quote        False
# 16     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 17     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 18     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 19     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 20     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 21     en-US     US    EQUITY   Equity           Delayed Quote        False
# 22     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 24     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 25     en-US     US    EQUITY   Equity           Delayed Quote        False
# 26     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 27     en-US     US    EQUITY   Equity           Delayed Quote        False
# 28     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 29     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 30     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 32     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33     en-US     US    EQUITY   Equity           Delayed Quote        False
# 34     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 35     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 36     en-US     US    EQUITY   Equity           Delayed Quote        False
# 37     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 38     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 40     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 41     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 42     en-US     US    EQUITY   Equity           Delayed Quote        False
# 43     en-US     US    EQUITY   Equity           Delayed Quote        False
# 44     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 45     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 46     en-US     US    EQUITY   Equity           Delayed Quote        False
# 47     en-US     US    EQUITY   Equity           Delayed Quote        False
# 48     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 49     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 50     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 51     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52     en-US     US    EQUITY   Equity           Delayed Quote         True
# 53     en-US     US    EQUITY   Equity           Delayed Quote        False
# 54     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55     en-US     US    EQUITY   Equity           Delayed Quote        False
# 56     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 57     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 58     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 59     en-US     US    EQUITY   Equity           Delayed Quote        False
# 60     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 62     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 63     en-US     US    EQUITY   Equity           Delayed Quote        False
# 64     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 65     en-US     US    EQUITY   Equity           Delayed Quote        False
# 66     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 67     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 68     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 69     en-US     US    EQUITY   Equity           Delayed Quote        False
# 70     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 71     en-US     US    EQUITY   Equity           Delayed Quote        False
# 72     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 73     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 74     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 75     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 76     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 77     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 78     en-US     US    EQUITY   Equity           Delayed Quote        False
# 79     en-US     US    EQUITY   Equity           Delayed Quote        False
# 80     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 81     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 82     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 83     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 84     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 85     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 86     en-US     US    EQUITY   Equity           Delayed Quote        False
# 87     en-US     US    EQUITY   Equity           Delayed Quote         True
# 88     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 89     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 90     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 91     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 92     en-US     US    EQUITY   Equity           Delayed Quote        False
# 93     en-US     US    EQUITY   Equity           Delayed Quote        False
# 94     en-US     US    EQUITY   Equity           Delayed Quote        False
# 95     en-US     US    EQUITY   Equity           Delayed Quote        False
# 96     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 97     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 98     en-US     US    EQUITY   Equity           Delayed Quote        False
# 99     en-US     US    EQUITY   Equity           Delayed Quote        False
# 100    en-US     US    EQUITY   Equity           Delayed Quote        False
# 101    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 102    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 103    en-US     US    EQUITY   Equity           Delayed Quote        False
# 104    en-US     US    EQUITY   Equity           Delayed Quote        False
# 105    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 106    en-US     US    EQUITY   Equity           Delayed Quote        False
# 107    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 108    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 109    en-US     US    EQUITY   Equity           Delayed Quote        False
# 110    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 111    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 112    en-US     US    EQUITY   Equity           Delayed Quote        False
# 113    en-US     US    EQUITY   Equity           Delayed Quote        False
# 114    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 115    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 116    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 117    en-US     US    EQUITY   Equity           Delayed Quote        False
# 118    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 119    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 120    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 121    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 122    en-US     US    EQUITY   Equity           Delayed Quote        False
# 123    en-US     US    EQUITY   Equity           Delayed Quote        False
# 124    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 125    en-US     US    EQUITY   Equity           Delayed Quote        False
# 126    en-US     US    EQUITY   Equity           Delayed Quote        False
# 127    en-US     US    EQUITY   Equity           Delayed Quote         True
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 131    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
# 133    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 134    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 135    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 136    en-US     US    EQUITY   Equity           Delayed Quote        False
# 137    en-US     US    EQUITY   Equity           Delayed Quote        False
# 138    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 139    en-US     US    EQUITY   Equity           Delayed Quote        False
# 140    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 141    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 142    en-US     US    EQUITY   Equity           Delayed Quote        False
# 143    en-US     US    EQUITY   Equity           Delayed Quote         True
# 144    en-US     US    EQUITY   Equity           Delayed Quote         True
# 145    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 146    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 147    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 148    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 149    en-US     US    EQUITY   Equity           Delayed Quote        False
# 150    en-US     US    EQUITY   Equity           Delayed Quote        False
# 151    en-US     US    EQUITY   Equity           Delayed Quote         True
# 152    en-US     US    EQUITY   Equity           Delayed Quote        False
# 153    en-US     US    EQUITY   Equity           Delayed Quote        False
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote        False
# 156    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#     customPriceAlertConfidence currency  regularMarketChangePercent  \
# 0                         HIGH      USD                    1.733230
# 1                         HIGH      USD                   -2.922080
# 2                          LOW      USD                   -2.209940
# 3                         HIGH      USD                   -8.197020
# 4                          LOW      USD                   -1.054480
# 5                         HIGH      USD                    0.155865
# 6                         HIGH      USD                   -3.661140
# 7                         HIGH      USD                   -0.231907
# 8                         HIGH      USD                   -9.621450
# 9                         HIGH      USD                   -0.182115
# 10                        HIGH      USD                    2.470260
# 11                         LOW      USD                   -1.764370
# 12                        HIGH      USD                    2.187210
# 13                        HIGH      USD                    1.586070
# 14                        HIGH      USD                   -0.146945
# 15                         LOW      USD                   -1.829270
# 16                        HIGH      USD                    1.725880
# 17                        HIGH      USD                    1.019820
# 18                         LOW      USD                    0.519319
# 19                         LOW      USD                    2.440720
# 20                         LOW      USD                   -3.277060
# 21                         LOW      USD                   -1.634620
# 22                         LOW      USD                   -1.558840
# 23                         LOW      USD                   -3.194330
# 24                         LOW      USD                   -3.869040
# 25                         LOW      USD                   -0.509686
# 26                         LOW      USD                    0.612613
# 27                         LOW      USD                   -1.550390
# 28                         LOW      USD                   -2.976520
# 29                        HIGH      USD                   -1.070160
# 30                         LOW      USD                   -0.883531
# 31                         LOW      USD                   -3.122960
# 32                        HIGH      USD                   -0.479726
# 33                         LOW      USD                   -1.592360
# 34                        HIGH      USD                    1.729950
# 35                         LOW      USD                   -9.647420
# 36                         LOW      USD                    1.034020
# 37                        HIGH      USD                    1.769530
# 38                        HIGH      USD                    1.050910
# 39                        HIGH      USD                    0.990375
# 40                        HIGH      USD                   -0.480912
# 41                        HIGH      USD                   -1.173520
# 42                         LOW      USD                   -7.350100
# 43                         LOW      USD                   -3.982300
# 44                         LOW      USD                   -1.204240
# 45                         LOW      USD                    0.203113
# 46                         LOW      USD                    0.560228
# 47                         LOW      USD                    2.846970
# 48                         LOW      USD                   -1.732900
# 49                        HIGH      USD                   -2.376100
# 50                         LOW      USD                   -1.595740
# 51                         LOW      USD                   -8.328190
# 52                        HIGH      USD                    0.085784
# 53                         LOW      USD                   -3.371710
# 54                         LOW      USD                   -1.794650
# 55                         LOW      USD                   -1.156680
# 56                        HIGH      USD                   -0.279024
# 57                         LOW      USD                    0.686951
# 58                         LOW      USD                   -1.166590
# 59                         LOW      USD                   -0.209517
# 60                         LOW      USD                   -0.625064
# 61                        HIGH      USD                    1.934830
# 62                         LOW      USD                  -13.338400
# 63                         LOW      USD                   -0.579836
# 64                         LOW      USD                   10.813000
# 65                         LOW      USD                    0.384460
# 66                        HIGH      USD                    0.545230
# 67                         LOW      USD                    0.146532
# 68                         LOW      USD                  -11.164500
# 69                         LOW      USD                    0.528442
# 70                         LOW      USD                  -17.451400
# 71                         LOW      USD                   -4.173440
# 72                         LOW      USD                    0.437200
# 73                         LOW      USD                   -2.377180
# 74                         LOW      USD                   -0.317552
# 75                         LOW      USD                   -2.268670
# 76                         LOW      USD                   -1.309760
# 77                        HIGH      USD                   -1.355730
# 78                         LOW      USD                   -1.486920
# 79                         LOW      USD                   -0.496867
# 80                        HIGH      USD                    0.700309
# 81                        HIGH      USD                   -2.314430
# 82                        HIGH      USD                   -6.995470
# 83                         LOW      USD                   -0.805275
# 84                        HIGH      USD                   -1.740290
# 85                        HIGH      USD                    1.513170
# 86                         LOW      USD                   -0.265459
# 87                        HIGH      USD                   -3.164560
# 88                         LOW      USD                   -2.645290
# 89                        HIGH      USD                   -4.545450
# 90                         LOW      USD                   -0.429903
# 91                         LOW      USD                   -0.070772
# 92                         LOW      USD                   -0.734152
# 93                         LOW      USD                    4.251390
# 94                         LOW      USD                    3.723560
# 95                         LOW      USD                   -1.115960
# 96                        HIGH      USD                   -0.650493
# 97                         LOW      USD                    1.418810
# 98                         LOW      USD                   -5.584510
# 99                         LOW      USD                   -0.742034
# 100                        LOW      USD                   -0.907029
# 101                       HIGH      USD                   -0.774076
# 102                       HIGH      USD                   -0.211042
# 103                        LOW      USD                   -0.538691
# 104                        LOW      USD                   -4.045890
# 105                        LOW      USD                    0.179631
# 106                        LOW      USD                  -15.864000
# 107                        LOW      USD                   -0.625978
# 108                        LOW      USD                    0.215232
# 109                        LOW      USD                   -0.158150
# 110                       HIGH      USD                   -1.195820
# 111                       HIGH      USD                    0.593551
# 112                        LOW      USD                    0.522308
# 113                        LOW      USD                    1.593200
# 114                       HIGH      USD                   -0.300670
# 115                       HIGH      USD                    0.274224
# 116                       HIGH      USD                    1.777780
# 117                        LOW      USD                   22.945300
# 118                        LOW      USD                    1.835250
# 119                        LOW      USD                   -1.576260
# 120                       HIGH      USD                   -0.432780
# 121                       HIGH      USD                   -5.742050
# 122                        LOW      USD                   -0.102619
# 123                        LOW      USD                  -10.836800
# 124                       HIGH      USD                   -1.699750
# 125                        LOW      USD                   -0.747657
# 126                        LOW      USD                   -0.371530
# 127                       HIGH      USD                    1.054190
# 128                       HIGH      USD                    0.948767
# 129                        LOW      USD                   -0.046643
# 130                       HIGH      USD                   -0.469639
# 131                        LOW      USD                    0.203919
# 132                        LOW      USD                   -1.507090
# 133                       HIGH      USD                    1.781740
# 134                        LOW      USD                   -0.811556
# 135                       HIGH      USD                    2.179400
# 136                        LOW      USD                    4.313010
# 137                        LOW      USD                    0.564817
# 138                       HIGH      USD                    2.871520
# 139                        LOW      USD                   -0.965904
# 140                        LOW      USD                   -0.079138
# 141                       HIGH      USD                   -4.050890
# 142                        LOW      USD                   -1.202890
# 143                       HIGH      USD                    0.528451
# 144                       HIGH      USD                   -0.116994
# 145                       HIGH      USD                    1.280120
# 146                        LOW      USD                   -2.530660
# 147                       HIGH      USD                    0.973799
# 148                        LOW      USD                   -0.420612
# 149                        LOW      USD                   -0.213539
# 150                        LOW      USD                   -0.143366
# 151                       HIGH      USD                   -0.276034
# 152                        LOW      USD                   -0.464981
# 153                        LOW      USD                   -0.099882
# 154                       HIGH      USD                   -7.676580
# 155                        LOW      USD                   -3.704550
# 156                       HIGH      USD                    5.800880
#
#      hasPrePostMarketData  firstTradeDateMilliseconds  priceHint  \
# 0                    True                917015400000          2
# 1                    True               1600435800000          4
# 2                    True                941203800000          4
# 3                    True               1277818200000          2
# 4                    True                 76253400000          2
# 5                    True               1601472600000          2
# 6                    True                322151400000          2
# 7                    True               1609770600000          2
# 8                    True               1127827800000          2
# 9                    True                345479400000          2
# 10                   True               1649856600000          2
# 11                   True               1336138200000          2
# 12                   True                322151400000          2
# 13                   True               1175175000000          2
# 14                   True               1627565400000          2
# 15                   True               1536759000000          4
# 16                   True                863703000000          2
# 17                   True               1092922200000          2
# 18                   True                 99153000000          2
# 19                   True               1459431000000          2
# 20                   True               1488465000000          2
# 21                   True               1016721000000          2
# 22                   True               1597671000000          2
# 23                   True                 99153000000          2
# 24                   True               1521552600000          4
# 25                   True               1337088600000          2
# 26                   True                438273000000          2
# 27                   True               1014647400000          2
# 28                   True               1170340200000          2
# 29                   True                322151400000          2
# 30                   True               1479306600000          2
# 31                   True                554131800000          2
# 32                   True               1438781400000          2
# 33                   True                322151400000          2
# 34                   True                454944600000          2
# 35                   True                864221400000          2
# 36                   True               1557495000000          2
# 37                   True               1249565400000          2
# 38                   True                962371800000          2
# 39                   True                511108200000          2
# 40                   True                635178600000          2
# 41                   True                322151400000          2
# 42                   True               1276090200000          2
# 43                   True                773069400000          4
# 44                   True               1445261400000          2
# 45                   True                 76253400000          2
# 46                   True                438273000000          2
# 47                   True               1516372200000          2
# 48                   True                344615400000          2
# 49                   True               1553866200000          2
# 50                   True                563121000000          2
# 51                   True               1596720600000          2
# 52                   True                342109800000          2
# 53                   True               1358519400000          2
# 54                   True               1013610600000          2
# 55                   True                322151400000          2
# 56                   True               1618407000000          2
# 57                   True               1592832600000          2
# 58                   True               1411133400000          2
# 59                   True               1600435800000          2
# 60                   True                221149800000          2
# 61                   True               1572615000000          2
# 62                   True               1138285800000          2
# 63                   True                805383000000          2
# 64                   True                706282200000          2
# 65                   True                511021800000          2
# 66                   True                897571800000          2
# 67                   True                322151400000          2
# 68                   True                315671400000          2
# 69                   True                876403800000          2
# 70                   True               1553088600000          2
# 71                   True                921162600000          2
# 72                   True               1474464600000          2
# 73                   True               1619011800000          2
# 74                   True               1555594200000          2
# 75                   True               1178199000000          2
# 76                   True               1615473000000          2
# 77                   True               1400765400000          2
# 78                   True               1290090600000          2
# 79                   True                105283800000          2
# 80                   True                452525400000          2
# 81                   True                709565400000          2
# 82                   True                957274200000          2
# 83                   True               -252322200000          2
# 84                   True               1564061400000          2
# 85                   True               1436189400000          2
# 86                   True                322151400000          2
# 87                   True               1625146200000          2
# 88                   True               1333114200000          2
# 89                   True               1403789400000          4
# 90                   True               1615386600000          2
# 91                   True                322151400000          2
# 92                   True               -252322200000          2
# 93                   True                766330200000          2
# 94                   True                689610600000          2
# 95                   True               -252322200000          2
# 96                   True                692634600000          2
# 97                   True                559315800000          2
# 98                   True                322151400000          2
# 99                   True                322237800000          2
# 100                  True               1159795800000          2
# 101                  True               1139236200000          2
# 102                  True               1532611800000          2
# 103                  True               1607956200000          2
# 104                  True               1623331800000          2
# 105                  True               1087997400000          2
# 106                  True                786897000000          2
# 107                  True                697300200000          2
# 108                  True               1560519000000          2
# 109                  True                928935000000          2
# 110                  True                763914600000          2
# 111                  True                322151400000          2
# 112                  True               1533216600000          2
# 113                  True               1598535000000          2
# 114                  True                 76253400000          2
# 115                  True               1610548200000          2
# 116                  True               1568899800000          2
# 117                  True               1532525400000          2
# 118                  True               -252322200000          2
# 119                  True               1544625000000          2
# 120                  True                278692200000          2
# 121                  True                326467800000          2
# 122                  True               1625059800000          2
# 123                  True               1607524200000          2
# 124                  True               1608129000000          2
# 125                  True               -252322200000          2
# 126                  True               1205933400000          2
# 127                  True                556464600000          2
# 128                  True               1624541400000          2
# 129                  True                809357400000          2
# 130                  True                761495400000          2
# 131                  True                730477800000          2
# 132                  True                322151400000          2
# 133                  True               1429191000000          2
# 134                  True               -244546200000          2
# 135                  True               1178285400000          2
# 136                  True               1103121000000          2
# 137                  True                570205800000          2
# 138                  True                735571800000          2
# 139                  True                942244200000          2
# 140                  True                551712600000          2
# 141                  True               1411392600000          2
# 142                  True               1411565400000          2
# 143                  True               1163773800000          2
# 144                  True                322151400000          2
# 145                  True               1607610600000          2
# 146                  True                578583000000          2
# 147                  True               1342791000000          2
# 148                  True                831648600000          2
# 149                  True               1584624600000          2
# 150                  True                378657000000          2
# 151                  True               1258554600000          2
# 152                  True                954253800000          2
# 153                  True                559834200000          2
# 154                  True                764001000000          2
# 155                  True                784996200000          2
# 156                  True               1176989400000          2
#
#      postMarketChangePercent  postMarketTime  postMarketPrice  \
# 0                  -0.089213      1753401598         173.5850
# 1                  -0.334448      1753401588           2.9800
# 2                  -0.016945      1753401569           1.7697
# 3                   0.569938      1753401597         307.0400
# 4                   0.177615      1753401598          11.2800
# 5                  -0.051661      1753401599         154.7800
# 6                  -4.595670      1753401597          21.5900
# 7                   0.140395      1753401597          21.5402
# 8                   0.698080      1753401598          11.5400
# 9                   0.135670      1753401580         214.0500
# 10                  0.089288      1753401599          11.2100
# 11                  0.062569      1753401594          17.2708
# 12                  1.431100      1753401597         164.4400
# 13                  0.038082      1753401598          52.5400
# 14                  0.058959      1753401591         101.9900
# 15                  0.000000      1753401598           4.8300
# 16                  0.150715      1753401592         232.5800
# 17                  0.145704      1753401594         192.4500
# 18                 -0.010335      1753401586          48.3850
# 19                  0.204225      1753401568          14.7200
# 20                  0.512321      1753401559           9.7899
# 21                  0.000000      1753401600          10.2300
# 22                 -0.514652      1753401590          12.5650
# 23                  0.458297      1753401596          10.9600
# 24                  0.619194      1753401534           3.2500
# 25                  0.000000      1753401482           9.7600
# 26                 -0.107452      1753401570          27.8900
# 27                  0.629921      1753400446           6.3900
# 28                  0.294981      1753401589          17.0000
# 29                  0.360585      1753401536          16.7000
# 30                  0.323337      1753401520          12.3799
# 31                  0.235056      1753401586          29.8500
# 32                 -0.189031      1753401594          10.5600
# 33                  0.161816      1753401508           6.1900
# 34                  0.465493      1753401597         112.2500
# 35                  2.744420      1753401591          23.9600
# 36                  0.231098      1753401599          91.0800
# 37                  0.084140      1753401588         288.9530
# 38                  0.351164      1753401593          74.3000
# 39                  0.178848      1753401595         511.7940
# 40                  0.232245      1753401479          68.4486
# 41                 -0.197907      1753401571          35.3000
# 42                  0.939459      1753401597           9.6700
# 43                  0.691238      1753401583           4.3700
# 44                  0.290101      1753401539          20.5695
# 45                  0.154999      1753401434          84.0000
# 46                  0.069635      1753401600          43.1100
# 47                 -3.229524      1753401300           8.3900
# 48                  0.197563      1753401585          75.5690
# 49                  0.417242      1753401564          14.4400
# 50                 -0.214592      1753397070          18.4603
# 51                 -0.201882      1753401565          14.8300
# 52                  0.028861      1753401489          35.0101
# 53                  0.000000      1753401479          23.5000
# 54                 -0.114749      1753401590          23.5030
# 55                  0.744688      1753401594           9.4700
# 56                 -0.103354      1753401599         396.2900
# 57                  0.031027      1753401574          61.5791
# 58                  0.049523      1753401584         121.2100
# 59                  0.419914      1753401600          33.4800
# 60                  0.062897      1753401536          95.4500
# 61                 -7.342660      1753401594          55.6500
# 62                  0.024486      1753401592          45.7512
# 63                  0.000000      1753401061          44.5800
# 64                  0.217169      1753401597          13.6596
# 65                  0.020592      1753401575         242.8800
# 66                 -0.416950      1753401599         413.1900
# 67                  3.968140      1753401594          63.9508
# 68                  0.270596      1753401507          33.3500
# 69                  0.765725      1753401588         243.4500
# 70                  0.358995      1753401581          25.1600
# 71                  0.169676      1753401152          17.7100
# 72                  0.117645      1753401497          85.1000
# 73                  0.081171      1753401550          12.3300
# 74                  1.008760      1753401582          38.0500
# 75                  0.073114      1753401593          54.7500
# 76                  0.033515      1753401239          30.1501
# 77                  0.028676      1753401594          33.4796
# 78                  0.095528      1753401570          52.3900
# 79                  0.434210      1753401449          46.2600
# 80                 -0.818159      1753401513          96.9800
# 81                  0.245468      1753401388          93.9300
# 82                  0.551411      1753401403          55.7457
# 83                  0.008202      1753401588         121.9600
# 84                  0.000000      1753401554          44.0400
# 85                  0.693910      1753401441          78.3600
# 86                  0.456277      1753399690          26.4200
# 87                  0.368623      1753400770           7.6782
# 88                 -0.041955      1753401592          35.5001
# 89                 -2.721090      1753401576           1.4300
# 90                  0.237046      1753401596         118.4000
# 91                  0.050590      1753401541         296.7000
# 92                  0.622810      1753400545          25.8500
# 93                  2.393621      1753401600          11.5500
# 94                  0.995597      1753401600         105.5000
# 95                  0.445366      1753401600         232.3000
# 96                  0.076688      1753401201         158.9620
# 97                  1.409330      1753401586          97.8600
# 98                  0.946371      1753401600          12.8000
# 99                  0.791558      1753396879          45.8400
# 100                -0.328374      1753400490           8.7113
# 101                 0.033543      1753401483          89.7601
# 102                 0.077746      1753401544         118.3020
# 103                 0.000000      1753401399          20.3100
# 104                 0.692257      1753401580          16.0000
# 105                 0.183037      1753401595         268.1900
# 106                 0.598578      1753401552          26.8900
# 107                 0.000000      1753401598          12.7000
# 108                 0.134226      1753401559          37.3000
# 109                 0.586090      1753400399          63.5000
# 110                 0.551115      1753400705          46.5250
# 111                -0.823936      1753401423         186.5700
# 112                 0.596010      1753401600         131.6500
# 113                 0.235233      1753401600          19.1750
# 114                -0.032417      1753401566         185.6300
# 115                 0.531751      1753401502          66.1700
# 116                 0.211516      1753401462         146.8700
# 117                 0.120983      1753401600          33.1000
# 118                 0.186560      1753401584         268.5100
# 119                 0.141313      1753401229          21.2600
# 120                 0.688071      1753399943          69.4949
# 121                 0.562319      1753401113          10.7300
# 122                 0.564975      1753401495          19.5800
# 123                 1.153843      1753401600          26.3000
# 124                 0.347649      1753401512          82.9875
# 125                -0.156940      1753401600          31.8100
# 126                 0.011303      1753401600         354.0100
# 127                 0.187774      1753401313          48.0200
# 128                -2.048119      1753401221          26.0552
# 129                 0.326181      1753400779          21.4999
# 130                 1.584090      1753401566          60.2800
# 131                -0.456136      1753401572         141.8500
# 132                -2.700263      1753400844          21.6200
# 133                 0.656458      1753401063          64.4000
# 134                 0.000000      1753401599         155.2200
# 135                 0.309126      1753401490          64.9000
# 136                -0.157515      1753401261          50.7100
# 137                -0.775611      1753396878          37.1000
# 138                 0.397310      1753401564          98.5500
# 139                 0.013945      1753401600         102.5443
# 140                 0.190082      1753401572         126.5000
# 141                 0.767618      1753400985          28.8800
# 142                 0.426142      1753400365          49.4900
# 143                 0.320939      1753401391         181.3000
# 144                 0.000000      1753400689          42.6900
# 145                 0.197711      1753399860         141.9000
# 146                 0.133831      1753401411          37.4100
# 147                 0.019881      1753401550         201.2000
# 148                 0.276735      1753401590         481.9300
# 149                 0.704931      1753399371          80.0000
# 150                -0.305100      1753401097          55.5500
# 151                -0.257704      1753401010         104.5000
# 152                 0.000000      1753400548          34.2500
# 153                 0.436287      1753401099         110.5000
# 154                 1.671030      1753400980          50.5000
# 155                 0.444803      1753401469         212.2700
# 156                -0.197939      1753401399         247.0100
#
#      postMarketChange  regularMarketChange  regularMarketTime  \
# 0           -0.154999             2.960010         1753387200
# 1           -0.010000            -0.090000         1753387202
# 2           -0.000300            -0.040000         1753387200
# 3            1.740020           -27.260000         1753387201
# 4            0.019999            -0.120000         1753387202
# 5           -0.080002             0.240997         1753387200
# 6           -1.040000            -0.860001         1753387201
# 7            0.030199            -0.049999         1753387201
# 8            0.080000            -1.220000         1753387201
# 9            0.290009            -0.389999         1753387201
# 10           0.010000             0.270000         1753387201
# 11           0.010799            -0.309999         1753387201
# 12           2.320100             3.470000         1753387201
# 13           0.020001             0.820000         1753387201
# 14           0.060097            -0.150002         1753387200
# 15           0.000000            -0.090000         1753387202
# 16           0.350006             3.940000         1753387201
# 17           0.279999             1.940000         1753387201
# 18          -0.005001             0.250000         1753387202
# 19           0.030001             0.349999         1753387200
# 20           0.049900            -0.330000         1753387202
# 21           0.000000            -0.170000         1753387202
# 22          -0.065001            -0.200000         1753387202
# 23           0.050000            -0.360001         1753387202
# 24           0.020000            -0.130000         1753387201
# 25           0.000000            -0.050000         1753387202
# 26          -0.030001             0.170000         1753387294
# 27           0.040000            -0.100000         1753387202
# 28           0.049999            -0.519999         1753387201
# 29           0.060001            -0.180000         1753387201
# 30           0.039900            -0.110000         1753387202
# 31           0.070000            -0.959999         1753387202
# 32          -0.019999            -0.051000         1753387200
# 33           0.010000            -0.100000         1753387202
# 34           0.520096             1.900000         1753387201
# 35           0.639999            -2.490000         1753387201
# 36           0.209999             0.930000         1753387202
# 37           0.242920             5.019990         1753387201
# 38           0.260002             0.770004         1753387201
# 39           0.913696             5.010010         1753387200
# 40           0.158600            -0.330002         1753387200
# 41          -0.070000            -0.420002         1753387201
# 42           0.090000            -0.760000         1753387202
# 43           0.030000            -0.180000         1753387202
# 44           0.059500            -0.250000         1753387298
# 45           0.129997             0.170006         1753387231
# 46           0.029999             0.240002         1753387202
# 47          -0.280000             0.240000         1753387202
# 48           0.149002            -1.330000         1753387202
# ...
# dtype: float64    2.127771             12.5
# 5        Ticker
# PLTR    0.000014
# dtype: float64    3.987127             12.5
# 6        Ticker
# INTC   -0.000006
# dtype: float64    0.426554              0.0
# 7        Ticker
# SOFI    0.000007
# dtype: float64    1.140148             37.5
# 8         Ticker
# AAL   -0.000023
# dtype: float64    0.431184              0.0
# 9        Ticker
# AAPL    0.000005
# dtype: float64    4.200115              0.0
# 10       Ticker
# APLD    0.000041
# dtype: float64    0.863715             37.5
# 11       Ticker
# MARA   -0.000043
# dtype: float64    0.680760             12.5
# 12        Ticker
# AMD    0.000016
# dtype: float64    1.913192             87.5
# 13       Ticker
# SMCI   -0.000002
# dtype: float64    1.571378             25.0
# 14       Ticker
# HOOD    0.000008
# dtype: float64    0.698600             87.5
# 15        Ticker
# NIO    0.000057
# dtype: float64    1.207221              0.0
# 16       Ticker
# AMZN    0.000012
# dtype: float64    3.112859             25.0
# 17      Ticker
# GOOGL    0.000017
# dtype: float64    0.408147             12.5
# 18        Ticker
# BAC    0.000019
# dtype: float64    3.065513             12.5
# 19       Ticker
# RIOT    0.000062
# dtype: float64    1.625889             25.0
# 20        Ticker
# SNAP    0.00001
# dtype: float64    1.821388              0.0
# 21       Ticker
# VALE    0.000019
# dtype: float64    0.993045              0.0
# 22         Ticker
# QS    0.000075
# dtype: float64    0.765221             25.0
# 23         Ticker
# CLF    0.00007
# dtype: float64    0.603553              0.0
# 24       Ticker
# BTBT   -0.000024
# dtype: float64    1.103670             12.5
# 25       Ticker
# AMCR    0.000012
# dtype: float64    3.131388              0.0
# 26          Ticker
# T    0.000013
# dtype: float64    0.485712             37.5
# 27       Ticker
# ITUB    0.000003
# dtype: float64    3.283965              0.0
# 28       Ticker
# QUBT   -0.000023
# dtype: float64    1.495613             25.0
# 29       Ticker
# HBAN    0.000001
# dtype: float64    4.500055             75.0
# 30       Ticker
# CLSK   -0.000006
# dtype: float64    1.503012             25.0
# 31        Ticker
# CCL    0.000008
# dtype: float64    2.301335             75.0
# 32        Ticker
# RUN   -0.000006
# dtype: float64    0.623989             75.0
# 33         Ticker
# HL    0.000004
# dtype: float64    1.051563              0.0
# 34         Ticker
# MU   -0.000021
# dtype: float64    2.370738             75.0
# 35       Ticker
# SBET   -0.000103
# dtype: float64    0.244663              0.0
# 36       Ticker
# UBER   -0.000004
# dtype: float64    1.671019              0.0
# 37       Ticker
# AVGO    0.000013
# dtype: float64    0.786804             50.0
# 38       Ticker
# MRVL    0.000025
# dtype: float64    1.418565              0.0
# 39       Ticker
# MSFT    0.000005
# dtype: float64    2.242567             87.5
# 40       Ticker
# CSCO    0.000005
# dtype: float64    5.283711             62.5
# 41      Ticker
# CMCSA    0.000006
# dtype: float64    2.681311              0.0
# 42       Ticker
# STLA    0.000007
# dtype: float64    0.037772              0.0
# 43        Ticker
# NOK   -0.000031
# dtype: float64    0.277220              0.0
# 44        Ticker
# HPE    0.000002
# dtype: float64    0.944761            100.0
# 45        Ticker
# WFC    0.000023
# dtype: float64    3.992441             50.0
# 46         Ticker
# VZ    0.000017
# dtype: float64    0.478282              0.0
# 47        Ticker
# ADT    0.000014
# dtype: float64    2.399548              0.0
# 48        Ticker
# NKE    0.000015
# dtype: float64    3.233499             37.5
# 49       Ticker
# LYFT   -0.000014
# dtype: float64    2.942359              0.0
# 50        Ticker
# KEY    0.000012
# dtype: float64    2.560131             37.5
# 51         Ticker
# RKT    0.00004
# dtype: float64    0.879635             25.0
# 52        Ticker
# CSX    0.000016
# dtype: float64    2.283516             37.5
# 53       Ticker
# NCLH    0.000009
# dtype: float64    1.843008              0.0
# 54        Ticker
# GME    0.000001
# dtype: float64    2.536112              0.0
# 55        Ticker
# CDE    0.000007
# dtype: float64    1.466223             37.5
# 56       Ticker
# COIN    0.000005
# dtype: float64    1.639628             75.0
# 57         Ticker
# MP    0.000011
# dtype: float64    1.500085              0.0
# 58       Ticker
# BABA    0.000018
# dtype: float64    2.348221              0.0
# 59          Ticker
# U    0.000013
# dtype: float64    0.979087              0.0
# 60          Ticker
# C    0.000017
# dtype: float64    2.883172             75.0
# 61       Ticker
# ASTS    0.000057
# dtype: float64    1.066761             87.5
# 62        Ticker
# CMG   -0.000057
# dtype: float64    0.010479              0.0
# 63        Ticker
# FCX    0.000005
# dtype: float64    0.884437             62.5
# 64        Ticker
# KSS    0.000241
# dtype: float64    0.459875             12.5
# 65       Ticker
# ORCL    0.000013
# dtype: float64    3.931204             75.0
# 66       Ticker
# MSTR   -0.000027
# dtype: float64    2.205721             37.5
# 67        Ticker
# NEM    0.000022
# dtype: float64    0.332456             25.0
# 68        Ticker
# LUV   -0.000042
# dtype: float64    0.509476              0.0
# 69        Ticker
# TSM    0.000009
# dtype: float64    0.366781             62.5
# 70        Ticker
# DOW   -0.000039
# dtype: float64    0.021383              0.0
# 71       Ticker
# INFY   -0.000016
# dtype: float64    0.491329              0.0
# 72        Ticker
# TTD    0.000014
# dtype: float64    2.323323              0.0
# 73       Ticker
# PATH   -0.000002
# dtype: float64    2.110176              0.0
# 74       Ticker
# PINS    0.000012
# dtype: float64    0.433942              0.0
# 75         Ticker
# DAL   -0.00001
# dtype: float64    2.765857             25.0
# 76       Ticker
# CPNG   -0.000012
# dtype: float64    2.711474             50.0
# 77         Ticker
# JD    0.000021
# dtype: float64    1.357985              0.0
# 78         Ticker
# GM   -0.000003
# dtype: float64    1.082829              0.0
# 79        Ticker
# USB    0.000002
# dtype: float64    2.694916             25.0
# 80   Ticker
# LRCX    4.387284e-07
# dtype: float64    2.046476             37.5
# 81       Ticker
# SBUX    0.000004
# dtype: float64    2.012133              0.0
# 82          Ticker
# ON   -0.00002
# dtype: float64    0.220217             50.0
# 83        Ticker
# DIS    0.000008
# dtype: float64    5.691157             37.5
# 84   Ticker
# DKNG   -2.938981e-07
# dtype: float64    2.456464             62.5
# 85       Ticker
# PYPL    0.000023
# dtype: float64    2.621720              0.0
# 86         Ticker
# RF    0.000033
# dtype: float64    1.466650             62.5
# 87        Ticker
# HTZ   -0.000007
# dtype: float64    1.158059             37.5
# 88       Ticker
# ENPH   -0.000045
# dtype: float64    0.460155              0.0
# 89       Ticker
# GPRO    0.000338
# dtype: float64    0.113061             12.5
# 90       Ticker
# RBLX    0.000017
# dtype: float64    3.212210             87.5
# 91        Ticker
# JPM    0.000011
# dtype: float64    5.130328             62.5
# 92        Ticker
# HPQ    0.000018
# dtype: float64    3.865950              0.0
# 93        Ticker
# AEO    0.000041
# dtype: float64    0.293044              0.0
# 94        Ticker
# APH    0.000018
# dtype: float64    2.765765             75.0
# 95         Ticker
# BA   -0.000002
# dtype: float64    2.529938             25.0
# 96       Ticker
# QCOM    0.000011
# dtype: float64    1.448709              0.0
# 97       Ticker
# SCHW    0.000019
# dtype: float64    1.620047             75.0
# 98        Ticker
# VFC    0.000025
# dtype: float64    0.431900              0.0
# 99        Ticker
# TFC    0.000007
# dtype: float64    5.399839             62.5
# 100        Ticker
# WU    0.000028
# dtype: float64    1.939999              0.0
# 101       Ticker
# UAL    0.000009
# dtype: float64    0.976167             12.5
# 102       Ticker
# PDD    0.000048
# dtype: float64    0.406891              0.0
# 103       Ticker
# OWL    0.000025
# dtype: float64    2.138932              0.0
# 104      Ticker
# ZETA    0.000037
# dtype: float64    1.458503              0.0
# 105       Ticker
# CRM    0.000013
# dtype: float64    3.636508              0.0
# 106       Ticker
# STM   -0.000054
# dtype: float64    0.103931             62.5
# 107         Ticker
# M    0.000019
# dtype: float64    0.264806              0.0
# 108      Ticker
# CHWY   -0.000011
# dtype: float64    2.796286             37.5
# 109   Ticker
# SKX    5.355872e-07
# dtype: float64   17.169827             75.0
# 110  Ticker
# CPRT    9.986030e-07
# dtype: float64    3.509847              0.0
# 111       Ticker
# AMAT   -0.00001
# dtype: float64    1.679231             75.0
# 112       Ticker
# VRT    0.000009
# dtype: float64    1.680711             25.0
# 113      Ticker
# XPEV    0.000027
# dtype: float64    1.133678              0.0
# 114       Ticker
# TXN   -0.000057
# dtype: float64    0.055577             25.0
# 115      Ticker
# AFRM   -0.000009
# dtype: float64    1.156986             25.0
# 116      Ticker
# DDOG    0.000019
# dtype: float64    2.344699             50.0
# 117        Ticker
# BE    0.000105
# dtype: float64    0.047863             25.0
# 118        Ticker
# GE    0.000006
# dtype: float64    2.496172             37.5
# 119       Ticker
# TME   -0.000005
# dtype: float64    1.174687             37.5
# 120       Ticker
# WDC    0.000009
# dtype: float64    2.116060            100.0
# 121       Ticker
# WEN    0.000007
# dtype: float64    0.237026              0.0
# 122         Ticker
# S    0.000037
# dtype: float64    0.253314              0.0
# 123        Ticker
# AI   -0.000014
# dtype: float64    0.226879              0.0
# 124      Ticker
# UPST    0.000038
# dtype: float64    1.291586             12.5
# 125         Ticker
# AA    0.00004
# dtype: float64    0.794894              0.0
# 126         Ticker
# V    0.000007
# dtype: float64    4.841256              0.0
# 127      Ticker
# FAST    0.000021
# dtype: float64    4.849200             37.5
# 128      Ticker
# CFLT    0.000028
# dtype: float64    1.267576              0.0
# 129        Ticker
# IVZ    0.00009
# dtype: float64    1.711892             50.0
# 130      Ticker
# TSCO    0.000019
# dtype: float64    0.878261             62.5
# 131         Ticker
# MS    0.00001
# dtype: float64    3.598833             50.0
# 132       Ticker
# FHN    0.000012
# dtype: float64    3.882617             75.0
# 133      Ticker
# ETSY    0.000048
# dtype: float64    0.545412             37.5
# 134       Ticker
# RTX    0.000015
# dtype: float64    1.441593              0.0
# 135       Ticker
# IBKR    0.00003
# dtype: float64    0.790865             50.0
# 136       Ticker
# LVS    0.000009
# dtype: float64    0.665032             50.0
# 137       Ticker
# MOS    0.000015
# dtype: float64    1.585658             25.0
# 138      Ticker
# ORLY    0.000025
# dtype: float64    2.202384              0.0
# 139        Ticker
# UPS    0.00001
# dtype: float64    1.464246              0.0
# 140       Ticker
# TJX    0.000013
# dtype: float64    5.193793             12.5
# 141       Ticker
# CZR   -0.000021
# dtype: float64    1.048126              0.0
# 142       Ticker
# CFG    0.000018
# dtype: float64    4.906574             62.5
# 143      Ticker
# FSLR    0.000019
# dtype: float64    2.697374              0.0
# 144      Ticker
# FITB   -0.000002
# dtype: float64    3.627260             25.0
# 145      Ticker
# ABNB    0.000014
# dtype: float64    2.957013              0.0
# 146       Ticker
# MGM   -0.000004
# dtype: float64    1.499817             50.0
# 147      Ticker
# PANW    0.000016
# dtype: float64    2.773169              0.0
# 148     Ticker
# BRK-B    0.000009
# dtype: float64    5.361256              0.0
# 149      Ticker
# CARR    0.000019
# dtype: float64    2.269269             87.5
# 150       Ticker
# GLW    0.000021
# dtype: float64    2.822978             37.5
# 151  Ticker
# FTNT    1.678167e-07
# dtype: float64    2.888507              0.0
# 152       Ticker
# IBN    0.000011
# dtype: float64    0.412327              0.0
# 153       Ticker
# JCI    0.000012
# dtype: float64    3.139509             50.0
# 154      Ticker
# FLEX   -0.000012
# dtype: float64    2.591483             75.0
# 155       Ticker
# COF   -0.000008
# dtype: float64    0.269768             37.5
# 156      Ticker
# TMUS    0.000032
# dtype: float64    0.226838              0.0
#
#      pct_sell_last_8d
# 0                 0.0
# 1                 0.0
# 2                12.5
# 3                 0.0
# 4                 0.0
# 5                 0.0
# 6                12.5
# 7                 0.0
# 8                75.0
# 9                12.5
# 10                0.0
# 11                0.0
# 12                0.0
# 13                0.0
# 14                0.0
# 15                0.0
# 16                0.0
# 17                0.0
# 18                0.0
# 19                0.0
# 20               37.5
# 21                0.0
# 22                0.0
# 23               25.0
# 24                0.0
# 25               37.5
# 26                0.0
# 27                0.0
# 28                0.0
# 29                0.0
# 30                0.0
# 31                0.0
# 32                0.0
# 33                0.0
# 34                0.0
# 35                0.0
# 36                0.0
# 37                0.0
# 38               12.5
# 39                0.0
# 40                0.0
# 41                0.0
# 42                0.0
# 43               12.5
# 44                0.0
# 45                0.0
# 46                0.0
# 47                0.0
# 48                0.0
# 49                0.0
# 50                0.0
# 51                0.0
# 52                0.0
# 53                0.0
# 54               37.5
# 55                0.0
# 56                0.0
# 57                0.0
# 58                0.0
# 59                0.0
# 60                0.0
# 61                0.0
# 62                0.0
# 63                0.0
# 64                0.0
# 65                0.0
# 66                0.0
# 67                0.0
# 68                0.0
# 69                0.0
# 70                0.0
# 71                0.0
# 72               37.5
# 73                0.0
# 74                0.0
# 75                0.0
# 76                0.0
# 77                0.0
# 78                0.0
# 79               12.5
# 80                0.0
# 81               25.0
# 82                0.0
# 83                0.0
# 84                0.0
# 85                0.0
# 86                0.0
# 87                0.0
# 88                0.0
# 89               25.0
# 90                0.0
# 91                0.0
# 92                0.0
# 93                0.0
# 94                0.0
# 95                0.0
# 96                0.0
# 97                0.0
# 98                0.0
# 99                0.0
# 100              50.0
# 101               0.0
# 102               0.0
# 103               0.0
# 104              37.5
# 105               0.0
# 106               0.0
# 107              12.5
# 108               0.0
# 109               0.0
# 110              25.0
# 111               0.0
# 112               0.0
# 113               0.0
# 114              37.5
# 115               0.0
# 116               0.0
# 117               0.0
# 118               0.0
# 119               0.0
# 120               0.0
# 121              25.0
# 122              62.5
# 123               0.0
# 124               0.0
# 125               0.0
# 126               0.0
# 127               0.0
# 128               0.0
# 129               0.0
# 130               0.0
# 131               0.0
# 132               0.0
# 133               0.0
# 134               0.0
# 135               0.0
# 136               0.0
# 137               0.0
# 138               0.0
# 139               0.0
# 140               0.0
# 141              62.5
# 142               0.0
# 143               0.0
# 144               0.0
# 145               0.0
# 146               0.0
# 147               0.0
# 148              50.0
# 149               0.0
# 150               0.0
# 151               0.0
# 152               0.0
# 153               0.0
# 154               0.0
# 155               0.0
# 156               0.0

# %%
import datetime
filterdf["AvgReturn_7d"] = 0 
today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-07-25.csv
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Peer closed connection.
