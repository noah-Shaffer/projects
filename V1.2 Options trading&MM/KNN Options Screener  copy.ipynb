# %% [markdown]
# Do a random forest return predictor for long time equity screens, maybe including rates/ sectors / commodities / geoploitic indicators.
# Find the % of regimes in the last 30 days that have a higher volatility than the current IV
# Add trend in shannon entropy or/and regime percentages to evaluate recessions / hostile environments beginning. could also look at earnings timestamps affecting options prices

# %% [markdown]
# Want to find stocks with a low hv/iv high regime % in highest stdev state, and high # of days with stdev above avg iv on options

# %%
import yfinance as yf 
from yfinance import EquityQuery
import numpy as np
import pandas as pd
import time

# %%
from yfinance import EquityQuery, screen
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time
num_stocks = 250  # Number of stocks to process in each batch

# --- Helper Functions ---


def find_closest_value(data_list, target_value):
    if len(data_list) == 0:
        return None
    return min(data_list, key=lambda x: abs(x - target_value))


def filter_special_expiry(expiry_list):
    """Return the two soonest (earliest) expiry dates from the list."""
    sorted_expiries = sorted(expiry_list)
    return sorted_expiries[:2]


def get_prev_day_price_volume(symbol):
    """Fetch the most recent full day's close price and volume for the symbol."""
    try:
        data = yf.Ticker(symbol).history(period="5d")
        if data.shape[0] < 2:
            return None, None
        prev_day = data.iloc[-2]
        price = float(prev_day['Close'])
        volume = int(prev_day['Volume'])
        return price, volume
    except Exception as e:
        print(f"Error fetching previous day price/volume for {symbol}: {e}")
        return None, None


def get_historical_volatility(symbol, window=20):
    try:
        data = yf.Ticker(symbol).history(period=f"{window*2}d")
        if data.shape[0] < window + 1:
            return None
        data = data['Close'].dropna()
        log_returns = np.log(data / data.shift(1)).dropna()
        vol = log_returns[-window:].std() * np.sqrt(252)
        return vol
    except Exception as e:
        print(f"Error calculating historical volatility for {symbol}: {e}")
        return None


def get_options(symbol, max_retries=3, retry_delay=60):
    for attempt in range(max_retries):
        try:
            stock = yf.Ticker(symbol)
            options_chain = stock.options
            if not options_chain:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
            filtered_expiries = filter_special_expiry(options_chain)
            options_data = []
            current_price, _ = get_prev_day_price_volume(symbol)
            if current_price is None:
                continue
            for expiry in filtered_expiries:
                chain = stock.option_chain(expiry)
                for opt_type, df in [('call', chain.calls), ('put', chain.puts)]:
                    if not df.empty:
                        closest_strike = find_closest_value(df['strike'], current_price)
                        filtered = df[df['strike'] == closest_strike].copy()
                        filtered['type'] = opt_type
                        filtered['expiry'] = expiry
                        filtered['symbol'] = symbol
                        options_data.append(filtered)
            if options_data:
                result = pd.concat(options_data, ignore_index=True)
                result = result[result['openInterest'] > 500]
                return result[['strike', 'impliedVolatility', 'openInterest', 'symbol']]
            else:
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
        except Exception as e:
            print(f"Error fetching options for {symbol}: {e}")
            if attempt < max_retries - 1:
                time.sleep(retry_delay)
                continue
            else:
                print(f"Max retries reached for {symbol}.")
                return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])
    return pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])


# --- Screen Query ---
screen_query = EquityQuery("and", [
    EquityQuery("is-in", ["region", "us"]),
    EquityQuery("is-in", ["sector",
        "Technology",
        "Financial Services",
        "Consumer Cyclical",
        "Communication Services",
        "Basic Materials",
        "Industrials"
    ]),
    EquityQuery("GTE", ["eodprice", 0.50]),
    EquityQuery("GTE", ["avgdailyvol3m", 100000]),
    EquityQuery("LTE", ["short_percentage_of_float.value", 100])
])


# --- Batch Processing Function ---
def process_batch(offset, filterdf, options):
    batch_size = num_stocks
    screener = screen(
        screen_query,
        sortField="avgdailyvol3m",
        sortAsc=False,
        size=batch_size,
        offset=offset
    )
    stocks = screener.get('quotes', [])
    if not stocks:
        print("No more stocks to load.")
        return filterdf, options, offset


    current_filterdf = pd.DataFrame(stocks)


    # --- Add price*volume filter for most recent full day ---
    current_filterdf['prev_day_price'] = None
    current_filterdf['prev_day_volume'] = None
    current_filterdf['price_volume'] = None


    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        price, volume = get_prev_day_price_volume(symbol)
        current_filterdf.at[idx, 'prev_day_price'] = price
        current_filterdf.at[idx, 'prev_day_volume'] = volume
        if price is not None and volume is not None:
            current_filterdf.at[idx, 'price_volume'] = price * volume


    current_filterdf = current_filterdf[current_filterdf['price_volume'] > 100_000_000]


    if current_filterdf.empty:
        print("No stocks passed the price*volume filter in this batch.")
        offset += batch_size
        return filterdf, options, offset


    current_filterdf['historical_volatility'] = None
    for idx, row in current_filterdf.iterrows():
        symbol = row['symbol']
        hv = get_historical_volatility(symbol, window=20)
        current_filterdf.at[idx, 'historical_volatility'] = hv


    filterstocks = current_filterdf['symbol'].tolist()
    options_list = []
    for symbol in filterstocks:
        options_data = get_options(symbol)
        options_list.append(options_data)


    if options_list:
        current_options = pd.concat(options_list, ignore_index=True)
        options = pd.concat([options, current_options], ignore_index=True)
    else:
        current_options = pd.DataFrame(columns=['strike', 'impliedVolatility', 'openInterest', 'symbol'])


    if not current_options.empty:
        qualifying_symbols = set(current_options['symbol'].str.upper().unique())
        current_filterdf = current_filterdf[current_filterdf['symbol'].str.upper().isin(qualifying_symbols)]
    else:
        current_filterdf = current_filterdf.iloc[0:0]


    if current_filterdf.empty:
        print("No stocks passed the open interest filter in this batch.")
        offset += batch_size
        return filterdf, options, offset


    if not options.empty and 'symbol' in options.columns and 'impliedVolatility' in options.columns:
        avg_iv = options.groupby('symbol')['impliedVolatility'].mean().reset_index()
        avg_iv.columns = ['symbol', 'avg_iv']
    else:
        avg_iv = pd.DataFrame(columns=['symbol', 'avg_iv'])


    current_filterdf['symbol'] = current_filterdf['symbol'].astype(str).str.upper()
    avg_iv['symbol'] = avg_iv['symbol'].astype(str).str.upper()
    current_filterdf = current_filterdf.merge(avg_iv, on='symbol', how='left')


    if 'avg_iv' in current_filterdf.columns and 'historical_volatility' in current_filterdf.columns:
        current_filterdf["iv/hv_ratio"] = current_filterdf["avg_iv"] / current_filterdf["historical_volatility"]
    else:
        current_filterdf["iv/hv_ratio"] = None


    filterdf = pd.concat([filterdf, current_filterdf], ignore_index=True)

    # --- ADD: Append mean openInterest per symbol ---
    if not options.empty and 'symbol' in options.columns and 'openInterest' in options.columns:
        mean_open_interest = options.groupby('symbol')['openInterest'].mean().reset_index()
        mean_open_interest.rename(columns={'openInterest': 'mean_openInterest'}, inplace=True)
        mean_open_interest['symbol'] = mean_open_interest['symbol'].astype(str).str.upper()
        filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()
        filterdf = filterdf.merge(mean_open_interest, on='symbol', how='left')

    offset += batch_size
    return filterdf, options, offset


# --- Main loop ---
offset = 0
filterdf = pd.DataFrame()
options = pd.DataFrame()


filterdf, options, offset = process_batch(offset, filterdf, options)
print("Initial batch:")
print(filterdf)


while True:
    user_input = input("Process next 100 stocks? (y/n): ")
    if user_input.lower() != 'y':
        break
    filterdf, options, offset = process_batch(offset, filterdf, options)
    print("Updated results:")
    print(filterdf)
# Out:
# Initial batch:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# ..       ...    ...       ...      ...                     ...          ...
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity           Delayed Quote         True
# 131    en-US     US    EQUITY   Equity           Delayed Quote        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#     customPriceAlertConfidence currency                        shortName  \
# 0                         HIGH      USD               NVIDIA Corporation
# 1                         HIGH      USD                Lucid Group, Inc.
# 2                         HIGH      USD                      Tesla, Inc.
# 3                          LOW      USD               Ford Motor Company
# 4                         HIGH      USD                Intel Corporation
# ..                         ...      ...                              ...
# 128                       HIGH      USD                   Fortinet, Inc.
# 129                        LOW      USD  Capital One Financial Corporati
# 130                       HIGH      USD                        Flex Ltd.
# 131                        LOW      USD                   Snowflake Inc.
# 132                        LOW      USD      International Paper Company
#
#         bid  ...            displayName  symbol ipoExpectedDate  \
# 0    173.61  ...                 NVIDIA    NVDA             NaN
# 1      2.40  ...                  Lucid    LCID      2021-07-26
# 2    302.56  ...                  Tesla    TSLA             NaN
# 3     10.79  ...                    NaN       F             NaN
# 4     19.28  ...                  Intel    INTC             NaN
# ..      ...  ...                    ...     ...             ...
# 128   97.00  ...               Fortinet    FTNT             NaN
# 129  207.47  ...  Capital One Financial     COF             NaN
# 130   49.44  ...                   Flex    FLEX             NaN
# 131  204.60  ...              Snowflake    SNOW      2020-09-16
# 132   46.10  ...                    NaN      IP             NaN
#
#      prev_day_price  prev_day_volume        price_volume  \
# 0        177.869995        221685400  39431181015.551758
# 1              2.46         65248900    160512296.489048
# 2        308.269989         85270900  26286459406.185913
# 3             11.07        101090900   1119076232.149506
# 4         19.799999         90665200   1795170890.827942
# ..              ...              ...                 ...
# 128       99.900002          4311900    430758816.579437
# 129           215.0          4299500         924392500.0
# 130       49.869999          5059800    252332220.595551
# 131           223.5          6227700        1391890950.0
# 132       46.740002         16292200    761497455.345917
#
#      historical_volatility    avg_iv  iv/hv_ratio  mean_openInterest
# 0                 0.253826  0.394598       1.5546            9096.00
# 1                 1.334923  1.160160     0.869084           28425.25
# 2                 0.532152  0.508855     0.956221            1248.25
# 3                 0.254434  0.348639     1.370252           20423.75
# 4                  0.46638  0.452642     0.970544           20577.75
# ..                     ...       ...          ...                ...
# 128                0.36179  0.660038     1.824368            3432.50
# 129               0.229699  0.325202     1.415773             956.00
# 130                0.35905  0.424322      1.18179             729.50
# 131               0.382992  0.483892     1.263451             995.00
# 132               0.554077  0.333503     0.601907             952.00
#
# [133 rows x 94 columns]
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_90866/439954546.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   current_options = pd.concat(options_list, ignore_index=True)
# Updated results:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# ..       ...    ...       ...      ...                     ...          ...
# 203    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 204    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 205    en-US     US    EQUITY   Equity           Delayed Quote        False
# 206    en-US     US    EQUITY   Equity           Delayed Quote        False
# 207    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
#
#     customPriceAlertConfidence currency                        shortName  \
# 0                         HIGH      USD               NVIDIA Corporation
# 1                         HIGH      USD                Lucid Group, Inc.
# 2                         HIGH      USD                      Tesla, Inc.
# 3                          LOW      USD               Ford Motor Company
# 4                         HIGH      USD                Intel Corporation
# ..                         ...      ...                              ...
# 203                       HIGH      USD  Take-Two Interactive Software,
# 204                       HIGH      USD               Zillow Group, Inc.
# 205                        LOW      USD              BILL Holdings, Inc.
# 206                        LOW      USD                Core & Main, Inc.
# 207                       HIGH      USD                 Tetra Tech, Inc.
#
#         bid  ...  symbol  ipoExpectedDate prev_day_price  prev_day_volume  \
# 0    173.61  ...    NVDA              NaN     177.869995        221685400
# 1      2.40  ...    LCID       2021-07-26           2.46         65248900
# 2    302.56  ...    TSLA              NaN     308.269989         85270900
# 3     10.79  ...       F              NaN          11.07        101090900
# 4     19.28  ...    INTC              NaN      19.799999         90665200
# ..      ...  ...     ...              ...            ...              ...
# 203  220.35  ...    TTWO              NaN     222.729996          1644000
# 204   80.13  ...       Z              NaN      79.550003          1630400
# 205   41.50  ...    BILL              NaN      42.849998          2348800
# 206   62.25  ...     CNM       2021-07-23      63.639999          3279800
# 207   33.47  ...    TTEK              NaN      36.740002          3915200
#
#            price_volume historical_volatility    avg_iv  iv/hv_ratio  \
# 0    39431181015.551758              0.253826  0.394598       1.5546
# 1      160512296.489048              1.334923  1.160160     0.869084
# 2    26286459406.185913              0.532152  0.508855     0.956221
# 3     1119076232.149506              0.254434  0.348639     1.370252
# 4     1795170890.827942               0.46638  0.452642     0.970544
# ..                  ...                   ...       ...          ...
# 203    366168112.976074              0.171804  0.475713     2.768935
# 204    129698324.975586              0.284434  0.700931     2.464296
# 205    100646076.416016              0.390506  0.500005     1.280404
# 206    208726469.998169              0.203022  0.433844     2.136925
# 207    143844454.571533              0.186722  0.507695     2.718987
#
#      mean_openInterest_x  mean_openInterest_y
# 0                9096.00              9096.00
# 1               28425.25             28425.25
# 2                1248.25              1248.25
# 3               20423.75             20423.75
# 4               20577.75             20577.75
# ..                   ...                  ...
# 203                  NaN               961.00
# 204                  NaN              2543.00
# 205                  NaN              8127.00
# 206                  NaN               554.00
# 207                  NaN              1731.50
#
# [208 rows x 95 columns]
# /var/folders/f_/1bh6mfq97bxdwzwnr49jf8nm0000gn/T/ipykernel_90866/439954546.py:167: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   current_options = pd.concat(options_list, ignore_index=True)
# Updated results:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# ..       ...    ...       ...      ...                     ...          ...
# 247    en-US     US    EQUITY   Equity           Delayed Quote        False
# 248    en-US     US    EQUITY   Equity           Delayed Quote        False
# 249    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 250    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 251    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#     customPriceAlertConfidence currency                      shortName  \
# 0                         HIGH      USD             NVIDIA Corporation
# 1                         HIGH      USD              Lucid Group, Inc.
# 2                         HIGH      USD                    Tesla, Inc.
# 3                          LOW      USD             Ford Motor Company
# 4                         HIGH      USD              Intel Corporation
# ..                         ...      ...                            ...
# 247                        LOW      USD          Shift4 Payments, Inc.
# 248                        LOW      USD                        Aon plc
# 249                        LOW      USD     Procore Technologies, Inc.
# 250                       HIGH      USD  C.H. Robinson Worldwide, Inc.
# 251                        LOW      USD                       GMS Inc.
#
#         bid  ...  ipoExpectedDate  prev_day_price prev_day_volume  \
# 0    173.61  ...              NaN      177.869995       221685400
# 1      2.40  ...       2021-07-26            2.46        65248900
# 2    302.56  ...              NaN      308.269989        85270900
# 3     10.79  ...              NaN           11.07       101090900
# 4     19.28  ...              NaN       19.799999        90665200
# ..      ...  ...              ...             ...             ...
# 247  101.73  ...       2020-06-05           103.0         1284800
# 248  339.67  ...              NaN      354.964996         1387300
# 249   61.85  ...       2021-05-20       71.629997         2352200
# 250  104.11  ...              NaN          115.32         6470000
# 251  109.61  ...              NaN      109.639999         1824500
#
#            price_volume  historical_volatility    avg_iv  iv/hv_ratio  \
# 0    39431181015.551758               0.253826  0.394598       1.5546
# 1      160512296.489048               1.334923  1.160160     0.869084
# 2    26286459406.185913               0.532152  0.508855     0.956221
# 3     1119076232.149506               0.254434  0.348639     1.370252
# 4     1795170890.827942                0.46638  0.452642     0.970544
# ..                  ...                    ...       ...          ...
# 247         132334400.0               0.235314  0.551396     2.343233
# 248    492442939.419556               0.259664  0.248726     0.957875
# 249     168488079.53949                 0.5653  0.514653     0.910407
# 250    746120398.025513                0.63698  0.263923     0.414335
# 251    200038178.886414               0.028031  0.167733     5.983847
#
#      mean_openInterest_x  mean_openInterest_y  mean_openInterest
# 0                9096.00              9096.00             9096.0
# 1               28425.25             28425.25           28425.25
# 2                1248.25              1248.25            1248.25
# 3               20423.75             20423.75           20423.75
# 4               20577.75             20577.75           20577.75
# ..                   ...                  ...                ...
# 247                  NaN                  NaN             4284.0
# 248                  NaN                  NaN             1861.0
# 249                  NaN                  NaN             1122.0
# 250                  NaN                  NaN              739.0
# 251                  NaN                  NaN            14117.0
#
# [252 rows x 96 columns]

# %%
import yfinance as yf
import numpy as np
from hmmlearn.hmm import GaussianHMM
from tqdm import tqdm

def get_last_120_returns(symbol):
    """Get last 120 days of daily log returns for a symbol."""
    try:
        data = yf.Ticker(symbol).history(period="130d")
        closes = data['Close'].dropna()
        if len(closes) < 121:
            return None
        returns = np.log(closes / closes.shift(1)).dropna()
        return returns[-120:]
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
        return None

def fit_hmm_and_stats(returns, n_states=3):
    """Fit HMM to returns, return means, stds, and state sequence."""
    model = GaussianHMM(
        n_components=n_states,
        covariance_type="diag",
        n_iter=500,
        tol=1e-2,
        random_state=42,
        verbose=False
    )
    X = returns.values.reshape(-1, 1)
    model.fit(X)
    hidden_states = model.predict(X)
    means = model.means_.flatten()
    stds = np.sqrt(np.array([np.diag(cov)[0] for cov in model.covars_]))
    return hidden_states, means, stds

def hmm_analysis(symbol):
    returns = get_last_120_returns(symbol)
    if returns is None:
        return {
            "hmm_mean_0": None,
            "hmm_std_0": None,
            "hmm_mean_1": None,
            "hmm_std_1": None,
            "hmm_mean_2": None,
            "hmm_std_2": None,
            "pct_last30_in_highest_stdev_state": None,
            "highest_stdev_state": None
        }
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    # Identify the state with the highest stdev
    high_stdev_state = int(np.argmax(stds))
    last30 = hidden_states[-30:]
    pct_high = np.mean(last30 == high_stdev_state) * 100
    return {
        "hmm_mean_0": means[0],
        "hmm_std_0": stds[0],
        "hmm_mean_1": means[1],
        "hmm_std_1": stds[1],
        "hmm_mean_2": means[2],
        "hmm_std_2": stds[2],
        "pct_last30_in_highest_stdev_state": pct_high,
        "highest_stdev_state": high_stdev_state
    }

# --- Apply to filterdf ---

filterdf['symbol'] = filterdf['symbol'].astype(str).str.upper()

for col in [
    'hmm_mean_0','hmm_std_0',
    'hmm_mean_1','hmm_std_1',
    'hmm_mean_2','hmm_std_2',
    'pct_last30_in_highest_stdev_state',
    'highest_stdev_state'
]:
    filterdf[col] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    hmm_stats = hmm_analysis(symbol)
    for col in hmm_stats:
        filterdf.at[idx, col] = hmm_stats[col]

# filterdf now has the HMM columns for states 0, 1, 2, and the % of last 30 closes in the highest stdev state.
# Out:
#   6%|▌         | 15/252 [00:02<00:42,  5.53it/s]Model is not converging.  Current: 287.0377515827018 is not greater than 287.0511136833532. Delta is -0.013362100651420405
#   6%|▋         | 16/252 [00:03<00:42,  5.61it/s]Model is not converging.  Current: 294.8717833392088 is not greater than 294.89808216496533. Delta is -0.02629882575655529
#   9%|▉         | 23/252 [00:04<00:42,  5.38it/s]Model is not converging.  Current: 185.9532831123019 is not greater than 185.95818812590238. Delta is -0.004905013600478014
#  10%|▉         | 24/252 [00:04<00:46,  4.93it/s]Model is not converging.  Current: 326.71725611600357 is not greater than 326.7295324945106. Delta is -0.012276378507010577
#  10%|▉         | 25/252 [00:04<00:47,  4.83it/s]Model is not converging.  Current: 309.7562995228235 is not greater than 310.04481635080475. Delta is -0.28851682798125466
#  13%|█▎        | 33/252 [00:06<00:52,  4.14it/s]Model is not converging.  Current: 278.295377800982 is not greater than 278.2955804369564. Delta is -0.0002026359744036199
#  14%|█▍        | 36/252 [00:07<00:42,  5.04it/s]Model is not converging.  Current: 315.1268796590995 is not greater than 315.3677771667286. Delta is -0.24089750762914264
#  21%|██        | 53/252 [00:10<00:36,  5.38it/s]Model is not converging.  Current: 249.76779606223153 is not greater than 249.778004744103. Delta is -0.010208681871461067
#  25%|██▌       | 64/252 [00:13<00:40,  4.60it/s]Model is not converging.  Current: 289.6451567694604 is not greater than 289.6766594243145. Delta is -0.03150265485407999
#  27%|██▋       | 67/252 [00:13<00:36,  5.06it/s]Model is not converging.  Current: 307.8306285804225 is not greater than 307.8865651559719. Delta is -0.05593657554936726
#  28%|██▊       | 70/252 [00:14<00:35,  5.07it/s]Model is not converging.  Current: 287.4546911010005 is not greater than 287.7291320170289. Delta is -0.2744409160284249
#  31%|███▏      | 79/252 [00:16<00:46,  3.70it/s]Model is not converging.  Current: 294.5823240776132 is not greater than 294.5841839182361. Delta is -0.0018598406228989006
#  32%|███▏      | 81/252 [00:17<00:47,  3.62it/s]Model is not converging.  Current: 318.77597128996007 is not greater than 318.84541048981947. Delta is -0.06943919985940283
#  37%|███▋      | 93/252 [00:20<00:34,  4.63it/s]Model is not converging.  Current: 268.4556305029589 is not greater than 268.7798147697737. Delta is -0.3241842668147683
#  39%|███▉      | 99/252 [00:21<00:32,  4.75it/s]Model is not converging.  Current: 307.0089258935792 is not greater than 307.0192008185018. Delta is -0.010274924922612172
#  40%|████      | 102/252 [00:22<00:31,  4.72it/s]Model is not converging.  Current: 293.71821572395055 is not greater than 293.7211561783597. Delta is -0.0029404544091562457
#  44%|████▍     | 111/252 [00:24<00:30,  4.57it/s]Model is not converging.  Current: 300.4168441807982 is not greater than 300.4601472396386. Delta is -0.04330305884042218
#  51%|█████     | 128/252 [00:28<00:28,  4.35it/s]Model is not converging.  Current: 278.7364449518858 is not greater than 278.7387910361081. Delta is -0.002346084222324407
#  51%|█████     | 129/252 [00:28<00:27,  4.47it/s]Model is not converging.  Current: 278.115989672766 is not greater than 278.2214120746055. Delta is -0.1054224018395189
#  52%|█████▏    | 130/252 [00:28<00:28,  4.21it/s]Model is not converging.  Current: 267.69154823572666 is not greater than 267.7817784697158. Delta is -0.0902302339891321
#  53%|█████▎    | 134/252 [00:29<00:28,  4.09it/s]Model is not converging.  Current: 237.53782322570106 is not greater than 237.5693719394568. Delta is -0.031548713755739755
#  54%|█████▎    | 135/252 [00:29<00:27,  4.22it/s]Model is not converging.  Current: 301.76179060345027 is not greater than 301.76179182546656. Delta is -1.2220162943776813e-06
#  55%|█████▌    | 139/252 [00:30<00:24,  4.58it/s]Model is not converging.  Current: 262.1778198611129 is not greater than 262.21300437739984. Delta is -0.03518451628696084
#  58%|█████▊    | 146/252 [00:32<00:23,  4.59it/s]Model is not converging.  Current: 200.8384606338579 is not greater than 200.84235697925746. Delta is -0.0038963453995677355
#  62%|██████▏   | 155/252 [00:34<00:22,  4.23it/s]Model is not converging.  Current: 321.9873257337569 is not greater than 322.00347164693585. Delta is -0.016145913178945648
#  63%|██████▎   | 158/252 [00:35<00:20,  4.56it/s]Model is not converging.  Current: 236.21654247396347 is not greater than 236.22360891365204. Delta is -0.007066439688571791
#  64%|██████▍   | 161/252 [00:35<00:18,  4.97it/s]Model is not converging.  Current: 260.269932048338 is not greater than 260.310212819138. Delta is -0.04028077079999548
#  64%|██████▍   | 162/252 [00:35<00:17,  5.16it/s]Model is not converging.  Current: 260.52071801542684 is not greater than 260.52606290209894. Delta is -0.005344886672105531
#  65%|██████▌   | 164/252 [00:36<00:18,  4.81it/s]Model is not converging.  Current: 286.7486873915204 is not greater than 286.7541485002278. Delta is -0.005461108707436324
#  66%|██████▌   | 166/252 [00:36<00:16,  5.12it/s]Model is not converging.  Current: 275.85627735897816 is not greater than 275.85991244477424. Delta is -0.0036350857960769645
#  68%|██████▊   | 171/252 [00:37<00:17,  4.70it/s]Model is not converging.  Current: 300.32587375706953 is not greater than 300.45131239592286. Delta is -0.12543863885332485
#  69%|██████▊   | 173/252 [00:38<00:17,  4.41it/s]Model is not converging.  Current: 278.49234945819785 is not greater than 278.49329598672085. Delta is -0.0009465285230021436
#  75%|███████▌  | 190/252 [00:41<00:11,  5.25it/s]Model is not converging.  Current: 341.670728771021 is not greater than 341.77304411108145. Delta is -0.10231534006044285
#  76%|███████▌  | 191/252 [00:42<00:12,  5.06it/s]Model is not converging.  Current: 283.80791601586736 is not greater than 283.8209588759786. Delta is -0.013042860111227128
#  77%|███████▋  | 195/252 [00:42<00:12,  4.71it/s]Model is not converging.  Current: 290.47863029211663 is not greater than 290.48591151344505. Delta is -0.007281221328412357
#  81%|████████  | 203/252 [00:44<00:10,  4.52it/s]Model is not converging.  Current: 306.0712974894421 is not greater than 306.2226693104674. Delta is -0.15137182102529323
#  81%|████████  | 204/252 [00:44<00:09,  4.83it/s]Model is not converging.  Current: 275.5940705780667 is not greater than 275.6987287079516. Delta is -0.10465812988491052
#  83%|████████▎ | 209/252 [00:45<00:07,  5.66it/s]Model is not converging.  Current: 308.25398037768883 is not greater than 308.2702348133259. Delta is -0.016254435637051756
#  85%|████████▍ | 214/252 [00:46<00:09,  4.08it/s]Model is not converging.  Current: 272.4188844433088 is not greater than 272.4368856274202. Delta is -0.018001184111426483
#  91%|█████████ | 229/252 [00:50<00:05,  4.02it/s]Model is not converging.  Current: 231.9857288820225 is not greater than 232.01171020333732. Delta is -0.02598132131481634
#  92%|█████████▏| 231/252 [00:51<00:05,  3.98it/s]Model is not converging.  Current: 284.9121371208665 is not greater than 284.9660630747062. Delta is -0.053925953839723206
#  95%|█████████▍| 239/252 [00:52<00:02,  4.98it/s]Model is not converging.  Current: 293.08620910342444 is not greater than 293.1760285858653. Delta is -0.08981948244087334
#  96%|█████████▌| 242/252 [00:53<00:02,  4.54it/s]Model is not converging.  Current: 269.97048727630187 is not greater than 269.99890688821995. Delta is -0.028419611918081955
#  98%|█████████▊| 247/252 [00:54<00:00,  5.23it/s]Model is not converging.  Current: 269.85973916557776 is not greater than 269.8599060673668. Delta is -0.0001669017890435498
#  99%|█████████▉| 249/252 [00:54<00:00,  4.66it/s]Model is not converging.  Current: 264.8877641326828 is not greater than 264.90047910685865. Delta is -0.012714974175878524
# 100%|██████████| 252/252 [00:55<00:00,  4.54it/s]

# %%
N = 252  # Or use 261, depending on your convention

def pct_regimes_higher_than_iv(hidden_states, stds, avg_iv):
    """% of regimes in last 30 days with annualized stdev higher than avg_iv."""
    last30 = hidden_states[-30:]
    # Annualize regime stdevs
    stds_annualized = stds * np.sqrt(N)
    last30_vols_annualized = stds_annualized[last30]
    pct_higher = np.mean(last30_vols_annualized > avg_iv) * 100
    return pct_higher

filterdf['pct_regimes_last30_higher_than_avg_iv'] = None

for idx, row in tqdm(filterdf.iterrows(), total=len(filterdf)):
    symbol = row['symbol']
    avg_iv = row['avg_iv']
    returns = get_last_120_returns(symbol)
    if returns is None or avg_iv is None:
        filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = None
        continue
    hidden_states, means, stds = fit_hmm_and_stats(returns, n_states=3)
    pct_higher = pct_regimes_higher_than_iv(hidden_states, stds, avg_iv)
    filterdf.at[idx, 'pct_regimes_last30_higher_than_avg_iv'] = pct_higher
# Out:
#   6%|▌         | 15/252 [00:03<01:02,  3.82it/s]Model is not converging.  Current: 287.0377515827018 is not greater than 287.0511136833532. Delta is -0.013362100651420405
#   6%|▋         | 16/252 [00:03<00:56,  4.21it/s]Model is not converging.  Current: 294.8717833392088 is not greater than 294.89808216496533. Delta is -0.02629882575655529
#   9%|▉         | 23/252 [00:04<00:45,  5.04it/s]Model is not converging.  Current: 185.9532831123019 is not greater than 185.95818812590238. Delta is -0.004905013600478014
#  10%|▉         | 24/252 [00:05<00:48,  4.71it/s]Model is not converging.  Current: 326.7172728914914 is not greater than 326.72954902323426. Delta is -0.012276131742851248
#  10%|▉         | 25/252 [00:05<00:50,  4.50it/s]Model is not converging.  Current: 309.7563004089375 is not greater than 310.0448165227642. Delta is -0.2885161138267449
#  13%|█▎        | 33/252 [00:07<00:46,  4.69it/s]Model is not converging.  Current: 278.295377800982 is not greater than 278.2955804369564. Delta is -0.0002026359744036199
#  14%|█▍        | 36/252 [00:07<00:45,  4.78it/s]Model is not converging.  Current: 315.12681726129154 is not greater than 315.36771757743173. Delta is -0.24090031614019836
#  21%|██        | 53/252 [00:11<00:41,  4.75it/s]Model is not converging.  Current: 249.76779606223153 is not greater than 249.778004744103. Delta is -0.010208681871461067
#  25%|██▌       | 64/252 [00:14<00:42,  4.41it/s]Model is not converging.  Current: 289.6451567694604 is not greater than 289.6766594243145. Delta is -0.03150265485407999
#  27%|██▋       | 67/252 [00:14<00:37,  4.95it/s]Model is not converging.  Current: 307.8306285804225 is not greater than 307.8865651559719. Delta is -0.05593657554936726
#  28%|██▊       | 70/252 [00:15<00:37,  4.89it/s]Model is not converging.  Current: 287.4546911010005 is not greater than 287.7291320170289. Delta is -0.2744409160284249
#  31%|███▏      | 79/252 [00:17<00:35,  4.91it/s]Model is not converging.  Current: 294.5823251928399 is not greater than 294.58418602437524. Delta is -0.0018608315353390026
#  32%|███▏      | 81/252 [00:17<00:40,  4.27it/s]Model is not converging.  Current: 318.7759744121889 is not greater than 318.845413579202. Delta is -0.06943916701311537
#  37%|███▋      | 93/252 [00:20<00:35,  4.51it/s]Model is not converging.  Current: 268.4556305029589 is not greater than 268.7798147697737. Delta is -0.3241842668147683
#  39%|███▉      | 99/252 [00:22<00:49,  3.07it/s]Model is not converging.  Current: 307.0089258935792 is not greater than 307.0192008185018. Delta is -0.010274924922612172
#  40%|████      | 102/252 [00:23<00:42,  3.53it/s]Model is not converging.  Current: 293.71821572395055 is not greater than 293.7211561783597. Delta is -0.0029404544091562457
#  44%|████▍     | 111/252 [00:25<00:31,  4.51it/s]Model is not converging.  Current: 300.4168441807982 is not greater than 300.46014723963873. Delta is -0.04330305884053587
#  51%|█████     | 128/252 [00:29<00:27,  4.49it/s]Model is not converging.  Current: 278.7364449518858 is not greater than 278.7387910361081. Delta is -0.002346084222324407
#  51%|█████     | 129/252 [00:29<00:24,  5.02it/s]Model is not converging.  Current: 278.11598321196027 is not greater than 278.2214058291006. Delta is -0.1054226171403343
#  52%|█████▏    | 130/252 [00:29<00:25,  4.74it/s]Model is not converging.  Current: 267.69154823572666 is not greater than 267.7817784697158. Delta is -0.0902302339891321
#  53%|█████▎    | 134/252 [00:30<00:32,  3.68it/s]Model is not converging.  Current: 237.53783630532823 is not greater than 237.5693858998375. Delta is -0.03154959450927208
#  54%|█████▎    | 135/252 [00:31<00:28,  4.12it/s]Model is not converging.  Current: 301.76179060345027 is not greater than 301.76179182546656. Delta is -1.2220162943776813e-06
#  55%|█████▌    | 139/252 [00:32<00:27,  4.18it/s]Model is not converging.  Current: 262.1778198611129 is not greater than 262.21300437739984. Delta is -0.03518451628696084
#  58%|█████▊    | 146/252 [00:33<00:20,  5.25it/s]Model is not converging.  Current: 200.8384606338579 is not greater than 200.84235697925746. Delta is -0.0038963453995677355
#  62%|██████▏   | 155/252 [00:35<00:23,  4.16it/s]Model is not converging.  Current: 321.98732573375696 is not greater than 322.00347164693574. Delta is -0.016145913178775118
#  63%|██████▎   | 158/252 [00:36<00:23,  4.00it/s]Model is not converging.  Current: 236.216560393981 is not greater than 236.2236269951147. Delta is -0.007066601133686845
#  64%|██████▍   | 161/252 [00:37<00:22,  4.04it/s]Model is not converging.  Current: 260.269932048338 is not greater than 260.310212819138. Delta is -0.04028077079999548
#  64%|██████▍   | 162/252 [00:37<00:20,  4.33it/s]Model is not converging.  Current: 260.52071801542684 is not greater than 260.52606290209894. Delta is -0.005344886672105531
#  65%|██████▌   | 164/252 [00:37<00:20,  4.34it/s]Model is not converging.  Current: 286.7486873915204 is not greater than 286.7541485002278. Delta is -0.005461108707436324
#  66%|██████▌   | 166/252 [00:38<00:22,  3.87it/s]Model is not converging.  Current: 275.8562773589779 is not greater than 275.859912444775. Delta is -0.003635085797100146
#  68%|██████▊   | 171/252 [00:39<00:18,  4.40it/s]Model is not converging.  Current: 300.32587375706953 is not greater than 300.45131239592286. Delta is -0.12543863885332485
#  69%|██████▊   | 173/252 [00:39<00:18,  4.19it/s]Model is not converging.  Current: 278.49234945819785 is not greater than 278.49329598672085. Delta is -0.0009465285230021436
#  75%|███████▌  | 190/252 [00:43<00:16,  3.84it/s]Model is not converging.  Current: 341.670728771021 is not greater than 341.77304411108145. Delta is -0.10231534006044285
#  76%|███████▌  | 191/252 [00:44<00:15,  3.89it/s]Model is not converging.  Current: 283.80791494757136 is not greater than 283.82095712821985. Delta is -0.013042180648483281
#  77%|███████▋  | 195/252 [00:45<00:14,  3.98it/s]Model is not converging.  Current: 290.47863029211663 is not greater than 290.48591151344505. Delta is -0.007281221328412357
#  81%|████████  | 203/252 [00:46<00:11,  4.38it/s]Model is not converging.  Current: 306.0712974894421 is not greater than 306.2226693104674. Delta is -0.15137182102529323
#  81%|████████  | 204/252 [00:47<00:10,  4.70it/s]Model is not converging.  Current: 275.5940705780667 is not greater than 275.6987287079516. Delta is -0.10465812988491052
#  83%|████████▎ | 209/252 [00:48<00:09,  4.76it/s]Model is not converging.  Current: 308.25398037768883 is not greater than 308.2702348133259. Delta is -0.016254435637051756
#  85%|████████▍ | 214/252 [00:49<00:08,  4.49it/s]Model is not converging.  Current: 272.418884443309 is not greater than 272.43688562742. Delta is -0.018001184110971735
#  91%|█████████ | 229/252 [00:52<00:06,  3.58it/s]Model is not converging.  Current: 231.9857288820225 is not greater than 232.01171020333732. Delta is -0.02598132131481634
#  92%|█████████▏| 231/252 [00:53<00:05,  3.82it/s]Model is not converging.  Current: 284.9121371208665 is not greater than 284.9660630747062. Delta is -0.053925953839723206
#  95%|█████████▍| 239/252 [00:55<00:02,  4.56it/s]Model is not converging.  Current: 293.08620910342444 is not greater than 293.1760285858653. Delta is -0.08981948244087334
#  96%|█████████▌| 242/252 [00:55<00:02,  4.73it/s]Model is not converging.  Current: 269.9704753151568 is not greater than 269.9988950361343. Delta is -0.028419720977467477
#  98%|█████████▊| 247/252 [00:56<00:00,  5.15it/s]Model is not converging.  Current: 269.85973916557776 is not greater than 269.8599060673668. Delta is -0.0001669017890435498
#  99%|█████████▉| 249/252 [00:57<00:00,  3.93it/s]Model is not converging.  Current: 264.8877641326828 is not greater than 264.90047910685865. Delta is -0.012714974175878524
# 100%|██████████| 252/252 [00:58<00:00,  4.33it/s]

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from scipy.stats import entropy
from hmmlearn.hmm import GaussianHMM
from statsmodels.tsa.stattools import adfuller

def shannon_entropy(series, bins=10):
    hist, _ = np.histogram(series, bins=bins, density=True)
    hist = hist[hist > 0]
    return entropy(hist, base=2)

def hmm_regime_switch_prob_and_count(returns, n_states=2):
    returns = returns.values.reshape(-1, 1)
    model = GaussianHMM(n_components=n_states, covariance_type="diag", n_iter=100)
    model.fit(returns)
    hidden_states = model.predict(returns)
    last_state = hidden_states[-1]
    transmat = model.transmat_
    switch_prob = 1 - transmat[last_state, last_state]
    regime_switch_count = np.sum(hidden_states[1:] != hidden_states[:-1])
    return switch_prob, regime_switch_count

entropy_list = []
regimeswitchprob_list = []
regimeswitchcount_list = []
adf_pvalue_list = []
avg_return_list = []

for ticker in filterdf['symbol']:
    try:
        # Download last 7 days of 1-minute data
        df = yf.download(ticker, period="7d", interval="1m", progress=False)
        closes = df['Close'].dropna()
        # Make sure you have enough data (e.g., at least 1000 minutes)
        if len(closes) < 1000:
            entropy_list.append(np.nan)
            regimeswitchprob_list.append(np.nan)
            regimeswitchcount_list.append(np.nan)
            adf_pvalue_list.append(np.nan)
            avg_return_list.append(np.nan)
            continue
        log_returns = np.log(closes).diff().dropna()         # For entropy, HMM, etc.
        simple_returns = closes.pct_change().dropna()        # For avg return only

        # Shannon entropy (log returns)
        ent = shannon_entropy(log_returns)
        entropy_list.append(ent)
        # HMM regime switch probability and count (log returns)
        switch_prob, switch_count = hmm_regime_switch_prob_and_count(log_returns)
        regimeswitchprob_list.append(round(switch_prob * 100, 2))  # as percentage
        regimeswitchcount_list.append(int(switch_count))
        # ADF test p-value on last 7 days of prices (not returns)
        adf_pvalue = adfuller(closes)[1]
        adf_pvalue_list.append(adf_pvalue)
        # Average return over last 7 days (mean of simple returns)
        avg_return = simple_returns.mean()
        avg_return_list.append(avg_return)
    except Exception as e:
        entropy_list.append(np.nan)
        regimeswitchprob_list.append(np.nan)
        regimeswitchcount_list.append(np.nan)
        adf_pvalue_list.append(np.nan)
        avg_return_list.append(np.nan)


filterdf['ShannonEntropy'] = entropy_list
filterdf['Regimeswitchprob'] = regimeswitchprob_list
filterdf['Regimeswitchcount'] = regimeswitchcount_list
filterdf['ADF_Pvalue'] = adf_pvalue_list
filterdf['AvgReturn_7d'] = avg_return_list
# Out:
# YF.download() has changed argument auto_adjust default to True
# Model is not converging.  Current: 14108.051894007485 is not greater than 14108.598752185002. Delta is -0.5468581775166967
# Model is not converging.  Current: 12574.45874764933 is not greater than 12575.06601993501. Delta is -0.607272285678846
# Model is not converging.  Current: 13725.64182530201 is not greater than 13726.821696479099. Delta is -1.179871177089808
# Model is not converging.  Current: 13998.65453609887 is not greater than 13999.487971467925. Delta is -0.8334353690552234
# Model is not converging.  Current: 13862.188349305332 is not greater than 13863.78143890813. Delta is -1.5930896027985
# Model is not converging.  Current: 14222.459950255055 is not greater than 14222.559724149436. Delta is -0.09977389438063256
# Model is not converging.  Current: 13695.030180988953 is not greater than 13695.707342445203. Delta is -0.6771614562494506
# Model is not converging.  Current: 12972.706996138313 is not greater than 12973.724380494541. Delta is -1.0173843562279217
# Model is not converging.  Current: 13039.758358303121 is not greater than 13045.5325873444. Delta is -5.774229041278886
# Model is not converging.  Current: 13091.00480863204 is not greater than 13094.438005552369. Delta is -3.4331969203285553
# Model is not converging.  Current: 13079.321064402018 is not greater than 13083.743874131327. Delta is -4.422809729308938
# Model is not converging.  Current: 13972.607923961972 is not greater than 13973.252596393533. Delta is -0.6446724315610481
# Model is not converging.  Current: 13221.0546821188 is not greater than 13221.22807857473. Delta is -0.17339645592983288
# Model is not converging.  Current: 14320.70191515693 is not greater than 14320.702408779956. Delta is -0.0004936230270686792
# Model is not converging.  Current: 13160.349845152175 is not greater than 13167.537488113096. Delta is -7.1876429609201296
# Model is not converging.  Current: 14196.040703435565 is not greater than 14197.014464997439. Delta is -0.9737615618741984
# Model is not converging.  Current: 13976.410813767096 is not greater than 13976.761150819779. Delta is -0.3503370526832441
# Model is not converging.  Current: 12784.695491909355 is not greater than 12785.06731523027. Delta is -0.37182332091470016
# Model is not converging.  Current: 12889.945495943315 is not greater than 12889.964147719473. Delta is -0.018651776157639688
# Model is not converging.  Current: 14160.762196637299 is not greater than 14166.903324902287. Delta is -6.141128264987856
# Model is not converging.  Current: 13829.455624862157 is not greater than 13831.846683234477. Delta is -2.391058372319094
# Model is not converging.  Current: 13825.092742583058 is not greater than 13829.628253674677. Delta is -4.5355110916189005
# Model is not converging.  Current: 14026.438147027313 is not greater than 14029.830602521348. Delta is -3.392455494034948
# Model is not converging.  Current: 13459.15844806072 is not greater than 13459.361981205495. Delta is -0.203533144775065
# Model is not converging.  Current: 13945.873566157437 is not greater than 13947.002016996472. Delta is -1.1284508390344854
# Model is not converging.  Current: 14022.884859826567 is not greater than 14023.299482442642. Delta is -0.41462261607557593
# Model is not converging.  Current: 13810.021065452363 is not greater than 13811.87048477709. Delta is -1.8494193247261137
# Model is not converging.  Current: 14287.568537004228 is not greater than 14288.341152406532. Delta is -0.7726154023039271
# Model is not converging.  Current: 14109.733175705269 is not greater than 14109.757797491658. Delta is -0.024621786389616318
# Model is not converging.  Current: 13892.037459814059 is not greater than 13900.794378665407. Delta is -8.756918851348019
# Model is not converging.  Current: 14284.868974878784 is not greater than 14284.973794635542. Delta is -0.10481975675793365
# Model is not converging.  Current: 13070.809656898246 is not greater than 13071.13510751595. Delta is -0.32545061770360917
# Model is not converging.  Current: 14057.176345410036 is not greater than 14057.779726652821. Delta is -0.6033812427849625
# Model is not converging.  Current: 11995.67860019964 is not greater than 11997.926101692019. Delta is -2.247501492378433
# Model is not converging.  Current: 13258.380732833895 is not greater than 13261.856445672138. Delta is -3.4757128382425435
# Model is not converging.  Current: 13866.588257899322 is not greater than 13868.595417017757. Delta is -2.0071591184350837
# Model is not converging.  Current: 13943.229165250705 is not greater than 13944.12658541706. Delta is -0.8974201663550048
# Model is not converging.  Current: 12932.882274054617 is not greater than 12933.408445978615. Delta is -0.5261719239988452
# Model is not converging.  Current: 13278.227463403144 is not greater than 13281.417824667587. Delta is -3.190361264443709
# Model is not converging.  Current: 14202.765255931272 is not greater than 14203.987687107126. Delta is -1.222431175854581
# Model is not converging.  Current: 13482.640514306715 is not greater than 13484.233136509049. Delta is -1.5926222023335868
# Model is not converging.  Current: 14060.768331211624 is not greater than 14060.777731142658. Delta is -0.009399931033840403
# Model is not converging.  Current: 13940.722868601282 is not greater than 13942.077951100331. Delta is -1.3550824990488763
# Model is not converging.  Current: 14270.432006802506 is not greater than 14273.115031211919. Delta is -2.68302440941261
# Model is not converging.  Current: 14162.550533131092 is not greater than 14164.310757230936. Delta is -1.760224099843981
# Model is not converging.  Current: 14184.638194418445 is not greater than 14184.856101677447. Delta is -0.2179072590024589
# Model is not converging.  Current: 13864.954098013692 is not greater than 13865.170423238153. Delta is -0.21632522446088842
# Model is not converging.  Current: 13848.582597363618 is not greater than 13851.337165578894. Delta is -2.7545682152758673
# Model is not converging.  Current: 14154.08292776856 is not greater than 14154.52031722604. Delta is -0.4373894574800943
# Model is not converging.  Current: 13916.746127922232 is not greater than 13916.788628224866. Delta is -0.04250030263392546
# Model is not converging.  Current: 13946.976559859493 is not greater than 13947.161439872143. Delta is -0.18488001264995546
# Model is not converging.  Current: 14258.335490453617 is not greater than 14258.382304628278. Delta is -0.04681417466053972
# Model is not converging.  Current: 14049.607987881727 is not greater than 14053.555041544834. Delta is -3.947053663106999
# Model is not converging.  Current: 13850.278015539936 is not greater than 13852.17271102827. Delta is -1.8946954883340368
# Model is not converging.  Current: 12855.304391824064 is not greater than 12855.357932046634. Delta is -0.05354022257051838
# Model is not converging.  Current: 13817.946917314513 is not greater than 13821.001432686171. Delta is -3.054515371657544
# Model is not converging.  Current: 14163.349794412323 is not greater than 14164.214634032489. Delta is -0.8648396201660944
# Model is not converging.  Current: 14306.500550982919 is not greater than 14309.701554911473. Delta is -3.2010039285542007
# Model is not converging.  Current: 14066.506688290341 is not greater than 14069.079515576885. Delta is -2.572827286543543
# Model is not converging.  Current: 13927.751093718482 is not greater than 13928.542655986867. Delta is -0.7915622683849506
# Model is not converging.  Current: 14042.245316075423 is not greater than 14043.784069550888. Delta is -1.5387534754645458
# Model is not converging.  Current: 14276.239508165203 is not greater than 14276.659214612797. Delta is -0.4197064475938532
# Model is not converging.  Current: 14060.585323062664 is not greater than 14063.594681830735. Delta is -3.0093587680712517
# Model is not converging.  Current: 12385.375719822605 is not greater than 12393.707928506621. Delta is -8.332208684016223
# Model is not converging.  Current: 13682.071211394838 is not greater than 13683.009772943034. Delta is -0.938561548196958
# Model is not converging.  Current: 14024.040077573673 is not greater than 14025.782355030762. Delta is -1.7422774570895854
# Model is not converging.  Current: 14147.10131474097 is not greater than 14150.917707593799. Delta is -3.8163928528283577
# Model is not converging.  Current: 13861.198462031385 is not greater than 13862.656560851337. Delta is -1.4580988199522835
# Model is not converging.  Current: 13675.585318116855 is not greater than 13676.147071558444. Delta is -0.5617534415887349
# Model is not converging.  Current: 13890.309620274485 is not greater than 13890.38620378181. Delta is -0.07658350732526742
# Model is not converging.  Current: 14192.699065042043 is not greater than 14194.87432425589. Delta is -2.175259213847312
# Model is not converging.  Current: 12899.570676774674 is not greater than 12902.176780038937. Delta is -2.606103264262856
# Model is not converging.  Current: 14178.01467821845 is not greater than 14179.551132533821. Delta is -1.5364543153718841
# Model is not converging.  Current: 14034.50921439385 is not greater than 14034.836033063953. Delta is -0.3268186701043305
# Model is not converging.  Current: 13563.840831735206 is not greater than 13565.521569866378. Delta is -1.6807381311718927
# Model is not converging.  Current: 12939.766073751682 is not greater than 12945.381554197917. Delta is -5.615480446234869
# Model is not converging.  Current: 14000.645813382074 is not greater than 14000.661142986244. Delta is -0.015329604169892264
# Model is not converging.  Current: 14245.672299614662 is not greater than 14246.258386143863. Delta is -0.586086529201566
# Model is not converging.  Current: 13986.568854321577 is not greater than 13991.821894043444. Delta is -5.253039721867026
# Model is not converging.  Current: 13236.892236107475 is not greater than 13244.712530432816. Delta is -7.82029432534182
# Model is not converging.  Current: 14250.164693559609 is not greater than 14252.262538954254. Delta is -2.097845394644537
# Model is not converging.  Current: 13920.317500114665 is not greater than 13920.319239186823. Delta is -0.0017390721586707514
# Model is not converging.  Current: 14285.841807844201 is not greater than 14286.757259373459. Delta is -0.9154515292575525
# Model is not converging.  Current: 14093.098233853405 is not greater than 14093.949539528394. Delta is -0.8513056749889074
# Model is not converging.  Current: 13963.443826698245 is not greater than 13963.447682769855. Delta is -0.0038560716093343217
# Model is not converging.  Current: 13953.349023026358 is not greater than 13955.801548295669. Delta is -2.4525252693110815
# Model is not converging.  Current: 13918.278031097838 is not greater than 13919.763172018722. Delta is -1.4851409208840778
# Model is not converging.  Current: 13973.766966947158 is not greater than 13977.654618846747. Delta is -3.8876518995894003
# Model is not converging.  Current: 13915.762640373012 is not greater than 13916.29783381483. Delta is -0.5351934418176825
# Model is not converging.  Current: 14202.426805816107 is not greater than 14204.695499350513. Delta is -2.2686935344063386
# Model is not converging.  Current: 13886.84919484354 is not greater than 13887.85693845746. Delta is -1.0077436139199563
# Model is not converging.  Current: 14082.049213235561 is not greater than 14082.226220463637. Delta is -0.17700722807603597
# Model is not converging.  Current: 13806.035882734455 is not greater than 13807.02234618582. Delta is -0.9864634513651254
# Model is not converging.  Current: 13839.795092230768 is not greater than 13841.366722539018. Delta is -1.5716303082499508
# Model is not converging.  Current: 13106.528910963172 is not greater than 13132.678287211382. Delta is -26.14937624820959
# Model is not converging.  Current: 14054.344903291598 is not greater than 14058.008017547932. Delta is -3.6631142563346657
# Model is not converging.  Current: 13716.771666025132 is not greater than 13722.499509276366. Delta is -5.727843251233935
# Model is not converging.  Current: 13725.216704870762 is not greater than 13735.350051834455. Delta is -10.133346963693839
# Model is not converging.  Current: 13758.776730351423 is not greater than 13759.7762243934. Delta is -0.9994940419765044
# Model is not converging.  Current: 14189.541279566309 is not greater than 14192.695458882623. Delta is -3.1541793163141847
# Model is not converging.  Current: 13572.29133272421 is not greater than 13573.643548867873. Delta is -1.3522161436630995
# Model is not converging.  Current: 13353.505747601168 is not greater than 13360.32394924534. Delta is -6.818201644171495
# Model is not converging.  Current: 14048.499313178158 is not greater than 14051.131874005803. Delta is -2.632560827645648
# Model is not converging.  Current: 13709.639996847716 is not greater than 13713.324707194819. Delta is -3.6847103471027367
# Model is not converging.  Current: 13969.762352509373 is not greater than 13971.814742895025. Delta is -2.052390385651961
# Model is not converging.  Current: 13312.948241629863 is not greater than 13313.145428318163. Delta is -0.19718668829955277
# Model is not converging.  Current: 13971.201916801292 is not greater than 13972.171107308148. Delta is -0.9691905068557389
# Model is not converging.  Current: 12852.652085768956 is not greater than 12852.664186503791. Delta is -0.012100734835257754
# Model is not converging.  Current: 14150.296764366309 is not greater than 14153.527616751144. Delta is -3.2308523848350887
# Model is not converging.  Current: 14047.742726404562 is not greater than 14047.776804622205. Delta is -0.034078217642672826
# Model is not converging.  Current: 14165.917435126186 is not greater than 14166.570033068903. Delta is -0.6525979427169659
# Model is not converging.  Current: 13348.440384438487 is not greater than 13351.425504825918. Delta is -2.9851203874313796
# Model is not converging.  Current: 13854.169493884901 is not greater than 13856.427446731568. Delta is -2.25795284666674
# Model is not converging.  Current: 14268.735818285259 is not greater than 14269.289944286653. Delta is -0.5541260013942519
# Model is not converging.  Current: 13600.820975581455 is not greater than 13603.849190915638. Delta is -3.0282153341831872
# Model is not converging.  Current: 13979.436916044759 is not greater than 13979.478759668697. Delta is -0.041843623937893426
# Model is not converging.  Current: 13730.439911967225 is not greater than 13742.064580507458. Delta is -11.62466854023296
# Model is not converging.  Current: 14118.457711771973 is not greater than 14118.54651647774. Delta is -0.08880470576696098
# Model is not converging.  Current: 13362.666980721828 is not greater than 13362.673191874677. Delta is -0.006211152849573409
# Model is not converging.  Current: 13563.473944955169 is not greater than 13567.113768474956. Delta is -3.6398235197866597
# Model is not converging.  Current: 13876.236227515756 is not greater than 13876.346775371469. Delta is -0.1105478557128663
# Model is not converging.  Current: 14060.33307025073 is not greater than 14062.932335356216. Delta is -2.599265105485756
# Model is not converging.  Current: 12840.909141731727 is not greater than 12842.395254046523. Delta is -1.4861123147966282
# Model is not converging.  Current: 13800.3882960606 is not greater than 13804.320880375037. Delta is -3.932584314436099
# Model is not converging.  Current: 13256.895178050496 is not greater than 13257.956823134424. Delta is -1.0616450839279423
# Model is not converging.  Current: 13133.519967569857 is not greater than 13133.85664796512. Delta is -0.3366803952631017
# Model is not converging.  Current: 14109.244980540128 is not greater than 14109.255408386713. Delta is -0.010427846584207145
# Model is not converging.  Current: 12737.825376056064 is not greater than 12737.854229942. Delta is -0.028853885936769075
# Model is not converging.  Current: 13642.016592694057 is not greater than 13643.5023006499. Delta is -1.485707955842372
# Model is not converging.  Current: 13550.627573031208 is not greater than 13552.01031663121. Delta is -1.3827436000010493
# Model is not converging.  Current: 12927.136361652732 is not greater than 12927.669392138323. Delta is -0.5330304855906434
# Model is not converging.  Current: 13583.860103606885 is not greater than 13583.864622954032. Delta is -0.0045193471469247015
# Model is not converging.  Current: 12496.60531408113 is not greater than 12504.94982686948. Delta is -8.344512788351494
# Model is not converging.  Current: 12225.20933425091 is not greater than 12227.56324650825. Delta is -2.3539122573401983
# Model is not converging.  Current: 14067.75040719579 is not greater than 14067.751912446589. Delta is -0.0015052507988002617
# Model is not converging.  Current: 13220.00799548707 is not greater than 13222.404934888873. Delta is -2.3969394018022285
# Model is not converging.  Current: 13145.216735626325 is not greater than 13152.196650961096. Delta is -6.9799153347703395
# Model is not converging.  Current: 13820.280603703613 is not greater than 13821.290504049333. Delta is -1.0099003457198705
# Model is not converging.  Current: 13545.588971869156 is not greater than 13548.794152867553. Delta is -3.205180998396827
# Model is not converging.  Current: 13272.771589004806 is not greater than 13279.349980908602. Delta is -6.578391903796728
# Model is not converging.  Current: 13229.812529965355 is not greater than 13232.285691162586. Delta is -2.473161197231093
# Model is not converging.  Current: 12075.742207673104 is not greater than 12077.251960803946. Delta is -1.5097531308420002
# Model is not converging.  Current: 12662.703723491557 is not greater than 12663.094592912736. Delta is -0.39086942117864965
# Model is not converging.  Current: 13143.370887254261 is not greater than 13144.828106666246. Delta is -1.4572194119846245
# Model is not converging.  Current: 13282.392928997238 is not greater than 13284.086324860455. Delta is -1.6933958632162103
# Model is not converging.  Current: 13315.681905470603 is not greater than 13318.93689175001. Delta is -3.2549862794076034
# Model is not converging.  Current: 13847.260327854796 is not greater than 13847.363969701331. Delta is -0.1036418465355382
# Model is not converging.  Current: 13401.21714335387 is not greater than 13401.219150300964. Delta is -0.002006947093832423
# Model is not converging.  Current: 12611.998233335333 is not greater than 12612.182933515427. Delta is -0.18470018009429623
# Model is not converging.  Current: 13296.45606336757 is not greater than 13303.209184073985. Delta is -6.7531207064148475
# Model is not converging.  Current: 12664.544892469428 is not greater than 12666.736617097258. Delta is -2.191724627829899
# Model is not converging.  Current: 12936.233185935173 is not greater than 12940.003818123416. Delta is -3.770632188243326
# Model is not converging.  Current: 12841.05621937768 is not greater than 12842.149909726568. Delta is -1.0936903488873213
# Model is not converging.  Current: 13757.087434573383 is not greater than 13760.629911779697. Delta is -3.542477206314288
# Model is not converging.  Current: 12831.97269544364 is not greater than 12832.963793345409. Delta is -0.9910979017695354
# Model is not converging.  Current: 13798.470879944056 is not greater than 13799.607318820938. Delta is -1.1364388768815843
# Model is not converging.  Current: 12390.519971754931 is not greater than 12394.749316947227. Delta is -4.229345192296023
# Model is not converging.  Current: 13062.583130484849 is not greater than 13076.285786860026. Delta is -13.702656375176957
# Model is not converging.  Current: 12459.811406041006 is not greater than 12461.119320002133. Delta is -1.3079139611272694
# Model is not converging.  Current: 13872.393810071215 is not greater than 13872.500046023551. Delta is -0.10623595233664673
# Model is not converging.  Current: 13593.920958806264 is not greater than 13597.497941867043. Delta is -3.57698306077873
# Model is not converging.  Current: 13668.188267192832 is not greater than 13673.115867903864. Delta is -4.927600711031118
# Model is not converging.  Current: 13626.80529467442 is not greater than 13627.87805789764. Delta is -1.0727632232210453
# Model is not converging.  Current: 13120.092257552184 is not greater than 13122.13096600649. Delta is -2.038708454307198
# Model is not converging.  Current: 11562.441147322079 is not greater than 11566.429077171244. Delta is -3.9879298491650843
# Model is not converging.  Current: 13416.752207665435 is not greater than 13416.83922077271. Delta is -0.0870131072751974
# Model is not converging.  Current: 13208.132048041565 is not greater than 13209.579110113777. Delta is -1.447062072211338
# Model is not converging.  Current: 12712.132699398198 is not greater than 12712.189159779184. Delta is -0.05646038098529971
# Model is not converging.  Current: 13070.111600927246 is not greater than 13072.609808595456. Delta is -2.498207668209943
# Model is not converging.  Current: 13204.730495552178 is not greater than 13208.751525765747. Delta is -4.021030213569247
# Model is not converging.  Current: 12308.129625817332 is not greater than 12310.42559138972. Delta is -2.2959655723880132
# Model is not converging.  Current: 11674.268505031268 is not greater than 11677.255715349944. Delta is -2.987210318675352
# Model is not converging.  Current: 12434.651367493905 is not greater than 12437.428714928805. Delta is -2.7773474348996388
# Model is not converging.  Current: 12470.426813463548 is not greater than 12475.202381893376. Delta is -4.775568429828127
# Model is not converging.  Current: 13520.780332267546 is not greater than 13525.933714992656. Delta is -5.153382725109623
# Model is not converging.  Current: 12354.766567143597 is not greater than 12355.236152768202. Delta is -0.4695856246053154
# Model is not converging.  Current: 12112.066736414085 is not greater than 12118.888341073136. Delta is -6.821604659051445
# Model is not converging.  Current: 12740.826175549422 is not greater than 12741.097842952471. Delta is -0.271667403048923

# %%
# Show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
filterdf["Shannon/IV"] = filterdf["ShannonEntropy"] / filterdf["avg_iv"]
display(filterdf)
# Out:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 5      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8      en-US     US    EQUITY   Equity           Delayed Quote         True
# 9      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12     en-US     US    EQUITY   Equity           Delayed Quote        False
# 13     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 16     en-US     US    EQUITY   Equity           Delayed Quote         True
# 17     en-US     US    EQUITY   Equity           Delayed Quote        False
# 18     en-US     US    EQUITY   Equity           Delayed Quote        False
# 19     en-US     US    EQUITY   Equity           Delayed Quote        False
# 20     en-US     US    EQUITY   Equity           Delayed Quote        False
# 21     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 22     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23     en-US     US    EQUITY   Equity           Delayed Quote        False
# 24     en-US     US    EQUITY   Equity           Delayed Quote        False
# 25     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 26     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 27     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 28     en-US     US    EQUITY   Equity           Delayed Quote        False
# 29     en-US     US    EQUITY   Equity           Delayed Quote        False
# 30     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31     en-US     US    EQUITY   Equity           Delayed Quote        False
# 32     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33     en-US     US    EQUITY   Equity           Delayed Quote        False
# 34     en-US     US    EQUITY   Equity           Delayed Quote         True
# 35     en-US     US    EQUITY   Equity           Delayed Quote         True
# 36     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 37     en-US     US    EQUITY   Equity           Delayed Quote        False
# 38     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39     en-US     US    EQUITY   Equity           Delayed Quote         True
# 40     en-US     US    EQUITY   Equity           Delayed Quote        False
# 41     en-US     US    EQUITY   Equity           Delayed Quote        False
# 42     en-US     US    EQUITY   Equity           Delayed Quote        False
# 43     en-US     US    EQUITY   Equity           Delayed Quote        False
# 44     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 45     en-US     US    EQUITY   Equity           Delayed Quote        False
# 46     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 47     en-US     US    EQUITY   Equity           Delayed Quote        False
# 48     en-US     US    EQUITY   Equity           Delayed Quote        False
# 49     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 50     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 51     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52     en-US     US    EQUITY   Equity           Delayed Quote        False
# 53     en-US     US    EQUITY   Equity           Delayed Quote        False
# 54     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 56     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 57     en-US     US    EQUITY   Equity           Delayed Quote        False
# 58     en-US     US    EQUITY   Equity           Delayed Quote        False
# 59     en-US     US    EQUITY   Equity           Delayed Quote        False
# 60     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61     en-US     US    EQUITY   Equity           Delayed Quote        False
# 62     en-US     US    EQUITY   Equity           Delayed Quote        False
# 63     en-US     US    EQUITY   Equity           Delayed Quote        False
# 64     en-US     US    EQUITY   Equity           Delayed Quote        False
# 65     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 66     en-US     US    EQUITY   Equity           Delayed Quote        False
# 67     en-US     US    EQUITY   Equity           Delayed Quote        False
# 68     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 69     en-US     US    EQUITY   Equity           Delayed Quote         True
# 70     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 71     en-US     US    EQUITY   Equity           Delayed Quote        False
# 72     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 73     en-US     US    EQUITY   Equity           Delayed Quote        False
# 74     en-US     US    EQUITY   Equity           Delayed Quote         True
# 75     en-US     US    EQUITY   Equity           Delayed Quote        False
# 76     en-US     US    EQUITY   Equity           Delayed Quote        False
# 77     en-US     US    EQUITY   Equity           Delayed Quote         True
# 78     en-US     US    EQUITY   Equity           Delayed Quote        False
# 79     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 80     en-US     US    EQUITY   Equity           Delayed Quote        False
# 81     en-US     US    EQUITY   Equity           Delayed Quote        False
# 82     en-US     US    EQUITY   Equity           Delayed Quote        False
# 83     en-US     US    EQUITY   Equity           Delayed Quote        False
# 84     en-US     US    EQUITY   Equity           Delayed Quote         True
# 85     en-US     US    EQUITY   Equity           Delayed Quote        False
# 86     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 87     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 88     en-US     US    EQUITY   Equity           Delayed Quote        False
# 89     en-US     US    EQUITY   Equity           Delayed Quote        False
# 90     en-US     US    EQUITY   Equity           Delayed Quote        False
# 91     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 92     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 93     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 94     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 95     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 96     en-US     US    EQUITY   Equity           Delayed Quote        False
# 97     en-US     US    EQUITY   Equity           Delayed Quote        False
# 98     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 99     en-US     US    EQUITY   Equity           Delayed Quote        False
# 100    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 101    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 102    en-US     US    EQUITY   Equity           Delayed Quote        False
# 103    en-US     US    EQUITY   Equity           Delayed Quote        False
# 104    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 105    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 106    en-US     US    EQUITY   Equity           Delayed Quote        False
# 107    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 108    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 109    en-US     US    EQUITY   Equity           Delayed Quote         True
# 110    en-US     US    EQUITY   Equity           Delayed Quote        False
# 111    en-US     US    EQUITY   Equity           Delayed Quote        False
# 112    en-US     US    EQUITY   Equity           Delayed Quote         True
# 113    en-US     US    EQUITY   Equity           Delayed Quote        False
# 114    en-US     US    EQUITY   Equity           Delayed Quote        False
# 115    en-US     US    EQUITY   Equity           Delayed Quote        False
# 116    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 117    en-US     US    EQUITY   Equity           Delayed Quote        False
# 118    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 119    en-US     US    EQUITY   Equity           Delayed Quote        False
# 120    en-US     US    EQUITY   Equity           Delayed Quote        False
# 121    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 122    en-US     US    EQUITY   Equity           Delayed Quote        False
# 123    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 124    en-US     US    EQUITY   Equity           Delayed Quote        False
# 125    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 126    en-US     US    EQUITY   Equity           Delayed Quote         True
# 127    en-US     US    EQUITY   Equity           Delayed Quote        False
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity           Delayed Quote         True
# 131    en-US     US    EQUITY   Equity           Delayed Quote        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
# 133    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 134    en-US     US    EQUITY   Equity           Delayed Quote        False
# 135    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 136    en-US     US    EQUITY   Equity           Delayed Quote        False
# 137    en-US     US    EQUITY   Equity           Delayed Quote        False
# 138    en-US     US    EQUITY   Equity           Delayed Quote        False
# 139    en-US     US    EQUITY   Equity           Delayed Quote         True
# 140    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 141    en-US     US    EQUITY   Equity           Delayed Quote        False
# 142    en-US     US    EQUITY   Equity           Delayed Quote        False
# 143    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 144    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 145    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 146    en-US     US    EQUITY   Equity           Delayed Quote        False
# 147    en-US     US    EQUITY   Equity           Delayed Quote        False
# 148    en-US     US    EQUITY   Equity           Delayed Quote        False
# 149    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 150    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 151    en-US     US    EQUITY   Equity           Delayed Quote        False
# 152    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 153    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote         True
# 156    en-US     US    EQUITY   Equity           Delayed Quote        False
# 157    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 158    en-US     US    EQUITY   Equity           Delayed Quote        False
# 159    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 160    en-US     US    EQUITY   Equity           Delayed Quote        False
# 161    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 162    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 163    en-US     US    EQUITY   Equity           Delayed Quote        False
# 164    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 165    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 166    en-US     US    EQUITY   Equity           Delayed Quote        False
# 167    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 168    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 169    en-US     US    EQUITY   Equity           Delayed Quote        False
# 170    en-US     US    EQUITY   Equity           Delayed Quote        False
# 171    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 172    en-US     US    EQUITY   Equity           Delayed Quote        False
# 173    en-US     US    EQUITY   Equity           Delayed Quote        False
# 174    en-US     US    EQUITY   Equity           Delayed Quote        False
# 175    en-US     US    EQUITY   Equity           Delayed Quote        False
# 176    en-US     US    EQUITY   Equity           Delayed Quote        False
# 177    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 178    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 179    en-US     US    EQUITY   Equity           Delayed Quote        False
# 180    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 181    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 182    en-US     US    EQUITY   Equity           Delayed Quote        False
# 183    en-US     US    EQUITY   Equity           Delayed Quote        False
# 184    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 185    en-US     US    EQUITY   Equity           Delayed Quote        False
# 186    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 187    en-US     US    EQUITY   Equity           Delayed Quote         True
# 188    en-US     US    EQUITY   Equity           Delayed Quote        False
# 189    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 190    en-US     US    EQUITY   Equity           Delayed Quote         True
# 191    en-US     US    EQUITY   Equity           Delayed Quote        False
# 192    en-US     US    EQUITY   Equity           Delayed Quote        False
# 193    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 194    en-US     US    EQUITY   Equity           Delayed Quote        False
# 195    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 196    en-US     US    EQUITY   Equity           Delayed Quote        False
# 197    en-US     US    EQUITY   Equity           Delayed Quote        False
# 198    en-US     US    EQUITY   Equity           Delayed Quote         True
# 199    en-US     US    EQUITY   Equity           Delayed Quote        False
# 200    en-US     US    EQUITY   Equity           Delayed Quote        False
# 201    en-US     US    EQUITY   Equity           Delayed Quote        False
# 202    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 203    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 204    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 205    en-US     US    EQUITY   Equity           Delayed Quote        False
# 206    en-US     US    EQUITY   Equity           Delayed Quote        False
# 207    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 208    en-US     US    EQUITY   Equity           Delayed Quote         True
# 209    en-US     US    EQUITY   Equity           Delayed Quote        False
# 210    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 211    en-US     US    EQUITY   Equity           Delayed Quote        False
# 212    en-US     US    EQUITY   Equity           Delayed Quote        False
# 213    en-US     US    EQUITY   Equity           Delayed Quote        False
# 214    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 215    en-US     US    EQUITY   Equity           Delayed Quote        False
# 216    en-US     US    EQUITY   Equity           Delayed Quote        False
# 217    en-US     US    EQUITY   Equity           Delayed Quote        False
# 218    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 219    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 220    en-US     US    EQUITY   Equity           Delayed Quote        False
# 221    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 222    en-US     US    EQUITY   Equity           Delayed Quote        False
# 223    en-US     US    EQUITY   Equity           Delayed Quote         True
# 224    en-US     US    EQUITY   Equity           Delayed Quote        False
# 225    en-US     US    EQUITY   Equity           Delayed Quote        False
# 226    en-US     US    EQUITY   Equity           Delayed Quote        False
# 227    en-US     US    EQUITY   Equity           Delayed Quote        False
# 228    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 229    en-US     US    EQUITY   Equity           Delayed Quote        False
# 230    en-US     US    EQUITY   Equity           Delayed Quote        False
# 231    en-US     US    EQUITY   Equity           Delayed Quote        False
# 232    en-US     US    EQUITY   Equity           Delayed Quote        False
# 233    en-US     US    EQUITY   Equity           Delayed Quote         True
# 234    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 235    en-US     US    EQUITY   Equity           Delayed Quote        False
# 236    en-US     US    EQUITY   Equity           Delayed Quote         True
# 237    en-US     US    EQUITY   Equity           Delayed Quote        False
# 238    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 239    en-US     US    EQUITY   Equity           Delayed Quote        False
# 240    en-US     US    EQUITY   Equity           Delayed Quote        False
# 241    en-US     US    EQUITY   Equity           Delayed Quote        False
# 242    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 243    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 244    en-US     US    EQUITY   Equity           Delayed Quote        False
# 245    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 246    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 247    en-US     US    EQUITY   Equity           Delayed Quote        False
# 248    en-US     US    EQUITY   Equity           Delayed Quote        False
# 249    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 250    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 251    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#     customPriceAlertConfidence currency                        shortName  \
# 0                         HIGH      USD               NVIDIA Corporation
# 1                         HIGH      USD                Lucid Group, Inc.
# 2                         HIGH      USD                      Tesla, Inc.
# 3                          LOW      USD               Ford Motor Company
# 4                         HIGH      USD                Intel Corporation
# 5                         HIGH      USD       Palantir Technologies Inc.
# 6                         HIGH      USD          SoFi Technologies, Inc.
# 7                         HIGH      USD    American Airlines Group, Inc.
# 8                         HIGH      USD                       Apple Inc.
# 9                         HIGH      USD     Advanced Micro Devices, Inc.
# 10                        HIGH      USD      Applied Digital Corporation
# 11                         LOW      USD              MARA Holdings, Inc.
# 12                         LOW      USD                         NIO Inc.
# 13                        HIGH      USD       Super Micro Computer, Inc.
# 14                        HIGH      USD          Robinhood Markets, Inc.
# 15                        HIGH      USD                 Amazon.com, Inc.
# 16                        HIGH      USD                    Alphabet Inc.
# 17                         LOW      USD                        VALE S.A.
# 18                         LOW      USD                Banco Bradesco Sa
# 19                         LOW      USD         QuantumScape Corporation
# 20                         LOW      USD      Bank of America Corporation
# 21                         LOW      USD             Riot Platforms, Inc.
# 22                         LOW      USD                        Snap Inc.
# 23                         LOW      USD            Cleveland-Cliffs Inc.
# 24                         LOW      USD                        AT&T Inc.
# 25                         LOW      USD   Itau Unibanco Banco Holding SA
# 26                        HIGH      USD  Huntington Bancshares Incorpora
# 27                         LOW      USD           Quantum Computing Inc.
# 28                         LOW      USD                 CleanSpark, Inc.
# 29                         LOW      USD                        Amcor plc
# 30                         LOW      USD           SharpLink Gaming, Inc.
# 31                         LOW      USD             Carnival Corporation
# 32                        HIGH      USD          Micron Technology, Inc.
# 33                         LOW      USD          Uber Technologies, Inc.
# 34                        HIGH      USD         Marvell Technology, Inc.
# 35                        HIGH      USD                    Broadcom Inc.
# 36                        HIGH      USD              Comcast Corporation
# 37                         LOW      USD                  Stellantis N.V.
# 38                        HIGH      USD              Cisco Systems, Inc.
# 39                        HIGH      USD            Microsoft Corporation
# 40                         LOW      USD                          KeyCorp
# 41                         LOW      USD                         ADT Inc.
# 42                         LOW      USD      Verizon Communications Inc.
# 43                         LOW      USD            Wells Fargo & Company
# 44                        HIGH      USD                       Lyft, Inc.
# 45                         LOW      USD           Rocket Companies, Inc.
# 46                         LOW      USD                       Nike, Inc.
# 47                         LOW      USD                      fuboTV Inc.
# 48                         LOW      USD     Eos Energy Enterprises, Inc.
# 49                         LOW      USD  Norwegian Cruise Line Holdings
# 50                        HIGH      USD            Coinbase Global, Inc.
# 51                         LOW      USD     Chipotle Mexican Grill, Inc.
# 52                         LOW      USD             GameStop Corporation
# 53                         LOW      USD           Freeport-McMoRan, Inc.
# 54                         LOW      USD               MP Materials Corp.
# 55                        HIGH      USD        Peloton Interactive, Inc.
# 56                         LOW      USD              Unity Software Inc.
# 57                         LOW      USD                  Citigroup, Inc.
# 58                         LOW      USD    Alibaba Group Holding Limited
# 59                         LOW      USD                         Dow Inc.
# 60                         LOW      USD               Oracle Corporation
# 61                         LOW      USD              Newmont Corporation
# 62                         LOW      USD                  Infosys Limited
# 63                         LOW      USD  Taiwan Semiconductor Manufactur
# 64                         LOW      USD                    Coupang, Inc.
# 65                        HIGH      USD                     Shopify Inc.
# 66                         LOW      USD            Delta Air Lines, Inc.
# 67                         LOW      USD    Regions Financial Corporation
# 68                        HIGH      USD                     JD.com, Inc.
# 69                        HIGH      USD         Lam Research Corporation
# 70                        HIGH      USD            PayPal Holdings, Inc.
# 71                         LOW      USD                     U.S. Bancorp
# 72                        HIGH      USD            Starbucks Corporation
# 73                         LOW      USD           General Motors Company
# 74                        HIGH      USD                  DraftKings Inc.
# 75                         LOW      USD            Arista Networks, Inc.
# 76                         LOW      USD  American Eagle Outfitters, Inc.
# 77                        HIGH      USD  Microchip Technology Incorporat
# 78                         LOW      USD             Enphase Energy, Inc.
# 79                         LOW      USD                          HP Inc.
# 80                         LOW      USD                 V.F. Corporation
# 81                         LOW      USD            JP Morgan Chase & Co.
# 82                         LOW      USD             Amphenol Corporation
# 83                         LOW      USD             Boeing Company (The)
# 84                        HIGH      USD            QUALCOMM Incorporated
# 85                         LOW      USD  Charles Schwab Corporation (The
# 86                        HIGH      USD                PDD Holdings Inc.
# 87                        HIGH      USD   United Airlines Holdings, Inc.
# 88                         LOW      USD         Bloom Energy Corporation
# 89                         LOW      USD            Blue Owl Capital Inc.
# 90                         LOW      USD             Vertiv Holdings, LLC
# 91                        HIGH      USD                     Copart, Inc.
# 92                         LOW      USD            Skechers U.S.A., Inc.
# 93                        HIGH      USD          Applied Materials, Inc.
# 94                        HIGH      USD   Texas Instruments Incorporated
# 95                        HIGH      USD                    Datadog, Inc.
# 96                         LOW      USD                SentinelOne, Inc.
# 97                         LOW      USD  Tencent Music Entertainment Gro
# 98                        HIGH      USD                  Confluent, Inc.
# 99                         LOW      USD                     GE Aerospace
# 100                       HIGH      USD                      Hut 8 Corp.
# 101                        LOW      USD                        Visa Inc.
# 102                        LOW      USD        First Horizon Corporation
# 103                        LOW      USD                Alcoa Corporation
# 104                       HIGH      USD           Upstart Holdings, Inc.
# 105                       HIGH      USD         Palo Alto Networks, Inc.
# 106                        LOW      USD                      Invesco Ltd
# 107                       HIGH      USD                 Fastenal Company
# 108                        LOW      USD      United Parcel Service, Inc.
# 109                       HIGH      USD             Applovin Corporation
# 110                        LOW      USD           Dell Technologies Inc.
# 111                        LOW      USD                   Morgan Stanley
# 112                       HIGH      USD                        eBay Inc.
# 113                        LOW      USD            Las Vegas Sands Corp.
# 114                        LOW      USD                  RTX Corporation
# 115                        LOW      USD        TJX Companies, Inc. (The)
# 116                       HIGH      USD        O'Reilly Automotive, Inc.
# 117                        LOW      USD   Citizens Financial Group, Inc.
# 118                       HIGH      USD              Fifth Third Bancorp
# 119                        LOW      USD       Carrier Global Corporation
# 120                        LOW      USD  Mitsubishi UFJ Financial Group,
# 121                        LOW      USD             Corning Incorporated
# 122                        LOW      USD  Johnson Controls International
# 123                       HIGH      USD                First Solar, Inc.
# 124                        LOW      USD    Applied Optoelectronics, Inc.
# 125                        LOW      USD         Franklin Resources, Inc.
# 126                       HIGH      USD                     Li Auto Inc.
# 127                        LOW      USD               ICICI Bank Limited
# 128                       HIGH      USD                   Fortinet, Inc.
# 129                        LOW      USD  Capital One Financial Corporati
# 130                       HIGH      USD                        Flex Ltd.
# 131                        LOW      USD                   Snowflake Inc.
# 132                        LOW      USD      International Paper Company
# 133                       HIGH      USD                Match Group, Inc.
# 134                        LOW      USD             Huntsman Corporation
# 135                        LOW      USD  International Business Machines
# 136                        LOW      USD     LyondellBasell Industries NV
# 137                        LOW      USD  Cinemark Holdings Inc Cinemark
# 138                        LOW      USD                Fluor Corporation
# 139                       HIGH      USD                   DoorDash, Inc.
# 140                       HIGH      USD             EchoStar Corporation
# 141                        LOW      USD                    Corteva, Inc.
# 142                        LOW      USD      Deckers Outdoor Corporation
# 143                       HIGH      USD                       Okta, Inc.
# 144                       HIGH      USD         Ares Capital Corporation
# 145                       HIGH      USD                       Roku, Inc.
# 146                        LOW      USD                      Carvana Co.
# 147                        LOW      USD                  Celestica, Inc.
# 148                        LOW      USD        Union Pacific Corporation
# 149                       HIGH      USD                     Nasdaq, Inc.
# 150                       HIGH      USD                   Maplebear Inc.
# 151                        LOW      USD               Best Buy Co., Inc.
# 152                       HIGH      USD                   Teradyne, Inc.
# 153                       HIGH      USD                       Adobe Inc.
# 154                       HIGH      USD                   Entegris, Inc.
# 155                       HIGH      USD     Honeywell International Inc.
# 156                        LOW      USD              Synchrony Financial
# 157                        LOW      USD                    Rio Tinto Plc
# 158                        LOW      USD            AngloGold Ashanti PLC
# 159                        LOW      USD              Brown & Brown, Inc.
# 160                        LOW      USD                       CarMax Inc
# 161                       HIGH      USD                  Freshworks Inc.
# 162                       HIGH      USD                      Baidu, Inc.
# 163                        LOW      USD           McDonald's Corporation
# 164                       HIGH      USD                    Netflix, Inc.
# 165                       HIGH      USD           SiriusXM Holdings Inc.
# 166                        LOW      USD            Howmet Aerospace Inc.
# 167                       HIGH      USD         Skyworks Solutions, Inc.
# 168                       HIGH      USD         lululemon athletica inc.
# 169                        LOW      USD                BHP Group Limited
# 170                        LOW      USD  Apollo Global Management, Inc.
# 171                       HIGH      USD                      PACCAR Inc.
# 172                        LOW      USD                    MetLife, Inc.
# 173                        LOW      USD             Global Payments Inc.
# 174                        LOW      USD  Knight-Swift Transportation Hol
# 175                        LOW      USD      Axalta Coating Systems Ltd.
# 176                        LOW      USD         American Express Company
# 177                       HIGH      USD           Trip.com Group Limited
# 178                        LOW      USD                  Dynatrace, Inc.
# 179                        LOW      USD               Pure Storage, Inc.
# 180                        LOW      USD                    Innodata Inc.
# 181                       HIGH      USD                    Nutanix, Inc.
# 182                        LOW      USD                Caterpillar, Inc.
# 183                        LOW      USD      Abercrombie & Fitch Company
# 184                       HIGH      USD           The Carlyle Group Inc.
# 185                        LOW      USD   Intercontinental Exchange Inc.
# 186                       HIGH      USD                  LKQ Corporation
# 187                       HIGH      USD       Allegro MicroSystems, Inc.
# 188                        LOW      USD  Brookfield Asset Management Inc
# 189                       HIGH      USD  Lattice Semiconductor Corporati
# 190                       HIGH      USD                   CME Group Inc.
# 191                        LOW      USD         Equitable Holdings, Inc.
# 192                        LOW      USD                        Aptiv PLC
# 193                       HIGH      USD           Lumentum Holdings Inc.
# 194                        LOW      USD               AFLAC Incorporated
# 195                       HIGH      USD                    Workday, Inc.
# 196                        LOW      USD       Builders FirstSource, Inc.
# 197                        LOW      USD                Masco Corporation
# 198                       HIGH      USD                     Hasbro, Inc.
# 199                        LOW      USD  PNC Financial Services Group, I
# 200                        LOW      USD  Goldman Sachs Group, Inc. (The)
# 201                        LOW      USD                       TransUnion
# 202                       HIGH      USD                    Paychex, Inc.
# 203                       HIGH      USD  Take-Two Interactive Software,
# 204                       HIGH      USD               Zillow Group, Inc.
# 205                        LOW      USD              BILL Holdings, Inc.
# 206                        LOW      USD                Core & Main, Inc.
# 207                       HIGH      USD                 Tetra Tech, Inc.
# 208                       HIGH      USD          Arch Capital Group Ltd.
# 209                        LOW      USD         State Street Corporation
# 210                       HIGH      USD       Northern Trust Corporation
# 211                        LOW      USD     Floor & Decor Holdings, Inc.
# 212                        LOW      USD     Lincoln National Corporation
# 213                        LOW      USD             Celanese Corporation
# 214                       HIGH      USD                      Qorvo, Inc.
# 215                        LOW      USD                  FMC Corporation
# 216                        LOW      USD         Eastman Chemical Company
# 217                        LOW      USD            Comerica Incorporated
# 218                       HIGH      USD           TTM Technologies, Inc.
# 219                       HIGH      USD               Cognex Corporation
# 220                        LOW      USD              TE Connectivity plc
# 221                       HIGH      USD              Expedia Group, Inc.
# 222                        LOW      USD                     Embraer S.A.
# 223                       HIGH      USD               FTAI Aviation Ltd.
# 224                        LOW      USD              Toll Brothers, Inc.
# 225                        LOW      USD      Lockheed Martin Corporation
# 226                        LOW      USD           A.O. Smith Corporation
# 227                        LOW      USD           Waste Management, Inc.
# 228                        LOW      USD  International Flavors & Fragran
# 229                        LOW      USD                     Polaris Inc.
# 230                        LOW      USD       Prudential Financial, Inc.
# 231                        LOW      USD        Magna International, Inc.
# 232                        LOW      USD   Sherwin-Williams Company (The)
# 233                       HIGH      USD                 Five Below, Inc.
# 234                       HIGH      USD        T. Rowe Price Group, Inc.
# 235                        LOW      USD            Whirlpool Corporation
# 236                       HIGH      USD                     Trimble Inc.
# 237                        LOW      USD      Ares Management Corporation
# 238                       HIGH      USD            Varonis Systems, Inc.
# 239                        LOW      USD             Planet Fitness, Inc.
# 240                        LOW      USD      Southern Copper Corporation
# 241                        LOW      USD                Shake Shack, Inc.
# 242                       HIGH      USD             Steel Dynamics, Inc.
# 243                        LOW      USD                       Jabil Inc.
# 244                        LOW      USD                        XPO, Inc.
# 245                       HIGH      USD          Avis Budget Group, Inc.
# 246                        LOW      USD                     GoDaddy Inc.
# 247                        LOW      USD            Shift4 Payments, Inc.
# 248                        LOW      USD                          Aon plc
# 249                        LOW      USD       Procore Technologies, Inc.
# 250                       HIGH      USD    C.H. Robinson Worldwide, Inc.
# 251                        LOW      USD                         GMS Inc.
#
#          bid      ask  regularMarketChangePercent exchange  fiftyTwoWeekHigh  \
# 0     173.61   182.83                   -2.333160      NMS        183.300000
# 1       2.40     2.47                   -1.626010      NMS          4.430000
# 2     302.56   302.84                   -1.829560      NMS        488.540000
# 3      10.79    10.81                   -2.258360      NYQ         11.970000
# 4      19.28    19.34                   -2.474750      NMS         27.550000
# 5     154.12   154.42                   -2.576572      NMS        160.890000
# 6      21.00    22.79                   -5.978740      NMS         25.110000
# 7      11.01    11.07                   -4.003480      NMS         19.100000
# 8     192.07   213.25                   -2.500362      NMS        260.100000
# 9     171.58   171.83                   -2.614710      NMS        182.500000
# 10     12.46    12.54                   -4.718420      NMS         15.420000
# 11     15.44    15.55                   -3.606960      NCM         30.280000
# 12      4.93     4.94                    2.874750      NYQ          7.710000
# 13     56.51    56.77                   -3.951160      NMS         66.440000
# 14     99.87   108.34                   -3.056770      NMS        113.439000
# 15    206.15   217.50                   -8.269617      NMS        242.520000
# 16    179.46   198.61                   -1.443454      NMS        207.050000
# 17      9.67     9.75                    1.888780      NYQ         12.050000
# 18      2.80     2.81                    1.444040      NYQ          3.130000
# 19      8.28     8.23                   -3.953490      NYQ         15.030000
# 20     45.68    45.75                   -3.405970      NYQ         49.310000
# 21     11.00    11.15                  -17.747952      NCM         15.870000
# 22      9.02     9.07                   -4.029690      NYQ         13.281000
# 23     10.07    10.09                   -4.372620      NYQ         14.340000
# 24     27.75    27.80                    1.240420      NYQ         29.190000
# 25      6.30     6.31                    0.318979      NYQ          6.950000
# 26     15.98    16.04                   -2.373700      NMS         18.450000
# 27     14.77    14.86                   -0.269542      NCM         27.150000
# 28      9.40    10.80                   -8.179420      NCM         17.970000
# 29      9.29     9.49                   -0.534761      NYQ         11.480000
# 30     13.52    22.10                   -8.878257      NCM        124.120000
# 31     29.10    29.08                   -2.351360      NYQ         31.010000
# 32    104.78   104.95                   -3.903250      NMS        129.850000
# 33     86.80    86.85                   -0.957261      NYQ         97.715000
# 34     74.34    74.70                   -7.365940      NMS        127.480000
# 35    288.35   306.56                   -1.722846      NMS        306.950000
# 36     30.96    34.52                   -2.136621      NMS         45.310000
# 37      8.76     8.77                   -1.124860      NYQ         16.920000
# 38     67.03    67.15                   -1.424796      NMS         69.780000
# 39    523.77   524.40                   -1.760078      NMS        555.450000
# 40     17.60    17.74                   -1.506700      NYQ         20.040000
# 41      8.10     8.45                   -0.598805      NYQ          8.800000
# 42     42.86    42.90                    0.280643      NYQ         47.360000
# 43     77.85    78.09                   -3.534660      NYQ         84.830000
# 44     13.57    13.65                   -3.129449      NMS         19.065000
# 45     16.54    16.58                   11.983800      NYQ         21.380000
# 46     74.41    74.60                   -0.093720      NYQ         90.620000
# 47      3.78     3.79                   -5.778890      NYQ          6.450000
# 48      5.36     5.69                   -3.333330      NCM          7.360000
# 49     24.36    24.37                   -4.147100      NYQ         29.290000
# 50    314.28   316.19                  -16.695800      NMS        444.650000
# 51     42.52    42.50                   -0.839554      NYQ         66.740000
# 52     22.16    22.22                   -1.559020      NYQ         35.810000
# 53     40.08    40.06                   -0.521876      NYQ         52.610000
# 54     63.55    64.00                    3.560970      NYQ         65.840000
# 55      5.59     7.55                   -7.563025      NMS         10.895000
# 56     31.80    31.77                   -4.586330      NYQ         38.960000
# 57     91.83    91.91                   -1.995730      NYQ         96.910000
# 58    116.95   117.00                   -2.951170      NYQ        148.430000
# 59     21.86    21.90                   -6.440530      NYQ         55.670000
# 60    244.20   244.00                   -3.684440      NYQ        260.870000
# 61     62.52    62.63                    0.789053      NYQ         66.570000
# 62     16.37    16.64                   -1.854060      NYQ         23.630000
# 63    234.10   235.00                   -2.652920      NYQ        248.280000
# 64     28.74    28.90                   -2.344550      NYQ         31.645000
# 65    118.45   118.78                   -2.953932      NMS        129.380000
# 66     50.97    51.22                   -3.871450      NYQ         69.980000
# 67     24.50    25.02                   -1.737070      NYQ         27.960000
# 68     30.78    35.49                   -1.841850      NMS         47.820000
# 69     89.93   100.16                    1.613250      NMS        102.590000
# 70     64.54    67.14                   -2.399650      NMS         93.660000
# 71     43.87    43.86                   -2.268680      NYQ         53.980000
# 72     82.21    91.31                   -2.579640      NMS        117.460000
# 73     52.26    52.58                   -1.518560      NYQ         61.240000
# 74     43.71    47.15                   -2.908529      NMS         53.610000
# 75    116.32   117.50                   -4.585300      NYQ        133.575000
# 76     10.75    11.05                   -0.555559      NYQ         22.830000
# 77     66.27    66.42                   -1.819790      NMS         82.870000
# 78     31.39    31.50                   -2.873920      NGM        130.080000
# 79     24.36    24.70                   -1.411280      NYQ         39.800000
# 80     11.55    11.70                   -0.511949      NYQ         29.020000
# 81    289.51   289.99                   -2.319060      NYQ        301.290000
# 82    103.76   107.86                   -2.065540      NYQ        108.850000
# 83    221.60   222.43                    0.027045      NYQ        242.690000
# 84    138.90   148.31                    0.974385      NMS        182.100000
# 85     95.54    96.20                   -2.251100      NYQ         99.590000
# 86     95.57   110.16                   -2.988100      NMS        155.670000
# 87     84.44    84.61                   -4.235080      NMS        116.000000
# 88     36.75    37.20                   -1.791920      NYQ         39.090000
# 89     18.75    19.00                   -2.635660      NYQ         26.725000
# 90    140.00   142.20                   -2.754130      NYQ        155.840000
# 91     45.00    48.91                    0.397080      NMS         64.380000
# 92     63.06    63.04                   -0.395257      NYQ         78.850000
# 93    179.91   180.08                   -0.038872      NMS        215.700000
# 94    170.05   190.15                   -0.110459      NMS        221.690000
# 95    135.43   135.73                   -3.129010      NMS        170.080000
# 96     17.92    17.95                   -2.181020      NYQ         29.290000
# 97     20.42    20.66                   -2.143870      NYQ         22.500000
# 98     17.08    17.26                   -2.961920      NMS         37.900000
# 99    269.40   269.70                   -0.627114      NYQ        274.940000
# 100    14.51    19.78                   -6.829950      NMS         31.950000
# 101   338.55   339.35                   -1.771500      NYQ        375.510000
# 102    21.31    21.45                   -2.154970      NYQ         23.000000
# 103    28.56    28.37                   -5.238570      NYQ         47.770000
# 104    79.07    79.38                   -3.082942      NMS         96.429000
# 105   172.73   173.08                   -0.414747      NMS        210.390000
# 106    20.62    20.61                   -1.903850      NYQ         21.850000
# 107    45.40    45.47                   -1.495778      NMS         48.100000
# ...
# 244                 17    0.950781
# 245                 18    0.841004
# 246                  0    0.984620
# 247                  2    0.574945
# 248               2459    0.545311
# 249                  8    0.978706
# 250                  6    0.765499
# 251                  0    0.035081
#
#                                    AvgReturn_7d  Shannon/IV
# 0        Ticker
# NVDA    0.000003
# dtype: float64    2.112159
# 1        Ticker
# LCID   -0.000083
# dtype: float64    1.187921
# 2        Ticker
# TSLA   -0.000007
# dtype: float64    1.490045
# 3           Ticker
# F   -0.000015
# dtype: float64    2.041484
# 4        Ticker
# INTC   -0.000071
# dtype: float64    2.231026
# 5        Ticker
# PLTR    0.000002
# dtype: float64    0.431804
# 6        Ticker
# SOFI   -0.000003
# dtype: float64    1.401426
# 7          Ticker
# AAL   -0.00002
# dtype: float64    2.243297
# 8        Ticker
# AAPL   -0.000021
# dtype: float64    1.497647
# 9         Ticker
# AMD    0.000029
# dtype: float64    0.457211
# 10       Ticker
# APLD    0.000057
# dtype: float64    0.102569
# 11       Ticker
# MARA   -0.000042
# dtype: float64    1.098762
# 12        Ticker
# NIO    0.000008
# dtype: float64    1.484589
# 13       Ticker
# SMCI    0.000036
# dtype: float64    0.717803
# 14       Ticker
# HOOD   -0.000006
# dtype: float64    0.441706
# 15       Ticker
# AMZN   -0.000023
# dtype: float64    0.430267
# 16      Ticker
# GOOGL   -0.000016
# dtype: float64    2.281300
# 17       Ticker
# VALE   -0.000021
# dtype: float64    1.502402
# 18        Ticker
# BBD   -0.000003
# dtype: float64    2.375572
# 19         Ticker
# QS   -0.000156
# dtype: float64    1.205350
# 20        Ticker
# BAC   -0.000021
# dtype: float64    2.271312
# 21        Ticker
# RIOT   -0.00009
# dtype: float64    0.301480
# 22       Ticker
# SNAP   -0.000038
# dtype: float64    0.713886
# 23        Ticker
# CLF   -0.000041
# dtype: float64    1.898817
# 24      Ticker
# T   -8.706973e-07
# dtype: float64    2.918384
# 25       Ticker
# ITUB   -0.000004
# dtype: float64    0.409342
# 26       Ticker
# HBAN   -0.000017
# dtype: float64    2.887210
# 27       Ticker
# QUBT   -0.000052
# dtype: float64    0.398818
# 28       Ticker
# CLSK   -0.000063
# dtype: float64    0.555737
# 29       Ticker
# AMCR   -0.000017
# dtype: float64    1.576650
# 30       Ticker
# SBET   -0.000147
# dtype: float64    0.732052
# 31        Ticker
# CCL   -0.000016
# dtype: float64    1.373818
# 32         Ticker
# MU   -0.000019
# dtype: float64    1.673605
# 33       Ticker
# UBER   -0.000019
# dtype: float64    1.027875
# 34       Ticker
# MRVL    0.000008
# dtype: float64    0.132367
# 35       Ticker
# AVGO   -0.000002
# dtype: float64    1.208878
# 36      Ticker
# CMCSA   -0.000035
# dtype: float64    0.895167
# 37       Ticker
# STLA   -0.000037
# dtype: float64    0.315380
# 38       Ticker
# CSCO   -0.000006
# dtype: float64    2.092024
# 39       Ticker
# MSFT    0.000011
# dtype: float64    0.134038
# 40        Ticker
# KEY   -0.000021
# dtype: float64    2.016229
# 41        Ticker
# ADT   -0.000001
# dtype: float64    2.287558
# 42     Ticker
# VZ   -6.714712e-07
# dtype: float64    1.199472
# 43        Ticker
# WFC   -0.000026
# dtype: float64    1.433569
# 44       Ticker
# LYFT   -0.000027
# dtype: float64    0.947521
# 45        Ticker
# RKT    0.000018
# dtype: float64    0.483472
# 46        Ticker
# NKE   -0.000008
# dtype: float64    1.417406
# 47       Ticker
# FUBO    0.000013
# dtype: float64    0.296632
# 48       Ticker
# EOSE   -0.000038
# dtype: float64    0.954538
# 49        Ticker
# NCLH    0.00001
# dtype: float64    0.311160
# 50       Ticker
# COIN   -0.000086
# dtype: float64    0.270752
# 51        Ticker
# CMG   -0.000025
# dtype: float64    2.619432
# 52        Ticker
# GME   -0.000028
# dtype: float64    3.150251
# 53        Ticker
# FCX   -0.000043
# dtype: float64    0.832912
# 54         Ticker
# MP    0.000013
# dtype: float64    0.763274
# 55       Ticker
# PTON    0.000004
# dtype: float64    0.136386
# 56          Ticker
# U   -0.000015
# dtype: float64    0.517653
# 57          Ticker
# C   -0.000016
# dtype: float64    0.685166
# 58       Ticker
# BABA   -0.000014
# dtype: float64    0.510804
# 59        Ticker
# DOW   -0.000082
# dtype: float64    2.081569
# 60       Ticker
# ORCL    0.000004
# dtype: float64    1.858188
# 61        Ticker
# NEM    0.000012
# dtype: float64    0.534013
# 62        Ticker
# INFY   -0.00003
# dtype: float64    2.357400
# 63        Ticker
# TSM   -0.000008
# dtype: float64    0.425135
# 64       Ticker
# CPNG   -0.000022
# dtype: float64    0.443511
# 65        Ticker
# SHOP   -0.00001
# dtype: float64    0.916590
# 66        Ticker
# DAL   -0.000026
# dtype: float64    0.828129
# 67         Ticker
# RF   -0.000021
# dtype: float64    3.022339
# 68         Ticker
# JD   -0.000034
# dtype: float64    0.704648
# 69       Ticker
# LRCX   -0.000004
# dtype: float64    0.127951
# 70       Ticker
# PYPL   -0.000051
# dtype: float64    0.200365
# 71        Ticker
# USB   -0.000019
# dtype: float64    3.268505
# 72       Ticker
# SBUX   -0.000031
# dtype: float64    1.218283
# 73         Ticker
# GM   -0.000002
# dtype: float64    2.056395
# 74       Ticker
# DKNG   -0.000009
# dtype: float64    0.818330
# 75       Ticker
# ANET    0.000012
# dtype: float64    0.320322
# 76        Ticker
# AEO   -0.000033
# dtype: float64    1.228540
# 77        Ticker
# MCHP   -0.00001
# dtype: float64    1.855072
# 78       Ticker
# ENPH   -0.000055
# dtype: float64    2.170664
# 79        Ticker
# HPQ   -0.000019
# dtype: float64    3.180431
# 80        Ticker
# VFC   -0.000035
# dtype: float64    0.497062
# 81         Ticker
# JPM   -0.00001
# dtype: float64    1.677473
# 82        Ticker
# APH    0.000007
# dtype: float64    2.076976
# 83         Ticker
# BA   -0.000019
# dtype: float64    3.183607
# 84       Ticker
# QCOM   -0.000024
# dtype: float64    0.495739
# 85       Ticker
# SCHW    0.000002
# dtype: float64    1.760207
# 86        Ticker
# PDD   -0.000033
# dtype: float64    2.433132
# 87        Ticker
# UAL   -0.000016
# dtype: float64    0.732933
# 88          Ticker
# BE    0.00008
# dtype: float64    0.315996
# 89        Ticker
# OWL   -0.000032
# dtype: float64    1.584440
# 90        Ticker
# VRT    0.000029
# dtype: float64    0.271584
# 91        Ticker
# CPRT   -0.00001
# dtype: float64    4.078032
# 92        Ticker
# SKX   -0.000001
# dtype: float64    7.072766
# 93       Ticker
# AMAT   -0.000016
# dtype: float64    1.816508
# 94        Ticker
# TXN   -0.000012
# dtype: float64    0.679393
# 95       Ticker
# DDOG   -0.000028
# dtype: float64    1.424038
# 96          Ticker
# S   -0.000032
# dtype: float64    0.990652
# 97        Ticker
# TME   -0.000015
# dtype: float64    0.293712
# 98        Ticker
# CFLT   -0.00013
# dtype: float64    0.016832
# 99         Ticker
# GE    0.000008
# dtype: float64    1.568774
# 100       Ticker
# HUT   -0.000028
# dtype: float64    1.008078
# 101         Ticker
# V   -0.000017
# dtype: float64    2.886872
# 102        Ticker
# FHN   -0.00002
# dtype: float64    2.835820
# 103        Ticker
# AA   -0.000041
# dtype: float64    1.002212
# 104      Ticker
# UPST   -0.000019
# dtype: float64    0.219475
# 105      Ticker
# PANW   -0.000051
# dtype: float64    0.274259
# 106       Ticker
# IVZ   -0.000014
# dtype: float64    1.954980
# 107      Ticker
# FAST   -0.000015
# dtype: float64    3.229474
# 108        Ticker
# UPS   -0.00007
# dtype: float64    1.098962
# 109       Ticker
# APP    0.000018
# dtype: float64    0.599543
# 110  Ticker
# DELL   -3.810054e-07
# dtype: float64    0.450418
# 111        Ticker
# MS   -0.000008
# dtype: float64    0.639902
# 112      Ticker
# EBAY    0.000045
# dtype: float64    0.048202
# 113       Ticker
# LVS    0.000003
# dtype: float64    2.856965
# 114       Ticker
# RTX    0.000001
# dtype: float64    2.064081
# 115   Ticker
# TJX   -5.630979e-07
# dtype: float64    5.366863
# 116      Ticker
# ORLY    0.000011
# dtype: float64    1.357580
# 117       Ticker
# CFG   -0.000023
# dtype: float64    2.364073
# 118      Ticker
# FITB   -0.000015
# dtype: float64    1.221101
# 119      Ticker
# CARR   -0.000062
# dtype: float64    1.880216
# 120      Ticker
# MUFG   -0.000022
# dtype: float64    1.175973
# 121       Ticker
# GLW    0.000041
# dtype: float64    0.320548
# 122       Ticker
# JCI   -0.000009
# dtype: float64    1.158221
# 123      Ticker
# FSLR    0.000011
# dtype: float64    0.629817
# 124      Ticker
# AAOI   -0.000075
# dtype: float64    0.502590
# 125       Ticker
# BEN   -0.000012
# dtype: float64    0.726710
# 126        Ticker
# LI   -0.000064
# dtype: float64    0.371420
# 127       Ticker
# IBN   -0.000007
# dtype: float64    0.929452
# 128      Ticker
# FTNT   -0.000031
# dtype: float64    1.615815
# 129       Ticker
# COF   -0.000022
# dtype: float64    2.849155
# 130      Ticker
# FLEX   -0.000008
# dtype: float64    1.095971
# 131      Ticker
# SNOW   -0.000019
# dtype: float64    0.327423
# 132        Ticker
# IP   -0.000057
# dtype: float64    1.657184
# 133      Ticker
# MTCH   -0.000004
# dtype: float64    1.558384
# 134       Ticker
# HUN   -0.000077
# dtype: float64    2.144639
# 135       Ticker
# IBM   -0.000012
# dtype: float64    2.291569
# 136       Ticker
# LYB   -0.000059
# dtype: float64    2.187533
# 137       Ticker
# CNK   -0.000056
# dtype: float64    0.341727
# 138       Ticker
# FLR   -0.000086
# dtype: float64    0.006299
# 139      Ticker
# DASH    0.000012
# dtype: float64    1.267602
# 140      Ticker
# SATS   -0.000035
# dtype: float64    0.744667
# 141      Ticker
# CTVA   -0.000011
# dtype: float64    2.796596
# 142       Ticker
# DECK   -0.00001
# dtype: float64    0.250523
# 143      Ticker
# OKTA   -0.000003
# dtype: float64    2.609618
# 144      Ticker
# ARCC   -0.000011
# dtype: float64    1.528537
# 145      Ticker
# ROKU   -0.000039
# dtype: float64    0.072778
# 146      Ticker
# CVNA    0.000034
# dtype: float64    0.128288
# 147       Ticker
# CLS    0.000054
# dtype: float64    1.655174
# 148        Ticker
# UNP   -0.00001
# dtype: float64    3.037533
# 149      Ticker
# NDAQ    0.000014
# dtype: float64    2.822511
# 150      Ticker
# CART   -0.000019
# dtype: float64    1.599033
# 151       Ticker
# BBY   -0.000027
# dtype: float64    1.881988
# 152        Ticker
# TER    0.00005
# dtype: float64    0.741850
# 153      Ticker
# ADBE   -0.000025
# dtype: float64    1.452512
# 154      Ticker
# ENTG   -0.000065
# dtype: float64    0.306563
# 155       Ticker
# HON   -0.000011
# dtype: float64    2.936993
# 156       Ticker
# SYF   -0.000023
# dtype: float64    1.579440
# 157       Ticker
# RIO   -0.000027
# dtype: float64    3.013255
# 158        Ticker
# AU   -0.000005
# dtype: float64    1.748825
# 159       Ticker
# BRO   -0.000038
# dtype: float64    0.465468
# 160       Ticker
# KMX   -0.000037
# dtype: float64    3.284281
# 161      Ticker
# FRSH   -0.000037
# dtype: float64    2.204779
# 162      Ticker
# BIDU   -0.000025
# dtype: float64    2.531101
# 163       Ticker
# MCD    0.000009
# dtype: float64    2.402695
# 164      Ticker
# NFLX   -0.000005
# dtype: float64    4.182965
# 165      Ticker
# SIRI   -0.000048
# dtype: float64    1.905813
# 166       Ticker
# HWM   -0.000004
# dtype: float64    1.330543
# 167      Ticker
# SWKS   -0.000026
# dtype: float64    1.667574
# 168      Ticker
# LULU   -0.000051
# dtype: float64    1.933001
# 169       Ticker
# BHP   -0.000027
# dtype: float64    1.989188
# 170       Ticker
# APO   -0.000036
# dtype: float64    0.556588
# 171      Ticker
# PCAR   -0.000016
# dtype: float64    3.693437
# 172       Ticker
# MET   -0.000019
# dtype: float64    2.396034
# 173       Ticker
# GPN   -0.000028
# dtype: float64    1.372171
# 174       Ticker
# KNX   -0.000042
# dtype: float64    3.780765
# 175      Ticker
# AXTA   -0.000027
# dtype: float64    0.802876
# 176       Ticker
# AXP   -0.000016
# dtype: float64    3.570496
# 177      Ticker
# TCOM   -0.000026
# dtype: float64    1.973621
# 178        Ticker
# DT   -0.000022
# dtype: float64    1.581372
# 179      Ticker
# PSTG   -0.000017
# dtype: float64    1.923487
# 180      Ticker
# INOD   -0.000015
# dtype: float64    0.263992
# 181      Ticker
# NTNX   -0.000012
# dtype: float64    1.742047
# 182       Ticker
# CAT    0.000002
# dtype: float64    0.866908
# 183       Ticker
# ANF   -0.000015
# dtype: float64    0.819466
# 184        Ticker
# CG   -0.000013
# dtype: float64    0.872496
# 185       Ticker
# ICE    0.000007
# dtype: float64    1.493106
# 186       Ticker
# LKQ   -0.000039
# dtype: float64    3.403965
# 187      Ticker
# ALGM   -0.000029
# dtype: float64    1.807565
# 188       Ticker
# BAM   -0.000017
# dtype: float64    0.796087
# 189      Ticker
# LSCC   -0.000032
# dtype: float64    1.797464
# 190       Ticker
# CME    0.000005
# dtype: float64    6.144409
# 191       Ticker
# EQH   -0.000019
# dtype: float64    2.323269
# 192      Ticker
# APTV   -0.000026
# dtype: float64    1.107466
# 193      Ticker
# LITE    0.000016
# dtype: float64    0.206864
# 194       Ticker
# AFL   -0.000018
# dtype: float64    3.804740
# 195      Ticker
# WDAY   -0.000032
# dtype: float64    2.268091
# 196       Ticker
# BLDR   -0.00001
# dtype: float64    1.971139
# 197       Ticker
# MAS    0.000008
# dtype: float64    0.595544
# 198       Ticker
# HAS   -0.000008
# dtype: float64    2.724084
# 199       Ticker
# PNC   -0.000024
# dtype: float64    2.095633
# 200        Ticker
# GS   -0.000005
# dtype: float64    1.208871
# 201       Ticker
# TRU   -0.000022
# dtype: float64    1.996805
# 202      Ticker
# PAYX   -0.000014
# dtype: float64    3.397244
# 203      Ticker
# TTWO   -0.000015
# dtype: float64    2.375300
# 204         Ticker
# Z    0.000004
# dtype: float64    2.148141
# 205      Ticker
# BILL   -0.000039
# dtype: float64    2.314646
# 206       Ticker
# CNM   -0.000013
# dtype: float64    1.552045
# 207      Ticker
# TTEK   -0.000027
# dtype: float64    1.869450
# 208      Ticker
# ACGL   -0.000002
# dtype: float64    2.666334
# 209       Ticker
# STT   -0.000007
# dtype: float64    2.866618
# 210      Ticker
# NTRS    0.000007
# dtype: float64    2.396887
# 211       Ticker
# FND   -0.000011
# dtype: float64    1.417247
# 212        Ticker
# LNC    0.00002
# dtype: float64    0.534111
# 213        Ticker
# CE   -0.000068
# dtype: float64    1.202438
# 214      Ticker
# QRVO   -0.000015
# dtype: float64    2.563788
# 215       Ticker
# FMC   -0.000049
# dtype: float64    1.324017
# 216        Ticker
# EMN   -0.00011
# dtype: float64    0.061638
# 217   Ticker
# CMA    1.027902e-07
# dtype: float64    2.821861
# 218      Ticker
# TTMI   -0.000021
# dtype: float64    0.815864
# 219      Ticker
# CGNX    0.000069
# dtype: float64    0.092741
# 220       Ticker
# TEL    0.000002
# dtype: float64    3.144406
# 221      Ticker
# EXPE   -0.000032
# dtype: float64    1.098373
# 222       Ticker
# ERJ    0.000058
# dtype: float64    1.176119
# 223      Ticker
# FTAI    0.000092
# dtype: float64    0.639408
# 224       Ticker
# TOL   -0.000011
# dtype: float64    1.589178
# 225       Ticker
# LMT   -0.000003
# dtype: float64    3.499639
# 226       Ticker
# AOS   -0.000011
# dtype: float64    2.860414
# 227        Ticker
# WM    0.000002
# dtype: float64    1.766312
# 228       Ticker
# IFF   -0.000038
# dtype: float64    2.220214
# 229       Ticker
# PII   -0.000019
# dtype: float64    1.860218
# 230       Ticker
# PRU   -0.000015
# dtype: float64    2.959227
# 231       Ticker
# MGA   -0.000015
# dtype: float64    1.820640
# 232       Ticker
# SHW    0.000005
# dtype: float64    5.323254
# 233      Ticker
# FIVE   -0.000017
# dtype: float64    1.701376
# 234      Ticker
# TROW   -0.000015
# dtype: float64    2.317809
# 235       Ticker
# WHR   -0.000062
# dtype: float64    0.399878
# 236      Ticker
# TRMB   -0.000003
# dtype: float64    2.133075
# 237      Ticker
# ARES    0.000004
# dtype: float64    1.191437
# 238      Ticker
# VRNS    0.000014
# dtype: float64    2.261223
# 239      Ticker
# PLNT   -0.000018
# dtype: float64    2.247772
# 240      Ticker
# SCCO   -0.000031
# dtype: float64    1.891820
# 241       Ticker
# SHAK   -0.00007
# dtype: float64    0.727275
# 242      Ticker
# STLD   -0.000024
# dtype: float64    1.116123
# 243       Ticker
# JBL   -0.000012
# dtype: float64    1.138034
# 244       Ticker
# XPO   -0.000047
# dtype: float64    0.975542
# 245       Ticker
# CAR   -0.000096
# dtype: float64    0.337026
# 246      Ticker
# GDDY   -0.000027
# dtype: float64    1.579594
# 247      Ticker
# FOUR   -0.000015
# dtype: float64    2.050726
# 248       Ticker
# AON   -0.000004
# dtype: float64    0.694225
# 249       Ticker
# PCOR   -0.00007
# dtype: float64    0.764631
# 250      Ticker
# CHRW    0.000052
# dtype: float64    3.369410
# 251   Ticker
# GMS    4.334801e-07
# dtype: float64    8.623325

# %%
import nest_asyncio
nest_asyncio.apply()
import asyncio
from ib_insync import *
import pandas as pd
import numpy as np
import ta
import plotly.graph_objects as go

"""
Filter parameters
-----------------
VOL_WINDOW:       ATR period (bars) for volatility calculation (consider higher for daily)
VOL_THRESHOLD:    Minimum ATR percent (ATR/close) for a bar to be considered volatile enough for trading (e.g., 0.01 = 1%)
REGIME_THRESHOLD: Rolling mean of returns must be above this (e.g., -0.1) to be considered "trending" regime
ADX_PERIOD:       ADX calculation period (bars)
ADX_THRESHOLD:    Minimum ADX value to confirm market is trending (20 = classic)
SMA_PERIOD:       SMA bars for trend filter (only long if above, short if below)
"""

# ========= CHART SETTINGS =========
BAR_SIZE = '1 day'      # IBKR bar size for daily candles
DURATION = '5 Y'        # How far back to get data (e.g., '5 Y' = 5 years)
NUM_BARS = 2000         # Approximate daily bars in 5 years
# ================================

# Filter tuning (adjust to your needs)
VOL_WINDOW       = 30        # ATR lookback period (bars); for daily, 14-30 is common
VOL_THRESHOLD    = 0.001     # Minimum ATR% for volatility filter (e.g., 0.01=1%)
REGIME_THRESHOLD = -0.1      # Regime filter threshold
ADX_PERIOD       = 14        # ADX lookback window (bars)
ADX_THRESHOLD    = 20        # Minimum ADX to allow signals (trend filter)
SMA_PERIOD       = 200       # SMA filter period (bars)

EXCHANGE    = 'SMART'
CURRENCY    = 'USD'
LOOKAHEAD   = 4
K_NEIGHBORS = 8

FEATURES = ['RSI', 'ADX', 'CCI', 'MACD']

filterdf['symbol'] = filterdf['symbol'].str.replace('-', ' ')

# ==== Data Fetch Function ====
async def fetch_ibkr_stock(symbol, exchange, currency, bar_size, duration, num_bars):
    """Fetches OHLCV bars from IBKR using specified bar size/duration."""
    ib = IB()
    await ib.connectAsync('127.0.0.1', 7497, clientId=np.random.randint(1000, 10000))
    contract = Stock(symbol, exchange, currency)
    await ib.qualifyContractsAsync(contract)
    bars = await ib.reqHistoricalDataAsync(
        contract=contract,
        endDateTime='',
        durationStr=duration,
        barSizeSetting=bar_size,
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1,
        keepUpToDate=False
    )
    df = util.df(bars)
    df.set_index('date', inplace=True)
    df = df.tail(num_bars)
    ib.disconnect()
    return df


# ==== ML Functions and Filters ====
def lorentzian_distance(a, b):
    return np.sum(np.log(1 + np.abs(a - b)))


def volatility_filter(df, vol_window, vol_thresh):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=vol_window).average_true_range()
    atr_pct = atr / df['close']
    return atr_pct > vol_thresh


def regime_filter(df, threshold):
    close_returns = df['close'].pct_change()
    regime = close_returns.rolling(window=20).mean()
    return regime > threshold


def adx_filter(df, adx_period, adx_threshold):
    adx = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=adx_period).adx()
    return adx > adx_threshold


def classify_lorentzian_knn_with_filters(
        df, features, sma_period,
        vol_window, vol_thresh,
        regime_thresh, adx_period, adx_thresh,
        n_neighbors=8, lookahead=4, max_bars_back=500):
    pred = np.full(len(df), np.nan)
    neighbors_info = {}

    closes = df['close'].values
    feature_mat = df[features].values
    sma = df['SMA'].values

    vol_filter = volatility_filter(df, vol_window, vol_thresh)
    regime_filt = regime_filter(df, regime_thresh)
    adx_filt = adx_filter(df, adx_period, adx_thresh)

    length = len(df)

    # Main loop - exclude last 'lookahead' bars
    for idx in range(max_bars_back, length - lookahead):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    # Explicit classification for last 'lookahead' bars
    for idx in range(length - lookahead, length):
        if np.isnan(sma[idx]) or closes[idx] == 0:
            continue
        if not (vol_filter.iloc[idx] and regime_filt.iloc[idx] and adx_filt.iloc[idx]):
            continue
        anchor_start = max(0, idx - max_bars_back)
        anchor_indices = np.arange(anchor_start, idx)
        anchor_feats = feature_mat[anchor_indices, :]
        target = feature_mat[idx]
        dists = np.array([lorentzian_distance(target, anchor_feats[j]) for j in range(anchor_feats.shape[0])])
        if len(dists) < n_neighbors:
            continue
        knn_indices = dists.argsort()[:n_neighbors]
        valid = anchor_indices[knn_indices] + lookahead < length
        selected = anchor_indices[knn_indices][valid]
        if len(selected) == 0:
            continue
        y_train = (closes[selected + lookahead] > closes[selected]).astype(int) - \
                  (closes[selected + lookahead] < closes[selected]).astype(int)
        vote = y_train.sum()
        raw_signal = np.sign(vote) if vote != 0 else 0
        if raw_signal == 1 and closes[idx] > sma[idx]:
            pred[idx] = 1
        elif raw_signal == -1 and closes[idx] < sma[idx]:
            pred[idx] = -1
        else:
            pred[idx] = 0
        neighbors_info[idx] = y_train.tolist()

    return pred, neighbors_info


# ==== Process symbols from filterdf ====
async def process_symbols_with_knn(filterdf):
    filterdf['pct_buy_last_8d'] = np.nan
    filterdf['pct_sell_last_8d'] = np.nan

    for i, row in filterdf.iterrows():
        symbol = row['symbol']  # Adjust if your symbol column is named differently
        print(f"Processing {symbol} ...")

        df = await fetch_ibkr_stock(symbol, EXCHANGE, CURRENCY, BAR_SIZE, DURATION, NUM_BARS)

        # Feature Engineering
        df['RSI'] = ta.momentum.RSIIndicator(df['close'], window=14).rsi()
        df['ADX'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close'], window=14).adx()
        df['CCI'] = ta.trend.CCIIndicator(df['high'], df['low'], df['close'], window=20).cci()
        df['SMA'] = ta.trend.SMAIndicator(df['close'], window=SMA_PERIOD).sma_indicator()
        macd_ind = ta.trend.MACD(df['close'], window_slow=26, window_fast=12, window_sign=9)
        df['MACD'] = macd_ind.macd()
        df['MACD_signal'] = macd_ind.macd_signal()
        df['MACD_hist'] = macd_ind.macd_diff()
        df = df.dropna().reset_index()

        preds, _ = classify_lorentzian_knn_with_filters(
            df, FEATURES, SMA_PERIOD, VOL_WINDOW, VOL_THRESHOLD,
            REGIME_THRESHOLD, ADX_PERIOD, ADX_THRESHOLD,
            n_neighbors=K_NEIGHBORS, lookahead=LOOKAHEAD, max_bars_back=500
        )
        df['raw_pred'] = preds

        # Calculate % buy and sell signals in the last 8 days of predictions
        last_8 = df['raw_pred'].tail(8)
        pct_buy = (last_8 == 1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0
        pct_sell = (last_8 == -1).sum() / len(last_8) * 100 if len(last_8) > 0 else 0

        filterdf.at[i, 'pct_buy_last_8d'] = pct_buy
        filterdf.at[i, 'pct_sell_last_8d'] = pct_sell

    return filterdf


# --- Example usage ---
# Make sure you have your filter dataframe loaded with a 'symbol' column
# Example:
# filterdf = pd.DataFrame({'symbol': ['GOOG', 'AAPL', 'MSFT']})

if __name__ == '__main__':
    import sys

    # Replace or load your filter dataframe here
    # For demo, you can define it manually or read from CSV

    df_results = asyncio.run(process_symbols_with_knn(filterdf))
    print(df_results[['symbol', 'pct_buy_last_8d', 'pct_sell_last_8d']])
# Out:
# Processing NVDA ...
# Processing LCID ...
# Processing TSLA ...
# Processing F ...
# Processing INTC ...
# Processing PLTR ...
# Processing SOFI ...
# Processing AAL ...
# Processing AAPL ...
# Processing AMD ...
# Processing APLD ...
# Processing MARA ...
# Processing NIO ...
# Processing SMCI ...
# Processing HOOD ...
# Processing AMZN ...
# Processing GOOGL ...
# Processing VALE ...
# Processing BBD ...
# Processing QS ...
# Processing BAC ...
# Processing RIOT ...
# Processing SNAP ...
# Processing CLF ...
# Processing T ...
# Processing ITUB ...
# Processing HBAN ...
# Processing QUBT ...
# Processing CLSK ...
# Processing AMCR ...
# Processing SBET ...
# Processing CCL ...
# Processing MU ...
# Processing UBER ...
# Processing MRVL ...
# Processing AVGO ...
# Processing CMCSA ...
# Processing STLA ...
# Processing CSCO ...
# Processing MSFT ...
# Processing KEY ...
# Processing ADT ...
# Processing VZ ...
# Processing WFC ...
# Processing LYFT ...
# Processing RKT ...
# Processing NKE ...
# Processing FUBO ...
# Processing EOSE ...
# Processing NCLH ...
# Processing COIN ...
# Processing CMG ...
# Processing GME ...
# Processing FCX ...
# Processing MP ...
# Processing PTON ...
# Processing U ...
# Processing C ...
# Processing BABA ...
# Processing DOW ...
# Processing ORCL ...
# Processing NEM ...
# Processing INFY ...
# Processing TSM ...
# Processing CPNG ...
# Processing SHOP ...
# Processing DAL ...
# Processing RF ...
# Processing JD ...
# Processing LRCX ...
# Processing PYPL ...
# Processing USB ...
# Processing SBUX ...
# Processing GM ...
# Processing DKNG ...
# Processing ANET ...
# Processing AEO ...
# Processing MCHP ...
# Processing ENPH ...
# Processing HPQ ...
# Processing VFC ...
# Processing JPM ...
# Processing APH ...
# Processing BA ...
# Processing QCOM ...
# Processing SCHW ...
# Processing PDD ...
# Processing UAL ...
# Processing BE ...
# Processing OWL ...
# Processing VRT ...
# Processing CPRT ...
# Processing SKX ...
# Processing AMAT ...
# Processing TXN ...
# Processing DDOG ...
# Processing S ...
# Processing TME ...
# Processing CFLT ...
# Processing GE ...
# Processing HUT ...
# Processing V ...
# Processing FHN ...
# Processing AA ...
# Processing UPST ...
# Processing PANW ...
# Processing IVZ ...
# Processing FAST ...
# Processing UPS ...
# Processing APP ...
# Processing DELL ...
# Processing MS ...
# Processing EBAY ...
# Processing LVS ...
# Processing RTX ...
# Processing TJX ...
# Processing ORLY ...
# Processing CFG ...
# Processing FITB ...
# Processing CARR ...
# Processing MUFG ...
# Processing GLW ...
# Processing JCI ...
# Processing FSLR ...
# Processing AAOI ...
# Processing BEN ...
# Processing LI ...
# Processing IBN ...
# Processing FTNT ...
# Processing COF ...
# Processing FLEX ...
# Processing SNOW ...
# Processing IP ...
# Processing MTCH ...
# Processing HUN ...
# Processing IBM ...
# Processing LYB ...
# Processing CNK ...
# Processing FLR ...
# Processing DASH ...
# Processing SATS ...
# Processing CTVA ...
# Processing DECK ...
# Processing OKTA ...
# Processing ARCC ...
# Processing ROKU ...
# Processing CVNA ...
# Processing CLS ...
# Processing UNP ...
# Processing NDAQ ...
# Processing CART ...
# Processing BBY ...
# Processing TER ...
# Processing ADBE ...
# Processing ENTG ...
# Processing HON ...
# Processing SYF ...
# Processing RIO ...
# Processing AU ...
# Processing BRO ...
# Processing KMX ...
# Processing FRSH ...
# Processing BIDU ...
# Processing MCD ...
# Processing NFLX ...
# Processing SIRI ...
# Processing HWM ...
# Processing SWKS ...
# Processing LULU ...
# Processing BHP ...
# Processing APO ...
# Processing PCAR ...
# Processing MET ...
# Processing GPN ...
# Processing KNX ...
# Processing AXTA ...
# Processing AXP ...
# Processing TCOM ...
# Processing DT ...
# Processing PSTG ...
# Processing INOD ...
# Processing NTNX ...
# Processing CAT ...
# Processing ANF ...
# Processing CG ...
# Processing ICE ...
# Processing LKQ ...
# Processing ALGM ...
# Processing BAM ...
# Processing LSCC ...
# Processing CME ...
# Processing EQH ...
# Processing APTV ...
# Processing LITE ...
# Processing AFL ...
# Processing WDAY ...
# Processing BLDR ...
# Processing MAS ...
# Processing HAS ...
# Processing PNC ...
# Processing GS ...
# Processing TRU ...
# Processing PAYX ...
# Processing TTWO ...
# Processing Z ...
# Processing BILL ...
# Processing CNM ...
# Processing TTEK ...
# Processing ACGL ...
# Processing STT ...
# Processing NTRS ...
# Processing FND ...
# Processing LNC ...
# Processing CE ...
# Processing QRVO ...
# Processing FMC ...
# Processing EMN ...
# Processing CMA ...
# Processing TTMI ...
# Processing CGNX ...
# Processing TEL ...
# Processing EXPE ...
# Processing ERJ ...
# Processing FTAI ...
# Processing TOL ...
# Processing LMT ...
# Processing AOS ...
# Processing WM ...
# Processing IFF ...
# Processing PII ...
# Processing PRU ...
# Processing MGA ...
# Processing SHW ...
# Processing FIVE ...
# Processing TROW ...
# Processing WHR ...
# Processing TRMB ...
# Processing ARES ...
# Processing VRNS ...
# Processing PLNT ...
# Processing SCCO ...
# Processing SHAK ...
# Processing STLD ...
# Processing JBL ...
# Processing XPO ...
# Processing CAR ...
# Processing GDDY ...
# Processing FOUR ...
# Processing AON ...
# Processing PCOR ...
# Processing CHRW ...
# Processing GMS ...
#     symbol  pct_buy_last_8d  pct_sell_last_8d
# 0     NVDA            100.0               0.0
# 1     LCID             25.0              25.0
# 2     TSLA              0.0               0.0
# 3        F              0.0               0.0
# 4     INTC              0.0              62.5
# 5     PLTR             25.0               0.0
# 6     SOFI             75.0               0.0
# 7      AAL              0.0              37.5
# 8     AAPL              0.0              37.5
# 9      AMD             75.0               0.0
# 10    APLD              0.0               0.0
# 11    MARA             25.0               0.0
# 12     NIO              0.0               0.0
# 13    SMCI             25.0               0.0
# 14    HOOD             87.5               0.0
# 15    AMZN             25.0               0.0
# 16   GOOGL             12.5               0.0
# 17    VALE              0.0               0.0
# 18     BBD             75.0               0.0
# 19      QS             12.5               0.0
# 20     BAC              0.0               0.0
# 21    RIOT             12.5               0.0
# 22    SNAP              0.0              50.0
# 23     CLF             25.0               0.0
# 24       T             75.0               0.0
# 25    ITUB              0.0               0.0
# 26    HBAN             12.5               0.0
# 27    QUBT             37.5               0.0
# 28    CLSK             37.5              12.5
# 29    AMCR              0.0               0.0
# 30    SBET             25.0               0.0
# 31     CCL             62.5               0.0
# 32      MU             62.5               0.0
# 33    UBER              0.0               0.0
# 34    MRVL              0.0               0.0
# 35    AVGO             75.0               0.0
# 36   CMCSA              0.0              50.0
# 37    STLA              0.0               0.0
# 38    CSCO             87.5               0.0
# 39    MSFT             87.5               0.0
# 40     KEY             62.5               0.0
# 41     ADT              0.0               0.0
# 42      VZ              0.0               0.0
# 43     WFC             25.0               0.0
# 44    LYFT              0.0               0.0
# 45     RKT             62.5               0.0
# 46     NKE             37.5               0.0
# 47    FUBO              0.0               0.0
# 48    EOSE             25.0               0.0
# 49    NCLH             37.5               0.0
# 50    COIN             25.0               0.0
# 51     CMG              0.0               0.0
# 52     GME              0.0               0.0
# 53     FCX             12.5              37.5
# 54      MP              0.0               0.0
# 55    PTON              0.0               0.0
# 56       U             12.5               0.0
# 57       C             87.5               0.0
# 58    BABA             12.5               0.0
# 59     DOW              0.0              12.5
# 60    ORCL             75.0               0.0
# 61     NEM             25.0               0.0
# 62    INFY              0.0               0.0
# 63     TSM             25.0               0.0
# 64    CPNG             87.5               0.0
# 65    SHOP              0.0               0.0
# 66     DAL              0.0               0.0
# 67      RF             50.0               0.0
# 68      JD              0.0               0.0
# 69    LRCX              0.0               0.0
# 70    PYPL              0.0              12.5
# 71     USB             12.5               0.0
# 72    SBUX              0.0              37.5
# 73      GM              0.0               0.0
# 74    DKNG             50.0               0.0
# 75    ANET             37.5               0.0
# 76     AEO              0.0              12.5
# 77    MCHP             25.0               0.0
# 78    ENPH              0.0               0.0
# 79     HPQ              0.0               0.0
# 80     VFC              0.0               0.0
# 81     JPM             75.0               0.0
# 82     APH             87.5               0.0
# 83      BA             25.0               0.0
# 84    QCOM              0.0               0.0
# 85    SCHW             75.0               0.0
# 86     PDD             25.0               0.0
# 87     UAL             25.0               0.0
# 88      BE             50.0               0.0
# 89     OWL              0.0               0.0
# 90     VRT              0.0               0.0
# 91    CPRT              0.0              75.0
# 92     SKX            100.0               0.0
# 93    AMAT             25.0               0.0
# 94     TXN              0.0              75.0
# 95    DDOG             50.0               0.0
# 96       S              0.0              75.0
# 97     TME             37.5               0.0
# 98    CFLT              0.0               0.0
# 99      GE             25.0               0.0
# 100    HUT             25.0               0.0
# 101      V              0.0               0.0
# 102    FHN             62.5               0.0
# 103     AA              0.0               0.0
# 104   UPST             25.0               0.0
# 105   PANW              0.0               0.0
# 106    IVZ             37.5               0.0
# 107   FAST             37.5               0.0
# 108    UPS              0.0              12.5
# 109    APP              0.0               0.0
# 110   DELL             62.5               0.0
# 111     MS             37.5               0.0
# 112   EBAY             62.5               0.0
# 113    LVS             25.0               0.0
# 114    RTX              0.0               0.0
# 115    TJX              0.0               0.0
# 116   ORLY             25.0               0.0
# 117    CFG             37.5               0.0
# 118   FITB             37.5              25.0
# 119   CARR             37.5              12.5
# 120   MUFG              0.0               0.0
# 121    GLW              0.0               0.0
# 122    JCI             37.5               0.0
# 123   FSLR              0.0               0.0
# 124   AAOI             25.0               0.0
# 125    BEN             12.5               0.0
# 126     LI              0.0               0.0
# 127    IBN              0.0               0.0
# 128   FTNT              0.0               0.0
# 129    COF             37.5               0.0
# 130   FLEX             50.0               0.0
# 131   SNOW             12.5               0.0
# 132     IP             12.5              12.5
# 133   MTCH             12.5               0.0
# 134    HUN              0.0               0.0
# 135    IBM             62.5               0.0
# 136    LYB              0.0              12.5
# 137    CNK              0.0              25.0
# 138    FLR             87.5               0.0
# 139   DASH             75.0               0.0
# 140   SATS             75.0               0.0
# 141   CTVA             50.0               0.0
# 142   DECK              0.0               0.0
# 143   OKTA             50.0               0.0
# 144   ARCC             50.0               0.0
# 145   ROKU             62.5               0.0
# 146   CVNA             50.0               0.0
# 147    CLS             50.0               0.0
# 148    UNP              0.0              12.5
# 149   NDAQ             50.0               0.0
# 150   CART              0.0               0.0
# 151    BBY              0.0               0.0
# 152    TER              0.0              12.5
# 153   ADBE              0.0              62.5
# 154   ENTG              0.0               0.0
# 155    HON             50.0               0.0
# 156    SYF             25.0               0.0
# 157    RIO             25.0              12.5
# 158     AU             37.5               0.0
# 159    BRO              0.0               0.0
# 160    KMX              0.0              37.5
# 161   FRSH              0.0               0.0
# 162   BIDU              0.0               0.0
# 163    MCD              0.0               0.0
# 164   NFLX             50.0               0.0
# 165   SIRI              0.0               0.0
# 166    HWM              0.0               0.0
# 167   SWKS              0.0               0.0
# 168   LULU              0.0              87.5
# 169    BHP             25.0               0.0
# 170    APO             37.5               0.0
# 171   PCAR              0.0              50.0
# 172    MET              0.0              25.0
# 173    GPN              0.0               0.0
# 174    KNX              0.0               0.0
# 175   AXTA              0.0              12.5
# 176    AXP              0.0               0.0
# 177   TCOM              0.0               0.0
# 178     DT              0.0               0.0
# 179   PSTG              0.0               0.0
# 180   INOD             12.5               0.0
# 181   NTNX              0.0               0.0
# 182    CAT             87.5               0.0
# 183    ANF              0.0              12.5
# 184     CG             87.5               0.0
# 185    ICE              0.0               0.0
# 186    LKQ              0.0              25.0
# 187   ALGM             12.5               0.0
# 188    BAM              0.0               0.0
# 189   LSCC              0.0               0.0
# 190    CME              0.0               0.0
# 191    EQH             12.5               0.0
# 192   APTV              0.0               0.0
# 193   LITE             50.0               0.0
# 194    AFL              0.0               0.0
# 195   WDAY              0.0               0.0
# 196   BLDR              0.0              12.5
# 197    MAS              0.0               0.0
# 198    HAS             37.5               0.0
# 199    PNC             50.0              12.5
# 200     GS             12.5               0.0
# 201    TRU             62.5               0.0
# 202   PAYX             25.0               0.0
# 203   TTWO             12.5               0.0
# 204      Z             12.5               0.0
# 205   BILL              0.0               0.0
# 206    CNM             75.0               0.0
# 207   TTEK             37.5              12.5
# 208   ACGL              0.0               0.0
# 209    STT             37.5               0.0
# 210   NTRS             50.0               0.0
# 211    FND              0.0               0.0
# 212    LNC              0.0               0.0
# 213     CE              0.0               0.0
# 214   QRVO              0.0               0.0
# 215    FMC              0.0               0.0
# 216    EMN              0.0               0.0
# 217    CMA             50.0               0.0
# 218   TTMI             87.5               0.0
# 219   CGNX             50.0               0.0
# 220    TEL              0.0               0.0
# 221   EXPE             62.5               0.0
# 222    ERJ             50.0               0.0
# 223   FTAI             12.5               0.0
# 224    TOL             12.5              37.5
# 225    LMT              0.0              62.5
# 226    AOS             62.5               0.0
# 227     WM             37.5               0.0
# 228    IFF              0.0               0.0
# 229    PII             25.0              12.5
# 230    PRU              0.0              25.0
# 231    MGA             50.0               0.0
# 232    SHW              0.0               0.0
# 233   FIVE             75.0               0.0
# 234   TROW              0.0              25.0
# 235    WHR              0.0              75.0
# 236   TRMB             87.5               0.0
# 237   ARES              0.0               0.0
# 238   VRNS             37.5               0.0
# 239   PLNT              0.0               0.0
# 240   SCCO              0.0               0.0
# 241   SHAK             62.5              12.5
# 242   STLD              0.0               0.0
# 243    JBL             12.5               0.0
# 244    XPO             12.5              12.5
# 245    CAR             62.5               0.0
# 246   GDDY              0.0              75.0
# 247   FOUR             75.0               0.0
# 248    AON              0.0              12.5
# 249   PCOR             37.5               0.0
# 250   CHRW             12.5               0.0
# 251    GMS             50.0               0.0

# %%
filterdf
# Out:
#     language region quoteType typeDisp         quoteSourceName  triggerable  \
# 0      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 1      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 2      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 3      en-US     US    EQUITY   Equity           Delayed Quote        False
# 4      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 5      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 6      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 7      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 8      en-US     US    EQUITY   Equity           Delayed Quote         True
# 9      en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 10     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 11     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 12     en-US     US    EQUITY   Equity           Delayed Quote        False
# 13     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 14     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 15     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 16     en-US     US    EQUITY   Equity           Delayed Quote         True
# 17     en-US     US    EQUITY   Equity           Delayed Quote        False
# 18     en-US     US    EQUITY   Equity           Delayed Quote        False
# 19     en-US     US    EQUITY   Equity           Delayed Quote        False
# 20     en-US     US    EQUITY   Equity           Delayed Quote        False
# 21     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 22     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 23     en-US     US    EQUITY   Equity           Delayed Quote        False
# 24     en-US     US    EQUITY   Equity           Delayed Quote        False
# 25     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 26     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 27     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 28     en-US     US    EQUITY   Equity           Delayed Quote        False
# 29     en-US     US    EQUITY   Equity           Delayed Quote        False
# 30     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 31     en-US     US    EQUITY   Equity           Delayed Quote        False
# 32     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 33     en-US     US    EQUITY   Equity           Delayed Quote        False
# 34     en-US     US    EQUITY   Equity           Delayed Quote         True
# 35     en-US     US    EQUITY   Equity           Delayed Quote         True
# 36     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 37     en-US     US    EQUITY   Equity           Delayed Quote        False
# 38     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 39     en-US     US    EQUITY   Equity           Delayed Quote         True
# 40     en-US     US    EQUITY   Equity           Delayed Quote        False
# 41     en-US     US    EQUITY   Equity           Delayed Quote        False
# 42     en-US     US    EQUITY   Equity           Delayed Quote        False
# 43     en-US     US    EQUITY   Equity           Delayed Quote        False
# 44     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 45     en-US     US    EQUITY   Equity           Delayed Quote        False
# 46     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 47     en-US     US    EQUITY   Equity           Delayed Quote        False
# 48     en-US     US    EQUITY   Equity           Delayed Quote        False
# 49     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 50     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 51     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 52     en-US     US    EQUITY   Equity           Delayed Quote        False
# 53     en-US     US    EQUITY   Equity           Delayed Quote        False
# 54     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 55     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 56     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 57     en-US     US    EQUITY   Equity           Delayed Quote        False
# 58     en-US     US    EQUITY   Equity           Delayed Quote        False
# 59     en-US     US    EQUITY   Equity           Delayed Quote        False
# 60     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 61     en-US     US    EQUITY   Equity           Delayed Quote        False
# 62     en-US     US    EQUITY   Equity           Delayed Quote        False
# 63     en-US     US    EQUITY   Equity           Delayed Quote        False
# 64     en-US     US    EQUITY   Equity           Delayed Quote        False
# 65     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 66     en-US     US    EQUITY   Equity           Delayed Quote        False
# 67     en-US     US    EQUITY   Equity           Delayed Quote        False
# 68     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 69     en-US     US    EQUITY   Equity           Delayed Quote         True
# 70     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 71     en-US     US    EQUITY   Equity           Delayed Quote        False
# 72     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 73     en-US     US    EQUITY   Equity           Delayed Quote        False
# 74     en-US     US    EQUITY   Equity           Delayed Quote         True
# 75     en-US     US    EQUITY   Equity           Delayed Quote        False
# 76     en-US     US    EQUITY   Equity           Delayed Quote        False
# 77     en-US     US    EQUITY   Equity           Delayed Quote         True
# 78     en-US     US    EQUITY   Equity           Delayed Quote        False
# 79     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 80     en-US     US    EQUITY   Equity           Delayed Quote        False
# 81     en-US     US    EQUITY   Equity           Delayed Quote        False
# 82     en-US     US    EQUITY   Equity           Delayed Quote        False
# 83     en-US     US    EQUITY   Equity           Delayed Quote        False
# 84     en-US     US    EQUITY   Equity           Delayed Quote         True
# 85     en-US     US    EQUITY   Equity           Delayed Quote        False
# 86     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 87     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 88     en-US     US    EQUITY   Equity           Delayed Quote        False
# 89     en-US     US    EQUITY   Equity           Delayed Quote        False
# 90     en-US     US    EQUITY   Equity           Delayed Quote        False
# 91     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 92     en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 93     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 94     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 95     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 96     en-US     US    EQUITY   Equity           Delayed Quote        False
# 97     en-US     US    EQUITY   Equity           Delayed Quote        False
# 98     en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 99     en-US     US    EQUITY   Equity           Delayed Quote        False
# 100    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 101    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 102    en-US     US    EQUITY   Equity           Delayed Quote        False
# 103    en-US     US    EQUITY   Equity           Delayed Quote        False
# 104    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 105    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 106    en-US     US    EQUITY   Equity           Delayed Quote        False
# 107    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 108    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 109    en-US     US    EQUITY   Equity           Delayed Quote         True
# 110    en-US     US    EQUITY   Equity           Delayed Quote        False
# 111    en-US     US    EQUITY   Equity           Delayed Quote        False
# 112    en-US     US    EQUITY   Equity           Delayed Quote         True
# 113    en-US     US    EQUITY   Equity           Delayed Quote        False
# 114    en-US     US    EQUITY   Equity           Delayed Quote        False
# 115    en-US     US    EQUITY   Equity           Delayed Quote        False
# 116    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 117    en-US     US    EQUITY   Equity           Delayed Quote        False
# 118    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 119    en-US     US    EQUITY   Equity           Delayed Quote        False
# 120    en-US     US    EQUITY   Equity           Delayed Quote        False
# 121    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 122    en-US     US    EQUITY   Equity           Delayed Quote        False
# 123    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 124    en-US     US    EQUITY   Equity           Delayed Quote        False
# 125    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 126    en-US     US    EQUITY   Equity           Delayed Quote         True
# 127    en-US     US    EQUITY   Equity           Delayed Quote        False
# 128    en-US     US    EQUITY   Equity           Delayed Quote         True
# 129    en-US     US    EQUITY   Equity           Delayed Quote        False
# 130    en-US     US    EQUITY   Equity           Delayed Quote         True
# 131    en-US     US    EQUITY   Equity           Delayed Quote        False
# 132    en-US     US    EQUITY   Equity           Delayed Quote        False
# 133    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 134    en-US     US    EQUITY   Equity           Delayed Quote        False
# 135    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 136    en-US     US    EQUITY   Equity           Delayed Quote        False
# 137    en-US     US    EQUITY   Equity           Delayed Quote        False
# 138    en-US     US    EQUITY   Equity           Delayed Quote        False
# 139    en-US     US    EQUITY   Equity           Delayed Quote         True
# 140    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 141    en-US     US    EQUITY   Equity           Delayed Quote        False
# 142    en-US     US    EQUITY   Equity           Delayed Quote        False
# 143    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 144    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 145    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 146    en-US     US    EQUITY   Equity           Delayed Quote        False
# 147    en-US     US    EQUITY   Equity           Delayed Quote        False
# 148    en-US     US    EQUITY   Equity           Delayed Quote        False
# 149    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 150    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 151    en-US     US    EQUITY   Equity           Delayed Quote        False
# 152    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 153    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 154    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 155    en-US     US    EQUITY   Equity           Delayed Quote         True
# 156    en-US     US    EQUITY   Equity           Delayed Quote        False
# 157    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 158    en-US     US    EQUITY   Equity           Delayed Quote        False
# 159    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 160    en-US     US    EQUITY   Equity           Delayed Quote        False
# 161    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 162    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 163    en-US     US    EQUITY   Equity           Delayed Quote        False
# 164    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 165    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 166    en-US     US    EQUITY   Equity           Delayed Quote        False
# 167    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 168    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 169    en-US     US    EQUITY   Equity           Delayed Quote        False
# 170    en-US     US    EQUITY   Equity           Delayed Quote        False
# 171    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 172    en-US     US    EQUITY   Equity           Delayed Quote        False
# 173    en-US     US    EQUITY   Equity           Delayed Quote        False
# 174    en-US     US    EQUITY   Equity           Delayed Quote        False
# 175    en-US     US    EQUITY   Equity           Delayed Quote        False
# 176    en-US     US    EQUITY   Equity           Delayed Quote        False
# 177    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 178    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 179    en-US     US    EQUITY   Equity           Delayed Quote        False
# 180    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 181    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 182    en-US     US    EQUITY   Equity           Delayed Quote        False
# 183    en-US     US    EQUITY   Equity           Delayed Quote        False
# 184    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 185    en-US     US    EQUITY   Equity           Delayed Quote        False
# 186    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 187    en-US     US    EQUITY   Equity           Delayed Quote         True
# 188    en-US     US    EQUITY   Equity           Delayed Quote        False
# 189    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 190    en-US     US    EQUITY   Equity           Delayed Quote         True
# 191    en-US     US    EQUITY   Equity           Delayed Quote        False
# 192    en-US     US    EQUITY   Equity           Delayed Quote        False
# 193    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 194    en-US     US    EQUITY   Equity           Delayed Quote        False
# 195    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 196    en-US     US    EQUITY   Equity           Delayed Quote        False
# 197    en-US     US    EQUITY   Equity           Delayed Quote        False
# 198    en-US     US    EQUITY   Equity           Delayed Quote         True
# 199    en-US     US    EQUITY   Equity           Delayed Quote        False
# 200    en-US     US    EQUITY   Equity           Delayed Quote        False
# 201    en-US     US    EQUITY   Equity           Delayed Quote        False
# 202    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 203    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 204    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 205    en-US     US    EQUITY   Equity           Delayed Quote        False
# 206    en-US     US    EQUITY   Equity           Delayed Quote        False
# 207    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 208    en-US     US    EQUITY   Equity           Delayed Quote         True
# 209    en-US     US    EQUITY   Equity           Delayed Quote        False
# 210    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 211    en-US     US    EQUITY   Equity           Delayed Quote        False
# 212    en-US     US    EQUITY   Equity           Delayed Quote        False
# 213    en-US     US    EQUITY   Equity           Delayed Quote        False
# 214    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 215    en-US     US    EQUITY   Equity           Delayed Quote        False
# 216    en-US     US    EQUITY   Equity           Delayed Quote        False
# 217    en-US     US    EQUITY   Equity           Delayed Quote        False
# 218    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 219    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 220    en-US     US    EQUITY   Equity           Delayed Quote        False
# 221    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 222    en-US     US    EQUITY   Equity           Delayed Quote        False
# 223    en-US     US    EQUITY   Equity           Delayed Quote         True
# 224    en-US     US    EQUITY   Equity           Delayed Quote        False
# 225    en-US     US    EQUITY   Equity           Delayed Quote        False
# 226    en-US     US    EQUITY   Equity           Delayed Quote        False
# 227    en-US     US    EQUITY   Equity           Delayed Quote        False
# 228    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 229    en-US     US    EQUITY   Equity           Delayed Quote        False
# 230    en-US     US    EQUITY   Equity           Delayed Quote        False
# 231    en-US     US    EQUITY   Equity           Delayed Quote        False
# 232    en-US     US    EQUITY   Equity           Delayed Quote        False
# 233    en-US     US    EQUITY   Equity           Delayed Quote         True
# 234    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 235    en-US     US    EQUITY   Equity           Delayed Quote        False
# 236    en-US     US    EQUITY   Equity           Delayed Quote         True
# 237    en-US     US    EQUITY   Equity           Delayed Quote        False
# 238    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 239    en-US     US    EQUITY   Equity           Delayed Quote        False
# 240    en-US     US    EQUITY   Equity           Delayed Quote        False
# 241    en-US     US    EQUITY   Equity           Delayed Quote        False
# 242    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 243    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 244    en-US     US    EQUITY   Equity           Delayed Quote        False
# 245    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 246    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 247    en-US     US    EQUITY   Equity           Delayed Quote        False
# 248    en-US     US    EQUITY   Equity           Delayed Quote        False
# 249    en-US     US    EQUITY   Equity  Nasdaq Real Time Price        False
# 250    en-US     US    EQUITY   Equity  Nasdaq Real Time Price         True
# 251    en-US     US    EQUITY   Equity           Delayed Quote        False
#
#     customPriceAlertConfidence currency                        shortName  \
# 0                         HIGH      USD               NVIDIA Corporation
# 1                         HIGH      USD                Lucid Group, Inc.
# 2                         HIGH      USD                      Tesla, Inc.
# 3                          LOW      USD               Ford Motor Company
# 4                         HIGH      USD                Intel Corporation
# 5                         HIGH      USD       Palantir Technologies Inc.
# 6                         HIGH      USD          SoFi Technologies, Inc.
# 7                         HIGH      USD    American Airlines Group, Inc.
# 8                         HIGH      USD                       Apple Inc.
# 9                         HIGH      USD     Advanced Micro Devices, Inc.
# 10                        HIGH      USD      Applied Digital Corporation
# 11                         LOW      USD              MARA Holdings, Inc.
# 12                         LOW      USD                         NIO Inc.
# 13                        HIGH      USD       Super Micro Computer, Inc.
# 14                        HIGH      USD          Robinhood Markets, Inc.
# 15                        HIGH      USD                 Amazon.com, Inc.
# 16                        HIGH      USD                    Alphabet Inc.
# 17                         LOW      USD                        VALE S.A.
# 18                         LOW      USD                Banco Bradesco Sa
# 19                         LOW      USD         QuantumScape Corporation
# 20                         LOW      USD      Bank of America Corporation
# 21                         LOW      USD             Riot Platforms, Inc.
# 22                         LOW      USD                        Snap Inc.
# 23                         LOW      USD            Cleveland-Cliffs Inc.
# 24                         LOW      USD                        AT&T Inc.
# 25                         LOW      USD   Itau Unibanco Banco Holding SA
# 26                        HIGH      USD  Huntington Bancshares Incorpora
# 27                         LOW      USD           Quantum Computing Inc.
# 28                         LOW      USD                 CleanSpark, Inc.
# 29                         LOW      USD                        Amcor plc
# 30                         LOW      USD           SharpLink Gaming, Inc.
# 31                         LOW      USD             Carnival Corporation
# 32                        HIGH      USD          Micron Technology, Inc.
# 33                         LOW      USD          Uber Technologies, Inc.
# 34                        HIGH      USD         Marvell Technology, Inc.
# 35                        HIGH      USD                    Broadcom Inc.
# 36                        HIGH      USD              Comcast Corporation
# 37                         LOW      USD                  Stellantis N.V.
# 38                        HIGH      USD              Cisco Systems, Inc.
# 39                        HIGH      USD            Microsoft Corporation
# 40                         LOW      USD                          KeyCorp
# 41                         LOW      USD                         ADT Inc.
# 42                         LOW      USD      Verizon Communications Inc.
# 43                         LOW      USD            Wells Fargo & Company
# 44                        HIGH      USD                       Lyft, Inc.
# 45                         LOW      USD           Rocket Companies, Inc.
# 46                         LOW      USD                       Nike, Inc.
# 47                         LOW      USD                      fuboTV Inc.
# 48                         LOW      USD     Eos Energy Enterprises, Inc.
# 49                         LOW      USD  Norwegian Cruise Line Holdings
# 50                        HIGH      USD            Coinbase Global, Inc.
# 51                         LOW      USD     Chipotle Mexican Grill, Inc.
# 52                         LOW      USD             GameStop Corporation
# 53                         LOW      USD           Freeport-McMoRan, Inc.
# 54                         LOW      USD               MP Materials Corp.
# 55                        HIGH      USD        Peloton Interactive, Inc.
# 56                         LOW      USD              Unity Software Inc.
# 57                         LOW      USD                  Citigroup, Inc.
# 58                         LOW      USD    Alibaba Group Holding Limited
# 59                         LOW      USD                         Dow Inc.
# 60                         LOW      USD               Oracle Corporation
# 61                         LOW      USD              Newmont Corporation
# 62                         LOW      USD                  Infosys Limited
# 63                         LOW      USD  Taiwan Semiconductor Manufactur
# 64                         LOW      USD                    Coupang, Inc.
# 65                        HIGH      USD                     Shopify Inc.
# 66                         LOW      USD            Delta Air Lines, Inc.
# 67                         LOW      USD    Regions Financial Corporation
# 68                        HIGH      USD                     JD.com, Inc.
# 69                        HIGH      USD         Lam Research Corporation
# 70                        HIGH      USD            PayPal Holdings, Inc.
# 71                         LOW      USD                     U.S. Bancorp
# 72                        HIGH      USD            Starbucks Corporation
# 73                         LOW      USD           General Motors Company
# 74                        HIGH      USD                  DraftKings Inc.
# 75                         LOW      USD            Arista Networks, Inc.
# 76                         LOW      USD  American Eagle Outfitters, Inc.
# 77                        HIGH      USD  Microchip Technology Incorporat
# 78                         LOW      USD             Enphase Energy, Inc.
# 79                         LOW      USD                          HP Inc.
# 80                         LOW      USD                 V.F. Corporation
# 81                         LOW      USD            JP Morgan Chase & Co.
# 82                         LOW      USD             Amphenol Corporation
# 83                         LOW      USD             Boeing Company (The)
# 84                        HIGH      USD            QUALCOMM Incorporated
# 85                         LOW      USD  Charles Schwab Corporation (The
# 86                        HIGH      USD                PDD Holdings Inc.
# 87                        HIGH      USD   United Airlines Holdings, Inc.
# 88                         LOW      USD         Bloom Energy Corporation
# 89                         LOW      USD            Blue Owl Capital Inc.
# 90                         LOW      USD             Vertiv Holdings, LLC
# 91                        HIGH      USD                     Copart, Inc.
# 92                         LOW      USD            Skechers U.S.A., Inc.
# 93                        HIGH      USD          Applied Materials, Inc.
# 94                        HIGH      USD   Texas Instruments Incorporated
# 95                        HIGH      USD                    Datadog, Inc.
# 96                         LOW      USD                SentinelOne, Inc.
# 97                         LOW      USD  Tencent Music Entertainment Gro
# 98                        HIGH      USD                  Confluent, Inc.
# 99                         LOW      USD                     GE Aerospace
# 100                       HIGH      USD                      Hut 8 Corp.
# 101                        LOW      USD                        Visa Inc.
# 102                        LOW      USD        First Horizon Corporation
# 103                        LOW      USD                Alcoa Corporation
# 104                       HIGH      USD           Upstart Holdings, Inc.
# 105                       HIGH      USD         Palo Alto Networks, Inc.
# 106                        LOW      USD                      Invesco Ltd
# 107                       HIGH      USD                 Fastenal Company
# 108                        LOW      USD      United Parcel Service, Inc.
# 109                       HIGH      USD             Applovin Corporation
# 110                        LOW      USD           Dell Technologies Inc.
# 111                        LOW      USD                   Morgan Stanley
# 112                       HIGH      USD                        eBay Inc.
# 113                        LOW      USD            Las Vegas Sands Corp.
# 114                        LOW      USD                  RTX Corporation
# 115                        LOW      USD        TJX Companies, Inc. (The)
# 116                       HIGH      USD        O'Reilly Automotive, Inc.
# 117                        LOW      USD   Citizens Financial Group, Inc.
# 118                       HIGH      USD              Fifth Third Bancorp
# 119                        LOW      USD       Carrier Global Corporation
# 120                        LOW      USD  Mitsubishi UFJ Financial Group,
# 121                        LOW      USD             Corning Incorporated
# 122                        LOW      USD  Johnson Controls International
# 123                       HIGH      USD                First Solar, Inc.
# 124                        LOW      USD    Applied Optoelectronics, Inc.
# 125                        LOW      USD         Franklin Resources, Inc.
# 126                       HIGH      USD                     Li Auto Inc.
# 127                        LOW      USD               ICICI Bank Limited
# 128                       HIGH      USD                   Fortinet, Inc.
# 129                        LOW      USD  Capital One Financial Corporati
# 130                       HIGH      USD                        Flex Ltd.
# 131                        LOW      USD                   Snowflake Inc.
# 132                        LOW      USD      International Paper Company
# 133                       HIGH      USD                Match Group, Inc.
# 134                        LOW      USD             Huntsman Corporation
# 135                        LOW      USD  International Business Machines
# 136                        LOW      USD     LyondellBasell Industries NV
# 137                        LOW      USD  Cinemark Holdings Inc Cinemark
# 138                        LOW      USD                Fluor Corporation
# 139                       HIGH      USD                   DoorDash, Inc.
# 140                       HIGH      USD             EchoStar Corporation
# 141                        LOW      USD                    Corteva, Inc.
# 142                        LOW      USD      Deckers Outdoor Corporation
# 143                       HIGH      USD                       Okta, Inc.
# 144                       HIGH      USD         Ares Capital Corporation
# 145                       HIGH      USD                       Roku, Inc.
# 146                        LOW      USD                      Carvana Co.
# 147                        LOW      USD                  Celestica, Inc.
# 148                        LOW      USD        Union Pacific Corporation
# 149                       HIGH      USD                     Nasdaq, Inc.
# 150                       HIGH      USD                   Maplebear Inc.
# 151                        LOW      USD               Best Buy Co., Inc.
# 152                       HIGH      USD                   Teradyne, Inc.
# 153                       HIGH      USD                       Adobe Inc.
# 154                       HIGH      USD                   Entegris, Inc.
# 155                       HIGH      USD     Honeywell International Inc.
# 156                        LOW      USD              Synchrony Financial
# 157                        LOW      USD                    Rio Tinto Plc
# 158                        LOW      USD            AngloGold Ashanti PLC
# 159                        LOW      USD              Brown & Brown, Inc.
# 160                        LOW      USD                       CarMax Inc
# 161                       HIGH      USD                  Freshworks Inc.
# 162                       HIGH      USD                      Baidu, Inc.
# 163                        LOW      USD           McDonald's Corporation
# 164                       HIGH      USD                    Netflix, Inc.
# 165                       HIGH      USD           SiriusXM Holdings Inc.
# 166                        LOW      USD            Howmet Aerospace Inc.
# 167                       HIGH      USD         Skyworks Solutions, Inc.
# 168                       HIGH      USD         lululemon athletica inc.
# 169                        LOW      USD                BHP Group Limited
# 170                        LOW      USD  Apollo Global Management, Inc.
# 171                       HIGH      USD                      PACCAR Inc.
# 172                        LOW      USD                    MetLife, Inc.
# 173                        LOW      USD             Global Payments Inc.
# 174                        LOW      USD  Knight-Swift Transportation Hol
# 175                        LOW      USD      Axalta Coating Systems Ltd.
# 176                        LOW      USD         American Express Company
# 177                       HIGH      USD           Trip.com Group Limited
# 178                        LOW      USD                  Dynatrace, Inc.
# 179                        LOW      USD               Pure Storage, Inc.
# 180                        LOW      USD                    Innodata Inc.
# 181                       HIGH      USD                    Nutanix, Inc.
# 182                        LOW      USD                Caterpillar, Inc.
# 183                        LOW      USD      Abercrombie & Fitch Company
# 184                       HIGH      USD           The Carlyle Group Inc.
# 185                        LOW      USD   Intercontinental Exchange Inc.
# 186                       HIGH      USD                  LKQ Corporation
# 187                       HIGH      USD       Allegro MicroSystems, Inc.
# 188                        LOW      USD  Brookfield Asset Management Inc
# 189                       HIGH      USD  Lattice Semiconductor Corporati
# 190                       HIGH      USD                   CME Group Inc.
# 191                        LOW      USD         Equitable Holdings, Inc.
# 192                        LOW      USD                        Aptiv PLC
# 193                       HIGH      USD           Lumentum Holdings Inc.
# 194                        LOW      USD               AFLAC Incorporated
# 195                       HIGH      USD                    Workday, Inc.
# 196                        LOW      USD       Builders FirstSource, Inc.
# 197                        LOW      USD                Masco Corporation
# 198                       HIGH      USD                     Hasbro, Inc.
# 199                        LOW      USD  PNC Financial Services Group, I
# 200                        LOW      USD  Goldman Sachs Group, Inc. (The)
# 201                        LOW      USD                       TransUnion
# 202                       HIGH      USD                    Paychex, Inc.
# 203                       HIGH      USD  Take-Two Interactive Software,
# 204                       HIGH      USD               Zillow Group, Inc.
# 205                        LOW      USD              BILL Holdings, Inc.
# 206                        LOW      USD                Core & Main, Inc.
# 207                       HIGH      USD                 Tetra Tech, Inc.
# 208                       HIGH      USD          Arch Capital Group Ltd.
# 209                        LOW      USD         State Street Corporation
# 210                       HIGH      USD       Northern Trust Corporation
# 211                        LOW      USD     Floor & Decor Holdings, Inc.
# 212                        LOW      USD     Lincoln National Corporation
# 213                        LOW      USD             Celanese Corporation
# 214                       HIGH      USD                      Qorvo, Inc.
# 215                        LOW      USD                  FMC Corporation
# 216                        LOW      USD         Eastman Chemical Company
# 217                        LOW      USD            Comerica Incorporated
# 218                       HIGH      USD           TTM Technologies, Inc.
# 219                       HIGH      USD               Cognex Corporation
# 220                        LOW      USD              TE Connectivity plc
# 221                       HIGH      USD              Expedia Group, Inc.
# 222                        LOW      USD                     Embraer S.A.
# 223                       HIGH      USD               FTAI Aviation Ltd.
# 224                        LOW      USD              Toll Brothers, Inc.
# 225                        LOW      USD      Lockheed Martin Corporation
# 226                        LOW      USD           A.O. Smith Corporation
# 227                        LOW      USD           Waste Management, Inc.
# 228                        LOW      USD  International Flavors & Fragran
# 229                        LOW      USD                     Polaris Inc.
# 230                        LOW      USD       Prudential Financial, Inc.
# 231                        LOW      USD        Magna International, Inc.
# 232                        LOW      USD   Sherwin-Williams Company (The)
# 233                       HIGH      USD                 Five Below, Inc.
# 234                       HIGH      USD        T. Rowe Price Group, Inc.
# 235                        LOW      USD            Whirlpool Corporation
# 236                       HIGH      USD                     Trimble Inc.
# 237                        LOW      USD      Ares Management Corporation
# 238                       HIGH      USD            Varonis Systems, Inc.
# 239                        LOW      USD             Planet Fitness, Inc.
# 240                        LOW      USD      Southern Copper Corporation
# 241                        LOW      USD                Shake Shack, Inc.
# 242                       HIGH      USD             Steel Dynamics, Inc.
# 243                        LOW      USD                       Jabil Inc.
# 244                        LOW      USD                        XPO, Inc.
# 245                       HIGH      USD          Avis Budget Group, Inc.
# 246                        LOW      USD                     GoDaddy Inc.
# 247                        LOW      USD            Shift4 Payments, Inc.
# 248                        LOW      USD                          Aon plc
# 249                        LOW      USD       Procore Technologies, Inc.
# 250                       HIGH      USD    C.H. Robinson Worldwide, Inc.
# 251                        LOW      USD                         GMS Inc.
#
#          bid      ask  regularMarketChangePercent exchange  fiftyTwoWeekHigh  \
# 0     173.61   182.83                   -2.333160      NMS        183.300000
# 1       2.40     2.47                   -1.626010      NMS          4.430000
# 2     302.56   302.84                   -1.829560      NMS        488.540000
# 3      10.79    10.81                   -2.258360      NYQ         11.970000
# 4      19.28    19.34                   -2.474750      NMS         27.550000
# 5     154.12   154.42                   -2.576572      NMS        160.890000
# 6      21.00    22.79                   -5.978740      NMS         25.110000
# 7      11.01    11.07                   -4.003480      NMS         19.100000
# 8     192.07   213.25                   -2.500362      NMS        260.100000
# 9     171.58   171.83                   -2.614710      NMS        182.500000
# 10     12.46    12.54                   -4.718420      NMS         15.420000
# 11     15.44    15.55                   -3.606960      NCM         30.280000
# 12      4.93     4.94                    2.874750      NYQ          7.710000
# 13     56.51    56.77                   -3.951160      NMS         66.440000
# 14     99.87   108.34                   -3.056770      NMS        113.439000
# 15    206.15   217.50                   -8.269617      NMS        242.520000
# 16    179.46   198.61                   -1.443454      NMS        207.050000
# 17      9.67     9.75                    1.888780      NYQ         12.050000
# 18      2.80     2.81                    1.444040      NYQ          3.130000
# 19      8.28     8.23                   -3.953490      NYQ         15.030000
# 20     45.68    45.75                   -3.405970      NYQ         49.310000
# 21     11.00    11.15                  -17.747952      NCM         15.870000
# 22      9.02     9.07                   -4.029690      NYQ         13.281000
# 23     10.07    10.09                   -4.372620      NYQ         14.340000
# 24     27.75    27.80                    1.240420      NYQ         29.190000
# 25      6.30     6.31                    0.318979      NYQ          6.950000
# 26     15.98    16.04                   -2.373700      NMS         18.450000
# 27     14.77    14.86                   -0.269542      NCM         27.150000
# 28      9.40    10.80                   -8.179420      NCM         17.970000
# 29      9.29     9.49                   -0.534761      NYQ         11.480000
# 30     13.52    22.10                   -8.878257      NCM        124.120000
# 31     29.10    29.08                   -2.351360      NYQ         31.010000
# 32    104.78   104.95                   -3.903250      NMS        129.850000
# 33     86.80    86.85                   -0.957261      NYQ         97.715000
# 34     74.34    74.70                   -7.365940      NMS        127.480000
# 35    288.35   306.56                   -1.722846      NMS        306.950000
# 36     30.96    34.52                   -2.136621      NMS         45.310000
# 37      8.76     8.77                   -1.124860      NYQ         16.920000
# 38     67.03    67.15                   -1.424796      NMS         69.780000
# 39    523.77   524.40                   -1.760078      NMS        555.450000
# 40     17.60    17.74                   -1.506700      NYQ         20.040000
# 41      8.10     8.45                   -0.598805      NYQ          8.800000
# 42     42.86    42.90                    0.280643      NYQ         47.360000
# 43     77.85    78.09                   -3.534660      NYQ         84.830000
# 44     13.57    13.65                   -3.129449      NMS         19.065000
# 45     16.54    16.58                   11.983800      NYQ         21.380000
# 46     74.41    74.60                   -0.093720      NYQ         90.620000
# 47      3.78     3.79                   -5.778890      NYQ          6.450000
# 48      5.36     5.69                   -3.333330      NCM          7.360000
# 49     24.36    24.37                   -4.147100      NYQ         29.290000
# 50    314.28   316.19                  -16.695800      NMS        444.650000
# 51     42.52    42.50                   -0.839554      NYQ         66.740000
# 52     22.16    22.22                   -1.559020      NYQ         35.810000
# 53     40.08    40.06                   -0.521876      NYQ         52.610000
# 54     63.55    64.00                    3.560970      NYQ         65.840000
# 55      5.59     7.55                   -7.563025      NMS         10.895000
# 56     31.80    31.77                   -4.586330      NYQ         38.960000
# 57     91.83    91.91                   -1.995730      NYQ         96.910000
# 58    116.95   117.00                   -2.951170      NYQ        148.430000
# 59     21.86    21.90                   -6.440530      NYQ         55.670000
# 60    244.20   244.00                   -3.684440      NYQ        260.870000
# 61     62.52    62.63                    0.789053      NYQ         66.570000
# 62     16.37    16.64                   -1.854060      NYQ         23.630000
# 63    234.10   235.00                   -2.652920      NYQ        248.280000
# 64     28.74    28.90                   -2.344550      NYQ         31.645000
# 65    118.45   118.78                   -2.953932      NMS        129.380000
# 66     50.97    51.22                   -3.871450      NYQ         69.980000
# 67     24.50    25.02                   -1.737070      NYQ         27.960000
# 68     30.78    35.49                   -1.841850      NMS         47.820000
# 69     89.93   100.16                    1.613250      NMS        102.590000
# 70     64.54    67.14                   -2.399650      NMS         93.660000
# 71     43.87    43.86                   -2.268680      NYQ         53.980000
# 72     82.21    91.31                   -2.579640      NMS        117.460000
# 73     52.26    52.58                   -1.518560      NYQ         61.240000
# 74     43.71    47.15                   -2.908529      NMS         53.610000
# 75    116.32   117.50                   -4.585300      NYQ        133.575000
# 76     10.75    11.05                   -0.555559      NYQ         22.830000
# 77     66.27    66.42                   -1.819790      NMS         82.870000
# 78     31.39    31.50                   -2.873920      NGM        130.080000
# 79     24.36    24.70                   -1.411280      NYQ         39.800000
# 80     11.55    11.70                   -0.511949      NYQ         29.020000
# 81    289.51   289.99                   -2.319060      NYQ        301.290000
# 82    103.76   107.86                   -2.065540      NYQ        108.850000
# 83    221.60   222.43                    0.027045      NYQ        242.690000
# 84    138.90   148.31                    0.974385      NMS        182.100000
# 85     95.54    96.20                   -2.251100      NYQ         99.590000
# 86     95.57   110.16                   -2.988100      NMS        155.670000
# 87     84.44    84.61                   -4.235080      NMS        116.000000
# 88     36.75    37.20                   -1.791920      NYQ         39.090000
# 89     18.75    19.00                   -2.635660      NYQ         26.725000
# 90    140.00   142.20                   -2.754130      NYQ        155.840000
# 91     45.00    48.91                    0.397080      NMS         64.380000
# 92     63.06    63.04                   -0.395257      NYQ         78.850000
# 93    179.91   180.08                   -0.038872      NMS        215.700000
# 94    170.05   190.15                   -0.110459      NMS        221.690000
# 95    135.43   135.73                   -3.129010      NMS        170.080000
# 96     17.92    17.95                   -2.181020      NYQ         29.290000
# 97     20.42    20.66                   -2.143870      NYQ         22.500000
# 98     17.08    17.26                   -2.961920      NMS         37.900000
# 99    269.40   269.70                   -0.627114      NYQ        274.940000
# 100    14.51    19.78                   -6.829950      NMS         31.950000
# 101   338.55   339.35                   -1.771500      NYQ        375.510000
# 102    21.31    21.45                   -2.154970      NYQ         23.000000
# 103    28.56    28.37                   -5.238570      NYQ         47.770000
# 104    79.07    79.38                   -3.082942      NMS         96.429000
# 105   172.73   173.08                   -0.414747      NMS        210.390000
# 106    20.62    20.61                   -1.903850      NYQ         21.850000
# 107    45.40    45.47                   -1.495778      NMS         48.100000
# ...
# 128      Ticker
# FTNT   -0.000031
# dtype: float64    1.615815              0.0
# 129       Ticker
# COF   -0.000022
# dtype: float64    2.849155             37.5
# 130      Ticker
# FLEX   -0.000008
# dtype: float64    1.095971             50.0
# 131      Ticker
# SNOW   -0.000019
# dtype: float64    0.327423             12.5
# 132        Ticker
# IP   -0.000057
# dtype: float64    1.657184             12.5
# 133      Ticker
# MTCH   -0.000004
# dtype: float64    1.558384             12.5
# 134       Ticker
# HUN   -0.000077
# dtype: float64    2.144639              0.0
# 135       Ticker
# IBM   -0.000012
# dtype: float64    2.291569             62.5
# 136       Ticker
# LYB   -0.000059
# dtype: float64    2.187533              0.0
# 137       Ticker
# CNK   -0.000056
# dtype: float64    0.341727              0.0
# 138       Ticker
# FLR   -0.000086
# dtype: float64    0.006299             87.5
# 139      Ticker
# DASH    0.000012
# dtype: float64    1.267602             75.0
# 140      Ticker
# SATS   -0.000035
# dtype: float64    0.744667             75.0
# 141      Ticker
# CTVA   -0.000011
# dtype: float64    2.796596             50.0
# 142       Ticker
# DECK   -0.00001
# dtype: float64    0.250523              0.0
# 143      Ticker
# OKTA   -0.000003
# dtype: float64    2.609618             50.0
# 144      Ticker
# ARCC   -0.000011
# dtype: float64    1.528537             50.0
# 145      Ticker
# ROKU   -0.000039
# dtype: float64    0.072778             62.5
# 146      Ticker
# CVNA    0.000034
# dtype: float64    0.128288             50.0
# 147       Ticker
# CLS    0.000054
# dtype: float64    1.655174             50.0
# 148        Ticker
# UNP   -0.00001
# dtype: float64    3.037533              0.0
# 149      Ticker
# NDAQ    0.000014
# dtype: float64    2.822511             50.0
# 150      Ticker
# CART   -0.000019
# dtype: float64    1.599033              0.0
# 151       Ticker
# BBY   -0.000027
# dtype: float64    1.881988              0.0
# 152        Ticker
# TER    0.00005
# dtype: float64    0.741850              0.0
# 153      Ticker
# ADBE   -0.000025
# dtype: float64    1.452512              0.0
# 154      Ticker
# ENTG   -0.000065
# dtype: float64    0.306563              0.0
# 155       Ticker
# HON   -0.000011
# dtype: float64    2.936993             50.0
# 156       Ticker
# SYF   -0.000023
# dtype: float64    1.579440             25.0
# 157       Ticker
# RIO   -0.000027
# dtype: float64    3.013255             25.0
# 158        Ticker
# AU   -0.000005
# dtype: float64    1.748825             37.5
# 159       Ticker
# BRO   -0.000038
# dtype: float64    0.465468              0.0
# 160       Ticker
# KMX   -0.000037
# dtype: float64    3.284281              0.0
# 161      Ticker
# FRSH   -0.000037
# dtype: float64    2.204779              0.0
# 162      Ticker
# BIDU   -0.000025
# dtype: float64    2.531101              0.0
# 163       Ticker
# MCD    0.000009
# dtype: float64    2.402695              0.0
# 164      Ticker
# NFLX   -0.000005
# dtype: float64    4.182965             50.0
# 165      Ticker
# SIRI   -0.000048
# dtype: float64    1.905813              0.0
# 166       Ticker
# HWM   -0.000004
# dtype: float64    1.330543              0.0
# 167      Ticker
# SWKS   -0.000026
# dtype: float64    1.667574              0.0
# 168      Ticker
# LULU   -0.000051
# dtype: float64    1.933001              0.0
# 169       Ticker
# BHP   -0.000027
# dtype: float64    1.989188             25.0
# 170       Ticker
# APO   -0.000036
# dtype: float64    0.556588             37.5
# 171      Ticker
# PCAR   -0.000016
# dtype: float64    3.693437              0.0
# 172       Ticker
# MET   -0.000019
# dtype: float64    2.396034              0.0
# 173       Ticker
# GPN   -0.000028
# dtype: float64    1.372171              0.0
# 174       Ticker
# KNX   -0.000042
# dtype: float64    3.780765              0.0
# 175      Ticker
# AXTA   -0.000027
# dtype: float64    0.802876              0.0
# 176       Ticker
# AXP   -0.000016
# dtype: float64    3.570496              0.0
# 177      Ticker
# TCOM   -0.000026
# dtype: float64    1.973621              0.0
# 178        Ticker
# DT   -0.000022
# dtype: float64    1.581372              0.0
# 179      Ticker
# PSTG   -0.000017
# dtype: float64    1.923487              0.0
# 180      Ticker
# INOD   -0.000015
# dtype: float64    0.263992             12.5
# 181      Ticker
# NTNX   -0.000012
# dtype: float64    1.742047              0.0
# 182       Ticker
# CAT    0.000002
# dtype: float64    0.866908             87.5
# 183       Ticker
# ANF   -0.000015
# dtype: float64    0.819466              0.0
# 184        Ticker
# CG   -0.000013
# dtype: float64    0.872496             87.5
# 185       Ticker
# ICE    0.000007
# dtype: float64    1.493106              0.0
# 186       Ticker
# LKQ   -0.000039
# dtype: float64    3.403965              0.0
# 187      Ticker
# ALGM   -0.000029
# dtype: float64    1.807565             12.5
# 188       Ticker
# BAM   -0.000017
# dtype: float64    0.796087              0.0
# 189      Ticker
# LSCC   -0.000032
# dtype: float64    1.797464              0.0
# 190       Ticker
# CME    0.000005
# dtype: float64    6.144409              0.0
# 191       Ticker
# EQH   -0.000019
# dtype: float64    2.323269             12.5
# 192      Ticker
# APTV   -0.000026
# dtype: float64    1.107466              0.0
# 193      Ticker
# LITE    0.000016
# dtype: float64    0.206864             50.0
# 194       Ticker
# AFL   -0.000018
# dtype: float64    3.804740              0.0
# 195      Ticker
# WDAY   -0.000032
# dtype: float64    2.268091              0.0
# 196       Ticker
# BLDR   -0.00001
# dtype: float64    1.971139              0.0
# 197       Ticker
# MAS    0.000008
# dtype: float64    0.595544              0.0
# 198       Ticker
# HAS   -0.000008
# dtype: float64    2.724084             37.5
# 199       Ticker
# PNC   -0.000024
# dtype: float64    2.095633             50.0
# 200        Ticker
# GS   -0.000005
# dtype: float64    1.208871             12.5
# 201       Ticker
# TRU   -0.000022
# dtype: float64    1.996805             62.5
# 202      Ticker
# PAYX   -0.000014
# dtype: float64    3.397244             25.0
# 203      Ticker
# TTWO   -0.000015
# dtype: float64    2.375300             12.5
# 204         Ticker
# Z    0.000004
# dtype: float64    2.148141             12.5
# 205      Ticker
# BILL   -0.000039
# dtype: float64    2.314646              0.0
# 206       Ticker
# CNM   -0.000013
# dtype: float64    1.552045             75.0
# 207      Ticker
# TTEK   -0.000027
# dtype: float64    1.869450             37.5
# 208      Ticker
# ACGL   -0.000002
# dtype: float64    2.666334              0.0
# 209       Ticker
# STT   -0.000007
# dtype: float64    2.866618             37.5
# 210      Ticker
# NTRS    0.000007
# dtype: float64    2.396887             50.0
# 211       Ticker
# FND   -0.000011
# dtype: float64    1.417247              0.0
# 212        Ticker
# LNC    0.00002
# dtype: float64    0.534111              0.0
# 213        Ticker
# CE   -0.000068
# dtype: float64    1.202438              0.0
# 214      Ticker
# QRVO   -0.000015
# dtype: float64    2.563788              0.0
# 215       Ticker
# FMC   -0.000049
# dtype: float64    1.324017              0.0
# 216        Ticker
# EMN   -0.00011
# dtype: float64    0.061638              0.0
# 217   Ticker
# CMA    1.027902e-07
# dtype: float64    2.821861             50.0
# 218      Ticker
# TTMI   -0.000021
# dtype: float64    0.815864             87.5
# 219      Ticker
# CGNX    0.000069
# dtype: float64    0.092741             50.0
# 220       Ticker
# TEL    0.000002
# dtype: float64    3.144406              0.0
# 221      Ticker
# EXPE   -0.000032
# dtype: float64    1.098373             62.5
# 222       Ticker
# ERJ    0.000058
# dtype: float64    1.176119             50.0
# 223      Ticker
# FTAI    0.000092
# dtype: float64    0.639408             12.5
# 224       Ticker
# TOL   -0.000011
# dtype: float64    1.589178             12.5
# 225       Ticker
# LMT   -0.000003
# dtype: float64    3.499639              0.0
# 226       Ticker
# AOS   -0.000011
# dtype: float64    2.860414             62.5
# 227        Ticker
# WM    0.000002
# dtype: float64    1.766312             37.5
# 228       Ticker
# IFF   -0.000038
# dtype: float64    2.220214              0.0
# 229       Ticker
# PII   -0.000019
# dtype: float64    1.860218             25.0
# 230       Ticker
# PRU   -0.000015
# dtype: float64    2.959227              0.0
# 231       Ticker
# MGA   -0.000015
# dtype: float64    1.820640             50.0
# 232       Ticker
# SHW    0.000005
# dtype: float64    5.323254              0.0
# 233      Ticker
# FIVE   -0.000017
# dtype: float64    1.701376             75.0
# 234      Ticker
# TROW   -0.000015
# dtype: float64    2.317809              0.0
# 235       Ticker
# WHR   -0.000062
# dtype: float64    0.399878              0.0
# 236      Ticker
# TRMB   -0.000003
# dtype: float64    2.133075             87.5
# 237      Ticker
# ARES    0.000004
# dtype: float64    1.191437              0.0
# 238      Ticker
# VRNS    0.000014
# dtype: float64    2.261223             37.5
# 239      Ticker
# PLNT   -0.000018
# dtype: float64    2.247772              0.0
# 240      Ticker
# SCCO   -0.000031
# dtype: float64    1.891820              0.0
# 241       Ticker
# SHAK   -0.00007
# dtype: float64    0.727275             62.5
# 242      Ticker
# STLD   -0.000024
# dtype: float64    1.116123              0.0
# 243       Ticker
# JBL   -0.000012
# dtype: float64    1.138034             12.5
# 244       Ticker
# XPO   -0.000047
# dtype: float64    0.975542             12.5
# 245       Ticker
# CAR   -0.000096
# dtype: float64    0.337026             62.5
# 246      Ticker
# GDDY   -0.000027
# dtype: float64    1.579594              0.0
# 247      Ticker
# FOUR   -0.000015
# dtype: float64    2.050726             75.0
# 248       Ticker
# AON   -0.000004
# dtype: float64    0.694225              0.0
# 249       Ticker
# PCOR   -0.00007
# dtype: float64    0.764631             37.5
# 250      Ticker
# CHRW    0.000052
# dtype: float64    3.369410             12.5
# 251   Ticker
# GMS    4.334801e-07
# dtype: float64    8.623325             50.0
#
#      pct_sell_last_8d
# 0                 0.0
# 1                25.0
# 2                 0.0
# 3                 0.0
# 4                62.5
# 5                 0.0
# 6                 0.0
# 7                37.5
# 8                37.5
# 9                 0.0
# 10                0.0
# 11                0.0
# 12                0.0
# 13                0.0
# 14                0.0
# 15                0.0
# 16                0.0
# 17                0.0
# 18                0.0
# 19                0.0
# 20                0.0
# 21                0.0
# 22               50.0
# 23                0.0
# 24                0.0
# 25                0.0
# 26                0.0
# 27                0.0
# 28               12.5
# 29                0.0
# 30                0.0
# 31                0.0
# 32                0.0
# 33                0.0
# 34                0.0
# 35                0.0
# 36               50.0
# 37                0.0
# 38                0.0
# 39                0.0
# 40                0.0
# 41                0.0
# 42                0.0
# 43                0.0
# 44                0.0
# 45                0.0
# 46                0.0
# 47                0.0
# 48                0.0
# 49                0.0
# 50                0.0
# 51                0.0
# 52                0.0
# 53               37.5
# 54                0.0
# 55                0.0
# 56                0.0
# 57                0.0
# 58                0.0
# 59               12.5
# 60                0.0
# 61                0.0
# 62                0.0
# 63                0.0
# 64                0.0
# 65                0.0
# 66                0.0
# 67                0.0
# 68                0.0
# 69                0.0
# 70               12.5
# 71                0.0
# 72               37.5
# 73                0.0
# 74                0.0
# 75                0.0
# 76               12.5
# 77                0.0
# 78                0.0
# 79                0.0
# 80                0.0
# 81                0.0
# 82                0.0
# 83                0.0
# 84                0.0
# 85                0.0
# 86                0.0
# 87                0.0
# 88                0.0
# 89                0.0
# 90                0.0
# 91               75.0
# 92                0.0
# 93                0.0
# 94               75.0
# 95                0.0
# 96               75.0
# 97                0.0
# 98                0.0
# 99                0.0
# 100               0.0
# 101               0.0
# 102               0.0
# 103               0.0
# 104               0.0
# 105               0.0
# 106               0.0
# 107               0.0
# 108              12.5
# 109               0.0
# 110               0.0
# 111               0.0
# 112               0.0
# 113               0.0
# 114               0.0
# 115               0.0
# 116               0.0
# 117               0.0
# 118              25.0
# 119              12.5
# 120               0.0
# 121               0.0
# 122               0.0
# 123               0.0
# 124               0.0
# 125               0.0
# 126               0.0
# 127               0.0
# 128               0.0
# 129               0.0
# 130               0.0
# 131               0.0
# 132              12.5
# 133               0.0
# 134               0.0
# 135               0.0
# 136              12.5
# 137              25.0
# 138               0.0
# 139               0.0
# 140               0.0
# 141               0.0
# 142               0.0
# 143               0.0
# 144               0.0
# 145               0.0
# 146               0.0
# 147               0.0
# 148              12.5
# 149               0.0
# 150               0.0
# 151               0.0
# 152              12.5
# 153              62.5
# 154               0.0
# 155               0.0
# 156               0.0
# 157              12.5
# 158               0.0
# 159               0.0
# 160              37.5
# 161               0.0
# 162               0.0
# 163               0.0
# 164               0.0
# 165               0.0
# 166               0.0
# 167               0.0
# 168              87.5
# 169               0.0
# 170               0.0
# 171              50.0
# 172              25.0
# 173               0.0
# 174               0.0
# 175              12.5
# 176               0.0
# 177               0.0
# 178               0.0
# 179               0.0
# 180               0.0
# 181               0.0
# 182               0.0
# 183              12.5
# 184               0.0
# 185               0.0
# 186              25.0
# 187               0.0
# 188               0.0
# 189               0.0
# 190               0.0
# 191               0.0
# 192               0.0
# 193               0.0
# 194               0.0
# 195               0.0
# 196              12.5
# 197               0.0
# 198               0.0
# 199              12.5
# 200               0.0
# 201               0.0
# 202               0.0
# 203               0.0
# 204               0.0
# 205               0.0
# 206               0.0
# 207              12.5
# 208               0.0
# 209               0.0
# 210               0.0
# 211               0.0
# 212               0.0
# 213               0.0
# 214               0.0
# 215               0.0
# 216               0.0
# 217               0.0
# 218               0.0
# 219               0.0
# 220               0.0
# 221               0.0
# 222               0.0
# 223               0.0
# 224              37.5
# 225              62.5
# 226               0.0
# 227               0.0
# 228               0.0
# 229              12.5
# 230              25.0
# 231               0.0
# 232               0.0
# 233               0.0
# 234              25.0
# 235              75.0
# 236               0.0
# 237               0.0
# 238               0.0
# 239               0.0
# 240               0.0
# 241              12.5
# 242               0.0
# 243               0.0
# 244              12.5
# 245               0.0
# 246              75.0
# 247               0.0
# 248              12.5
# 249               0.0
# 250               0.0
# 251               0.0

# %%
import datetime
filterdf["AvgReturn_7d"] = 0 
today = datetime.datetime.today().strftime('%Y-%m-%d')
filename = f'/Users/nshaffer/Desktop/equity_vol_screen_{today}.csv'
filterdf.to_csv(filename, index=False)
print(f"Results saved to {filename}")
# Out:
# Results saved to /Users/nshaffer/Desktop/equity_vol_screen_2025-08-02.csv
