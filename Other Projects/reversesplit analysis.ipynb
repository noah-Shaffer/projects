# %%
import pandas as pd

# For Windows
#df = pd.read_csv(r'C:\Users\nshaffer\Desktop\returns_df.csv')

# For Mac/Linux
df = pd.read_csv('/Users/nshaffer/Desktop/returns_df2.csv',index_col=0)

# Remove rows where any value is greater than 1
#df = df[(df <= 1).all(axis=1)]
df.drop(df[df.max(axis=1) > 1].index, inplace=True)
df.drop(df[df.min(axis=1) < -1].index, inplace=True)
df
# Out:
#             -6        -5        -4        -3        -2        -1         0  \
# AAON -0.103450  0.115387 -0.068967  0.037038  0.000000  0.035715 -0.034484
# ABUS  0.051282 -0.016260 -0.008264 -0.025000 -0.025641  0.000000  0.087719
# ACHV -0.115385  0.065217  0.000000  0.163265  0.228070 -0.142857  0.135833
# ACLS  0.029412 -0.050000 -0.052632  0.023810  0.019380  0.022814  0.015799
# ACON  0.058201 -0.062500  0.026667 -0.029870 -0.230254 -0.092174 -0.140060
# ...        ...       ...       ...       ...       ...       ...       ...
# KTTA       NaN       NaN       NaN -0.053118 -0.048780 -0.051282  0.087838
# LDWY       NaN       NaN       NaN  0.172414 -0.098039 -0.086957  0.243197
# TURN       NaN       NaN       NaN -0.018868  0.028846  0.037383 -0.025526
# APLD       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# FORA       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
import matplotlib.pyplot as plt

# returns_df: rows = stocks, columns = days after split

for day in df.columns:
    plt.figure(figsize=(7, 4))
    plt.hist(df[day].dropna(), bins=30, edgecolor='black')
    plt.title(f"Histogram of Returns: Day {day} After Reverse Split")
    plt.xlabel("Daily Return")
    plt.ylabel("Frequency")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

# Assuming returns_df is your DataFrame: rows=tickers, columns=days after split

# Calculate mean, std, and skew for each day (i.e., for each column)
summary_df = pd.DataFrame({
    'mean': df.mean(axis=0, skipna=True),
    'std': df.std(axis=0, skipna=True),
    'skew': df.skew(axis=0, skipna=True),
    'kurtosis': df.kurtosis(axis=0, skipna=True)
})

print(summary_df)
df['drift'] = df.mean(axis=1)
df
# Out:
#                 mean       std      skew   kurtosis
# -6         -0.002333  0.092346  5.781978  57.937513
# -5         -0.000927  0.098752  1.619358  25.970600
# -4         -0.002659  0.085964  1.283757  21.029945
# -3         -0.009892  0.084613 -0.151383   8.537058
# -2         -0.039837  0.127016 -0.681518   8.436330
# -1         -0.020620  0.123560  1.361982  16.295846
# 0          -0.029669  0.170161  0.108103   4.929563
# 1          -0.012922  0.145059  2.264952  11.031830
# 2          -0.009304  0.114518  1.529174  10.405496
# 3          -0.000101  0.112209  2.185595  19.290033
# 4          -0.001028  0.099579  2.100770  16.965687
# 5           0.000105  0.095090  0.434189  19.035946
# 6           0.003603  0.087609  1.734589  10.649440
# 7          -0.002002  0.082646  2.856740  25.799055
# -7         -0.005875  0.069558  1.350314   8.412762
# drift      -0.009979  0.028716 -0.045074   2.950008
# drift_-7_0 -0.016494  0.044334 -0.056278   4.084916
# ...

# %%
cols_neg7_0 = ['-7','-6','-5','-4','-3','-2','-1','0']
cols_0_7 = ['0','1','2','3','4','5','6','7']

df['drift_-7_0'] = df[cols_neg7_0].mean(axis=1)
df['drift_0_7'] = df[cols_0_7].mean(axis=1)
df
# Out:
#             -6        -5        -4        -3        -2        -1         0  \
# AAON -0.103450  0.115387 -0.068967  0.037038  0.000000  0.035715 -0.034484
# ABUS  0.051282 -0.016260 -0.008264 -0.025000 -0.025641  0.000000  0.087719
# ACHV -0.115385  0.065217  0.000000  0.163265  0.228070 -0.142857  0.135833
# ACLS  0.029412 -0.050000 -0.052632  0.023810  0.019380  0.022814  0.015799
# ACON  0.058201 -0.062500  0.026667 -0.029870 -0.230254 -0.092174 -0.140060
# ...        ...       ...       ...       ...       ...       ...       ...
# KTTA       NaN       NaN       NaN -0.053118 -0.048780 -0.051282  0.087838
# LDWY       NaN       NaN       NaN  0.172414 -0.098039 -0.086957  0.243197
# TURN       NaN       NaN       NaN -0.018868  0.028846  0.037383 -0.025526
# APLD       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# FORA       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
