# %%
import glob
import polars as pl
import zstandard as zstd
import io
from datetime import datetime


def read_zst_csv(path):
    dctx = zstd.ZstdDecompressor()
    with open(path, "rb") as f_in:
        with dctx.stream_reader(f_in) as reader:
            decompressed_data = reader.read()
    csv_bytes = io.BytesIO(decompressed_data)
    return pl.read_csv(csv_bytes, encoding="utf8-lossy", 
                      low_memory=True, infer_schema_length=10000)


def path_in_date_range(path, start_date, end_date):
    fname = path.rsplit("/", 1)[-1]
    date_str = fname.split(".")[0].split("-")[2]
    file_date = datetime.strptime(date_str, "%Y%m%d").date()
    return start_date <= file_date <= end_date


folder = "/Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W"
output_path = f"{folder}/TSLA_2025-08-27_to_2025-11-26.csv"

all_paths = glob.glob(folder + "/*.csv.zst")
start_date = datetime(2025, 8, 27).date()
end_date = datetime(2025, 11, 26).date()

paths = [p for p in all_paths if path_in_date_range(p, start_date, end_date)]
print(f"Found {len(paths)} files")

first_file = True
total_rows = 0

for i, path in enumerate(sorted(paths)):
    print(f"[{i+1}/{len(paths)}] {path.rsplit('/', 1)[-1]}")

    df = read_zst_csv(path)
    rows_added = df.shape[0]
    total_rows += rows_added

    mode = "wb" if first_file else "ab"
    with open(output_path, mode) as f:
        df.write_csv(f, include_header=first_file)

    first_file = False
    del df
    print(f"  Added {rows_added:,} rows (total: {total_rows:,})")

print(f"\nCOMPLETE! Saved {total_rows:,} rows to {output_path}")
# Out:
# Found 65 files
# [1/65] xnas-itch-20250827.mbp-10.csv.zst
#   Added 2,566,550 rows (total: 2,566,550)
# [2/65] xnas-itch-20250828.mbp-10.csv.zst
#   Added 2,292,123 rows (total: 4,858,673)
# [3/65] xnas-itch-20250829.mbp-10.csv.zst
#   Added 2,848,032 rows (total: 7,706,705)
# [4/65] xnas-itch-20250902.mbp-10.csv.zst
#   Added 2,386,281 rows (total: 10,092,986)
# [5/65] xnas-itch-20250903.mbp-10.csv.zst
#   Added 3,260,405 rows (total: 13,353,391)
# [6/65] xnas-itch-20250904.mbp-10.csv.zst
#   Added 2,029,982 rows (total: 15,383,373)
# [7/65] xnas-itch-20250905.mbp-10.csv.zst
#   Added 4,208,061 rows (total: 19,591,434)
# [8/65] xnas-itch-20250908.mbp-10.csv.zst
#   Added 2,736,046 rows (total: 22,327,480)
# [9/65] xnas-itch-20250909.mbp-10.csv.zst
#   Added 1,774,500 rows (total: 24,101,980)
# [10/65] xnas-itch-20250910.mbp-10.csv.zst
#   Added 2,122,637 rows (total: 26,224,617)
# [11/65] xnas-itch-20250911.mbp-10.csv.zst
#   Added 3,012,529 rows (total: 29,237,146)
# [12/65] xnas-itch-20250912.mbp-10.csv.zst
#   Added 3,957,611 rows (total: 33,194,757)
# [13/65] xnas-itch-20250915.mbp-10.csv.zst
#   Added 4,172,734 rows (total: 37,367,491)
# [14/65] xnas-itch-20250916.mbp-10.csv.zst
#   Added 2,991,679 rows (total: 40,359,170)
# [15/65] xnas-itch-20250917.mbp-10.csv.zst
#   Added 3,103,570 rows (total: 43,462,740)
# [16/65] xnas-itch-20250918.mbp-10.csv.zst
#   Added 2,907,580 rows (total: 46,370,320)
# [17/65] xnas-itch-20250919.mbp-10.csv.zst
#   Added 2,349,870 rows (total: 48,720,190)
# [18/65] xnas-itch-20250922.mbp-10.csv.zst
#   Added 3,460,582 rows (total: 52,180,772)
# [19/65] xnas-itch-20250923.mbp-10.csv.zst
#   Added 2,589,758 rows (total: 54,770,530)
# [20/65] xnas-itch-20250924.mbp-10.csv.zst
#   Added 2,950,534 rows (total: 57,721,064)
# [21/65] xnas-itch-20250925.mbp-10.csv.zst
#   Added 3,428,642 rows (total: 61,149,706)
# [22/65] xnas-itch-20250926.mbp-10.csv.zst
#   Added 2,868,272 rows (total: 64,017,978)
# [23/65] xnas-itch-20250929.mbp-10.csv.zst
#   Added 2,679,900 rows (total: 66,697,878)
# [24/65] xnas-itch-20250930.mbp-10.csv.zst
#   Added 3,260,283 rows (total: 69,958,161)
# [25/65] xnas-itch-20251001.mbp-10.csv.zst
#   Added 3,243,002 rows (total: 73,201,163)
# [26/65] xnas-itch-20251002.mbp-10.csv.zst
#   Added 4,553,992 rows (total: 77,755,155)
# [27/65] xnas-itch-20251003.mbp-10.csv.zst
#   Added 4,144,250 rows (total: 81,899,405)
# [28/65] xnas-itch-20251006.mbp-10.csv.zst
#   Added 2,297,471 rows (total: 84,196,876)
# [29/65] xnas-itch-20251007.mbp-10.csv.zst
#   Added 3,015,722 rows (total: 87,212,598)
# [30/65] xnas-itch-20251008.mbp-10.csv.zst
#   Added 2,607,197 rows (total: 89,819,795)
# [31/65] xnas-itch-20251009.mbp-10.csv.zst
#   Added 2,982,727 rows (total: 92,802,522)
# [32/65] xnas-itch-20251010.mbp-10.csv.zst
#   Added 5,123,802 rows (total: 97,926,324)
# [33/65] xnas-itch-20251013.mbp-10.csv.zst
#   Added 2,459,381 rows (total: 100,385,705)
# [34/65] xnas-itch-20251014.mbp-10.csv.zst
#   Added 2,082,951 rows (total: 102,468,656)
# [35/65] xnas-itch-20251015.mbp-10.csv.zst
#   Added 2,288,653 rows (total: 104,757,309)
# [36/65] xnas-itch-20251016.mbp-10.csv.zst
#   Added 2,554,069 rows (total: 107,311,378)
# [37/65] xnas-itch-20251017.mbp-10.csv.zst
#   Added 2,920,615 rows (total: 110,231,993)
# [38/65] xnas-itch-20251020.mbp-10.csv.zst
#   Added 1,948,882 rows (total: 112,180,875)
# [39/65] xnas-itch-20251021.mbp-10.csv.zst
#   Added 2,043,241 rows (total: 114,224,116)
# [40/65] xnas-itch-20251022.mbp-10.csv.zst
#   Added 3,322,420 rows (total: 117,546,536)
# [41/65] xnas-itch-20251023.mbp-10.csv.zst
#   Added 3,899,332 rows (total: 121,445,868)
# [42/65] xnas-itch-20251024.mbp-10.csv.zst
#   Added 3,074,103 rows (total: 124,519,971)
# [43/65] xnas-itch-20251027.mbp-10.csv.zst
#   Added 3,187,124 rows (total: 127,707,095)
# [44/65] xnas-itch-20251028.mbp-10.csv.zst
#   Added 2,598,041 rows (total: 130,305,136)
# [45/65] xnas-itch-20251029.mbp-10.csv.zst
#   Added 2,703,543 rows (total: 133,008,679)
# [46/65] xnas-itch-20251030.mbp-10.csv.zst
#   Added 2,290,956 rows (total: 135,299,635)
# [47/65] xnas-itch-20251031.mbp-10.csv.zst
#   Added 2,986,663 rows (total: 138,286,298)
# [48/65] xnas-itch-20251103.mbp-10.csv.zst
#   Added 2,941,946 rows (total: 141,228,244)
# [49/65] xnas-itch-20251104.mbp-10.csv.zst
#   Added 3,429,216 rows (total: 144,657,460)
# [50/65] xnas-itch-20251105.mbp-10.csv.zst
#   Added 1,992,800 rows (total: 146,650,260)
# [51/65] xnas-itch-20251106.mbp-10.csv.zst
#   Added 3,119,221 rows (total: 149,769,481)
# [52/65] xnas-itch-20251107.mbp-10.csv.zst
#   Added 3,590,700 rows (total: 153,360,181)
# [53/65] xnas-itch-20251110.mbp-10.csv.zst
#   Added 2,358,741 rows (total: 155,718,922)
# [54/65] xnas-itch-20251111.mbp-10.csv.zst
#   Added 1,856,631 rows (total: 157,575,553)
# [55/65] xnas-itch-20251112.mbp-10.csv.zst
#   Added 2,446,745 rows (total: 160,022,298)
# [56/65] xnas-itch-20251113.mbp-10.csv.zst
#   Added 5,023,704 rows (total: 165,046,002)
# [57/65] xnas-itch-20251114.mbp-10.csv.zst
#   Added 3,521,791 rows (total: 168,567,793)
# [58/65] xnas-itch-20251117.mbp-10.csv.zst
#   Added 4,450,295 rows (total: 173,018,088)
# [59/65] xnas-itch-20251118.mbp-10.csv.zst
#   Added 3,080,272 rows (total: 176,098,360)
# [60/65] xnas-itch-20251119.mbp-10.csv.zst
#   Added 2,491,079 rows (total: 178,589,439)
# [61/65] xnas-itch-20251120.mbp-10.csv.zst
#   Added 5,562,464 rows (total: 184,151,903)
# [62/65] xnas-itch-20251121.mbp-10.csv.zst
#   Added 3,582,761 rows (total: 187,734,664)
# [63/65] xnas-itch-20251124.mbp-10.csv.zst
#   Added 3,768,632 rows (total: 191,503,296)
# [64/65] xnas-itch-20251125.mbp-10.csv.zst
#   Added 3,282,756 rows (total: 194,786,052)
# [65/65] xnas-itch-20251126.mbp-10.csv.zst
#   Added 2,786,853 rows (total: 197,572,905)
#
# COMPLETE! Saved 197,572,905 rows to /Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W/TSLA_2025-08-27_to_2025-11-26.csv

# %%
import pandas as pd


# Corrected MBP-10 headers with proper bid/ask order (53 columns)
mbp10_headers = [
    'ts_recv', 'ts_event', 'rtype', 'publisher_id', 'instrument_id',
    'action', 'side', 'depth', 'price', 'size', 'flags', 
    'ts_in_delta', 'sequence',
    'bid_px_00', 'ask_px_00', 'bid_sz_00', 'ask_sz_00', 'bid_ct_00', 'ask_ct_00',
    'bid_px_01', 'ask_px_01', 'bid_sz_01', 'ask_sz_01', 'bid_ct_01', 'ask_ct_01',
    'bid_px_02', 'ask_px_02', 'bid_sz_02', 'ask_sz_02', 'bid_ct_02', 'ask_ct_02',
    'bid_px_03', 'ask_px_03', 'bid_sz_03', 'ask_sz_03', 'bid_ct_03', 'ask_ct_03',
    'bid_px_04', 'ask_px_04', 'bid_sz_04', 'ask_sz_04', 'bid_ct_04', 'ask_ct_04',
    'bid_px_05', 'ask_px_05', 'bid_sz_05', 'ask_sz_05', 'bid_ct_05', 'ask_ct_05',
    'bid_px_06', 'ask_px_06', 'bid_sz_06', 'ask_sz_06', 'bid_ct_06', 'ask_ct_06',
    'bid_px_07', 'ask_px_07', 'bid_sz_07', 'ask_sz_07', 'bid_ct_07', 'ask_ct_07',
    'bid_px_08', 'ask_px_08', 'bid_sz_08', 'ask_sz_08', 'bid_ct_08', 'ask_ct_08',
    'bid_px_09', 'ask_px_09', 'bid_sz_09', 'ask_sz_09', 'bid_ct_09', 'ask_ct_09'
]


# Load CSV then shift headers LEFT by 1 (data moves right to match shifted names)
df = pd.read_csv('/Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W/TSLA_2025-08-27_to_2025-11-26.csv',
                 header=0)


# Shift column names LEFT by 1 - first header gets data from col 0, second from col 1, etc.
df.columns = mbp10_headers[:len(df.columns)-1] + [mbp10_headers[-1]]  # Simple shift


print(f"Shape: {df.shape}")
print(df.head())
print(df.info())
print("Columns:", df.columns.tolist())
