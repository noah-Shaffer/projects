# %%
## Here I'll attempt to simulate tree branching structures with Data science concepts like Fourier transform, sinusoidals, and probability distributions, with bias parameters. 
"""
Concept Mapping:
Factors:
Sunlight 
Height 
Width 
Leaf structure
Branch Structure 
Location
"""
