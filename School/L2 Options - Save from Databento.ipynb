# %%
import glob
import polars as pl
import zstandard as zstd
import io
from datetime import datetime
import os

def read_zst_csv(path):
    """Read single .csv.zst - minimal memory"""
    dctx = zstd.ZstdDecompressor()
    with open(path, "rb") as f_in:
        with dctx.stream_reader(f_in) as reader:
            decompressed_data = reader.read()
    
    csv_bytes = io.BytesIO(decompressed_data)
    return pl.read_csv(csv_bytes, encoding="utf8-lossy", 
                      low_memory=True, infer_schema_length=10000)

def path_in_date_range(path, start_date, end_date):
    fname = path.rsplit("/", 1)[-1]
    date_str = fname.split(".")[0].split("-")[2]
    file_date = datetime.strptime(date_str, "%Y%m%d").date()
    return start_date <= file_date <= end_date

# Setup
folder = "/Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W"
output_path = f"{folder}/TSLA_2025-08-27_to_2025-11-26.csv"

all_paths = glob.glob(folder + "/*.csv.zst")
start_date = datetime(2025, 8, 27).date()
end_date = datetime(2025, 11, 26).date()

paths = [p for p in all_paths if path_in_date_range(p, start_date, end_date)]
print(f"Found {len(paths)} files")

# Process ONE file at a time, append to CSV
first_file = True
total_rows = 0
mode = 'w' if first_file else 'a'

for i, path in enumerate(paths):
    print(f"[{i+1}/{len(paths)}] {path.rsplit('/', 1)[-1]}")
    
    df = read_zst_csv(path)
    rows_added = df.shape[0]
    total_rows += rows_added
    
    # CSV append works perfectly
    df.write_csv(output_path, include_header=first_file)
    first_file = False
    
    del df
    print(f"  Added {rows_added:,} rows (total: {total_rows:,})")

print(f"\nCOMPLETE! Saved {total_rows:,} rows to {output_path}")
# Out:
# Found 65 files
# [1/65] xnas-itch-20251120.mbp-10.csv.zst
#   Added 5,562,464 rows (total: 5,562,464)
# [2/65] xnas-itch-20251023.mbp-10.csv.zst
#   Added 3,899,332 rows (total: 9,461,796)
# [3/65] xnas-itch-20250909.mbp-10.csv.zst
#   Added 1,774,500 rows (total: 11,236,296)
# [4/65] xnas-itch-20251031.mbp-10.csv.zst
#   Added 2,986,663 rows (total: 14,222,959)
# [5/65] xnas-itch-20251024.mbp-10.csv.zst
#   Added 3,074,103 rows (total: 17,297,062)
# [6/65] xnas-itch-20250915.mbp-10.csv.zst
#   Added 4,172,734 rows (total: 21,469,796)
# [7/65] xnas-itch-20251126.mbp-10.csv.zst
#   Added 2,786,853 rows (total: 24,256,649)
# [8/65] xnas-itch-20251030.mbp-10.csv.zst
#   Added 2,290,956 rows (total: 26,547,605)
# [9/65] xnas-itch-20250908.mbp-10.csv.zst
#   Added 2,736,046 rows (total: 29,283,651)
# [10/65] xnas-itch-20250912.mbp-10.csv.zst
#   Added 3,957,611 rows (total: 33,241,262)
# [11/65] xnas-itch-20251022.mbp-10.csv.zst
#   Added 3,322,420 rows (total: 36,563,682)
# [12/65] xnas-itch-20251121.mbp-10.csv.zst
#   Added 3,582,761 rows (total: 40,146,443)
# [13/65] xnas-itch-20251020.mbp-10.csv.zst
#   Added 1,948,882 rows (total: 42,095,325)
# [14/65] xnas-itch-20250905.mbp-10.csv.zst
#   Added 4,208,061 rows (total: 46,303,386)
# [15/65] xnas-itch-20250910.mbp-10.csv.zst
#   Added 2,122,637 rows (total: 48,426,023)
# [16/65] xnas-itch-20250918.mbp-10.csv.zst
#   Added 2,907,580 rows (total: 51,333,603)
# [17/65] xnas-itch-20251028.mbp-10.csv.zst
#   Added 2,598,041 rows (total: 53,931,644)
# [18/65] xnas-itch-20251027.mbp-10.csv.zst
#   Added 3,187,124 rows (total: 57,118,768)
# [19/65] xnas-itch-20251124.mbp-10.csv.zst
#   Added 3,768,632 rows (total: 60,887,400)
# [20/65] xnas-itch-20250917.mbp-10.csv.zst
#   Added 3,103,570 rows (total: 63,990,970)
# [21/65] xnas-itch-20250902.mbp-10.csv.zst
#   Added 2,386,281 rows (total: 66,377,251)
# [22/65] xnas-itch-20251125.mbp-10.csv.zst
#   Added 3,282,756 rows (total: 69,660,007)
# [23/65] xnas-itch-20250903.mbp-10.csv.zst
#   Added 3,260,405 rows (total: 72,920,412)
# [24/65] xnas-itch-20250916.mbp-10.csv.zst
#   Added 2,991,679 rows (total: 75,912,091)
# [25/65] xnas-itch-20250919.mbp-10.csv.zst
#   Added 2,349,870 rows (total: 78,261,961)
# [26/65] xnas-itch-20251029.mbp-10.csv.zst
#   Added 2,703,543 rows (total: 80,965,504)
# [27/65] xnas-itch-20251021.mbp-10.csv.zst
#   Added 2,043,241 rows (total: 83,008,745)
# [28/65] xnas-itch-20250911.mbp-10.csv.zst
#   Added 3,012,529 rows (total: 86,021,274)
# [29/65] xnas-itch-20250904.mbp-10.csv.zst
#   Added 2,029,982 rows (total: 88,051,256)
# [30/65] xnas-itch-20251008.mbp-10.csv.zst
#   Added 2,607,197 rows (total: 90,658,453)
# [31/65] xnas-itch-20251103.mbp-10.csv.zst
#   Added 2,941,946 rows (total: 93,600,399)
# [32/65] xnas-itch-20251015.mbp-10.csv.zst
#   Added 2,288,653 rows (total: 95,889,052)
# [33/65] xnas-itch-20250925.mbp-10.csv.zst
#   Added 3,428,642 rows (total: 99,317,694)
# [34/65] xnas-itch-20250930.mbp-10.csv.zst
#   Added 3,260,283 rows (total: 102,577,977)
# [35/65] xnas-itch-20250829.mbp-10.csv.zst
#   Added 2,848,032 rows (total: 105,426,009)
# [36/65] xnas-itch-20251119.mbp-10.csv.zst
#   Added 2,491,079 rows (total: 107,917,088)
# [37/65] xnas-itch-20251007.mbp-10.csv.zst
#   Added 3,015,722 rows (total: 110,932,810)
# [38/65] xnas-itch-20251111.mbp-10.csv.zst
#   Added 1,856,631 rows (total: 112,789,441)
# [39/65] xnas-itch-20251104.mbp-10.csv.zst
#   Added 3,429,216 rows (total: 116,218,657)
# [40/65] xnas-itch-20250922.mbp-10.csv.zst
#   Added 3,460,582 rows (total: 119,679,239)
# [41/65] xnas-itch-20251105.mbp-10.csv.zst
#   Added 1,992,800 rows (total: 121,672,039)
# [42/65] xnas-itch-20251110.mbp-10.csv.zst
#   Added 2,358,741 rows (total: 124,030,780)
# [43/65] xnas-itch-20251013.mbp-10.csv.zst
#   Added 2,459,381 rows (total: 126,490,161)
# [44/65] xnas-itch-20251006.mbp-10.csv.zst
#   Added 2,297,471 rows (total: 128,787,632)
# [45/65] xnas-itch-20250923.mbp-10.csv.zst
#   Added 2,589,758 rows (total: 131,377,390)
# [46/65] xnas-itch-20250828.mbp-10.csv.zst
#   Added 2,292,123 rows (total: 133,669,513)
# [47/65] xnas-itch-20251118.mbp-10.csv.zst
#   Added 3,080,272 rows (total: 136,749,785)
# [48/65] xnas-itch-20251001.mbp-10.csv.zst
#   Added 3,243,002 rows (total: 139,992,787)
# [49/65] xnas-itch-20251014.mbp-10.csv.zst
#   Added 2,082,951 rows (total: 142,075,738)
# [50/65] xnas-itch-20251117.mbp-10.csv.zst
#   Added 4,450,295 rows (total: 146,526,033)
# [51/65] xnas-itch-20250924.mbp-10.csv.zst
#   Added 2,950,534 rows (total: 149,476,567)
# [52/65] xnas-itch-20250827.mbp-10.csv.zst
#   Added 2,566,550 rows (total: 152,043,117)
# [53/65] xnas-itch-20251009.mbp-10.csv.zst
#   Added 2,982,727 rows (total: 155,025,844)
# [54/65] xnas-itch-20250926.mbp-10.csv.zst
#   Added 2,868,272 rows (total: 157,894,116)
# [55/65] xnas-itch-20251003.mbp-10.csv.zst
#   Added 4,144,250 rows (total: 162,038,366)
# [56/65] xnas-itch-20251016.mbp-10.csv.zst
#   Added 2,554,069 rows (total: 164,592,435)
# [57/65] xnas-itch-20251107.mbp-10.csv.zst
#   Added 3,590,700 rows (total: 168,183,135)
# [58/65] xnas-itch-20251112.mbp-10.csv.zst
#   Added 2,446,745 rows (total: 170,629,880)
# [59/65] xnas-itch-20250929.mbp-10.csv.zst
#   Added 2,679,900 rows (total: 173,309,780)
# [60/65] xnas-itch-20251113.mbp-10.csv.zst
#   Added 5,023,704 rows (total: 178,333,484)
# [61/65] xnas-itch-20251106.mbp-10.csv.zst
#   Added 3,119,221 rows (total: 181,452,705)
# [62/65] xnas-itch-20251010.mbp-10.csv.zst
#   Added 5,123,802 rows (total: 186,576,507)
# [63/65] xnas-itch-20251017.mbp-10.csv.zst
#   Added 2,920,615 rows (total: 189,497,122)
# [64/65] xnas-itch-20251002.mbp-10.csv.zst
#   Added 4,553,992 rows (total: 194,051,114)
# [65/65] xnas-itch-20251114.mbp-10.csv.zst
#   Added 3,521,791 rows (total: 197,572,905)
#
# COMPLETE! Saved 197,572,905 rows to /Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W/TSLA_2025-08-27_to_2025-11-26.csv

# %%
import pandas as pd


# Corrected MBP-10 headers with proper bid/ask order (53 columns)
mbp10_headers = [
    'ts_recv', 'ts_event', 'rtype', 'publisher_id', 'instrument_id',
    'action', 'side', 'depth', 'price', 'size', 'flags', 
    'ts_in_delta', 'sequence',
    'bid_px_00', 'ask_px_00', 'bid_sz_00', 'ask_sz_00', 'bid_ct_00', 'ask_ct_00',
    'bid_px_01', 'ask_px_01', 'bid_sz_01', 'ask_sz_01', 'bid_ct_01', 'ask_ct_01',
    'bid_px_02', 'ask_px_02', 'bid_sz_02', 'ask_sz_02', 'bid_ct_02', 'ask_ct_02',
    'bid_px_03', 'ask_px_03', 'bid_sz_03', 'ask_sz_03', 'bid_ct_03', 'ask_ct_03',
    'bid_px_04', 'ask_px_04', 'bid_sz_04', 'ask_sz_04', 'bid_ct_04', 'ask_ct_04',
    'bid_px_05', 'ask_px_05', 'bid_sz_05', 'ask_sz_05', 'bid_ct_05', 'ask_ct_05',
    'bid_px_06', 'ask_px_06', 'bid_sz_06', 'ask_sz_06', 'bid_ct_06', 'ask_ct_06',
    'bid_px_07', 'ask_px_07', 'bid_sz_07', 'ask_sz_07', 'bid_ct_07', 'ask_ct_07',
    'bid_px_08', 'ask_px_08', 'bid_sz_08', 'ask_sz_08', 'bid_ct_08', 'ask_ct_08',
    'bid_px_09', 'ask_px_09', 'bid_sz_09', 'ask_sz_09', 'bid_ct_09', 'ask_ct_09'
]


# Load CSV then shift headers LEFT by 1 (data moves right to match shifted names)
df = pd.read_csv('/Users/nshaffer/Desktop/TSLA L2/XNAS-20251128-V7KRYJ435W/TSLA_2025-08-27_to_2025-11-26.csv',
                 header=0)


# Shift column names LEFT by 1 - first header gets data from col 0, second from col 1, etc.
df.columns = mbp10_headers[:len(df.columns)-1] + [mbp10_headers[-1]]  # Simple shift


print(f"Shape: {df.shape}")
print(df.head())
print(df.info())
print("Columns:", df.columns.tolist())
# Out:
# Shape: (3521790, 74)
#                           ts_recv                        ts_event  rtype  \
# 0  2025-11-14T09:00:00.014670205Z  2025-11-14T09:00:00.014492106Z     10
# 1  2025-11-14T09:00:00.020480687Z  2025-11-14T09:00:00.020311998Z     10
# 2  2025-11-14T09:00:00.021813305Z  2025-11-14T09:00:00.021650075Z     10
# 3  2025-11-14T09:00:00.022498732Z  2025-11-14T09:00:00.022335644Z     10
# 4  2025-11-14T09:00:00.024060816Z  2025-11-14T09:00:00.023897202Z     10
#
#    publisher_id  instrument_id action side  depth   price  size  ...  \
# 0             2          16244      A    A      0  394.60     2  ...
# 1             2          16244      A    A      1  480.00    40  ...
# 2             2          16244      A    B      0  393.51   100  ...
# 3             2          16244      A    A      0  393.99   100  ...
# 4             2          16244      C    A      1  394.60     2  ...
#
#    ask_sz_08  bid_ct_08  ask_ct_08  bid_px_09  ask_px_09  bid_sz_09  \
# 0          0          0          0        NaN        NaN          0
# 1          0          0          0        NaN        NaN          0
# 2          0          0          0        NaN        NaN          0
# 3          0          0          0        NaN        NaN          0
# 4          0          0          0        NaN        NaN          0
#
#    ask_sz_09  bid_ct_09  ask_ct_09  ask_ct_09
# 0          0          0          0       TSLA
# 1          0          0          0       TSLA
# 2          0          0          0       TSLA
# 3          0          0          0       TSLA
# 4          0          0          0       TSLA
#
# [5 rows x 74 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521790 entries, 0 to 3521789
# Data columns (total 74 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ts_recv        object
#  1   ts_event       object
#  2   rtype          int64
#  3   publisher_id   int64
#  4   instrument_id  int64
#  5   action         object
#  6   side           object
#  7   depth          int64
#  8   price          float64
#  9   size           int64
#  10  flags          int64
#  11  ts_in_delta    int64
#  12  sequence       int64
#  13  bid_px_00      float64
#  14  ask_px_00      float64
#  15  bid_sz_00      int64
#  16  ask_sz_00      int64
#  17  bid_ct_00      int64
#  18  ask_ct_00      int64
#  19  bid_px_01      float64
#  20  ask_px_01      float64
#  21  bid_sz_01      int64
#  22  ask_sz_01      int64
#  23  bid_ct_01      int64
#  24  ask_ct_01      int64
#  25  bid_px_02      float64
#  26  ask_px_02      float64
#  27  bid_sz_02      int64
#  28  ask_sz_02      int64
#  29  bid_ct_02      int64
#  30  ask_ct_02      int64
#  31  bid_px_03      float64
#  32  ask_px_03      float64
#  33  bid_sz_03      int64
#  34  ask_sz_03      int64
#  35  bid_ct_03      int64
#  36  ask_ct_03      int64
#  37  bid_px_04      float64
#  38  ask_px_04      float64
#  39  bid_sz_04      int64
#  40  ask_sz_04      int64
#  41  bid_ct_04      int64
#  42  ask_ct_04      int64
#  43  bid_px_05      float64
#  44  ask_px_05      float64
#  45  bid_sz_05      int64
#  46  ask_sz_05      int64
#  47  bid_ct_05      int64
#  48  ask_ct_05      int64
#  49  bid_px_06      float64
#  50  ask_px_06      float64
#  51  bid_sz_06      int64
#  52  ask_sz_06      int64
#  53  bid_ct_06      int64
#  54  ask_ct_06      int64
#  55  bid_px_07      float64
#  56  ask_px_07      float64
#  57  bid_sz_07      int64
#  58  ask_sz_07      int64
#  59  bid_ct_07      int64
#  60  ask_ct_07      int64
#  61  bid_px_08      float64
#  62  ask_px_08      float64
#  63  bid_sz_08      int64
#  64  ask_sz_08      int64
#  65  bid_ct_08      int64
#  66  ask_ct_08      int64
#  67  bid_px_09      float64
#  68  ask_px_09      float64
#  69  bid_sz_09      int64
#  70  ask_sz_09      int64
#  71  bid_ct_09      int64
#  72  ask_ct_09      int64
#  73  ask_ct_09      object
# dtypes: float64(21), int64(48), object(5)
# memory usage: 1.9+ GB
# None
# Columns: ['ts_recv', 'ts_event', 'rtype', 'publisher_id', 'instrument_id', 'action', 'side', 'depth', 'price', 'size', 'flags', 'ts_in_delta', 'sequence', 'bid_px_00', 'ask_px_00', 'bid_sz_00', 'ask_sz_00', 'bid_ct_00', 'ask_ct_00', 'bid_px_01', 'ask_px_01', 'bid_sz_01', 'ask_sz_01', 'bid_ct_01', 'ask_ct_01', 'bid_px_02', 'ask_px_02', 'bid_sz_02', 'ask_sz_02', 'bid_ct_02', 'ask_ct_02', 'bid_px_03', 'ask_px_03', 'bid_sz_03', 'ask_sz_03', 'bid_ct_03', 'ask_ct_03', 'bid_px_04', 'ask_px_04', 'bid_sz_04', 'ask_sz_04', 'bid_ct_04', 'ask_ct_04', 'bid_px_05', 'ask_px_05', 'bid_sz_05', 'ask_sz_05', 'bid_ct_05', 'ask_ct_05', 'bid_px_06', 'ask_px_06', 'bid_sz_06', 'ask_sz_06', 'bid_ct_06', 'ask_ct_06', 'bid_px_07', 'ask_px_07', 'bid_sz_07', 'ask_sz_07', 'bid_ct_07', 'ask_ct_07', 'bid_px_08', 'ask_px_08', 'bid_sz_08', 'ask_sz_08', 'bid_ct_08', 'ask_ct_08', 'bid_px_09', 'ask_px_09', 'bid_sz_09', 'ask_sz_09', 'bid_ct_09', 'ask_ct_09', 'ask_ct_09']
